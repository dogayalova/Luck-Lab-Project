# %% [markdown]
# # AlphaFold metrics
# Created by Andreas 04.04.2025
#
# This is the main notebook to add the following informations and metrics to a given AlphaFold run:
#
# 1. [RMSD](#3-rmsd-with-pymol)
# 2. [DockQ](#4-dockq)
# 3. [ipSAE](#5-ipsae-metric)
# 4. [Interface Interaction metrics](#6-interaction-metrics)
#
# The sections (e.g. RMSD, DockQ) can be run individually to recalculate only some metrics. For this, set the *load_previous* setting to True.
#
# The benchmark set of Lee et al. encodes information about a PPI in a string (e.g. *PF10208_PF00012_6H9U_B_resi130_resi169.A_resi30_resi406*). This script breaks it down into the PDB ID, PFAM ID, and ELM instance. Also, as it was worked with minimal interacting regions (i.e. only the motif or domain), the included chains (i.e. their IDs) as well as the boundaries were either extracted from the prediction name (DDI) or determined by comparing with the experimentally solved structure.
#
# As input, the .pdb files need to be stored in the corrosponding benchmark set:
#
# ```bash
# ├── DDI
# │   ├── known_DDI
# │   └── random_DDI
# ├── DMI
# │   ├── known_DMI
# │   ├── mutations_DMI
# │   └── random_DMI
# ```
#
# Every structure inside this folder should follow this layout:
# ```bash
# ├── DEG_APCC_KENBOX_2_4GGD
# │   ├── ranked_0.pdb
# │   ├── ranked_1.pdb
# │   ├── ranked_2.pdb
# │   ├── ranked_3.pdb
# │   └── ranked_4.pdb
# ```
#
# The experimentally solved structures should have the following folder structure:
#
# ```bash
# ├── DDI
# ├── DDI_hydrogens
# ├── DMI
# ├── DMI_hydrogens
# ```
#
# with the hydrogen folders containing the structures with added hydrogen.
#
# It is also necessary to provide the output file of the AlphaFold run. For AlphaFold 2, this file was created by Lee et al., while for AlphaFold 3 the <a href="AF3 raw output parsing.ipynb">AF3 raw output parsing.ipynb</a> notebook is able to generate one. This file should list all AlphaFold predictions with AlphaFold derived metrics like the model cofidence, the number of clashes etc.
#
# By default, you specify a *resource* path with a *AF2*/*AF3* and *solved* folder inside in it. Also, a *AF3_hydrogens* folder can be included.

# %% [markdown]
# ### 0 Imports and Settings

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axes._axes import Axes
from matplotlib.figure import Figure
from pathlib import Path
from sklearn.metrics import roc_curve, roc_auc_score
import re
import tempfile
import shutil
import os
import subprocess
import sys
stdout, stderr = sys.stdout, sys.stderr
from typing import Literal

import pymol
from Bio.SeqUtils import seq1
from Bio.PDB import PDBParser
from Bio.PDB.Structure import Structure as BioPy_PDBStructure
from Bio.PDB.Model import Model as BioPy_PDBModel
from Bio.PDB.Chain import Chain
from Bio.PDB.PDBExceptions import PDBConstructionException
parser = PDBParser(QUIET=True)

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
# Settings

# Which AF output should be parsed
af_mode: Literal["AF2", "AF3"] = "AF3"
# Should be the hydrogens folder used?
af3_hydrogens: bool = True

# Path to resource folder with the structures and metadata tables
path_resources = Path("/Users/imb/Desktop")
# Path to the Luck Drive folder (used for ipSAE metric to get the json file)
path_AF_luck_drive = Path("/Volumes/imb-luckgr/imb-luckgr2/projects/AlphaFold")
if af_mode == "AF3":
    path_AF_luck_drive = path_AF_luck_drive / "AlphaFold3"

# Paths to the local folders
path_AF = path_resources / ((af_mode + "_hydrogens") if (af3_hydrogens and af_mode == "AF3") else af_mode)
path_solved = path_resources / "DMI_solved_structures"

# The path to the ipsae.py
path_ipsae_script = Path("/Users/imb/Desktop/ipsae.py")

# If set to true, load the previous dataframe
load_previous = False

# To parse structures, Pymol should be run headless. However, for debugging the code the GUI may be helpful
pymol_headless = True

# %%
if not pymol_headless:
    pymol.finish_launching()
    sys.stdout = stdout # Needed in case of debugging to redicrct 
    sys.stderr = stderr

# %%
def enhance_dataframe():
    """ Reorder the columns in the dataAF dataframe and convert to an appropriate dtype """
    global dataAF
    # Some columns are integer, but contain None values. Default behaviour of pandas is to use dtype float. Therefore change the dtype to the pd.Int64Dtype allowing None
    for c in ["chainA_start", "chainA_end", "chainB_start", "chainB_end", "num_mutations", "num_align_atoms_domain", "num_align_resi_domain", "hbonds", "salt_bridges", "hydrophobic_interactions", "disulfide_bonds"]:
        if c not in dataAF.columns:
            print(f"Column {bcolors.FAIL}{c}{bcolors.ENDC} not (yet) in data frame")
            continue
        dataAF[c] = dataAF[c].astype(pd.Int64Dtype())

    def _reorder_column(c:list[str], column: str, prev_column: str = None, index:int = None):
        if column not in c:
            print(f"Column {bcolors.FAIL}{column}{bcolors.ENDC} not (yet) in data frame")
            return
        if index is None:
            if prev_column not in c:
                print(f"Column {bcolors.FAIL}{prev_column}{bcolors.ENDC} (used for sorting) not (yet) in data frame")
                return
            index = c.index(prev_column) + 1
        c.remove(column)
        c.insert(index, column)

    # Reordering of the columns
    c = list(dataAF.columns)
    if af_mode == "AF2":
        _reorder_column(c, "run_id", index=1)
        _reorder_column(c, "benchmark_set", index=2)
    elif af_mode == "AF3":
        _reorder_column(c, "benchmark_set", index=1)
    _reorder_column(c, "prediction_name", prev_column="benchmark_set")
    _reorder_column(c, "model_id", prev_column="prediction_name")
    _reorder_column(c, "model_path", prev_column="model_id")  # Added line
    if af_mode == "AF3": 
        _reorder_column(c, "ranking_score", prev_column="model_path")  # Updated 
        _reorder_column(c, "chainA_length", prev_column="ranking_score")
    else:
        _reorder_column(c, "chainA_length", prev_column="model_path")  # Updated 
    _reorder_column(c, "chainB_length", prev_column="chainA_length")
    _reorder_column(c, "chainA_id", prev_column="chainB_length")
    _reorder_column(c, "chainB_id", prev_column="chainA_id")
    _reorder_column(c, "chainA_start", prev_column="chainB_id")
    _reorder_column(c, "chainA_end", prev_column="chainA_start")
    _reorder_column(c, "chainB_start", prev_column="chainA_end")
    _reorder_column(c, "chainB_end", prev_column="chainB_start")
    _reorder_column(c, "PDB_id", prev_column="chainB_end")
    _reorder_column(c, "ELM_instance", prev_column="PDB_id")
    _reorder_column(c, "DDI_pfam_id", prev_column="ELM_instance")
    _reorder_column(c, "PDB_id_random_paired", prev_column="DDI_pfam_id")
    _reorder_column(c, "ELM_instance_random_paired", prev_column="PDB_id_random_paired")
    _reorder_column(c, "DDI_pfam_id_random_paired", prev_column="ELM_instance_random_paired")
    _reorder_column(c, "sequence_initial", prev_column="DDI_pfam_id_random_paired")
    _reorder_column(c, "sequence_mutated", prev_column="sequence_initial")
    _reorder_column(c, "num_mutations", prev_column="sequence_mutated")

    _reorder_column(c, "align_score_domain", prev_column="num_atom_atom_contact")
    _reorder_column(c, "num_align_atoms_domain", prev_column="align_score_domain")
    _reorder_column(c, "num_align_resi_domain", prev_column="num_align_atoms_domain")
    _reorder_column(c, "RMSD_domain", prev_column="num_align_resi_domain")
    _reorder_column(c, "RMSD_backbone_peptide", prev_column="RMSD_domain")
    _reorder_column(c, "RMSD_all_atom_peptide", prev_column="RMSD_backbone_peptide")
    _reorder_column(c, "RMSD_all_atom", prev_column="RMSD_all_atom_peptide")

    _reorder_column(c, "buried_area", prev_column="Fnonnat")
    _reorder_column(c, "min_distance", prev_column="buried_area")
    _reorder_column(c, "disulfide_bonds", prev_column="min_distance")
    _reorder_column(c, "salt_bridges", prev_column="disulfide_bonds")
    _reorder_column(c, "hbonds", prev_column="salt_bridges")
    _reorder_column(c, "hydrophobic_interactions", prev_column="hbonds")
    

    dataAF = dataAF[c]

# %%
# Load data
if load_previous:
    dataAF = pd.read_csv(path_AF / (path_AF.name + "_metrics.tsv"), sep="\t")
else:
    # Read in the AF data
    if af_mode == "AF2":
        dataAF = pd.read_excel(path_AF / "AF2_extension_metrics.xlsx")

        print(dataAF.columns.tolist())

        # Drop columns to recalculate them
        dataAF.drop(columns=["label"], inplace=True)


        # Adding benchmark set column
        benchmark_set_replace_dict = {"1": "mutations_DMI", "2" : "mutations_DMI", "approved minimal DDI": "known_DDI", "known minimal": "known_DMI", "random minimal": "random_DMI", "random minimal DDI": "random_DDI", "known_extension" : "known_extension", "random_extension" : "random_extension"}
        dataAF["benchmark_set"] = None
        dataAF["num_mutations"] = None

        for i, row in dataAF.iterrows():
            if row["mutation_in_motif"] == "1":
                dataAF.at[i, "num_mutations"] = 1
            elif row["mutation_in_motif"] == "2":
                dataAF.at[i, "num_mutations"] = 2
            benchmark_set = benchmark_set_replace_dict[row["mutation_in_motif"]]
            dataAF.at[i, "benchmark_set"] = benchmark_set
        dataAF.drop(columns=["mutation_in_motif"], inplace=True)

    elif af_mode == "AF3":
        dataAF = pd.read_csv(path_resources / "AF3_output.tsv", sep="\t")

        benchmark_set_replace_dict = {"mutations": "mutations_DMI", "known_minimal": "known_DMI", "known_ddi": "known_DDI", "random_minimal": "random_DMI", "random_ddi": "random_DDI", "known_extension" : "known_extension", "random_extension" : "random_extension"}
            
        for i, row in dataAF.iterrows():
            benchmark_set = benchmark_set_replace_dict[row["benchmark_set"]]
            dataAF.at[i, "benchmark_set"] = benchmark_set
enhance_dataframe()
display(dataAF)
# Out:
# Column chainA_start not (yet) in data frame
# Column chainA_end not (yet) in data frame
# Column chainB_start not (yet) in data frame
# Column chainB_end not (yet) in data frame
# Column num_mutations not (yet) in data frame
# Column num_align_atoms_domain not (yet) in data frame
# Column num_align_resi_domain not (yet) in data frame
# Column hbonds not (yet) in data frame
# Column salt_bridges not (yet) in data frame
# Column hydrophobic_interactions not (yet) in data frame
# Column disulfide_bonds not (yet) in data frame
# Column chainA_id not (yet) in data frame
# Column chainB_id not (yet) in data frame
# Column chainA_start not (yet) in data frame
# Column chainA_end not (yet) in data frame
# Column chainB_start not (yet) in data frame
# Column chainB_end not (yet) in data frame
# Column PDB_id not (yet) in data frame
# Column ELM_instance not (yet) in data frame
# Column DDI_pfam_id not (yet) in data frame
# Column PDB_id_random_paired not (yet) in data frame
# Column ELM_instance_random_paired not (yet) in data frame
# Column DDI_pfam_id_random_paired not (yet) in data frame
# Column sequence_initial not (yet) in data frame
# Column sequence_mutated not (yet) in data frame
# Column num_mutations not (yet) in data frame
# Column align_score_domain not (yet) in data frame
# Column num_align_atoms_domain not (yet) in data frame
# Column num_align_resi_domain not (yet) in data frame
# Column RMSD_domain not (yet) in data frame
# Column RMSD_backbone_peptide not (yet) in data frame
# Column RMSD_all_atom_peptide not (yet) in data frame
# Column RMSD_all_atom not (yet) in data frame
# Column buried_area not (yet) in data frame
# Column min_distance not (yet) in data frame
# Column disulfide_bonds not (yet) in data frame
# Column salt_bridges not (yet) in data frame
# Column hbonds not (yet) in data frame
# Column hydrophobic_interactions not (yet) in data frame
#      model_preset benchmark_set  \
# 0      alphafold3     known_DMI
# 1      alphafold3     known_DMI
# 2      alphafold3     known_DMI
# 3      alphafold3     known_DMI
# 4      alphafold3     known_DMI
# ...           ...           ...
# 5995   alphafold3    random_DDI
# 5996   alphafold3    random_DDI
# 5997   alphafold3    random_DDI
# 5998   alphafold3    random_DDI
# 5999   alphafold3    random_DDI
#
#                                     prediction_name  model_id  \
# 0                            DEG_APCC_KENBOX_2_4GGD  ranked_0
# 1                            DEG_APCC_KENBOX_2_4GGD  ranked_1
# 2                            DEG_APCC_KENBOX_2_4GGD  ranked_2
# 3                            DEG_APCC_KENBOX_2_4GGD  ranked_3
# 4                            DEG_APCC_KENBOX_2_4GGD  ranked_4
# ...                                             ...       ...
# 5995  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_0
# 5996  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_1
# 5997  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_2
# 5998  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_3
# 5999  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_4
#
#                                              model_path  ranking_score  \
# 0     AlphaFold_benchmark_DMI/known_minimal/sharp_sh...           0.97
# 1     AlphaFold_benchmark_DMI/known_minimal/sharp_sh...           0.97
# 2     AlphaFold_benchmark_DMI/known_minimal/sharp_sh...           0.96
# 3     AlphaFold_benchmark_DMI/known_minimal/sharp_sh...           0.96
# 4     AlphaFold_benchmark_DMI/known_minimal/sharp_sh...           0.96
# ...                                                 ...            ...
# 5995  AlphaFold_benchmark_DDI/random_ddi/angry_sange...           0.36
# 5996  AlphaFold_benchmark_DDI/random_ddi/angry_sange...           0.23
# 5997  AlphaFold_benchmark_DDI/random_ddi/angry_sange...           0.22
# 5998  AlphaFold_benchmark_DDI/random_ddi/angry_sange...           0.21
# 5999  AlphaFold_benchmark_DDI/random_ddi/angry_sange...           0.20
#
#       chainA_length  chainB_length  fraction_disordered  has_clash  ...  \
# 0             312.0            5.0                 0.02        0.0  ...
# 1             312.0            5.0                 0.02        0.0  ...
# 2             312.0            5.0                 0.02        0.0  ...
# 3             312.0            5.0                 0.02        0.0  ...
# 4             312.0            5.0                 0.02        0.0  ...
# ...             ...            ...                  ...        ...  ...
# 5995           60.0          113.0                 0.22        0.0  ...
# 5996           60.0          113.0                 0.08        0.0  ...
# 5997           60.0          113.0                 0.14        0.0  ...
# 5998           60.0          113.0                 0.07        0.0  ...
# 5999           60.0          113.0                 0.07        0.0  ...
#
#       chainA_intf_avg_plddt  chainB_intf_avg_plddt  intf_avg_plddt  \
# 0                     96.21                  88.25           94.54
# 1                     96.23                  88.12           94.20
# 2                     96.14                  86.06           93.49
# 3                     95.48                  83.80           92.56
# 4                     95.73                  84.93           93.03
# ...                     ...                    ...             ...
# 5995                  54.62                  64.94           59.98
# 5996                  55.21                  72.04           64.46
# 5997                  48.38                  51.87           50.40
# 5998                  52.31                  61.57           56.68
# 5999                  51.57                  63.62           57.96
#
#       num_chainA_intf_res  num_chainB_intf_res  num_res_res_contact  \
# 0                    15.0                  4.0                 25.0
# 1                    15.0                  5.0                 26.0
# 2                    14.0                  5.0                 27.0
# 3                    15.0                  5.0                 26.0
# 4                    15.0                  5.0                 27.0
# ...                   ...                  ...                  ...
# 5995                 12.0                 13.0                 24.0
# 5996                  9.0                 11.0                 18.0
# 5997                  8.0                 11.0                 20.0
# 5998                 19.0                 17.0                 39.0
# 5999                 23.0                 26.0                 62.0
#
#       num_atom_atom_contact   iPAE  pDockQ  chains_flipped
# 0                     252.0   1.85    0.20            True
# 1                     263.0   1.85    0.20            True
# 2                     280.0   2.15    0.20            True
# 3                     261.0   1.90    0.15            True
# 4                     271.0   1.95    0.19            True
# ...                     ...    ...     ...             ...
# 5995                  130.0  12.30    0.04           False
# 5996                  120.0  18.69    0.04           False
# 5997                  141.0  22.10    0.03           False
# 5998                  290.0  21.80    0.06           False
# 5999                  495.0  24.10    0.12           False
#
# [6000 rows x 22 columns]

# %%
# Read in solved structure data

dataSolved = pd.DataFrame(columns=["set", "PDB_id", "DDI_pfam_id", "path", "chainA_id", "chainB_id"])

# DMI
for structure_file in [p for p in path_solved.iterdir() if p.is_file() and p.suffix == ".pdb"]:
    pdb_id = structure_file.name.split("_")[0]
    dataSolved.loc[len(dataSolved)] = {"set" : "DMI", "PDB_id": pdb_id, "path": structure_file.relative_to(path_solved), "chainA_id": "A", "chainB_id": "B"}

# DDI
"""
for structure_file in [p for p in path_solved.iterdir() if p.is_file() and p.suffix == ".pdb"]:
    ddi_pfam_id = "_".join(structure_file.name.split("_")[0:2])
    pdb_id = structure_file.name.split("_")[2]
    chainA_id = structure_file.name.split("_")[3][0]
    chainB_id = structure_file.name.split("_")[3][1]
    dataSolved.loc[len(dataSolved)] = {"set" : "DDI", "PDB_id": pdb_id, "DDI_pfam_id": ddi_pfam_id, "path": structure_file.relative_to(path_solved), "chainA_id": chainA_id, "chainB_id": chainB_id}
"""
display(dataSolved)
# Out:
#      set PDB_id  DDI_pfam_id              path chainA_id chainB_id
# 0    DMI   2JK9          NaN  2JK9_min_DMI.pdb         A         B
# 1    DMI   1B8Q          NaN  1B8Q_min_DMI.pdb         A         B
# 2    DMI   4GGD          NaN  4GGD_min_DMI.pdb         A         B
# 3    DMI   5F74          NaN  5F74_min_DMI.pdb         A         B
# 4    DMI   1DDV          NaN  1DDV_min_DMI.pdb         A         B
# ..   ...    ...          ...               ...       ...       ...
# 133  DMI   1UTC          NaN  1UTC_min_DMI.pdb         A         B
# 134  DMI   3GM1          NaN  3GM1_min_DMI.pdb         A         B
# 135  DMI   1NTV          NaN  1NTV_min_DMI.pdb         A         B
# 136  DMI   1ZUB          NaN  1ZUB_min_DMI.pdb         A         B
# 137  DMI   1KKQ          NaN  1KKQ_min_DMI.pdb         A         B
#
# [138 rows x 6 columns]

# %% [markdown]
# ### 1 Parsing the file names
# Many informations (PDB ID, mutation sequence, ...) are included in the filename. This section parses them and adds them to the metrics data frame. The detected values include:
# * **PDB_id** (all structures): RCSB Protein Data Bank ID
# * **ELM_instance** (DMI): ID of the motif in the Eukaryotic Linear Motif database
# * **DDI_pfam_id** (DDI): ID of the two domains in the Pfam Database separated by an underscore
# * **PDB_id_random_paired**, **ELM_instance_random_paired** and **DDI_pfam_id_random_paired** (random_DMI, random_DDI): The id of the second domain/motif for the randomly paired DMI and DDI. For DMI, the random fields always encode the motif.
# * **sequence_initial** and **sequence_mutated** (mutations_DMI): For the mutations, this fields encode the initinal and mutated sequence of the motif
# * **chainA_id**, **chainA_start**, **chainA_end** and the same three for **chainB** (all structures where data is available): The start and end residue as well as the ID of the chains in the experimentally solved structure. For known_DDI, the information is encoded in the prediction name and carried over to the random_DDI set. For DMI structures, the information will be added in section 2 by aligning with the template file. Chain A and B refer to the IDs in the AlphaFold predictions. For DMI, chain B is always the motif chain.
#
# Note: known_extensions were excluded from the benchmark set, but if you need to parse them remove the comments in the code cell below. But the code needs to be tested !!

# %%
# Simplified regex pattern for extension samples
import re

# Pattern for known extensions - handles all the variations we've seen
known_extension_pattern = r"^(.+?)_[Mm](\d+|min|fl|FL|Min|Fl)(?:_[Mm](\d+|min|fl|FL|Min|Fl))?_[Dd](\d+|min|fl|FL|Min|Fl)(?:_[Dd](\d+|min|fl|FL|Min|Fl))?$"

def parse_known_extension_name(prediction_name):
    """Parse known extension prediction name and return extracted components"""
    match = re.search(known_extension_pattern, prediction_name)
    if not match:
        return None, None, None, None, None, None, None
    
    groups = match.groups()
    elm_instance = groups[0]  # Base name
    
    # Handle motif positions (M/m) - first is always present
    m_start = groups[1] if groups[1] else None
    m_end = groups[2] if groups[2] else None  # May be None for single M format
    
    # Handle domain positions (D/d) - first is always present  
    d_start = groups[3] if groups[3] else None
    d_end = groups[4] if groups[4] else None  # May be None for single D format
    
    # Convert numeric strings to integers
    def convert_to_int(value):
        if value and value.isdigit():
            return int(value)
        return None
    
    c1_start = convert_to_int(m_start)
    c1_end = convert_to_int(m_end)
    c2_start = convert_to_int(d_start)
    c2_end = convert_to_int(d_end)
    
    return elm_instance, c1_start, c1_end, c2_start, c2_end, "A", "B"

# Initialize columns for known extensions only
columns_to_add = [
    "ELM_instance", "chainA_id", "chainB_id",
    "chainA_start", "chainA_end", "chainB_start", "chainB_end"
]

for col in columns_to_add:
    if col not in dataAF.columns:
        dataAF[col] = None

print("Processing known extension samples only...")

successful_matches = 0
failed_matches = []

# Process only known extension samples
known_extension_mask = dataAF["benchmark_set"] == "known_extension"
known_extension_data = dataAF[known_extension_mask]

for i, row in known_extension_data.iterrows():
    prediction_name = row["prediction_name"]
    
    # Parse the prediction name
    elm_instance, c1_start, c1_end, c2_start, c2_end, chain1, chain2 = parse_known_extension_name(prediction_name)
    
    if elm_instance is not None:
        # Update the dataframe
        dataAF.at[i, "ELM_instance"] = elm_instance
        dataAF.at[i, "chainA_id"] = chain1
        dataAF.at[i, "chainB_id"] = chain2
        dataAF.at[i, "chainA_start"] = c1_start
        dataAF.at[i, "chainA_end"] = c1_end
        dataAF.at[i, "chainB_start"] = c2_start
        dataAF.at[i, "chainB_end"] = c2_end
        dataAF.at[i,"DDI_pfam_id"] = None
        dataAF.at[i, "PDB_id_random_paired"] = None
        dataAF.at[i, "ELM_instance_random_paired"] = None
        dataAF.at[i, "DDI_pfam_id_random_paired"] = None
        
        
        successful_matches += 1
    else:
        failed_matches.append(prediction_name)

# Filter to only keep known extension samples
dataAF = dataAF[known_extension_mask]

af3_metrics_old = pd.read_csv(path_resources/'af3_metrics.tsv', sep='\t')
dataAF['PDB_id'] = dataAF['ELM_instance'].map(dict(zip(af3_metrics_old['ELM_instance'], af3_metrics_old['PDB_id'])))

print(f"\nMatching Results for Known Extensions:")
print(f"Successful matches: {successful_matches}")
print(f"Failed matches: {len(failed_matches)}")

if failed_matches:
    print(f"\nFailed matches:")
    for filename in failed_matches[:20]:  # Show first 20 failures
        print(f"  {filename}")
    if len(failed_matches) > 20:
        print(f"  ... and {len(failed_matches) - 20} more")

print(f"\nTotal known extension rows: {len(dataAF)}")
if len(dataAF) > 0:
    print("\nSample processed data:")
    display(dataAF.head())

display(dataAF)
# Out:
# Processing known extension samples only...
#
# Matching Results for Known Extensions:
# Successful matches: 2820
# Failed matches: 0
#
# Total known extension rows: 2820
#
# Sample processed data:
#      model_preset    benchmark_set                    prediction_name  \
# 2710          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2711          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2712          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2713          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2714          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
#
#       model_id                                         model_path  \
# 2710  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2711  ranked_1  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2712  ranked_2  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2713  ranked_3  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2714  ranked_4  AlphaFold_benchmark_DMI/known_extension/nostal...
#
#       ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 2710            1.0            NaN            NaN                  NaN
# 2711            0.9            NaN            NaN                  NaN
# 2712            0.8            NaN            NaN                  NaN
# 2713            0.7            NaN            NaN                  NaN
# 2714            0.6            NaN            NaN                  NaN
#
#       has_clash  ...  chainB_id  chainA_start  chainA_end  chainB_start  \
# 2710        NaN  ...          B            15          39             1
# 2711        NaN  ...          B            15          39             1
# 2712        NaN  ...          B            15          39             1
# 2713        NaN  ...          B            15          39             1
# 2714        NaN  ...          B            15          39             1
#
#       chainB_end  DDI_pfam_id  PDB_id_random_paired  \
# 2710         499         None                  None
# 2711         499         None                  None
# 2712         499         None                  None
# 2713         499         None                  None
# 2714         499         None                  None
#
#       ELM_instance_random_paired  DDI_pfam_id_random_paired  PDB_id
# 2710                        None                       None    4GGD
# 2711                        None                       None    4GGD
# 2712                        None                       None    4GGD
# 2713                        None                       None    4GGD
# 2714                        None                       None    4GGD
#
# [5 rows x 34 columns]
#      model_preset    benchmark_set                    prediction_name  \
# 2710          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2711          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2712          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2713          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2714          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# ...           ...              ...                                ...
# 5525          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5526          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5527          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5528          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5529          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
#
#       model_id                                         model_path  \
# 2710  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2711  ranked_1  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2712  ranked_2  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2713  ranked_3  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2714  ranked_4  AlphaFold_benchmark_DMI/known_extension/nostal...
# ...        ...                                                ...
# 5525  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5526  ranked_1  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5527  ranked_2  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5528  ranked_3  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5529  ranked_4  AlphaFold_benchmark_DMI/known_extension/sponta...
#
#       ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 2710            1.0            NaN            NaN                  NaN
# 2711            0.9            NaN            NaN                  NaN
# 2712            0.8            NaN            NaN                  NaN
# 2713            0.7            NaN            NaN                  NaN
# 2714            0.6            NaN            NaN                  NaN
# ...             ...            ...            ...                  ...
# 5525            1.0            NaN            NaN                  NaN
# 5526            0.9            NaN            NaN                  NaN
# 5527            0.8            NaN            NaN                  NaN
# 5528            0.7            NaN            NaN                  NaN
# 5529            0.6            NaN            NaN                  NaN
#
#       has_clash  ...  chainB_id  chainA_start  chainA_end  chainB_start  \
# 2710        NaN  ...          B            15          39             1
# 2711        NaN  ...          B            15          39             1
# 2712        NaN  ...          B            15          39             1
# 2713        NaN  ...          B            15          39             1
# 2714        NaN  ...          B            15          39             1
# ...         ...  ...        ...           ...         ...           ...
# 5525        NaN  ...          B          None        None          None
# 5526        NaN  ...          B          None        None          None
# 5527        NaN  ...          B          None        None          None
# 5528        NaN  ...          B          None        None          None
# 5529        NaN  ...          B          None        None          None
#
#       chainB_end  DDI_pfam_id  PDB_id_random_paired  \
# 2710         499         None                  None
# 2711         499         None                  None
# 2712         499         None                  None
# 2713         499         None                  None
# 2714         499         None                  None
# ...          ...          ...                   ...
# 5525        None         None                  None
# 5526        None         None                  None
# 5527        None         None                  None
# 5528        None         None                  None
# 5529        None         None                  None
#
#       ELM_instance_random_paired  DDI_pfam_id_random_paired  PDB_id
# 2710                        None                       None    4GGD
# 2711                        None                       None    4GGD
# 2712                        None                       None    4GGD
# 2713                        None                       None    4GGD
# 2714                        None                       None    4GGD
# ...                          ...                        ...     ...
# 5525                        None                       None    2G30
# 5526                        None                       None    2G30
# 5527                        None                       None    2G30
# 5528                        None                       None    2G30
# 5529                        None                       None    2G30
#
# [2820 rows x 34 columns]

# %% [markdown]
# ### 2 Adding domain and motif start / end from template file
# While for the DDI structures selection start and end are included in the filename, for DMI structures there is absolutely no information about start/end of motif and domain. At least, the DMI structures are cut to only include the minimal domain/motif, but there still may be mutations or missing residues in experimental structures. To restore this information use the template and perform a simple search for three consecutive residues in both chains and calculate the offset between the chain IDs. Then take the most common offset and use it if at least 50 % of the AF residues were matched this way.

# %%
def align_sequences(chain_af:  Chain, chain_template: Chain) -> tuple[int, int, float, str, str]:
    """ Estimate the residue id offset between two chains based on a neighbour local alignment (BioPython has no convinient alignment function).
    
        :returns tuple[int, int, float, str, str]: Start ID, End ID, score, Sequence Chain A, Sequence Chain B
    """
    residues_af = [r for r in chain_af.get_residues()]
    residues_tpl = [r for r in chain_template.get_residues()]
    seq_af = seq1(''.join([r.resname for r in residues_af]))
    seq_tpl = seq1(''.join([r.resname for r in residues_tpl]))
    offset_list = []

    misscounts = 0
    for t0, t1, t2 in zip(residues_tpl[:-2], residues_tpl[1:-1], residues_tpl[2:]):
        _found = False
        for a0, a1, a2 in zip(residues_af[:-2], residues_af[1:-1], residues_af[2:]):
            if a0.resname == t0.resname and a1.resname == t1.resname and a2.resname == t2.resname:
                offset_list.append(t1.id[1] - a1.id[1])
                _found = True
        if not _found:
            misscounts += 1

    # For degenerated short chains (motif) use no neighbours for matching
    # if len(offset_list) == 0:
    #     for r1 in residues_af:
    #         for r2 in residues_tpl:
    #             if r1.resname == r2.resname:
    #                 offset_list.append(r2.id[1] - r1.id[1])

    if len(offset_list) == 0:
        return (None, None, 0, seq_af, seq_tpl)
    offsets, counts = np.unique(offset_list, return_counts=True)
    offset = offsets[np.argmax(counts)]
    score = 1 - misscounts/(len(residues_tpl) - 2)
    return  offset + 1, offset + len(residues_af), score, seq_af, seq_tpl

for i, row in dataAF[dataAF["benchmark_set"].isin(["known_extension"])].iterrows():
    pdb_id = str(row["PDB_id"])
    pdb_id_2 = None
    #if row["PDB_id_random_paired"] is not None:
        #pdb_id_2 = str(row["PDB_id_random_paired"])
    prediction_name = row["prediction_name"]
    benchmark_set = row["benchmark_set"]
    model_id = row["model_id"]

    if model_id == "ranked_0":
        print(bcolors.OKBLUE + f"{prediction_name} ({benchmark_set})" + bcolors.ENDC)

    #if not prediction_name == "MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS": continue

    af_path = path_resources / "DMI" / benchmark_set / prediction_name / (model_id + ".pdb")
    af_biopy = parser.get_structure("structure", file=af_path)[0]
    chainA_af = af_biopy["A"]
    chainB_af = af_biopy["B"]    

    template1_path = path_solved / (pdb_id + "_min_DMI.pdb")
    if not template1_path.exists():
        print(f"\t", bcolors.WARNING + f"{prediction_name} has no template file for {pdb_id}" + bcolors.WARNING)
        continue
    template1_biopy = parser.get_structure("structure", file=template1_path)[0]
    chainA_tlp = template1_biopy["A"]
    if pdb_id_2 is not None:
        template2_path = path_solved / "DMI" / (pdb_id_2 + "_min_DMI.pdb")
        if not template2_path.exists():
            print(f"\t", f"{prediction_name} has no template file for {pdb_id}")
            continue
        template2_biopy = parser.get_structure("structure", file=template2_path)[0]
        chainB_tlp = template2_biopy["B"]
    else:
        chainB_tlp = template1_biopy["B"]

    chainA_start, chainA_end, chainA_score, seqA_af, seqA_tpl = align_sequences(chain_af=chainA_af, chain_template=chainA_tlp)
    if chainA_start is not None:
        if model_id == "ranked_0":
            print("\t", f"chainA: {chainA_start}-{chainA_end} ({bcolors.WARNING if chainA_score < 0.5 else ''}{chainA_score:0.3f}{bcolors.ENDC})")
        dataAF.at[i, "chainA_start"] =  chainA_start
        dataAF.at[i, "chainA_end"] =  chainA_end
    else:
        if model_id == "ranked_0":
            print(f"\t", bcolors.WARNING + "Chain A alignment failed" + bcolors.ENDC)
    if model_id == "ranked_0" and chainA_score < 0.5:
        print("\t\t", seqA_af)
        print("\t\t", seqA_tpl)

    chainB_start, chainB_end, chainB_score, seqB_af, seqB_tpl = align_sequences(chain_af=chainB_af, chain_template=chainB_tlp)
    if chainB_start is not None:
        if model_id == "ranked_0":
            print("\t", f"chainB: {chainB_start}-{chainB_end} ({bcolors.WARNING if chainB_score < 0.5 else ''}{chainB_score:0.3f}{bcolors.ENDC})")
        dataAF.at[i, "chainB_start"] =  chainB_start
        dataAF.at[i, "chainB_end"] =  chainB_end
    else:
        if model_id == "ranked_0":
            print(f"\t", bcolors.WARNING + "Chain B alignment failed" + bcolors.ENDC)
    if model_id == "ranked_0" and chainB_score < 0.5:
        print("\t\t", seqB_af)
        print("\t\t", seqB_tpl)
    
    

# For the mutations, the alignment mostly fails. For those restore the information using the known_DMI dataset
for i, row in dataAF[dataAF["benchmark_set"].isin(["mutations_DMI"])].iterrows():
    prediction_name = row["prediction_name"]
    benchmark_set = row["benchmark_set"]
    pdb_id = row["PDB_id"]
    pdb_id_2 = row["PDB_id_random_paired"] if row["PDB_id_random_paired"] is not None else pdb_id
    
    if len(list((_row1 := dataAF[np.logical_and(dataAF["benchmark_set"] == "known_DMI", dataAF["PDB_id"] == pdb_id)])["chainA_id"])) == 0:
        if model_id == "ranked_0":
            print(f"Can't find {pdb_id} from {prediction_name} ({benchmark_set}, chain A) in the known_DMI set")
        continue
    if len(list((_row2 := dataAF[np.logical_and(dataAF["benchmark_set"] == "known_DMI", dataAF["PDB_id"] == pdb_id_2)])["chainB_id"])) == 0:
        if model_id == "ranked_0":
            print(f"Can't find {pdb_id_2} from {prediction_name} ({benchmark_set}, chain B) in the known_DMI set")
        continue
    dataAF.at[i, "chainA_start"] = list(_row1["chainA_start"])[0]
    dataAF.at[i, "chainA_end"] = list(_row1["chainA_end"])[0]
    dataAF.at[i, "chainB_start"] = list(_row2["chainB_start"])[0]
    dataAF.at[i, "chainB_end"] = list(_row2["chainB_end"])[0]
# Out:
# DEG_APCC_KENBOX_2_M15_M39_D1_D499 (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: -4-20 (1.000)
# DEG_APCC_KENBOX_2_M15_M39_Dmin (known_extension)
# 	 chainA: 170-476 (0.984)
# 	 chainB: -4-20 (1.000)
# DEG_APCC_KENBOX_2_M1_M189_D1_D499 (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: -18-170 (1.000)
# DEG_APCC_KENBOX_2_M1_M189_Dmin (known_extension)
# 	 chainA: 170-476 (0.984)
# 	 chainB: -18-170 (1.000)
# DEG_APCC_KENBOX_2_M1_M57_D1_D499 (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: -18-38 (1.000)
# DEG_APCC_KENBOX_2_M1_M57_Dmin (known_extension)
# 	 chainA: 170-476 (0.984)
# 	 chainB: -18-38 (1.000)
# DEG_APCC_KENBOX_2_M20_M34_D1_D499 (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: 1-15 (1.000)
# DEG_APCC_KENBOX_2_M20_M34_Dmin (known_extension)
# 	 chainA: 170-476 (0.984)
# 	 chainB: 1-15 (1.000)
# DEG_APCC_KENBOX_2_M5_M49_D1_D499 (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: -14-30 (1.000)
# DEG_APCC_KENBOX_2_M5_M49_Dmin (known_extension)
# 	 chainA: 170-476 (0.984)
# 	 chainB: -14-30 (1.000)
# DEG_APCC_KENBOX_2_MFL_Dmin (known_extension)
# 	 chainA: 170-476 (0.984)
# 	 chainB: -18-1031 (1.000)
# DEG_APCC_KENBOX_2_Mmin_D1_D499 (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: 6-10 (1.000)
# DEG_APCC_KENBOX_2_Mmin_DFL (known_extension)
# 	 chainA: 1-499 (1.000)
# 	 chainB: 6-10 (1.000)
# DEG_Kelch_Keap1_1_M1_M568_D175_D624 (known_extension)
# 	 chainA: 175-624 (1.000)
# 	 chainB: 1-568 (1.000)
# DEG_Kelch_Keap1_1_M1_M568_D295_D624 (known_extension)
# 	 chainA: 295-624 (1.000)
# 	 chainB: 1-568 (1.000)
# DEG_Kelch_Keap1_1_M1_M568_Dmin (known_extension)
# 	 chainA: 330-609 (0.982)
# 	 chainB: 1-568 (1.000)
# DEG_Kelch_Keap1_1_M41_M118_D175_D624 (known_extension)
# 	 chainA: 175-624 (1.000)
# 	 chainB: 41-118 (1.000)
# DEG_Kelch_Keap1_1_M41_M118_D295_D624 (known_extension)
# 	 chainA: 295-624 (1.000)
# 	 chainB: 41-118 (1.000)
# DEG_Kelch_Keap1_1_M41_M118_Dmin (known_extension)
# 	 chainA: 330-609 (0.982)
# 	 chainB: 41-118 (1.000)
# DEG_Kelch_Keap1_1_M53_M106_D175_D624 (known_extension)
# 	 chainA: 175-624 (1.000)
# 	 chainB: 53-106 (1.000)
# DEG_Kelch_Keap1_1_M53_M106_D295_D624 (known_extension)
# 	 chainA: 295-624 (1.000)
# 	 chainB: 53-106 (1.000)
# DEG_Kelch_Keap1_1_M53_M106_Dmin (known_extension)
# 	 chainA: 330-609 (0.982)
# 	 chainB: 53-106 (1.000)
# DEG_Kelch_Keap1_1_M65_M94_D175_D624 (known_extension)
# 	 chainA: 175-624 (1.000)
# 	 chainB: 65-94 (1.000)
# DEG_Kelch_Keap1_1_M65_M94_D295_D624 (known_extension)
# 	 chainA: 295-624 (1.000)
# 	 chainB: 65-94 (1.000)
# DEG_Kelch_Keap1_1_M65_M94_Dmin (known_extension)
# 	 chainA: 330-609 (0.982)
# 	 chainB: 65-94 (1.000)
# DEG_Kelch_Keap1_1_M71_M88_D175_D624 (known_extension)
# 	 chainA: 175-624 (1.000)
# 	 chainB: 71-88 (1.000)
# DEG_Kelch_Keap1_1_M71_M88_D295_D624 (known_extension)
# 	 chainA: 295-624 (1.000)
# 	 chainB: 71-88 (1.000)
# DEG_Kelch_Keap1_1_M71_M88_Dmin (known_extension)
# 	 chainA: 330-609 (0.982)
# 	 chainB: 71-88 (1.000)
# DEG_Kelch_Keap1_1_MFL_Dmin (known_extension)
# 	 chainA: 330-609 (0.982)
# 	 chainB: 1-605 (1.000)
# DEG_Kelch_Keap1_1_Mmin_D175_D624 (known_extension)
# 	 chainA: 175-624 (1.000)
# 	 chainB: 77-82 (1.000)
# DEG_Kelch_Keap1_1_Mmin_D295_D624 (known_extension)
# 	 chainA: 295-624 (1.000)
# 	 chainB: 77-82 (1.000)
# DEG_Kelch_Keap1_1_Mmin_DFL (known_extension)
# 	 chainA: 1-624 (1.000)
# 	 chainB: 77-82 (1.000)
# DEG_MDM2_SWIB_1_M11_M34_D1_D290 (known_extension)
# 	 chainA: 1-290 (1.000)
# 	 chainB: 11-34 (1.000)
# DEG_MDM2_SWIB_1_M11_M34_D1_D337 (known_extension)
# 	 chainA: 1-337 (1.000)
# 	 chainB: 11-34 (1.000)
# DEG_MDM2_SWIB_1_M11_M34_Dmin (known_extension)
# 	 chainA: 35-109 (0.949)
# 	 chainB: 11-34 (1.000)
# DEG_MDM2_SWIB_1_M1_M298_D1_D290 (known_extension)
# 	 chainA: 1-290 (1.000)
# 	 chainB: 1-298 (1.000)
# DEG_MDM2_SWIB_1_M1_M298_D1_D337 (known_extension)
# 	 chainA: 1-337 (1.000)
# 	 chainB: 1-298 (1.000)
# DEG_MDM2_SWIB_1_M1_M298_Dmin (known_extension)
# 	 chainA: 35-109 (0.949)
# 	 chainB: 1-298 (1.000)
# DEG_MDM2_SWIB_1_M1_M58_D1_D290 (known_extension)
# 	 chainA: 1-290 (1.000)
# 	 chainB: 1-58 (1.000)
# DEG_MDM2_SWIB_1_M1_M58_D1_D337 (known_extension)
# 	 chainA: 1-337 (1.000)
# 	 chainB: 1-58 (1.000)
# DEG_MDM2_SWIB_1_M1_M58_Dmin (known_extension)
# 	 chainA: 35-109 (0.949)
# 	 chainB: 1-58 (1.000)
# DEG_MDM2_SWIB_1_M1_M74_D1_D290 (known_extension)
# 	 chainA: 1-290 (1.000)
# 	 chainB: 1-74 (1.000)
# DEG_MDM2_SWIB_1_M1_M74_D1_D337 (known_extension)
# 	 chainA: 1-337 (1.000)
# 	 chainB: 1-74 (1.000)
# DEG_MDM2_SWIB_1_M1_M74_Dmin (known_extension)
# 	 chainA: 35-109 (0.949)
# 	 chainB: 1-74 (1.000)
# DEG_MDM2_SWIB_1_M3_M42_D1_D290 (known_extension)
# 	 chainA: 1-290 (1.000)
# 	 chainB: 3-42 (1.000)
# DEG_MDM2_SWIB_1_M3_M42_D1_D337 (known_extension)
# 	 chainA: 1-337 (1.000)
# 	 chainB: 3-42 (1.000)
# DEG_MDM2_SWIB_1_M3_M42_Dmin (known_extension)
# 	 chainA: 35-109 (0.949)
# 	 chainB: 3-42 (1.000)
# DEG_MDM2_SWIB_1_MFL_Dmin (known_extension)
# 	 chainA: 35-109 (0.949)
# 	 chainB: 1-393 (1.000)
# DEG_MDM2_SWIB_1_Mmin_D1_D290 (known_extension)
# 	 chainA: 1-290 (1.000)
# 	 chainB: 19-26 (1.000)
# DEG_MDM2_SWIB_1_Mmin_D1_D337 (known_extension)
# 	 chainA: 1-337 (1.000)
# 	 chainB: 19-26 (1.000)
# DEG_MDM2_SWIB_1_Mmin_DFL (known_extension)
# 	 chainA: 1-491 (1.000)
# 	 chainB: 19-26 (1.000)
# DEG_SIAH_1_M1_M166_D1_D282 (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 1-166 (1.000)
# DEG_SIAH_1_M1_M166_Dmin (known_extension)
# 	 chainA: 95-282 (0.965)
# 	 chainB: 1-166 (1.000)
# DEG_SIAH_1_M23_M103_D1_D282 (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 23-103 (1.000)
# DEG_SIAH_1_M23_M103_Dmin (known_extension)
# 	 chainA: 95-282 (0.965)
# 	 chainB: 23-103 (1.000)
# DEG_SIAH_1_M41_M85_D1_D282 (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 41-85 (1.000)
# DEG_SIAH_1_M41_M85_Dmin (known_extension)
# 	 chainA: 95-282 (0.965)
# 	 chainB: 41-85 (1.000)
# DEG_SIAH_1_M50_M76_D1_D282 (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 50-76 (1.000)
# DEG_SIAH_1_M50_M76_Dmin (known_extension)
# 	 chainA: 95-282 (0.965)
# 	 chainB: 50-76 (1.000)
# DEG_SIAH_1_M5_M121_D1_D282 (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 5-121 (1.000)
# DEG_SIAH_1_M5_M121_Dmin (known_extension)
# 	 chainA: 95-282 (0.965)
# 	 chainB: 5-121 (1.000)
# DEG_SIAH_1_MFL_Dmin (known_extension)
# 	 chainA: 95-282 (0.965)
# 	 chainB: 1-228 (1.000)
# DEG_SIAH_1_Mmin_D1_D282 (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 59-67 (1.000)
# DEG_SIAH_1_Mmin_DFL (known_extension)
# 	 chainA: 1-282 (0.965)
# 	 chainB: 59-67 (1.000)
# DOC_ANK_TNKS_1_M1_M322_D391_D742 (known_extension)
# 	 chainA: 391-742 (1.000)
# 	 chainB: -71-250 (1.000)
# DOC_ANK_TNKS_1_M1_M322_D471_D669 (known_extension)
# 	 chainA: 471-669 (1.000)
# 	 chainB: -71-250 (1.000)
# DOC_ANK_TNKS_1_M1_M322_Dmin (known_extension)
# 	 chainA: 494-648 (0.968)
# 	 chainB: -71-250 (1.000)
# DOC_ANK_TNKS_1_M29_M132_D391_D742 (known_extension)
# 	 chainA: 391-742 (1.000)
# 	 chainB: -43-60 (1.000)
# DOC_ANK_TNKS_1_M29_M132_D471_D669 (known_extension)
# 	 chainA: 471-669 (1.000)
# 	 chainB: -43-60 (1.000)
# DOC_ANK_TNKS_1_M29_M132_Dmin (known_extension)
# 	 chainA: 494-648 (0.968)
# 	 chainB: -43-60 (1.000)
# DOC_ANK_TNKS_1_M45_M116_D391_D742 (known_extension)
# 	 chainA: 391-742 (1.000)
# 	 chainB: -27-44 (1.000)
# DOC_ANK_TNKS_1_M45_M116_D471_D669 (known_extension)
# 	 chainA: 471-669 (1.000)
# 	 chainB: -27-44 (1.000)
# DOC_ANK_TNKS_1_M45_M116_Dmin (known_extension)
# 	 chainA: 494-648 (0.968)
# 	 chainB: -27-44 (1.000)
# DOC_ANK_TNKS_1_M61_M100_D391_D742 (known_extension)
# 	 chainA: 391-742 (1.000)
# 	 chainB: -11-28 (1.000)
# DOC_ANK_TNKS_1_M61_M100_D471_D669 (known_extension)
# 	 chainA: 471-669 (1.000)
# 	 chainB: -11-28 (1.000)
# DOC_ANK_TNKS_1_M61_M100_Dmin (known_extension)
# 	 chainA: 494-648 (0.968)
# 	 chainB: -11-28 (1.000)
# DOC_ANK_TNKS_1_M69_M92_D391_D742 (known_extension)
# 	 chainA: 391-742 (1.000)
# 	 chainB: -3-20 (1.000)
# DOC_ANK_TNKS_1_M69_M92_D471_D669 (known_extension)
# 	 chainA: 471-669 (1.000)
# 	 chainB: -3-20 (1.000)
# DOC_ANK_TNKS_1_M69_M92_Dmin (known_extension)
# 	 chainA: 494-648 (0.968)
# 	 chainB: -3-20 (1.000)
# DOC_ANK_TNKS_1_MFL_Dmin (known_extension)
# 	 chainA: 494-648 (0.968)
# 	 chainB: -71-278 (1.000)
# DOC_ANK_TNKS_1_Mmin_D391_D742 (known_extension)
# 	 chainA: 391-742 (1.000)
# 	 chainB: 5-12 (1.000)
# DOC_ANK_TNKS_1_Mmin_D471_D669 (known_extension)
# 	 chainA: 471-669 (1.000)
# 	 chainB: 5-12 (1.000)
# DOC_ANK_TNKS_1_Mmin_DFL (known_extension)
# 	 chainA: 1-1166 (1.000)
# 	 chainB: 5-12 (1.000)
# DOC_MAPK_JIP1_4_M29_M455_D1_D464 (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 29-455 (1.000)
# DOC_MAPK_JIP1_4_M29_M455_Dmin (known_extension)
# 	 chainA: 50-400 (0.980)
# 	 chainB: 29-455 (1.000)
# DOC_MAPK_JIP1_4_M301_M391_D1_D464 (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 301-391 (1.000)
# DOC_MAPK_JIP1_4_M301_M391_Dmin (known_extension)
# 	 chainA: 50-400 (0.980)
# 	 chainB: 301-391 (1.000)
# DOC_MAPK_JIP1_4_M315_M377_D1_D464 (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 315-377 (1.000)
# DOC_MAPK_JIP1_4_M315_M377_Dmin (known_extension)
# 	 chainA: 50-400 (0.980)
# 	 chainB: 315-377 (1.000)
# DOC_MAPK_JIP1_4_M329_M363_D1_D464 (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 329-363 (1.000)
# DOC_MAPK_JIP1_4_M329_M363_Dmin (known_extension)
# 	 chainA: 50-400 (0.980)
# 	 chainB: 329-363 (1.000)
# DOC_MAPK_JIP1_4_M336_M356_D1_D464 (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 336-356 (1.000)
# DOC_MAPK_JIP1_4_M336_M356_Dmin (known_extension)
# 	 chainA: 50-400 (0.980)
# 	 chainB: 336-356 (1.000)
# DOC_MAPK_JIP1_4_MFL_Dmin (known_extension)
# 	 chainA: 50-400 (0.980)
# 	 chainB: 1-455 (1.000)
# DOC_MAPK_JIP1_4_Mmin_D1_D464 (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 343-349 (1.000)
# DOC_MAPK_JIP1_4_Mmin_DFL (known_extension)
# 	 chainA: 1-464 (0.994)
# 	 chainB: 343-349 (1.000)
# DOC_SPAK_OSR1_1_M1006_M1030_D301_D527 (known_extension)
# 	 chainA: 301-527 (0.983)
# 	 chainB: 994-1018 (1.000)
# DOC_SPAK_OSR1_1_M1006_M1030_D7_D527 (known_extension)
# 	 chainA: 7-527 (0.983)
# 	 chainB: 994-1018 (1.000)
# DOC_SPAK_OSR1_1_M1006_M1030_Dmin (known_extension)
# 	 chainA: 437-493 (0.917)
# 	 chainB: 994-1018 (1.000)
# DOC_SPAK_OSR1_1_M1011_M1025_D301_D527 (known_extension)
# 	 chainA: 301-527 (0.983)
# 	 chainB: 999-1013 (1.000)
# DOC_SPAK_OSR1_1_M1011_M1025_D7_D527 (known_extension)
# 	 chainA: 7-527 (0.983)
# 	 chainB: 999-1013 (1.000)
# DOC_SPAK_OSR1_1_M1011_M1025_Dmin (known_extension)
# 	 chainA: 437-493 (0.917)
# 	 chainB: 999-1013 (1.000)
# DOC_SPAK_OSR1_1_M443_M1243_D301_D527 (known_extension)
# 	 chainA: 301-527 (0.983)
# 	 chainB: 431-1231 (1.000)
# DOC_SPAK_OSR1_1_M443_M1243_D7_D527 (known_extension)
# 	 chainA: 7-527 (0.983)
# 	 chainB: 431-1231 (1.000)
# DOC_SPAK_OSR1_1_M443_M1243_Dmin (known_extension)
# 	 chainA: 437-493 (0.917)
# 	 chainB: 431-1231 (1.000)
# DOC_SPAK_OSR1_1_M986_M1050_D301_D527 (known_extension)
# 	 chainA: 301-527 (0.983)
# 	 chainB: 974-1038 (1.000)
# DOC_SPAK_OSR1_1_M986_M1050_D7_D527 (known_extension)
# 	 chainA: 7-527 (0.983)
# 	 chainB: 974-1038 (1.000)
# DOC_SPAK_OSR1_1_M986_M1050_Dmin (known_extension)
# 	 chainA: 437-493 (0.917)
# 	 chainB: 974-1038 (1.000)
# DOC_SPAK_OSR1_1_M996_M1040_D301_D527 (known_extension)
# 	 chainA: 301-527 (0.983)
# 	 chainB: 984-1028 (1.000)
# DOC_SPAK_OSR1_1_M996_M1040_D7_D527 (known_extension)
# 	 chainA: 7-527 (0.983)
# 	 chainB: 984-1028 (1.000)
# DOC_SPAK_OSR1_1_M996_M1040_Dmin (known_extension)
# 	 chainA: 437-493 (0.917)
# 	 chainB: 984-1028 (1.000)
# DOC_SPAK_OSR1_1_MFL_Dmin (known_extension)
# 	 chainA: 437-493 (0.917)
# 	 chainB: -11-1231 (1.000)
# DOC_SPAK_OSR1_1_Mmin_D301_D527 (known_extension)
# 	 chainA: 301-527 (0.983)
# 	 chainB: 1004-1008 (1.000)
# DOC_SPAK_OSR1_1_Mmin_D7_D527 (known_extension)
# 	 chainA: 7-527 (0.983)
# 	 chainB: 1004-1008 (1.000)
# DOC_SPAK_OSR1_1_Mmin_DFL (known_extension)
# 	 chainA: 1-527 (0.983)
# 	 chainB: 1004-1008 (1.000)
# DOC_USP7_MATH_1_M290_M491_D1_D204 (known_extension)
# 	 chainA: 1-204 (0.978)
# 	 chainB: 290-491 (1.000)
# DOC_USP7_MATH_1_M290_M491_D1_D528 (known_extension)
# 	 chainA: 1-528 (0.985)
# 	 chainB: 290-491 (1.000)
# DOC_USP7_MATH_1_M290_M491_Dmin (known_extension)
# 	 chainA: 68-205 (0.956)
# 	 chainB: 290-491 (1.000)
# DOC_USP7_MATH_1_M367_M431_D1_D204 (known_extension)
# 	 chainA: 1-204 (0.978)
# 	 chainB: 367-431 (1.000)
# DOC_USP7_MATH_1_M367_M431_D1_D528 (known_extension)
# 	 chainA: 1-528 (0.985)
# 	 chainB: 367-431 (1.000)
# DOC_USP7_MATH_1_M367_M431_Dmin (known_extension)
# 	 chainA: 68-205 (0.956)
# 	 chainB: 367-431 (1.000)
# DOC_USP7_MATH_1_M377_M421_D1_D204 (known_extension)
# 	 chainA: 1-204 (0.978)
# 	 chainB: 377-421 (1.000)
# DOC_USP7_MATH_1_M377_M421_D1_D528 (known_extension)
# 	 chainA: 1-528 (0.985)
# 	 chainB: 377-421 (1.000)
# DOC_USP7_MATH_1_M377_M421_Dmin (known_extension)
# 	 chainA: 68-205 (0.956)
# 	 chainB: 377-421 (1.000)
# DOC_USP7_MATH_1_M387_M411_D1_D204 (known_extension)
# 	 chainA: 1-204 (0.978)
# 	 chainB: 387-411 (1.000)
# DOC_USP7_MATH_1_M387_M411_D1_D528 (known_extension)
# 	 chainA: 1-528 (0.985)
# 	 chainB: 387-411 (1.000)
# DOC_USP7_MATH_1_M387_M411_Dmin (known_extension)
# 	 chainA: 68-205 (0.956)
# 	 chainB: 387-411 (1.000)
# DOC_USP7_MATH_1_M392_M406_D1_D204 (known_extension)
# 	 chainA: 1-204 (0.978)
# 	 chainB: 392-406 (1.000)
# DOC_USP7_MATH_1_M392_M406_D1_D528 (known_extension)
# 	 chainA: 1-528 (0.985)
# 	 chainB: 392-406 (1.000)
# DOC_USP7_MATH_1_M392_M406_Dmin (known_extension)
# 	 chainA: 68-205 (0.956)
# 	 chainB: 392-406 (1.000)
# DOC_USP7_MATH_1_MFL_Dmin (known_extension)
# 	 chainA: 68-205 (0.956)
# 	 chainB: 1-491 (1.000)
# DOC_USP7_MATH_1_Mmin_D1_D204 (known_extension)
# 	 chainA: 1-204 (0.978)
# 	 chainB: 397-401 (1.000)
# DOC_USP7_MATH_1_Mmin_D1_D528 (known_extension)
# 	 chainA: 1-528 (0.985)
# 	 chainB: 397-401 (1.000)
# DOC_USP7_MATH_1_Mmin_DFL (known_extension)
# 	 chainA: 1-1102 (0.993)
# 	 chainB: 397-401 (1.000)
# DOC_USP7_UBL2_3_M1099_M1135_D204_D1096 (known_extension)
# 	 chainA: 204-1096 (1.000)
# 	 chainB: 1095-1131 (1.000)
# DOC_USP7_UBL2_3_M1099_M1135_D528_D865 (known_extension)
# 	 chainA: 528-865 (1.000)
# 	 chainB: 1095-1131 (1.000)
# DOC_USP7_UBL2_3_M1099_M1135_Dmin (known_extension)
# 	 chainA: 623-867 (0.980)
# 	 chainB: 1095-1131 (1.000)
# DOC_USP7_UBL2_3_M1099_M1140_D204_D1096 (known_extension)
# 	 chainA: 204-1096 (1.000)
# 	 chainB: 1095-1136 (1.000)
# DOC_USP7_UBL2_3_M1099_M1140_D528_D865 (known_extension)
# 	 chainA: 528-865 (1.000)
# 	 chainB: 1095-1136 (1.000)
# DOC_USP7_UBL2_3_M1099_M1140_Dmin (known_extension)
# 	 chainA: 623-867 (0.980)
# 	 chainB: 1095-1136 (1.000)
# DOC_USP7_UBL2_3_M1101_M1125_D204_D1096 (known_extension)
# 	 chainA: 204-1096 (1.000)
# 	 chainB: 1097-1121 (1.000)
# DOC_USP7_UBL2_3_M1101_M1125_D528_D865 (known_extension)
# 	 chainA: 528-865 (1.000)
# 	 chainB: 1097-1121 (1.000)
# DOC_USP7_UBL2_3_M1101_M1125_Dmin (known_extension)
# 	 chainA: 623-867 (0.980)
# 	 chainB: 1097-1121 (1.000)
# DOC_USP7_UBL2_3_M1106_M1120_D204_D1096 (known_extension)
# 	 chainA: 204-1096 (1.000)
# 	 chainB: 1102-1116 (1.000)
# DOC_USP7_UBL2_3_M1106_M1120_D528_D865 (known_extension)
# 	 chainA: 528-865 (1.000)
# 	 chainB: 1102-1116 (1.000)
# DOC_USP7_UBL2_3_M1106_M1120_Dmin (known_extension)
# 	 chainA: 623-867 (0.980)
# 	 chainB: 1102-1116 (1.000)
# DOC_USP7_UBL2_3_M922_M1603_D204_D1096 (known_extension)
# 	 chainA: 204-1096 (1.000)
# 	 chainB: 918-1599 (1.000)
# DOC_USP7_UBL2_3_M922_M1603_D528_D865 (known_extension)
# 	 chainA: 528-865 (1.000)
# 	 chainB: 918-1599 (1.000)
# DOC_USP7_UBL2_3_M922_M1603_Dmin (known_extension)
# 	 chainA: 623-867 (0.980)
# 	 chainB: 918-1599 (1.000)
# DOC_USP7_UBL2_3_MFL_Dmin (known_extension)
# 	 chainA: 623-867 (0.980)
# 	 chainB: -3-1612 (1.000)
# DOC_USP7_UBL2_3_Mmin_D204_D1096 (known_extension)
# 	 chainA: 204-1096 (1.000)
# 	 chainB: 1111-1115 (1.000)
# DOC_USP7_UBL2_3_Mmin_D528_D865 (known_extension)
# 	 chainA: 528-865 (1.000)
# 	 chainB: 1111-1115 (1.000)
# DOC_USP7_UBL2_3_Mmin_DFL (known_extension)
# 	 chainA: 1-1102 (1.000)
# 	 chainB: 1111-1115 (1.000)
# LIG_BIR_III_2_M151_M416_D156_D497 (known_extension)
# 	 chainA: 156-497 (1.000)
# 	 chainB: 151-416 (1.000)
# LIG_BIR_III_2_M151_M416_D240_D437 (known_extension)
# 	 chainA: 240-437 (1.000)
# 	 chainB: 151-416 (1.000)
# LIG_BIR_III_2_M151_M416_Dmin (known_extension)
# 	 chainA: 268-333 (0.928)
# 	 chainB: 151-416 (1.000)
# LIG_BIR_III_2_M285_M349_D156_D497 (known_extension)
# 	 chainA: 156-497 (1.000)
# 	 chainB: 285-349 (1.000)
# LIG_BIR_III_2_M285_M349_D240_D437 (known_extension)
# 	 chainA: 240-437 (1.000)
# 	 chainB: 285-349 (1.000)
# LIG_BIR_III_2_M285_M349_Dmin (known_extension)
# 	 chainA: 268-333 (0.928)
# 	 chainB: 285-349 (1.000)
# LIG_BIR_III_2_M295_M339_D156_D497 (known_extension)
# 	 chainA: 156-497 (1.000)
# 	 chainB: 295-339 (1.000)
# LIG_BIR_III_2_M295_M339_D240_D437 (known_extension)
# 	 chainA: 240-437 (1.000)
# 	 chainB: 295-339 (1.000)
# LIG_BIR_III_2_M295_M339_Dmin (known_extension)
# 	 chainA: 268-333 (0.928)
# 	 chainB: 295-339 (1.000)
# LIG_BIR_III_2_M305_M329_D156_D497 (known_extension)
# 	 chainA: 156-497 (1.000)
# 	 chainB: 305-329 (1.000)
# LIG_BIR_III_2_M305_M329_D240_D437 (known_extension)
# 	 chainA: 240-437 (1.000)
# 	 chainB: 305-329 (1.000)
# LIG_BIR_III_2_M305_M329_Dmin (known_extension)
# 	 chainA: 268-333 (0.928)
# 	 chainB: 305-329 (1.000)
# LIG_BIR_III_2_M310_M324_D156_D497 (known_extension)
# 	 chainA: 156-497 (1.000)
# 	 chainB: 310-324 (1.000)
# LIG_BIR_III_2_M310_M324_D240_D437 (known_extension)
# 	 chainA: 240-437 (1.000)
# 	 chainB: 310-324 (1.000)
# LIG_BIR_III_2_M310_M324_Dmin (known_extension)
# 	 chainA: 268-333 (0.928)
# 	 chainB: 310-324 (1.000)
# LIG_BIR_III_2_MFL_Dmin (known_extension)
# 	 chainA: 268-333 (0.928)
# 	 chainB: 1-416 (1.000)
# LIG_BIR_III_2_Mmin_D156_D497 (known_extension)
# 	 chainA: 156-497 (1.000)
# 	 chainB: 315-319 (1.000)
# LIG_BIR_III_2_Mmin_D240_D437 (known_extension)
# 	 chainA: 240-437 (1.000)
# 	 chainB: 315-319 (1.000)
# LIG_BIR_III_2_Mmin_DFL (known_extension)
# 	 chainA: 1-497 (1.000)
# 	 chainB: 315-319 (1.000)
# LIG_CAP-Gly_1_M1406_M1438_D1_D517 (known_extension)
# 	 chainA: 1-517 (1.000)
# 	 chainB: 1395-1427 (1.000)
# LIG_CAP-Gly_1_M1406_M1438_D1_D815 (known_extension)
# 	 chainA: 1-815 (1.000)
# 	 chainB: 1395-1427 (1.000)
# LIG_CAP-Gly_1_M1406_M1438_Dmin (known_extension)
# 	 chainA: 51-91 (0.886)
# 	 chainB: 1395-1427 (1.000)
# LIG_CAP-Gly_1_M1432_M1438_D1_D517 (known_extension)
# 	 chainA: 1-517 (1.000)
# 	 chainB: 1421-1427 (1.000)
# LIG_CAP-Gly_1_M1432_M1438_D1_D815 (known_extension)
# 	 chainA: 1-815 (1.000)
# 	 chainB: 1421-1427 (1.000)
# LIG_CAP-Gly_1_M1432_M1438_Dmin (known_extension)
# 	 chainA: 51-91 (0.886)
# 	 chainB: 1421-1427 (1.000)
# LIG_CAP-Gly_1_MFL_Dmin (known_extension)
# 	 chainA: 51-91 (0.886)
# 	 chainB: -10-1427 (1.000)
# LIG_CAP-Gly_1_Mmin_D1_D517 (known_extension)
# 	 chainA: 1-517 (1.000)
# 	 chainB: 1423-1427 (1.000)
# LIG_CAP-Gly_1_Mmin_D1_D815 (known_extension)
# 	 chainA: 1-815 (1.000)
# 	 chainB: 1423-1427 (1.000)
# LIG_CAP-Gly_1_Mmin_DFL (known_extension)
# 	 chainA: 1-1278 (1.000)
# 	 chainB: 1423-1427 (1.000)
# LIG_CAP-Gly_2_M120_M581_D1_D204 (known_extension)
# 	 chainA: 1-204 (1.000)
# 	 chainB: 120-581 (1.000)
# LIG_CAP-Gly_2_M120_M581_D1_D288 (known_extension)
# 	 chainA: 1-288 (1.000)
# 	 chainB: 120-581 (1.000)
# LIG_CAP-Gly_2_M120_M581_Dmin (known_extension)
# 	 chainA: 81-122 (0.889)
# 	 chainB: 120-581 (1.000)
# LIG_CAP-Gly_2_M533_M581_D1_D204 (known_extension)
# 	 chainA: 1-204 (1.000)
# 	 chainB: 533-581 (1.000)
# LIG_CAP-Gly_2_M533_M581_D1_D288 (known_extension)
# 	 chainA: 1-288 (1.000)
# 	 chainB: 533-581 (1.000)
# LIG_CAP-Gly_2_M533_M581_Dmin (known_extension)
# 	 chainA: 81-122 (0.889)
# 	 chainB: 533-581 (1.000)
# LIG_CAP-Gly_2_M547_M581_D1_D204 (known_extension)
# 	 chainA: 1-204 (1.000)
# 	 chainB: 547-581 (1.000)
# LIG_CAP-Gly_2_M547_M581_D1_D288 (known_extension)
# 	 chainA: 1-288 (1.000)
# 	 chainB: 547-581 (1.000)
# LIG_CAP-Gly_2_M547_M581_Dmin (known_extension)
# 	 chainA: 81-122 (0.889)
# 	 chainB: 547-581 (1.000)
# LIG_CAP-Gly_2_M561_M581_D1_D204 (known_extension)
# 	 chainA: 1-204 (1.000)
# 	 chainB: 561-581 (1.000)
# LIG_CAP-Gly_2_M561_M581_D1_D288 (known_extension)
# 	 chainA: 1-288 (1.000)
# 	 chainB: 561-581 (1.000)
# LIG_CAP-Gly_2_M561_M581_Dmin (known_extension)
# 	 chainA: 81-122 (0.889)
# 	 chainB: 561-581 (1.000)
# LIG_CAP-Gly_2_M568_M581_D1_D204 (known_extension)
# 	 chainA: 1-204 (1.000)
# 	 chainB: 568-581 (1.000)
# LIG_CAP-Gly_2_M568_M581_D1_D288 (known_extension)
# 	 chainA: 1-288 (1.000)
# 	 chainB: 568-581 (1.000)
# LIG_CAP-Gly_2_M568_M581_Dmin (known_extension)
# 	 chainA: 81-122 (0.889)
# 	 chainB: 568-581 (1.000)
# LIG_CAP-Gly_2_MFL_Dmin (known_extension)
# 	 chainA: 81-122 (0.889)
# 	 chainB: 1-581 (1.000)
# LIG_CAP-Gly_2_Mmin_D1_D204 (known_extension)
# 	 chainA: 1-204 (1.000)
# 	 chainB: 575-581 (1.000)
# LIG_CAP-Gly_2_Mmin_D1_D288 (known_extension)
# 	 chainA: 1-288 (1.000)
# 	 chainB: 575-581 (1.000)
# LIG_CAP-Gly_2_Mmin_DFL (known_extension)
# 	 chainA: 1-1438 (1.000)
# 	 chainB: 575-581 (1.000)
# LIG_CNOT1_NIM_1_M1_M109_D1377_D2376 (known_extension)
# 	 chainA: 1377-2376 (0.998)
# 	 chainB: 1-109 (1.000)
# LIG_CNOT1_NIM_1_M1_M109_D1544_D2376 (known_extension)
# 	 chainA: 1544-2376 (0.998)
# 	 chainB: 1-109 (1.000)
# LIG_CNOT1_NIM_1_M1_M109_Dmin (known_extension)
# 	 chainA: 1930-2361 (0.986)
# 	 chainB: 1-109 (1.000)
# LIG_CNOT1_NIM_1_M1_M276_D1377_D2376 (known_extension)
# 	 chainA: 1377-2376 (0.998)
# 	 chainB: 1-276 (1.000)
# LIG_CNOT1_NIM_1_M1_M276_D1544_D2376 (known_extension)
# 	 chainA: 1544-2376 (0.998)
# 	 chainB: 1-276 (1.000)
# LIG_CNOT1_NIM_1_M1_M276_Dmin (known_extension)
# 	 chainA: 1930-2361 (0.986)
# 	 chainB: 1-276 (1.000)
# LIG_CNOT1_NIM_1_M1_M89_D1377_D2376 (known_extension)
# 	 chainA: 1377-2376 (0.998)
# 	 chainB: 1-89 (1.000)
# LIG_CNOT1_NIM_1_M1_M89_D1544_D2376 (known_extension)
# 	 chainA: 1544-2376 (0.998)
# 	 chainB: 1-89 (1.000)
# LIG_CNOT1_NIM_1_M1_M89_Dmin (known_extension)
# 	 chainA: 1930-2361 (0.986)
# 	 chainB: 1-89 (1.000)
# LIG_CNOT1_NIM_1_M20_M69_D1377_D2376 (known_extension)
# 	 chainA: 1377-2376 (0.998)
# 	 chainB: 20-69 (1.000)
# LIG_CNOT1_NIM_1_M20_M69_D1544_D2376 (known_extension)
# 	 chainA: 1544-2376 (0.998)
# 	 chainB: 20-69 (1.000)
# LIG_CNOT1_NIM_1_M20_M69_Dmin (known_extension)
# 	 chainA: 1930-2361 (0.986)
# 	 chainB: 20-69 (1.000)
# LIG_CNOT1_NIM_1_M30_M59_D1377_D2376 (known_extension)
# 	 chainA: 1377-2376 (0.998)
# 	 chainB: 30-59 (1.000)
# LIG_CNOT1_NIM_1_M30_M59_D1544_D2376 (known_extension)
# 	 chainA: 1544-2376 (0.998)
# 	 chainB: 30-59 (1.000)
# LIG_CNOT1_NIM_1_M30_M59_Dmin (known_extension)
# 	 chainA: 1930-2361 (0.986)
# 	 chainB: 30-59 (1.000)
# LIG_CNOT1_NIM_1_MFL_Dmin (known_extension)
# 	 chainA: 1930-2361 (0.986)
# 	 chainB: 1-292 (1.000)
# LIG_CNOT1_NIM_1_Mmin_D1377_D2376 (known_extension)
# 	 chainA: 1377-2376 (0.998)
# 	 chainB: 40-49 (1.000)
# LIG_CNOT1_NIM_1_Mmin_D1544_D2376 (known_extension)
# 	 chainA: 1544-2376 (0.998)
# 	 chainB: 40-49 (1.000)
# LIG_CNOT1_NIM_1_Mmin_DFL (known_extension)
# 	 chainA: 1-2376 (0.998)
# 	 chainB: 40-49 (1.000)
# LIG_EF_ALG2_ABM_1_M403_M868_D1_D191 (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: -395-70 (1.000)
# LIG_EF_ALG2_ABM_1_M403_M868_Dmin (known_extension)
# 	 chainA: 29-191 (0.970)
# 	 chainB: -395-70 (1.000)
# LIG_EF_ALG2_ABM_1_M748_M864_D1_D191 (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: -50-66 (1.000)
# LIG_EF_ALG2_ABM_1_M748_M864_Dmin (known_extension)
# 	 chainA: 29-191 (0.970)
# 	 chainB: -50-66 (1.000)
# LIG_EF_ALG2_ABM_1_M766_M846_D1_D191 (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: -32-48 (1.000)
# LIG_EF_ALG2_ABM_1_M766_M846_Dmin (known_extension)
# 	 chainA: 29-191 (0.970)
# 	 chainB: -32-48 (1.000)
# LIG_EF_ALG2_ABM_1_M784_M828_D1_D191 (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: -14-30 (1.000)
# LIG_EF_ALG2_ABM_1_M784_M828_Dmin (known_extension)
# 	 chainA: 29-191 (0.970)
# 	 chainB: -14-30 (1.000)
# LIG_EF_ALG2_ABM_1_M793_M819_D1_D191 (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: -5-21 (1.000)
# LIG_EF_ALG2_ABM_1_M793_M819_Dmin (known_extension)
# 	 chainA: 29-191 (0.970)
# 	 chainB: -5-21 (1.000)
# LIG_EF_ALG2_ABM_1_MFL_Dmin (known_extension)
# 	 chainA: 29-191 (0.970)
# 	 chainB: -797-70 (1.000)
# LIG_EF_ALG2_ABM_1_Mmin_D1_D191 (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: 4-12 (1.000)
# LIG_EF_ALG2_ABM_1_Mmin_DFL (known_extension)
# 	 chainA: 1-191 (1.000)
# 	 chainB: 4-12 (1.000)
# LIG_GYF_M125_M351_D1_D341 (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: -106-120 (1.000)
# LIG_GYF_M125_M351_Dmin (known_extension)
# 	 chainA: 6-62 (0.917)
# 	 chainB: -106-120 (1.000)
# LIG_GYF_M241_M351_D1_D341 (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: 10-120 (1.000)
# LIG_GYF_M241_M351_Dmin (known_extension)
# 	 chainA: 6-62 (0.917)
# 	 chainB: 10-120 (1.000)
# LIG_GYF_M259_M339_D1_D341 (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: 28-108 (1.000)
# LIG_GYF_M259_M339_Dmin (known_extension)
# 	 chainA: 6-62 (0.917)
# 	 chainB: 28-108 (1.000)
# LIG_GYF_M277_M321_D1_D341 (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: 46-90 (1.000)
# LIG_GYF_M277_M321_Dmin (known_extension)
# 	 chainA: 6-62 (0.917)
# 	 chainB: 46-90 (1.000)
# LIG_GYF_M286_M312_D1_D341 (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: 55-81 (1.000)
# LIG_GYF_M286_M312_Dmin (known_extension)
# 	 chainA: 6-62 (0.917)
# 	 chainB: 55-81 (1.000)
# LIG_GYF_MFL_Dmin (known_extension)
# 	 chainA: 6-62 (0.917)
# 	 chainB: -230-120 (1.000)
# LIG_GYF_Mmin_D1_D341 (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: 64-72 (1.000)
# LIG_GYF_Mmin_DFL (known_extension)
# 	 chainA: -278-62 (1.000)
# 	 chainB: 64-72 (1.000)
# LIG_HOMEOBOX_M156_M207_D242_D430 (known_extension)
# 	 chainA: 242-430 (0.901)
# 	 chainB: 156-207 (1.000)
# LIG_HOMEOBOX_M156_M207_D30_D430 (known_extension)
# 	 chainA: 30-430 (1.000)
# 	 chainB: 156-207 (1.000)
# LIG_HOMEOBOX_M156_M207_Dmin (known_extension)
# 	 chainA: 240-307 (0.930)
# 	 chainB: 156-207 (1.000)
# LIG_HOMEOBOX_M164_M199_D242_D430 (known_extension)
# 	 chainA: 242-430 (0.901)
# 	 chainB: 164-199 (1.000)
# LIG_HOMEOBOX_M164_M199_D30_D430 (known_extension)
# 	 chainA: 30-430 (1.000)
# 	 chainB: 164-199 (1.000)
# LIG_HOMEOBOX_M164_M199_Dmin (known_extension)
# 	 chainA: 240-307 (0.930)
# 	 chainB: 164-199 (1.000)
# LIG_HOMEOBOX_M172_M191_D242_D430 (known_extension)
# 	 chainA: 242-430 (0.901)
# 	 chainB: 172-191 (1.000)
# LIG_HOMEOBOX_M172_M191_D30_D430 (known_extension)
# 	 chainA: 30-430 (1.000)
# 	 chainB: 172-191 (1.000)
# LIG_HOMEOBOX_M172_M191_Dmin (known_extension)
# 	 chainA: 240-307 (0.930)
# 	 chainB: 172-191 (1.000)
# LIG_HOMEOBOX_M176_M187_D242_D430 (known_extension)
# 	 chainA: 242-430 (0.901)
# 	 chainB: 176-187 (1.000)
# LIG_HOMEOBOX_M176_M187_D30_D430 (known_extension)
# 	 chainA: 30-430 (1.000)
# 	 chainB: 176-187 (1.000)
# LIG_HOMEOBOX_M176_M187_Dmin (known_extension)
# 	 chainA: 240-307 (0.930)
# 	 chainB: 176-187 (1.000)
# LIG_HOMEOBOX_M1_M270_D242_D430 (known_extension)
# 	 chainA: 242-430 (0.901)
# 	 chainB: 1-270 (1.000)
# LIG_HOMEOBOX_M1_M270_D30_D430 (known_extension)
# 	 chainA: 30-430 (1.000)
# 	 chainB: 1-270 (1.000)
# LIG_HOMEOBOX_M1_M270_Dmin (known_extension)
# 	 chainA: 240-307 (0.930)
# 	 chainB: 1-270 (1.000)
# LIG_HOMEOBOX_MFL_Dmin (known_extension)
# 	 chainA: 240-307 (0.930)
# 	 chainB: 1-301 (1.000)
# LIG_HOMEOBOX_Mmin_D242_D430 (known_extension)
# 	 chainA: 242-430 (0.901)
# 	 chainB: 180-183 (1.000)
# LIG_HOMEOBOX_Mmin_D30_D430 (known_extension)
# 	 chainA: 30-430 (1.000)
# 	 chainB: 180-183 (1.000)
# LIG_HOMEOBOX_Mmin_DFL (known_extension)
# 	 chainA: 1-430 (1.000)
# 	 chainB: 180-183 (1.000)
# LIG_LIR_Gen_1_M369_M966_D1_D117 (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 369-966 (1.000)
# LIG_LIR_Gen_1_M369_M966_Dmin (known_extension)
# 	 chainA: 6-115 (0.956)
# 	 chainB: 369-966 (1.000)
# LIG_LIR_Gen_1_M664_M806_D1_D117 (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 664-806 (1.000)
# LIG_LIR_Gen_1_M664_M806_Dmin (known_extension)
# 	 chainA: 6-115 (0.956)
# 	 chainB: 664-806 (1.000)
# LIG_LIR_Gen_1_M686_M784_D1_D117 (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 686-784 (1.000)
# LIG_LIR_Gen_1_M686_M784_Dmin (known_extension)
# 	 chainA: 6-115 (0.956)
# 	 chainB: 686-784 (1.000)
# LIG_LIR_Gen_1_M708_M762_D1_D117 (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 708-762 (1.000)
# LIG_LIR_Gen_1_M708_M762_Dmin (known_extension)
# 	 chainA: 6-115 (0.956)
# 	 chainB: 708-762 (1.000)
# LIG_LIR_Gen_1_M719_M751_D1_D117 (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 719-751 (1.000)
# LIG_LIR_Gen_1_M719_M751_Dmin (known_extension)
# 	 chainA: 6-115 (0.956)
# 	 chainB: 719-751 (1.000)
# LIG_LIR_Gen_1_MFL_Dmin (known_extension)
# 	 chainA: 6-115 (0.956)
# 	 chainB: 1-966 (1.000)
# LIG_LIR_Gen_1_Mmin_D1_D117 (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 730-740 (1.000)
# LIG_LIR_Gen_1_Mmin_DFL (known_extension)
# 	 chainA: 1-117 (0.991)
# 	 chainB: 730-740 (1.000)
# LIG_LRP6_Inhibitor_1_M1_M149_D1_D362 (known_extension)
# 	 chainA: 1-362 (1.000)
# 	 chainB: 1-149 (1.000)
# LIG_LRP6_Inhibitor_1_M1_M149_D1_D422 (known_extension)
# 	 chainA: 1-422 (1.000)
# 	 chainB: 1-149 (1.000)
# LIG_LRP6_Inhibitor_1_M1_M149_Dmin (known_extension)
# 	 chainA: 25-324 (0.983)
# 	 chainB: 1-149 (1.000)
# LIG_LRP6_Inhibitor_1_M1_M85_D1_D362 (known_extension)
# 	 chainA: 1-362 (1.000)
# 	 chainB: 1-85 (1.000)
# LIG_LRP6_Inhibitor_1_M1_M85_D1_D422 (known_extension)
# 	 chainA: 1-422 (1.000)
# 	 chainB: 1-85 (1.000)
# LIG_LRP6_Inhibitor_1_M1_M85_Dmin (known_extension)
# 	 chainA: 25-324 (0.983)
# 	 chainB: 1-85 (1.000)
# LIG_LRP6_Inhibitor_1_M23_M57_D1_D362 (known_extension)
# 	 chainA: 1-362 (1.000)
# 	 chainB: 23-57 (1.000)
# LIG_LRP6_Inhibitor_1_M23_M57_D1_D422 (known_extension)
# 	 chainA: 1-422 (1.000)
# 	 chainB: 23-57 (1.000)
# LIG_LRP6_Inhibitor_1_M23_M57_Dmin (known_extension)
# 	 chainA: 25-324 (0.983)
# 	 chainB: 23-57 (1.000)
# LIG_LRP6_Inhibitor_1_M30_M50_D1_D362 (known_extension)
# 	 chainA: 1-362 (1.000)
# 	 chainB: 30-50 (1.000)
# LIG_LRP6_Inhibitor_1_M30_M50_D1_D422 (known_extension)
# 	 chainA: 1-422 (1.000)
# 	 chainB: 30-50 (1.000)
# LIG_LRP6_Inhibitor_1_M30_M50_Dmin (known_extension)
# 	 chainA: 25-324 (0.983)
# 	 chainB: 30-50 (1.000)
# LIG_LRP6_Inhibitor_1_M9_M71_D1_D362 (known_extension)
# 	 chainA: 1-362 (1.000)
# 	 chainB: 9-71 (1.000)
# LIG_LRP6_Inhibitor_1_M9_M71_D1_D422 (known_extension)
# 	 chainA: 1-422 (1.000)
# 	 chainB: 9-71 (1.000)
# LIG_LRP6_Inhibitor_1_M9_M71_Dmin (known_extension)
# 	 chainA: 25-324 (0.983)
# 	 chainB: 9-71 (1.000)
# LIG_LRP6_Inhibitor_1_MFL_Dmin (known_extension)
# 	 chainA: 25-324 (0.983)
# 	 chainB: 1-266 (1.000)
# LIG_LRP6_Inhibitor_1_Mmin_D1_D362 (known_extension)
# 	 chainA: 1-362 (1.000)
# 	 chainB: 37-43 (1.000)
# LIG_LRP6_Inhibitor_1_Mmin_D1_D422 (known_extension)
# 	 chainA: 1-422 (1.000)
# 	 chainB: 37-43 (1.000)
# LIG_LRP6_Inhibitor_1_Mmin_DFL (known_extension)
# 	 chainA: 1-1613 (1.000)
# 	 chainB: 37-43 (1.000)
# LIG_NBox_RRM_1_M1_M102_D1_D559 (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 1-102 (1.000)
# LIG_NBox_RRM_1_M1_M102_Dmin (known_extension)
# 	 chainA: 107-297 (0.974)
# 	 chainB: 1-102 (1.000)
# LIG_NBox_RRM_1_M1_M175_D1_D559 (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 1-175 (1.000)
# LIG_NBox_RRM_1_M1_M175_Dmin (known_extension)
# 	 chainA: 107-297 (0.974)
# 	 chainB: 1-175 (1.000)
# LIG_NBox_RRM_1_M1_M85_D1_D559 (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 1-85 (1.000)
# LIG_NBox_RRM_1_M1_M85_Dmin (known_extension)
# 	 chainA: 107-297 (0.974)
# 	 chainB: 1-85 (1.000)
# LIG_NBox_RRM_1_M20_M52_D1_D559 (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 20-52 (1.000)
# LIG_NBox_RRM_1_M20_M52_Dmin (known_extension)
# 	 chainA: 107-297 (0.974)
# 	 chainB: 20-52 (1.000)
# LIG_NBox_RRM_1_M9_M63_D1_D559 (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 9-63 (1.000)
# LIG_NBox_RRM_1_M9_M63_Dmin (known_extension)
# 	 chainA: 107-297 (0.974)
# 	 chainB: 9-63 (1.000)
# LIG_NBox_RRM_1_MFL_Dmin (known_extension)
# 	 chainA: 107-297 (0.974)
# 	 chainB: 1-644 (1.000)
# LIG_NBox_RRM_1_Mmin_D1_D559 (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 31-41 (1.000)
# LIG_NBox_RRM_1_Mmin_DFL (known_extension)
# 	 chainA: -16-542 (1.000)
# 	 chainB: 31-41 (1.000)
# LIG_NRBOX_M453_M826_D174_D595 (known_extension)
# 	 chainA: 174-595 (1.000)
# 	 chainB: 453-826 (1.000)
# LIG_NRBOX_M453_M826_D262_D542 (known_extension)
# 	 chainA: 262-542 (0.976)
# 	 chainB: 453-826 (1.000)
# LIG_NRBOX_M453_M826_Dmin (known_extension)
# 	 chainA: 342-548 (0.976)
# 	 chainB: 453-826 (1.000)
# LIG_NRBOX_M647_M737_D174_D595 (known_extension)
# 	 chainA: 174-595 (1.000)
# 	 chainB: 647-737 (1.000)
# LIG_NRBOX_M647_M737_D262_D542 (known_extension)
# 	 chainA: 262-542 (0.976)
# 	 chainB: 647-737 (1.000)
# LIG_NRBOX_M647_M737_Dmin (known_extension)
# 	 chainA: 342-548 (0.976)
# 	 chainB: 647-737 (1.000)
# LIG_NRBOX_M661_M723_D174_D595 (known_extension)
# 	 chainA: 174-595 (1.000)
# 	 chainB: 661-723 (1.000)
# LIG_NRBOX_M661_M723_D262_D542 (known_extension)
# 	 chainA: 262-542 (0.976)
# 	 chainB: 661-723 (1.000)
# LIG_NRBOX_M661_M723_Dmin (known_extension)
# 	 chainA: 342-548 (0.976)
# 	 chainB: 661-723 (1.000)
# LIG_NRBOX_M675_M709_D174_D595 (known_extension)
# 	 chainA: 174-595 (1.000)
# 	 chainB: 675-709 (1.000)
# LIG_NRBOX_M675_M709_D262_D542 (known_extension)
# 	 chainA: 262-542 (0.976)
# 	 chainB: 675-709 (1.000)
# LIG_NRBOX_M675_M709_Dmin (known_extension)
# 	 chainA: 342-548 (0.976)
# 	 chainB: 675-709 (1.000)
# LIG_NRBOX_M682_M702_D174_D595 (known_extension)
# 	 chainA: 174-595 (1.000)
# 	 chainB: 682-702 (1.000)
# LIG_NRBOX_M682_M702_D262_D542 (known_extension)
# 	 chainA: 262-542 (0.976)
# 	 chainB: 682-702 (1.000)
# LIG_NRBOX_M682_M702_Dmin (known_extension)
# 	 chainA: 342-548 (0.976)
# 	 chainB: 682-702 (1.000)
# LIG_NRBOX_MFL_Dmin (known_extension)
# 	 chainA: 342-548 (0.976)
# 	 chainB: 1-1464 (1.000)
# LIG_NRBOX_Mmin_D174_D595 (known_extension)
# 	 chainA: 174-595 (1.000)
# 	 chainB: 689-695 (1.000)
# LIG_NRBOX_Mmin_D262_D542 (known_extension)
# 	 chainA: 262-542 (0.976)
# 	 chainB: 689-695 (1.000)
# LIG_NRBOX_Mmin_DFL (known_extension)
# 	 chainA: 1-595 (1.000)
# 	 chainB: 689-695 (1.000)
# LIG_OCRL_FandH_1_M12_M249_D235_D901 (known_extension)
# 	 chainA: 235-901 (0.993)
# 	 chainB: -210-27 (1.000)
# LIG_OCRL_FandH_1_M12_M249_D534_D901 (known_extension)
# 	 chainA: 534-901 (0.993)
# 	 chainB: -210-27 (1.000)
# LIG_OCRL_FandH_1_M12_M249_Dmin (known_extension)
# 	 chainA: 563-896 (0.993)
# 	 chainB: -210-27 (1.000)
# LIG_OCRL_FandH_1_M145_M249_D235_D901 (known_extension)
# 	 chainA: 235-901 (0.993)
# 	 chainB: -77-27 (1.000)
# LIG_OCRL_FandH_1_M145_M249_D534_D901 (known_extension)
# 	 chainA: 534-901 (0.993)
# 	 chainB: -77-27 (1.000)
# LIG_OCRL_FandH_1_M145_M249_Dmin (known_extension)
# 	 chainA: 563-896 (0.993)
# 	 chainB: -77-27 (1.000)
# LIG_OCRL_FandH_1_M171_M249_D235_D901 (known_extension)
# 	 chainA: 235-901 (0.993)
# 	 chainB: -51-27 (1.000)
# LIG_OCRL_FandH_1_M171_M249_D534_D901 (known_extension)
# 	 chainA: 534-901 (0.993)
# 	 chainB: -51-27 (1.000)
# LIG_OCRL_FandH_1_M171_M249_Dmin (known_extension)
# 	 chainA: 563-896 (0.993)
# 	 chainB: -51-27 (1.000)
# LIG_OCRL_FandH_1_M197_M249_D235_D901 (known_extension)
# 	 chainA: 235-901 (0.993)
# 	 chainB: -25-27 (1.000)
# LIG_OCRL_FandH_1_M197_M249_D534_D901 (known_extension)
# 	 chainA: 534-901 (0.993)
# 	 chainB: -25-27 (1.000)
# LIG_OCRL_FandH_1_M197_M249_Dmin (known_extension)
# 	 chainA: 563-896 (0.993)
# 	 chainB: -25-27 (1.000)
# LIG_OCRL_FandH_1_M210_M248_D235_D901 (known_extension)
# 	 chainA: 235-901 (0.993)
# 	 chainB: -12-26 (1.000)
# LIG_OCRL_FandH_1_M210_M248_D534_D901 (known_extension)
# 	 chainA: 534-901 (0.993)
# 	 chainB: -12-26 (1.000)
# LIG_OCRL_FandH_1_M210_M248_Dmin (known_extension)
# 	 chainA: 563-896 (0.993)
# 	 chainB: -12-26 (1.000)
# LIG_OCRL_FandH_1_MFL_Dmin (known_extension)
# 	 chainA: 563-896 (0.993)
# 	 chainB: -221-27 (1.000)
# LIG_OCRL_FandH_1_Mmin_D235_D901 (known_extension)
# 	 chainA: 235-901 (0.993)
# 	 chainB: 1-13 (1.000)
# LIG_OCRL_FandH_1_Mmin_D534_D901 (known_extension)
# 	 chainA: 534-901 (0.993)
# 	 chainB: 1-13 (1.000)
# LIG_OCRL_FandH_1_Mmin_DFL (known_extension)
# 	 chainA: 1-901 (0.997)
# 	 chainB: 1-13 (1.000)
# LIG_PAM2_1_M1_M127_D286_D636 (known_extension)
# 	 chainA: -252-98 (1.000)
# 	 chainB: -104-22 (1.000)
# LIG_PAM2_1_M1_M127_D373_D636 (known_extension)
# 	 chainA: -165-98 (1.000)
# 	 chainB: -104-22 (1.000)
# LIG_PAM2_1_M1_M127_Dmin (known_extension)
# 	 chainA: 11-78 (0.930)
# 	 chainB: -104-22 (1.000)
# LIG_PAM2_1_M31_M127_D286_D636 (known_extension)
# 	 chainA: -252-98 (1.000)
# 	 chainB: -74-22 (1.000)
# LIG_PAM2_1_M31_M127_D373_D636 (known_extension)
# 	 chainA: -165-98 (1.000)
# 	 chainB: -74-22 (1.000)
# LIG_PAM2_1_M31_M127_Dmin (known_extension)
# 	 chainA: 11-78 (0.930)
# 	 chainB: -74-22 (1.000)
# LIG_PAM2_1_M57_M127_D286_D636 (known_extension)
# 	 chainA: -252-98 (1.000)
# 	 chainB: -48-22 (1.000)
# LIG_PAM2_1_M57_M127_D373_D636 (known_extension)
# 	 chainA: -165-98 (1.000)
# 	 chainB: -48-22 (1.000)
# LIG_PAM2_1_M57_M127_Dmin (known_extension)
# 	 chainA: 11-78 (0.930)
# 	 chainB: -48-22 (1.000)
# LIG_PAM2_1_M83_M127_D286_D636 (known_extension)
# 	 chainA: -252-98 (1.000)
# 	 chainB: -22-22 (1.000)
# LIG_PAM2_1_M83_M127_D373_D636 (known_extension)
# 	 chainA: -165-98 (1.000)
# 	 chainB: -22-22 (1.000)
# LIG_PAM2_1_M83_M127_Dmin (known_extension)
# 	 chainA: 11-78 (0.930)
# 	 chainB: -22-22 (1.000)
# LIG_PAM2_1_M96_M127_D286_D636 (known_extension)
# 	 chainA: -252-98 (1.000)
# 	 chainB: -9-22 (1.000)
# LIG_PAM2_1_M96_M127_D373_D636 (known_extension)
# 	 chainA: -165-98 (1.000)
# 	 chainB: -9-22 (1.000)
# LIG_PAM2_1_M96_M127_Dmin (known_extension)
# 	 chainA: 11-78 (0.930)
# 	 chainB: -9-22 (1.000)
# LIG_PAM2_1_MFL_Dmin (known_extension)
# 	 chainA: 11-78 (0.930)
# 	 chainB: -104-22 (1.000)
# LIG_PAM2_1_Mmin_D286_D636 (known_extension)
# 	 chainA: -252-98 (1.000)
# 	 chainB: 4-16 (1.000)
# LIG_PAM2_1_Mmin_D373_D636 (known_extension)
# 	 chainA: -165-98 (1.000)
# 	 chainB: 4-16 (1.000)
# LIG_PAM2_1_Mmin_DFL (known_extension)
# 	 chainA: -537-98 (1.000)
# 	 chainB: 4-16 (1.000)
# LIG_PAM2_2_M1248_M1522_D286_D636 (known_extension)
# 	 chainA: 286-636 (0.933)
# 	 chainB: 1248-1522 (1.000)
# LIG_PAM2_2_M1248_M1522_D373_D636 (known_extension)
# 	 chainA: 373-636 (0.933)
# 	 chainB: 1248-1522 (1.000)
# LIG_PAM2_2_M1248_M1522_Dmin (known_extension)
# 	 chainA: 545-616 (0.933)
# 	 chainB: 1248-1522 (1.000)
# LIG_PAM2_2_M1301_M1482_D286_D636 (known_extension)
# 	 chainA: 286-636 (0.933)
# 	 chainB: 1301-1482 (1.000)
# LIG_PAM2_2_M1301_M1482_D373_D636 (known_extension)
# 	 chainA: 373-636 (0.933)
# 	 chainB: 1301-1482 (1.000)
# LIG_PAM2_2_M1301_M1482_Dmin (known_extension)
# 	 chainA: 545-616 (0.933)
# 	 chainB: 1301-1482 (1.000)
# LIG_PAM2_2_M1329_M1454_D286_D636 (known_extension)
# 	 chainA: 286-636 (0.933)
# 	 chainB: 1329-1454 (1.000)
# LIG_PAM2_2_M1329_M1454_D373_D636 (known_extension)
# 	 chainA: 373-636 (0.933)
# 	 chainB: 1329-1454 (1.000)
# LIG_PAM2_2_M1329_M1454_Dmin (known_extension)
# 	 chainA: 545-616 (0.933)
# 	 chainB: 1329-1454 (1.000)
# LIG_PAM2_2_M1357_M1426_D286_D636 (known_extension)
# 	 chainA: 286-636 (0.933)
# 	 chainB: 1357-1426 (1.000)
# LIG_PAM2_2_M1357_M1426_D373_D636 (known_extension)
# 	 chainA: 373-636 (0.933)
# 	 chainB: 1357-1426 (1.000)
# LIG_PAM2_2_M1357_M1426_Dmin (known_extension)
# 	 chainA: 545-616 (0.933)
# 	 chainB: 1357-1426 (1.000)
# LIG_PAM2_2_M1371_M1412_D286_D636 (known_extension)
# 	 chainA: 286-636 (0.933)
# 	 chainB: 1371-1412 (1.000)
# LIG_PAM2_2_M1371_M1412_D373_D636 (known_extension)
# 	 chainA: 373-636 (0.933)
# 	 chainB: 1371-1412 (1.000)
# LIG_PAM2_2_M1371_M1412_Dmin (known_extension)
# 	 chainA: 545-616 (0.933)
# 	 chainB: 1371-1412 (1.000)
# LIG_PAM2_2_MFL_Dmin (known_extension)
# 	 chainA: 545-616 (0.933)
# 	 chainB: 1-1690 (1.000)
# LIG_PAM2_2_Mmin_D286_D636 (known_extension)
# 	 chainA: 286-636 (0.933)
# 	 chainB: 1385-1398 (1.000)
# LIG_PAM2_2_Mmin_D373_D636 (known_extension)
# 	 chainA: 373-636 (0.933)
# 	 chainB: 1385-1398 (1.000)
# LIG_PAM2_2_Mmin_DFL (known_extension)
# 	 chainA: 1-636 (0.933)
# 	 chainB: 1385-1398 (1.000)
# LIG_PCNA_PIPBox_1_M104_M164_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 104-164 (1.000)
# LIG_PCNA_PIPBox_1_M104_M164_Dmin (known_extension)
# 	 chainA: 6-255 (0.976)
# 	 chainB: 104-164 (1.000)
# LIG_PCNA_PIPBox_1_M11_M164_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 11-164 (1.000)
# LIG_PCNA_PIPBox_1_M11_M164_Dmin (known_extension)
# 	 chainA: 6-255 (0.976)
# 	 chainB: 11-164 (1.000)
# LIG_PCNA_PIPBox_1_M124_M164_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 124-164 (1.000)
# LIG_PCNA_PIPBox_1_M124_M164_Dmin (known_extension)
# 	 chainA: 6-255 (0.976)
# 	 chainB: 124-164 (1.000)
# LIG_PCNA_PIPBox_1_M134_M163_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 134-163 (1.000)
# LIG_PCNA_PIPBox_1_M134_M163_Dmin (known_extension)
# 	 chainA: 6-255 (0.976)
# 	 chainB: 134-163 (1.000)
# LIG_PCNA_PIPBox_1_M84_M164_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 84-164 (1.000)
# LIG_PCNA_PIPBox_1_M84_M164_Dmin (known_extension)
# 	 chainA: 6-255 (0.976)
# 	 chainB: 84-164 (1.000)
# LIG_PCNA_PIPBox_1_MFL_Dmin (known_extension)
# 	 chainA: 6-255 (0.976)
# 	 chainB: 1-164 (1.000)
# LIG_PCNA_PIPBox_1_Mmin_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 144-153 (1.000)
# LIG_PCNA_PIPBox_1_Mmin_DFL (known_extension)
# 	 chainA: 1-261 (0.992)
# 	 chainB: 144-153 (1.000)
# LIG_PCNA_TLS_4_M401_M870_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 401-870 (1.000)
# LIG_PCNA_TLS_4_M401_M870_Dmin (known_extension)
# 	 chainA: 6-255 (0.967)
# 	 chainB: 401-870 (1.000)
# LIG_PCNA_TLS_4_M814_M870_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 814-870 (1.000)
# LIG_PCNA_TLS_4_M814_M870_Dmin (known_extension)
# 	 chainA: 6-255 (0.967)
# 	 chainB: 814-870 (1.000)
# LIG_PCNA_TLS_4_M830_M870_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 830-870 (1.000)
# LIG_PCNA_TLS_4_M830_M870_Dmin (known_extension)
# 	 chainA: 6-255 (0.967)
# 	 chainB: 830-870 (1.000)
# LIG_PCNA_TLS_4_M846_M870_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 846-870 (1.000)
# LIG_PCNA_TLS_4_M846_M870_Dmin (known_extension)
# 	 chainA: 6-255 (0.967)
# 	 chainB: 846-870 (1.000)
# LIG_PCNA_TLS_4_M854_M870_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 854-870 (1.000)
# LIG_PCNA_TLS_4_M854_M870_Dmin (known_extension)
# 	 chainA: 6-255 (0.967)
# 	 chainB: 854-870 (1.000)
# LIG_PCNA_TLS_4_MFL_Dmin (known_extension)
# 	 chainA: 6-255 (0.967)
# 	 chainB: 1-870 (1.000)
# LIG_PCNA_TLS_4_Mmin_D1_D261 (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 862-869 (1.000)
# LIG_PCNA_TLS_4_Mmin_DFL (known_extension)
# 	 chainA: 1-261 (0.984)
# 	 chainB: 862-869 (1.000)
# LIG_PDZ_Class_1_M1560_M1601_D1084_D1593 (known_extension)
# 	 chainA: -276-233 (1.000)
# 	 chainB: -26-15 (1.000)
# LIG_PDZ_Class_1_M1560_M1601_D1185_D1492 (known_extension)
# 	 chainA: -175-132 (1.000)
# 	 chainB: -26-15 (1.000)
# LIG_PDZ_Class_1_M1560_M1601_Dmin (known_extension)
# 	 chainA: 6-96 (0.947)
# 	 chainB: -26-15 (1.000)
# LIG_PDZ_Class_1_M1572_M1601_D1084_D1593 (known_extension)
# 	 chainA: -276-233 (1.000)
# 	 chainB: -14-15 (1.000)
# LIG_PDZ_Class_1_M1572_M1601_D1185_D1492 (known_extension)
# 	 chainA: -175-132 (1.000)
# 	 chainB: -14-15 (1.000)
# LIG_PDZ_Class_1_M1572_M1601_Dmin (known_extension)
# 	 chainA: 6-96 (0.947)
# 	 chainB: -14-15 (1.000)
# LIG_PDZ_Class_1_M1584_M1601_D1084_D1593 (known_extension)
# 	 chainA: -276-233 (1.000)
# 	 chainB: -2-15 (1.000)
# LIG_PDZ_Class_1_M1584_M1601_D1185_D1492 (known_extension)
# 	 chainA: -175-132 (1.000)
# 	 chainB: -2-15 (1.000)
# LIG_PDZ_Class_1_M1584_M1601_Dmin (known_extension)
# 	 chainA: 6-96 (0.947)
# 	 chainB: -2-15 (1.000)
# LIG_PDZ_Class_1_M1590_M1601_D1084_D1593 (known_extension)
# 	 chainA: -276-233 (1.000)
# 	 chainB: 4-15 (1.000)
# LIG_PDZ_Class_1_M1590_M1601_D1185_D1492 (known_extension)
# 	 chainA: -175-132 (1.000)
# 	 chainB: 4-15 (1.000)
# LIG_PDZ_Class_1_M1590_M1601_Dmin (known_extension)
# 	 chainA: 6-96 (0.947)
# 	 chainB: 4-15 (1.000)
# LIG_PDZ_Class_1_M853_M1601_D1084_D1593 (known_extension)
# 	 chainA: -276-233 (1.000)
# 	 chainB: -733-15 (1.000)
# LIG_PDZ_Class_1_M853_M1601_D1185_D1492 (known_extension)
# 	 chainA: -175-132 (1.000)
# 	 chainB: -733-15 (1.000)
# LIG_PDZ_Class_1_M853_M1601_Dmin (known_extension)
# 	 chainA: 6-96 (0.947)
# 	 chainB: -733-15 (1.000)
# LIG_PDZ_Class_1_MFL_Dmin (known_extension)
# 	 chainA: 6-96 (0.947)
# 	 chainB: -1585-15 (1.000)
# LIG_PDZ_Class_1_Mmin_D1084_D1593 (known_extension)
# 	 chainA: -276-233 (1.000)
# 	 chainB: 10-15 (1.000)
# LIG_PDZ_Class_1_Mmin_D1185_D1492 (known_extension)
# 	 chainA: -175-132 (1.000)
# 	 chainB: 10-15 (1.000)
# LIG_PDZ_Class_1_Mmin_DFL (known_extension)
# 	 chainA: -1359-1125 (1.000)
# 	 chainB: 10-15 (1.000)
# LIG_Pex14_3_M1_M412_D1_D377 (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 1-412 (1.000)
# LIG_Pex14_3_M1_M412_Dmin (known_extension)
# 	 chainA: 17-80 (0.925)
# 	 chainB: 1-412 (1.000)
# LIG_Pex14_3_M26_M103_D1_D377 (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 26-103 (1.000)
# LIG_Pex14_3_M26_M103_Dmin (known_extension)
# 	 chainA: 17-80 (0.925)
# 	 chainB: 26-103 (1.000)
# LIG_Pex14_3_M38_M91_D1_D377 (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 38-91 (1.000)
# LIG_Pex14_3_M38_M91_Dmin (known_extension)
# 	 chainA: 17-80 (0.925)
# 	 chainB: 38-91 (1.000)
# LIG_Pex14_3_M50_M79_D1_D377 (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 50-79 (1.000)
# LIG_Pex14_3_M50_M79_Dmin (known_extension)
# 	 chainA: 17-80 (0.925)
# 	 chainB: 50-79 (1.000)
# LIG_Pex14_3_M56_M73_D1_D377 (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 56-73 (1.000)
# LIG_Pex14_3_M56_M73_Dmin (known_extension)
# 	 chainA: 17-80 (0.925)
# 	 chainB: 56-73 (1.000)
# LIG_Pex14_3_MFL_Dmin (known_extension)
# 	 chainA: 17-80 (0.925)
# 	 chainB: 1-639 (1.000)
# LIG_Pex14_3_Mmin_D1_D377 (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 62-67 (1.000)
# LIG_Pex14_3_Mmin_DFL (known_extension)
# 	 chainA: 1-377 (0.940)
# 	 chainB: 62-67 (1.000)
# LIG_REV1ctd_RIR_1_M401_M870_D1002_D1251 (known_extension)
# 	 chainA: 1002-1251 (0.969)
# 	 chainB: 401-870 (1.000)
# LIG_REV1ctd_RIR_1_M401_M870_D1052_D1251 (known_extension)
# 	 chainA: 1052-1251 (0.969)
# 	 chainB: 401-870 (1.000)
# LIG_REV1ctd_RIR_1_M401_M870_Dmin (known_extension)
# 	 chainA: 1158-1251 (0.948)
# 	 chainB: 401-870 (1.000)
# LIG_REV1ctd_RIR_1_M526_M624_D1002_D1251 (known_extension)
# 	 chainA: 1002-1251 (0.969)
# 	 chainB: 526-624 (1.000)
# LIG_REV1ctd_RIR_1_M526_M624_D1052_D1251 (known_extension)
# 	 chainA: 1052-1251 (0.969)
# 	 chainB: 526-624 (1.000)
# LIG_REV1ctd_RIR_1_M526_M624_Dmin (known_extension)
# 	 chainA: 1158-1251 (0.948)
# 	 chainB: 526-624 (1.000)
# LIG_REV1ctd_RIR_1_M526_M648_D1002_D1251 (known_extension)
# 	 chainA: 1002-1251 (0.969)
# 	 chainB: 526-648 (1.000)
# LIG_REV1ctd_RIR_1_M526_M648_D1052_D1251 (known_extension)
# 	 chainA: 1052-1251 (0.969)
# 	 chainB: 526-648 (1.000)
# LIG_REV1ctd_RIR_1_M526_M648_Dmin (known_extension)
# 	 chainA: 1158-1251 (0.948)
# 	 chainB: 526-648 (1.000)
# LIG_REV1ctd_RIR_1_M541_M600_D1002_D1251 (known_extension)
# 	 chainA: 1002-1251 (0.969)
# 	 chainB: 541-600 (1.000)
# LIG_REV1ctd_RIR_1_M541_M600_D1052_D1251 (known_extension)
# 	 chainA: 1052-1251 (0.969)
# 	 chainB: 541-600 (1.000)
# LIG_REV1ctd_RIR_1_M541_M600_Dmin (known_extension)
# 	 chainA: 1158-1251 (0.948)
# 	 chainB: 541-600 (1.000)
# LIG_REV1ctd_RIR_1_M553_M588_D1002_D1251 (known_extension)
# 	 chainA: 1002-1251 (0.969)
# 	 chainB: 553-588 (1.000)
# LIG_REV1ctd_RIR_1_M553_M588_D1052_D1251 (known_extension)
# 	 chainA: 1052-1251 (0.969)
# 	 chainB: 553-588 (1.000)
# LIG_REV1ctd_RIR_1_M553_M588_Dmin (known_extension)
# 	 chainA: 1158-1251 (0.948)
# 	 chainB: 553-588 (1.000)
# LIG_REV1ctd_RIR_1_MFL_Dmin (known_extension)
# 	 chainA: 1158-1251 (0.948)
# 	 chainB: 1-870 (1.000)
# LIG_REV1ctd_RIR_1_Mmin_D1002_D1251 (known_extension)
# 	 chainA: 1002-1251 (0.969)
# 	 chainB: 565-576 (1.000)
# LIG_REV1ctd_RIR_1_Mmin_D1052_D1251 (known_extension)
# 	 chainA: 1052-1251 (0.969)
# 	 chainB: 565-576 (1.000)
# LIG_REV1ctd_RIR_1_Mmin_DFL (known_extension)
# 	 chainA: 1-1251 (0.969)
# 	 chainB: 565-576 (1.000)
# LIG_RPA_C_Vert_M1_M144_D1_D270 (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 1-144 (1.000)
# LIG_RPA_C_Vert_M1_M144_Dmin (known_extension)
# 	 chainA: 177-264 (1.000)
# 	 chainB: 1-144 (1.000)
# LIG_RPA_C_Vert_M1_M309_D1_D270 (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 1-309 (1.000)
# LIG_RPA_C_Vert_M1_M309_Dmin (known_extension)
# 	 chainA: 177-264 (1.000)
# 	 chainB: 1-309 (1.000)
# LIG_RPA_C_Vert_M41_M120_D1_D270 (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 41-120 (1.000)
# LIG_RPA_C_Vert_M41_M120_Dmin (known_extension)
# 	 chainA: 177-264 (1.000)
# 	 chainB: 41-120 (1.000)
# LIG_RPA_C_Vert_M57_M104_D1_D270 (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 57-104 (1.000)
# LIG_RPA_C_Vert_M57_M104_Dmin (known_extension)
# 	 chainA: 177-264 (1.000)
# 	 chainB: 57-104 (1.000)
# LIG_RPA_C_Vert_M9_M144_D1_D270 (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 9-144 (1.000)
# LIG_RPA_C_Vert_M9_M144_Dmin (known_extension)
# 	 chainA: 177-264 (1.000)
# 	 chainB: 9-144 (1.000)
# LIG_RPA_C_Vert_MFL_Dmin (known_extension)
# 	 chainA: 177-264 (1.000)
# 	 chainB: 1-313 (1.000)
# LIG_RPA_C_Vert_Mmin_D1_D270 (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 73-88 (1.000)
# LIG_RPA_C_Vert_Mmin_DFL (known_extension)
# 	 chainA: 1-270 (1.000)
# 	 chainB: 73-88 (1.000)
# LIG_TRFH_1_M10_M451_D1_D370 (known_extension)
# 	 chainA: 1-370 (0.990)
# 	 chainB: 10-451 (1.000)
# LIG_TRFH_1_M10_M451_D1_D437 (known_extension)
# 	 chainA: 1-437 (0.990)
# 	 chainB: 10-451 (1.000)
# LIG_TRFH_1_M10_M451_Dmin (known_extension)
# 	 chainA: 67-268 (0.965)
# 	 chainB: 10-451 (1.000)
# LIG_TRFH_1_M228_M292_D1_D370 (known_extension)
# 	 chainA: 1-370 (0.990)
# 	 chainB: 228-292 (1.000)
# LIG_TRFH_1_M228_M292_D1_D437 (known_extension)
# 	 chainA: 1-437 (0.990)
# 	 chainB: 228-292 (1.000)
# LIG_TRFH_1_M228_M292_Dmin (known_extension)
# 	 chainA: 67-268 (0.965)
# 	 chainB: 228-292 (1.000)
# LIG_TRFH_1_M238_M282_D1_D370 (known_extension)
# 	 chainA: 1-370 (0.990)
# 	 chainB: 238-282 (1.000)
# LIG_TRFH_1_M238_M282_D1_D437 (known_extension)
# 	 chainA: 1-437 (0.990)
# 	 chainB: 238-282 (1.000)
# LIG_TRFH_1_M238_M282_Dmin (known_extension)
# 	 chainA: 67-268 (0.965)
# 	 chainB: 238-282 (1.000)
# LIG_TRFH_1_M248_M272_D1_D370 (known_extension)
# 	 chainA: 1-370 (0.990)
# 	 chainB: 248-272 (1.000)
# LIG_TRFH_1_M248_M272_D1_D437 (known_extension)
# 	 chainA: 1-437 (0.990)
# 	 chainB: 248-272 (1.000)
# LIG_TRFH_1_M248_M272_Dmin (known_extension)
# 	 chainA: 67-268 (0.965)
# 	 chainB: 248-272 (1.000)
# LIG_TRFH_1_M253_M267_D1_D370 (known_extension)
# 	 chainA: 1-370 (0.990)
# 	 chainB: 253-267 (1.000)
# LIG_TRFH_1_M253_M267_D1_D437 (known_extension)
# 	 chainA: 1-437 (0.990)
# 	 chainB: 253-267 (1.000)
# LIG_TRFH_1_M253_M267_Dmin (known_extension)
# 	 chainA: 67-268 (0.965)
# 	 chainB: 253-267 (1.000)
# LIG_TRFH_1_MFL_Dmin (known_extension)
# 	 chainA: 67-268 (0.965)
# 	 chainB: 1-451 (1.000)
# LIG_TRFH_1_Mmin_D1_D370 (known_extension)
# 	 chainA: 1-370 (0.990)
# 	 chainB: 258-262 (1.000)
# LIG_TRFH_1_Mmin_D1_D437 (known_extension)
# 	 chainA: 1-437 (0.990)
# 	 chainB: 258-262 (1.000)
# LIG_TRFH_1_Mmin_DFL (known_extension)
# 	 chainA: 1-439 (0.990)
# 	 chainB: 258-262 (1.000)
# LIG_ULM_U2AF65_1_M1_M140_D251_D475 (known_extension)
# 	 chainA: 251-475 (1.000)
# 	 chainB: 1-140 (1.000)
# LIG_ULM_U2AF65_1_M1_M140_D340_D475 (known_extension)
# 	 chainA: 340-475 (1.000)
# 	 chainB: 1-140 (1.000)
# LIG_ULM_U2AF65_1_M1_M140_Dmin (known_extension)
# 	 chainA: 377-475 (0.951)
# 	 chainB: 1-140 (1.000)
# LIG_ULM_U2AF65_1_M1_M41_D251_D475 (known_extension)
# 	 chainA: 251-475 (1.000)
# 	 chainB: 1-41 (1.000)
# LIG_ULM_U2AF65_1_M1_M41_D340_D475 (known_extension)
# 	 chainA: 340-475 (1.000)
# 	 chainB: 1-41 (1.000)
# LIG_ULM_U2AF65_1_M1_M41_Dmin (known_extension)
# 	 chainA: 377-475 (0.951)
# 	 chainB: 1-41 (1.000)
# LIG_ULM_U2AF65_1_M1_M59_D251_D475 (known_extension)
# 	 chainA: 251-475 (1.000)
# 	 chainB: 1-59 (1.000)
# LIG_ULM_U2AF65_1_M1_M59_D340_D475 (known_extension)
# 	 chainA: 340-475 (1.000)
# 	 chainB: 1-59 (1.000)
# LIG_ULM_U2AF65_1_M1_M59_Dmin (known_extension)
# 	 chainA: 377-475 (0.951)
# 	 chainB: 1-59 (1.000)
# LIG_ULM_U2AF65_1_M1_M77_D251_D475 (known_extension)
# 	 chainA: 251-475 (1.000)
# 	 chainB: 1-77 (1.000)
# LIG_ULM_U2AF65_1_M1_M77_D340_D475 (known_extension)
# 	 chainA: 340-475 (1.000)
# 	 chainB: 1-77 (1.000)
# LIG_ULM_U2AF65_1_M1_M77_Dmin (known_extension)
# 	 chainA: 377-475 (0.951)
# 	 chainB: 1-77 (1.000)
# LIG_ULM_U2AF65_1_M6_M32_D251_D475 (known_extension)
# 	 chainA: 251-475 (1.000)
# 	 chainB: 6-32 (1.000)
# LIG_ULM_U2AF65_1_M6_M32_D340_D475 (known_extension)
# 	 chainA: 340-475 (1.000)
# 	 chainB: 6-32 (1.000)
# LIG_ULM_U2AF65_1_M6_M32_Dmin (known_extension)
# 	 chainA: 377-475 (0.951)
# 	 chainB: 6-32 (1.000)
# LIG_ULM_U2AF65_1_MFL_Dmin (known_extension)
# 	 chainA: 377-475 (0.951)
# 	 chainB: 1-639 (1.000)
# LIG_ULM_U2AF65_1_Mmin_D251_D475 (known_extension)
# 	 chainA: 251-475 (1.000)
# 	 chainB: 15-23 (1.000)
# LIG_ULM_U2AF65_1_Mmin_D340_D475 (known_extension)
# 	 chainA: 340-475 (1.000)
# 	 chainB: 15-23 (1.000)
# LIG_ULM_U2AF65_1_Mmin_DFL (known_extension)
# 	 chainA: 1-475 (1.000)
# 	 chainB: 15-23 (1.000)
# LIG_Vh1_VBS_1_M196_M1983_D1_D471 (known_extension)
# 	 chainA: 1-471 (1.000)
# 	 chainB: 196-1983 (1.000)
# LIG_Vh1_VBS_1_M196_M1983_D1_D925 (known_extension)
# 	 chainA: 1-925 (1.000)
# 	 chainB: 196-1983 (1.000)
# LIG_Vh1_VBS_1_M196_M1983_Dmin (known_extension)
# 	 chainA: 6-258 (0.980)
# 	 chainB: 196-1983 (1.000)
# LIG_Vh1_VBS_1_M494_M740_D1_D471 (known_extension)
# 	 chainA: 1-471 (1.000)
# 	 chainB: 494-740 (1.000)
# LIG_Vh1_VBS_1_M494_M740_D1_D925 (known_extension)
# 	 chainA: 1-925 (1.000)
# 	 chainB: 494-740 (1.000)
# LIG_Vh1_VBS_1_M494_M740_Dmin (known_extension)
# 	 chainA: 6-258 (0.980)
# 	 chainB: 494-740 (1.000)
# LIG_Vh1_VBS_1_M532_M702_D1_D471 (known_extension)
# 	 chainA: 1-471 (1.000)
# 	 chainB: 532-702 (1.000)
# LIG_Vh1_VBS_1_M532_M702_D1_D925 (known_extension)
# 	 chainA: 1-925 (1.000)
# 	 chainB: 532-702 (1.000)
# LIG_Vh1_VBS_1_M532_M702_Dmin (known_extension)
# 	 chainA: 6-258 (0.980)
# 	 chainB: 532-702 (1.000)
# LIG_Vh1_VBS_1_M570_M664_D1_D471 (known_extension)
# 	 chainA: 1-471 (1.000)
# 	 chainB: 570-664 (1.000)
# LIG_Vh1_VBS_1_M570_M664_D1_D925 (known_extension)
# 	 chainA: 1-925 (1.000)
# 	 chainB: 570-664 (1.000)
# LIG_Vh1_VBS_1_M570_M664_Dmin (known_extension)
# 	 chainA: 6-258 (0.980)
# 	 chainB: 570-664 (1.000)
# LIG_Vh1_VBS_1_M589_M645_D1_D471 (known_extension)
# 	 chainA: 1-471 (1.000)
# 	 chainB: 589-645 (1.000)
# LIG_Vh1_VBS_1_M589_M645_D1_D925 (known_extension)
# 	 chainA: 1-925 (1.000)
# 	 chainB: 589-645 (1.000)
# LIG_Vh1_VBS_1_M589_M645_Dmin (known_extension)
# 	 chainA: 6-258 (0.980)
# 	 chainB: 589-645 (1.000)
# LIG_Vh1_VBS_1_MFL_Dmin (known_extension)
# 	 chainA: 6-258 (0.980)
# 	 chainB: 1-2541 (1.000)
# LIG_Vh1_VBS_1_Mmin_D1_D471 (known_extension)
# 	 chainA: 1-471 (1.000)
# 	 chainB: 608-626 (1.000)
# LIG_Vh1_VBS_1_Mmin_D1_D925 (known_extension)
# 	 chainA: 1-925 (1.000)
# 	 chainB: 608-626 (1.000)
# LIG_Vh1_VBS_1_Mmin_DFL (known_extension)
# 	 chainA: 1-1134 (1.000)
# 	 chainB: 608-626 (1.000)
# LIG_WW_1_M597_M895_D2925_D3362 (known_extension)
# 	 chainA: -75-362 (1.000)
# 	 chainB: -283-15 (1.000)
# LIG_WW_1_M597_M895_Dmin (known_extension)
# 	 chainA: 51-306 (0.984)
# 	 chainB: -283-15 (1.000)
# LIG_WW_1_M865_M895_D2925_D3362 (known_extension)
# 	 chainA: -75-362 (1.000)
# 	 chainB: -15-15 (1.000)
# LIG_WW_1_M865_M895_Dmin (known_extension)
# 	 chainA: 51-306 (0.984)
# 	 chainB: -15-15 (1.000)
# LIG_WW_1_M873_M895_D2925_D3362 (known_extension)
# 	 chainA: -75-362 (1.000)
# 	 chainB: -7-15 (1.000)
# LIG_WW_1_M873_M895_Dmin (known_extension)
# 	 chainA: 51-306 (0.984)
# 	 chainB: -7-15 (1.000)
# LIG_WW_1_M881_M895_D2925_D3362 (known_extension)
# 	 chainA: -75-362 (1.000)
# 	 chainB: 1-15 (1.000)
# LIG_WW_1_M881_M895_Dmin (known_extension)
# 	 chainA: 51-306 (0.984)
# 	 chainB: 1-15 (1.000)
# LIG_WW_1_M885_M895_D2925_D3362 (known_extension)
# 	 chainA: -75-362 (1.000)
# 	 chainB: 5-15 (1.000)
# LIG_WW_1_M885_M895_Dmin (known_extension)
# 	 chainA: 51-306 (0.984)
# 	 chainB: 5-15 (1.000)
# LIG_WW_1_MFL_Dmin (known_extension)
# 	 chainA: 51-306 (0.984)
# 	 chainB: -879-15 (1.000)
# LIG_WW_1_Mmin_D2925_D3362 (known_extension)
# 	 chainA: -75-362 (1.000)
# 	 chainB: 9-12 (1.000)
# TRG_AP2beta_CARGO_1_M190_M308_D4_D937 (known_extension)
# 	 chainA: 4-937 (1.000)
# 	 chainB: -61-57 (1.000)
# TRG_AP2beta_CARGO_1_M190_M308_D542_D937 (known_extension)
# 	 chainA: 542-937 (1.000)
# 	 chainB: -61-57 (1.000)
# TRG_AP2beta_CARGO_1_M190_M308_Dmin (known_extension)
# 	 chainA: 706-937 (0.996)
# 	 chainB: -61-57 (1.000)
# TRG_AP2beta_CARGO_1_M212_M308_D4_D937 (known_extension)
# 	 chainA: 4-937 (1.000)
# 	 chainB: -39-57 (1.000)
# TRG_AP2beta_CARGO_1_M212_M308_D542_D937 (known_extension)
# 	 chainA: 542-937 (1.000)
# 	 chainB: -39-57 (1.000)
# TRG_AP2beta_CARGO_1_M212_M308_Dmin (known_extension)
# 	 chainA: 706-937 (0.996)
# 	 chainB: -39-57 (1.000)
# TRG_AP2beta_CARGO_1_M234_M288_D4_D937 (known_extension)
# 	 chainA: 4-937 (1.000)
# 	 chainB: -17-37 (1.000)
# TRG_AP2beta_CARGO_1_M234_M288_D542_D937 (known_extension)
# 	 chainA: 542-937 (1.000)
# 	 chainB: -17-37 (1.000)
# TRG_AP2beta_CARGO_1_M234_M288_Dmin (known_extension)
# 	 chainA: 706-937 (0.996)
# 	 chainB: -17-37 (1.000)
# TRG_AP2beta_CARGO_1_M245_M277_D4_D937 (known_extension)
# 	 chainA: 4-937 (1.000)
# 	 chainB: -6-26 (1.000)
# TRG_AP2beta_CARGO_1_M245_M277_D542_D937 (known_extension)
# 	 chainA: 542-937 (1.000)
# 	 chainB: -6-26 (1.000)
# TRG_AP2beta_CARGO_1_M245_M277_Dmin (known_extension)
# 	 chainA: 706-937 (0.996)
# 	 chainB: -6-26 (1.000)
# TRG_AP2beta_CARGO_1_M38_M308_D4_D937 (known_extension)
# 	 chainA: 4-937 (1.000)
# 	 chainB: -213-57 (1.000)
# TRG_AP2beta_CARGO_1_M38_M308_D542_D937 (known_extension)
# 	 chainA: 542-937 (1.000)
# 	 chainB: -213-57 (1.000)
# TRG_AP2beta_CARGO_1_M38_M308_Dmin (known_extension)
# 	 chainA: 706-937 (0.996)
# 	 chainB: -213-57 (1.000)
# TRG_AP2beta_CARGO_1_MFL_Dmin (known_extension)
# 	 chainA: 706-937 (0.996)
# 	 chainB: -250-57 (1.000)
# TRG_AP2beta_CARGO_1_Mmin_D4_D937 (known_extension)
# 	 chainA: 4-937 (1.000)
# 	 chainB: 5-15 (1.000)
# TRG_AP2beta_CARGO_1_Mmin_D542_D937 (known_extension)
# 	 chainA: 542-937 (1.000)
# 	 chainB: 5-15 (1.000)
# TRG_AP2beta_CARGO_1_Mmin_DFL (known_extension)
# 	 chainA: 1-937 (1.000)
# 	 chainB: 5-15 (1.000)

# %%
dataAF[np.logical_and(dataAF["model_id"] == "ranked_0", True)]
# Out:
#      model_preset    benchmark_set                     prediction_name  \
# 2710          NaN  known_extension   DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2715          NaN  known_extension      DEG_APCC_KENBOX_2_M15_M39_Dmin
# 2720          NaN  known_extension   DEG_APCC_KENBOX_2_M1_M189_D1_D499
# 2725          NaN  known_extension      DEG_APCC_KENBOX_2_M1_M189_Dmin
# 2730          NaN  known_extension    DEG_APCC_KENBOX_2_M1_M57_D1_D499
# ...           ...              ...                                 ...
# 5505          NaN  known_extension   TRG_AP2beta_CARGO_1_M38_M308_Dmin
# 5510          NaN  known_extension        TRG_AP2beta_CARGO_1_MFL_Dmin
# 5515          NaN  known_extension    TRG_AP2beta_CARGO_1_Mmin_D4_D937
# 5520          NaN  known_extension  TRG_AP2beta_CARGO_1_Mmin_D542_D937
# 5525          NaN  known_extension        TRG_AP2beta_CARGO_1_Mmin_DFL
#
#       model_id                                         model_path  \
# 2710  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2715  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2720  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2725  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2730  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# ...        ...                                                ...
# 5505  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5510  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5515  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5520  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5525  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
#
#       ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 2710            1.0            NaN            NaN                  NaN
# 2715            1.0            NaN            NaN                  NaN
# 2720            1.0            NaN            NaN                  NaN
# 2725            1.0            NaN            NaN                  NaN
# 2730            1.0            NaN            NaN                  NaN
# ...             ...            ...            ...                  ...
# 5505            1.0            NaN            NaN                  NaN
# 5510            1.0            NaN            NaN                  NaN
# 5515            1.0            NaN            NaN                  NaN
# 5520            1.0            NaN            NaN                  NaN
# 5525            1.0            NaN            NaN                  NaN
#
#       has_clash  ...  chainB_id  chainA_start  chainA_end  chainB_start  \
# 2710        NaN  ...          B             1         499            -4
# 2715        NaN  ...          B           170         476            -4
# 2720        NaN  ...          B             1         499           -18
# 2725        NaN  ...          B           170         476           -18
# 2730        NaN  ...          B             1         499           -18
# ...         ...  ...        ...           ...         ...           ...
# 5505        NaN  ...          B           706         937          -213
# 5510        NaN  ...          B           706         937          -250
# 5515        NaN  ...          B             4         937             5
# 5520        NaN  ...          B           542         937             5
# 5525        NaN  ...          B             1         937             5
#
#       chainB_end  DDI_pfam_id  PDB_id_random_paired  \
# 2710          20         None                  None
# 2715          20         None                  None
# 2720         170         None                  None
# 2725         170         None                  None
# 2730          38         None                  None
# ...          ...          ...                   ...
# 5505          57         None                  None
# 5510          57         None                  None
# 5515          15         None                  None
# 5520          15         None                  None
# 5525          15         None                  None
#
#       ELM_instance_random_paired  DDI_pfam_id_random_paired  PDB_id
# 2710                        None                       None    4GGD
# 2715                        None                       None    4GGD
# 2720                        None                       None    4GGD
# 2725                        None                       None    4GGD
# 2730                        None                       None    4GGD
# ...                          ...                        ...     ...
# 5505                        None                       None    2G30
# 5510                        None                       None    2G30
# 5515                        None                       None    2G30
# 5520                        None                       None    2G30
# 5525                        None                       None    2G30
#
# [564 rows x 34 columns]

# %%
print(dataAF[dataAF["chainA_end"].isna()])
# Out:
# Empty DataFrame
# Columns: [model_preset, benchmark_set, prediction_name, model_id, model_path, ranking_score, chainA_length, chainB_length, fraction_disordered, has_clash, iptm, ptm, chainA_intf_avg_plddt, chainB_intf_avg_plddt, intf_avg_plddt, num_chainA_intf_res, num_chainB_intf_res, num_res_res_contact, num_atom_atom_contact, iPAE, pDockQ, chains_flipped, ELM_instance, chainA_id, chainB_id, chainA_start, chainA_end, chainB_start, chainB_end, DDI_pfam_id, PDB_id_random_paired, ELM_instance_random_paired, DDI_pfam_id_random_paired, PDB_id]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ### 3 RMSD with PyMOL
#
# For all structures, calculate the overall RMSD
# - **RMSD_all_atom**: RMSD aligning the whole structure
#
# For DMI, align the domains (chain A) first
# - **align_score_domain**: Score of domain alignment
# - **num_align_atoms_domain** and **num_align_resi_domain**: Count of aligned atoms/residues of domain
# - **RMSD_domain**: RMSD of the domain (chain A) after aligning on the domain
# For known_DMI and mutations_DMI (excluding the mutated residues):
# - **RMSD_backbone_peptide** and **RMSD_all_atom_peptide**: RMSD of the motif chain (chain B) after aligning on the domain
#
# For DDI perform, use the longest chain (or chain A if both have equal length) as domain and define the shorter one as peptide. Then use the same definition as for DMI

# %%
# Calculating the RMSD related values using pymol
import pymol.cmd as cmd

dataAF["align_score_domain"] = None
dataAF["num_align_atoms_domain"] = None
dataAF["num_align_resi_domain"] = None
dataAF["RMSD_all_atom"] = None
dataAF["RMSD_domain"] = None
dataAF["RMSD_backbone_peptide"] = None
dataAF["RMSD_all_atom_peptide"] = None

for i,row in dataAF.iterrows():
    benchmark_set = str(row["benchmark_set"])
    _set = "DDI" if "DDI" in benchmark_set else "DMI"
    pdb_id = str(row["PDB_id"]) if row.notnull()["PDB_id"] else None
    pdb_id_2 = None
    ddi_pfam_id = None
    ddi_pfam_id_2 = None
    prediction_name = str(row["prediction_name"]) if row.notnull()["prediction_name"] else None
    model_id = str(row["model_id"]) if row.notnull()["model_id"] else None
    chainA_id = str(row["chainA_id"]) if row.notnull()["chainA_id"] else None
    chainB_id = str(row["chainB_id"]) if row.notnull()["chainB_id"] else None
    chainA_start = int(row["chainA_start"]) if row.notnull()["chainA_start"] else None
    chainB_start = int(row["chainB_start"]) if row.notnull()["chainB_start"] else None
    chainA_end = int(row["chainA_end"]) if row.notnull()["chainA_end"] else None
    chainB_end = int(row["chainB_end"]) if row.notnull()["chainB_end"] else None
    chainA_length = int(row["chainA_length"]) if row.notnull()["chainA_length"] else None
    chainB_length = int(row["chainB_length"]) if row.notnull()["chainB_length"] else None

    if model_id == "ranked_0":
        pymol.cmd.reinitialize() 
        print(f"{bcolors.OKBLUE}{prediction_name} ({benchmark_set}){bcolors.ENDC}")    

    structure_path = path_resources / "DMI" / benchmark_set / prediction_name / (model_id + ".pdb")
    
    if not structure_path.exists():
        print(f"\t{bcolors.FAIL}{prediction_name} ({benchmark_set}) does not exist.{bcolors.ENDC} Skip RMSD calculation")
        continue


   
    template_row = dataSolved.loc[np.logical_and(dataSolved["set"] == _set, np.logical_and(dataSolved["PDB_id"] == pdb_id, np.logical_or(dataSolved["DDI_pfam_id"] == ddi_pfam_id, dataSolved["DDI_pfam_id"].isna())))]
    if len(template_row) == 0:
        print(f"\t{bcolors.FAIL}Can't find template structure for {prediction_name} ({benchmark_set}) and PDB ID {pdb_id}.{bcolors.ENDC} Skip RMSD calculation")
        continue
    elif len(template_row) >= 2:
        print(f"\t{bcolors.FAIL}Multiple template structures found for {prediction_name} ({benchmark_set}) and PDB ID {pdb_id}.{bcolors.ENDC} Skip RMSD calculation")
        continue
        
    template_path = path_solved / str(template_row["path"].item())
    

    template2_path = None
    if pdb_id_2 is not None:
        template2_row = dataSolved.loc[np.logical_and(dataSolved["set"] == _set, np.logical_and(dataSolved["PDB_id"] == pdb_id_2, np.logical_or(dataSolved["DDI_pfam_id"] == ddi_pfam_id_2, dataSolved["DDI_pfam_id"].isna())))]
        if len(template2_row) == 0:
            print(f"\t{bcolors.FAIL}Can't find template structure for {prediction_name} ({benchmark_set}) and PDB ID {pdb_id_2}.{bcolors.ENDC} Skip RMSD calculation")
            continue
        elif len(template2_row) >= 2:
            print(f"\t{bcolors.FAIL}Multiple template structures found for {prediction_name} ({benchmark_set}) and PDB ID {pdb_id_2}.{bcolors.ENDC} Skip RMSD calculation")
            continue

        template2_path = path_resources / "solved" / str(template2_row["path"].item())

    
    #pymol.cmd.reinitialize() # Not needed usually, but slows performance significantly down
    for o in pymol.cmd.get_object_list():
        pymol.cmd.delete("all")
    pymol.cmd.sort()

    # First loading the structures. Use two temporary objects to allow renaming the chains even if the chains have the same name or have switched IDs

    pymol.cmd.load(structure_path, "af")


    if template2_path is not None:
        # Updating the object is possible, but turned out to be unstable
        pymol.cmd.load(template_path, "solvedA")
        pymol.cmd.load(template2_path, "solvedB")
        pymol.cmd.create("solved1", f"solvedA and chain {chainA_id}")
        pymol.cmd.create("solved2", f"solvedB and chain {chainB_id}")
        pymol.cmd.delete("solvedA")
        pymol.cmd.delete("solvedB")
    else:
        pymol.cmd.load(template_path, "solvedraw")
        pymol.cmd.create("solved1", f"solvedraw and chain {chainA_id}")
        pymol.cmd.sort()
        pymol.cmd.create("solved2", f"solvedraw and chain {chainB_id}")
        pymol.cmd.delete("solvedraw")


    
    pymol.cmd.sort()
    # Now rename the chains and create merged object
    pymol.cmd.alter(f"solved1 and chain {chainA_id}", "chain = 'A'")
    pymol.cmd.sort()
    pymol.cmd.alter(f"solved2 and chain {chainB_id}", "chain = 'B'")
    pymol.cmd.sort()
    pymol.cmd.create("solved", f"solved1 or solved2")
    pymol.cmd.delete("solved1")
    pymol.cmd.delete("solved2")
    pymol.cmd.sort()

    # Remove hydrogens and hetatm
    #pymol.cmd.remove(selection="elem 'H' or hetatm")
    pymol.cmd.remove(selection="not backbone and not sidechain or elem 'H'")
    pymol.cmd.sort()

    # Remove alternate location identifiers
    pymol.cmd.remove("not alt ''+A") # Using +A syntax to only effect the atoms with an alternate location identifier set
    pymol.cmd.sort()
    pymol.cmd.alter("all", "alt=''")
    pymol.cmd.sort()

    # Slice the chains to the known start/end residues. For chain B and AF a reindexing is performed as the rms_cur cmd of pymol requires same residue numbers for alignment
    if chainA_start is not None and chainB_start is not None:
        pymol.cmd.create("solved", f"solved and ((chain A and resi {chainA_start}-{chainA_end}) or (chain B and resi {chainB_start}-{chainB_end}))", source_state=0, target_state=0)
        pymol.cmd.sort()
        offsetA = chainA_start - 1
        pymol.cmd.alter("af and chain A", f"resi = (int(resi) + {offsetA})")
        pymol.cmd.sort()

        offsetB = chainB_start - 1
        pymol.cmd.alter("af and chain B", f"resi = (int(resi) + {offsetB})")
        pymol.cmd.sort()
    else:
        print(f"\t{bcolors.FAIL}Can't find information about the chain start/end in the template.{bcolors.ENDC} This may lead to wrong RMSD peptide values, so skip")
        continue

    pymol.cmd.sort()

    # DDI
    chain_align_1, chain_align_2 = "A", "B"
    if _set == "DDI" and chainB_length > chainA_length:
        chain_align_1, chain_align_2 = "B", "A"

    #For debugging
    #space = {'solved_resi': [], "af_resi": []}
    #pymol.cmd.iterate("solved and chain B", "solved_resi.append(int(resi))", space=space)
    #pymol.cmd.iterate("af and chain B", "af_resi.append(int(resi))", space=space)

    #    0: RMSD after refinement
    #    1: Number of aligned atoms after refinement
    #    2: Number of refinement cycles
    #    3: RMSD before refinement
    #    4: Number of aligned atoms before refinement
    #    5: Raw alignment score
    #    6: Number of residues aligned
    # Cycles = 0 to prevent rejection of outliers
    align_output_1 = pymol.cmd.align(mobile=f"af and chain {chain_align_1}", target=f"solved and chain {chain_align_1}", object="algn_domain", cycles=0)
    pymol.cmd.sort()
    RMSD_domain = align_output_1[0]
    num_align_atoms_domain = align_output_1[1]
    align_score_domain = align_output_1[5]
    num_align_resi_domain = align_output_1[6]

    RMSD_backbone_peptide = pymol.cmd.rms_cur(mobile=f"af and chain {chain_align_2} and bb.", target=f"solved and chain {chain_align_2} and bb.", object="peptide_super_bb", cycles=0)
    RMSD_all_atom_peptide = pymol.cmd.rms_cur(mobile=f"af and chain {chain_align_2}", target=f"solved and chain {chain_align_2}", object="peptide_super_all_atoms", cycles=0)
    
    align_output_all = pymol.cmd.align(mobile="af", target="solved", object="algn_all", cycles=0, )
    RMSD_all_atoms = align_output_all[0]

    dataAF.at[i, "RMSD_domain"] =  RMSD_domain
    dataAF.at[i, "align_score_domain"] =  align_score_domain
    dataAF.at[i, "num_align_atoms_domain"] =  num_align_atoms_domain
    dataAF.at[i, "num_align_resi_domain"] =  num_align_resi_domain

    if "random" not in benchmark_set:
        dataAF.at[i, "RMSD_backbone_peptide"] =  RMSD_backbone_peptide
        dataAF.at[i, "RMSD_all_atom_peptide"] =  RMSD_all_atom_peptide

    dataAF.at[i, "RMSD_all_atom"] =  RMSD_all_atoms
        
display(dataAF)
# Out:
# DEG_APCC_KENBOX_2_M15_M39_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M15_M39_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M1_M189_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M1_M189_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M1_M57_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M1_M57_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M20_M34_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M20_M34_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M5_M49_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M5_M49_Dmin (known_extension)
# DEG_APCC_KENBOX_2_MFL_Dmin (known_extension)
# DEG_APCC_KENBOX_2_Mmin_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_Mmin_DFL (known_extension)
# DEG_Kelch_Keap1_1_M1_M568_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M1_M568_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M1_M568_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M41_M118_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M41_M118_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M41_M118_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M53_M106_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M53_M106_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M53_M106_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M65_M94_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M65_M94_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M65_M94_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M71_M88_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M71_M88_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M71_M88_Dmin (known_extension)
# DEG_Kelch_Keap1_1_MFL_Dmin (known_extension)
# DEG_Kelch_Keap1_1_Mmin_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_Mmin_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_Mmin_DFL (known_extension)
# DEG_MDM2_SWIB_1_M11_M34_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M11_M34_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M11_M34_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M1_M298_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M1_M298_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M1_M298_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M1_M58_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M1_M58_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M1_M58_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M1_M74_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M1_M74_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M1_M74_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M3_M42_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M3_M42_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M3_M42_Dmin (known_extension)
# DEG_MDM2_SWIB_1_MFL_Dmin (known_extension)
# DEG_MDM2_SWIB_1_Mmin_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_Mmin_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_Mmin_DFL (known_extension)
# DEG_SIAH_1_M1_M166_D1_D282 (known_extension)
# DEG_SIAH_1_M1_M166_Dmin (known_extension)
# DEG_SIAH_1_M23_M103_D1_D282 (known_extension)
# DEG_SIAH_1_M23_M103_Dmin (known_extension)
# DEG_SIAH_1_M41_M85_D1_D282 (known_extension)
# DEG_SIAH_1_M41_M85_Dmin (known_extension)
# DEG_SIAH_1_M50_M76_D1_D282 (known_extension)
# DEG_SIAH_1_M50_M76_Dmin (known_extension)
# DEG_SIAH_1_M5_M121_D1_D282 (known_extension)
# DEG_SIAH_1_M5_M121_Dmin (known_extension)
# DEG_SIAH_1_MFL_Dmin (known_extension)
# DEG_SIAH_1_Mmin_D1_D282 (known_extension)
# DEG_SIAH_1_Mmin_DFL (known_extension)
# DOC_ANK_TNKS_1_M1_M322_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M1_M322_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M1_M322_Dmin (known_extension)
# DOC_ANK_TNKS_1_M29_M132_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M29_M132_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M29_M132_Dmin (known_extension)
# DOC_ANK_TNKS_1_M45_M116_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M45_M116_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M45_M116_Dmin (known_extension)
# DOC_ANK_TNKS_1_M61_M100_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M61_M100_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M61_M100_Dmin (known_extension)
# DOC_ANK_TNKS_1_M69_M92_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M69_M92_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M69_M92_Dmin (known_extension)
# DOC_ANK_TNKS_1_MFL_Dmin (known_extension)
# DOC_ANK_TNKS_1_Mmin_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_Mmin_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_Mmin_DFL (known_extension)
# DOC_MAPK_JIP1_4_M29_M455_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M29_M455_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M301_M391_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M301_M391_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M315_M377_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M315_M377_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M329_M363_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M329_M363_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M336_M356_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M336_M356_Dmin (known_extension)
# DOC_MAPK_JIP1_4_MFL_Dmin (known_extension)
# DOC_MAPK_JIP1_4_Mmin_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_Mmin_DFL (known_extension)
# DOC_SPAK_OSR1_1_M1006_M1030_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1006_M1030_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1006_M1030_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M1011_M1025_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1011_M1025_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1011_M1025_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M443_M1243_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M443_M1243_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M443_M1243_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M986_M1050_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M986_M1050_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M986_M1050_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M996_M1040_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M996_M1040_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M996_M1040_Dmin (known_extension)
# DOC_SPAK_OSR1_1_MFL_Dmin (known_extension)
# DOC_SPAK_OSR1_1_Mmin_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_Mmin_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_Mmin_DFL (known_extension)
# DOC_USP7_MATH_1_M290_M491_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M290_M491_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M290_M491_Dmin (known_extension)
# DOC_USP7_MATH_1_M367_M431_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M367_M431_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M367_M431_Dmin (known_extension)
# DOC_USP7_MATH_1_M377_M421_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M377_M421_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M377_M421_Dmin (known_extension)
# DOC_USP7_MATH_1_M387_M411_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M387_M411_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M387_M411_Dmin (known_extension)
# DOC_USP7_MATH_1_M392_M406_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M392_M406_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M392_M406_Dmin (known_extension)
# DOC_USP7_MATH_1_MFL_Dmin (known_extension)
# DOC_USP7_MATH_1_Mmin_D1_D204 (known_extension)
# DOC_USP7_MATH_1_Mmin_D1_D528 (known_extension)
# DOC_USP7_MATH_1_Mmin_DFL (known_extension)
# DOC_USP7_UBL2_3_M1099_M1135_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1135_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1135_Dmin (known_extension)
# DOC_USP7_UBL2_3_M1099_M1140_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1140_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1140_Dmin (known_extension)
# DOC_USP7_UBL2_3_M1101_M1125_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1101_M1125_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1101_M1125_Dmin (known_extension)
# DOC_USP7_UBL2_3_M1106_M1120_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1106_M1120_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1106_M1120_Dmin (known_extension)
# DOC_USP7_UBL2_3_M922_M1603_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M922_M1603_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M922_M1603_Dmin (known_extension)
# DOC_USP7_UBL2_3_MFL_Dmin (known_extension)
# DOC_USP7_UBL2_3_Mmin_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_Mmin_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_Mmin_DFL (known_extension)
# LIG_BIR_III_2_M151_M416_D156_D497 (known_extension)
# LIG_BIR_III_2_M151_M416_D240_D437 (known_extension)
# LIG_BIR_III_2_M151_M416_Dmin (known_extension)
# LIG_BIR_III_2_M285_M349_D156_D497 (known_extension)
# LIG_BIR_III_2_M285_M349_D240_D437 (known_extension)
# LIG_BIR_III_2_M285_M349_Dmin (known_extension)
# LIG_BIR_III_2_M295_M339_D156_D497 (known_extension)
# LIG_BIR_III_2_M295_M339_D240_D437 (known_extension)
# LIG_BIR_III_2_M295_M339_Dmin (known_extension)
# LIG_BIR_III_2_M305_M329_D156_D497 (known_extension)
# LIG_BIR_III_2_M305_M329_D240_D437 (known_extension)
# LIG_BIR_III_2_M305_M329_Dmin (known_extension)
# LIG_BIR_III_2_M310_M324_D156_D497 (known_extension)
# LIG_BIR_III_2_M310_M324_D240_D437 (known_extension)
# LIG_BIR_III_2_M310_M324_Dmin (known_extension)
# LIG_BIR_III_2_MFL_Dmin (known_extension)
# LIG_BIR_III_2_Mmin_D156_D497 (known_extension)
# LIG_BIR_III_2_Mmin_D240_D437 (known_extension)
# LIG_BIR_III_2_Mmin_DFL (known_extension)
# LIG_CAP-Gly_1_M1406_M1438_D1_D517 (known_extension)
# LIG_CAP-Gly_1_M1406_M1438_D1_D815 (known_extension)
# LIG_CAP-Gly_1_M1406_M1438_Dmin (known_extension)
# LIG_CAP-Gly_1_M1432_M1438_D1_D517 (known_extension)
# LIG_CAP-Gly_1_M1432_M1438_D1_D815 (known_extension)
# LIG_CAP-Gly_1_M1432_M1438_Dmin (known_extension)
# LIG_CAP-Gly_1_MFL_Dmin (known_extension)
# LIG_CAP-Gly_1_Mmin_D1_D517 (known_extension)
# LIG_CAP-Gly_1_Mmin_D1_D815 (known_extension)
# LIG_CAP-Gly_1_Mmin_DFL (known_extension)
# LIG_CAP-Gly_2_M120_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M120_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M120_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M533_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M533_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M533_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M547_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M547_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M547_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M561_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M561_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M561_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M568_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M568_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M568_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_MFL_Dmin (known_extension)
# LIG_CAP-Gly_2_Mmin_D1_D204 (known_extension)
# LIG_CAP-Gly_2_Mmin_D1_D288 (known_extension)
# LIG_CAP-Gly_2_Mmin_DFL (known_extension)
# LIG_CNOT1_NIM_1_M1_M109_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M109_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M109_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M1_M276_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M276_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M276_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M1_M89_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M89_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M89_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M20_M69_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M20_M69_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M20_M69_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M30_M59_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M30_M59_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M30_M59_Dmin (known_extension)
# LIG_CNOT1_NIM_1_MFL_Dmin (known_extension)
# LIG_CNOT1_NIM_1_Mmin_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_Mmin_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_Mmin_DFL (known_extension)
# LIG_EF_ALG2_ABM_1_M403_M868_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M403_M868_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M748_M864_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M748_M864_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M766_M846_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M766_M846_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M784_M828_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M784_M828_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M793_M819_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M793_M819_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_MFL_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_Mmin_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_Mmin_DFL (known_extension)
# LIG_GYF_M125_M351_D1_D341 (known_extension)
# LIG_GYF_M125_M351_Dmin (known_extension)
# LIG_GYF_M241_M351_D1_D341 (known_extension)
# LIG_GYF_M241_M351_Dmin (known_extension)
# LIG_GYF_M259_M339_D1_D341 (known_extension)
# LIG_GYF_M259_M339_Dmin (known_extension)
# LIG_GYF_M277_M321_D1_D341 (known_extension)
# LIG_GYF_M277_M321_Dmin (known_extension)
# LIG_GYF_M286_M312_D1_D341 (known_extension)
# LIG_GYF_M286_M312_Dmin (known_extension)
# LIG_GYF_MFL_Dmin (known_extension)
# LIG_GYF_Mmin_D1_D341 (known_extension)
# LIG_GYF_Mmin_DFL (known_extension)
# LIG_HOMEOBOX_M156_M207_D242_D430 (known_extension)
# LIG_HOMEOBOX_M156_M207_D30_D430 (known_extension)
# LIG_HOMEOBOX_M156_M207_Dmin (known_extension)
# LIG_HOMEOBOX_M164_M199_D242_D430 (known_extension)
# LIG_HOMEOBOX_M164_M199_D30_D430 (known_extension)
# LIG_HOMEOBOX_M164_M199_Dmin (known_extension)
# LIG_HOMEOBOX_M172_M191_D242_D430 (known_extension)
# LIG_HOMEOBOX_M172_M191_D30_D430 (known_extension)
# LIG_HOMEOBOX_M172_M191_Dmin (known_extension)
# LIG_HOMEOBOX_M176_M187_D242_D430 (known_extension)
# LIG_HOMEOBOX_M176_M187_D30_D430 (known_extension)
# LIG_HOMEOBOX_M176_M187_Dmin (known_extension)
# LIG_HOMEOBOX_M1_M270_D242_D430 (known_extension)
# LIG_HOMEOBOX_M1_M270_D30_D430 (known_extension)
# LIG_HOMEOBOX_M1_M270_Dmin (known_extension)
# LIG_HOMEOBOX_MFL_Dmin (known_extension)
# LIG_HOMEOBOX_Mmin_D242_D430 (known_extension)
# LIG_HOMEOBOX_Mmin_D30_D430 (known_extension)
# LIG_HOMEOBOX_Mmin_DFL (known_extension)
# LIG_LIR_Gen_1_M369_M966_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M369_M966_Dmin (known_extension)
# LIG_LIR_Gen_1_M664_M806_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M664_M806_Dmin (known_extension)
# LIG_LIR_Gen_1_M686_M784_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M686_M784_Dmin (known_extension)
# LIG_LIR_Gen_1_M708_M762_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M708_M762_Dmin (known_extension)
# LIG_LIR_Gen_1_M719_M751_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M719_M751_Dmin (known_extension)
# LIG_LIR_Gen_1_MFL_Dmin (known_extension)
# LIG_LIR_Gen_1_Mmin_D1_D117 (known_extension)
# LIG_LIR_Gen_1_Mmin_DFL (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M149_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M149_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M149_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M85_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M85_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M85_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M23_M57_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M23_M57_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M23_M57_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M30_M50_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M30_M50_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M30_M50_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M9_M71_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M9_M71_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M9_M71_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_MFL_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_Mmin_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_Mmin_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_Mmin_DFL (known_extension)
# LIG_NBox_RRM_1_M1_M102_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M1_M102_Dmin (known_extension)
# LIG_NBox_RRM_1_M1_M175_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M1_M175_Dmin (known_extension)
# LIG_NBox_RRM_1_M1_M85_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M1_M85_Dmin (known_extension)
# LIG_NBox_RRM_1_M20_M52_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M20_M52_Dmin (known_extension)
# LIG_NBox_RRM_1_M9_M63_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M9_M63_Dmin (known_extension)
# LIG_NBox_RRM_1_MFL_Dmin (known_extension)
# LIG_NBox_RRM_1_Mmin_D1_D559 (known_extension)
# LIG_NBox_RRM_1_Mmin_DFL (known_extension)
# LIG_NRBOX_M453_M826_D174_D595 (known_extension)
# LIG_NRBOX_M453_M826_D262_D542 (known_extension)
# LIG_NRBOX_M453_M826_Dmin (known_extension)
# LIG_NRBOX_M647_M737_D174_D595 (known_extension)
# LIG_NRBOX_M647_M737_D262_D542 (known_extension)
# LIG_NRBOX_M647_M737_Dmin (known_extension)
# LIG_NRBOX_M661_M723_D174_D595 (known_extension)
# LIG_NRBOX_M661_M723_D262_D542 (known_extension)
# LIG_NRBOX_M661_M723_Dmin (known_extension)
# LIG_NRBOX_M675_M709_D174_D595 (known_extension)
# LIG_NRBOX_M675_M709_D262_D542 (known_extension)
# LIG_NRBOX_M675_M709_Dmin (known_extension)
# LIG_NRBOX_M682_M702_D174_D595 (known_extension)
# LIG_NRBOX_M682_M702_D262_D542 (known_extension)
# LIG_NRBOX_M682_M702_Dmin (known_extension)
# LIG_NRBOX_MFL_Dmin (known_extension)
# LIG_NRBOX_Mmin_D174_D595 (known_extension)
# LIG_NRBOX_Mmin_D262_D542 (known_extension)
# LIG_NRBOX_Mmin_DFL (known_extension)
# LIG_OCRL_FandH_1_M12_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M12_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M12_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M145_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M145_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M145_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M171_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M171_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M171_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M197_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M197_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M197_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M210_M248_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M210_M248_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M210_M248_Dmin (known_extension)
# LIG_OCRL_FandH_1_MFL_Dmin (known_extension)
# LIG_OCRL_FandH_1_Mmin_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_Mmin_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_Mmin_DFL (known_extension)
# LIG_PAM2_1_M1_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M1_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M1_M127_Dmin (known_extension)
# LIG_PAM2_1_M31_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M31_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M31_M127_Dmin (known_extension)
# LIG_PAM2_1_M57_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M57_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M57_M127_Dmin (known_extension)
# LIG_PAM2_1_M83_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M83_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M83_M127_Dmin (known_extension)
# LIG_PAM2_1_M96_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M96_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M96_M127_Dmin (known_extension)
# LIG_PAM2_1_MFL_Dmin (known_extension)
# LIG_PAM2_1_Mmin_D286_D636 (known_extension)
# LIG_PAM2_1_Mmin_D373_D636 (known_extension)
# LIG_PAM2_1_Mmin_DFL (known_extension)
# LIG_PAM2_2_M1248_M1522_D286_D636 (known_extension)
# LIG_PAM2_2_M1248_M1522_D373_D636 (known_extension)
# LIG_PAM2_2_M1248_M1522_Dmin (known_extension)
# LIG_PAM2_2_M1301_M1482_D286_D636 (known_extension)
# LIG_PAM2_2_M1301_M1482_D373_D636 (known_extension)
# LIG_PAM2_2_M1301_M1482_Dmin (known_extension)
# LIG_PAM2_2_M1329_M1454_D286_D636 (known_extension)
# LIG_PAM2_2_M1329_M1454_D373_D636 (known_extension)
# LIG_PAM2_2_M1329_M1454_Dmin (known_extension)
# LIG_PAM2_2_M1357_M1426_D286_D636 (known_extension)
# LIG_PAM2_2_M1357_M1426_D373_D636 (known_extension)
# LIG_PAM2_2_M1357_M1426_Dmin (known_extension)
# LIG_PAM2_2_M1371_M1412_D286_D636 (known_extension)
# LIG_PAM2_2_M1371_M1412_D373_D636 (known_extension)
# LIG_PAM2_2_M1371_M1412_Dmin (known_extension)
# LIG_PAM2_2_MFL_Dmin (known_extension)
# LIG_PAM2_2_Mmin_D286_D636 (known_extension)
# LIG_PAM2_2_Mmin_D373_D636 (known_extension)
# LIG_PAM2_2_Mmin_DFL (known_extension)
# LIG_PCNA_PIPBox_1_M104_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M104_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M11_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M11_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M124_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M124_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M134_M163_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M134_M163_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M84_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M84_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_MFL_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_Mmin_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_Mmin_DFL (known_extension)
# LIG_PCNA_TLS_4_M401_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M401_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M814_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M814_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M830_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M830_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M846_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M846_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M854_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M854_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_MFL_Dmin (known_extension)
# LIG_PCNA_TLS_4_Mmin_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_Mmin_DFL (known_extension)
# LIG_PDZ_Class_1_M1560_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1560_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1560_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M1572_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1572_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1572_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M1584_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1584_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1584_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M1590_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1590_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1590_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M853_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M853_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M853_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_MFL_Dmin (known_extension)
# LIG_PDZ_Class_1_Mmin_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_Mmin_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_Mmin_DFL (known_extension)
# LIG_Pex14_3_M1_M412_D1_D377 (known_extension)
# LIG_Pex14_3_M1_M412_Dmin (known_extension)
# LIG_Pex14_3_M26_M103_D1_D377 (known_extension)
# LIG_Pex14_3_M26_M103_Dmin (known_extension)
# LIG_Pex14_3_M38_M91_D1_D377 (known_extension)
# LIG_Pex14_3_M38_M91_Dmin (known_extension)
# LIG_Pex14_3_M50_M79_D1_D377 (known_extension)
# LIG_Pex14_3_M50_M79_Dmin (known_extension)
# LIG_Pex14_3_M56_M73_D1_D377 (known_extension)
# LIG_Pex14_3_M56_M73_Dmin (known_extension)
# LIG_Pex14_3_MFL_Dmin (known_extension)
# LIG_Pex14_3_Mmin_D1_D377 (known_extension)
# LIG_Pex14_3_Mmin_DFL (known_extension)
# LIG_REV1ctd_RIR_1_M401_M870_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M401_M870_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M401_M870_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M526_M624_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M624_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M624_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M526_M648_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M648_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M648_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M541_M600_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M541_M600_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M541_M600_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M553_M588_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M553_M588_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M553_M588_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_MFL_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_Mmin_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_Mmin_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_Mmin_DFL (known_extension)
# LIG_RPA_C_Vert_M1_M144_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M1_M144_Dmin (known_extension)
# LIG_RPA_C_Vert_M1_M309_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M1_M309_Dmin (known_extension)
# LIG_RPA_C_Vert_M41_M120_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M41_M120_Dmin (known_extension)
# LIG_RPA_C_Vert_M57_M104_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M57_M104_Dmin (known_extension)
# LIG_RPA_C_Vert_M9_M144_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M9_M144_Dmin (known_extension)
# LIG_RPA_C_Vert_MFL_Dmin (known_extension)
# LIG_RPA_C_Vert_Mmin_D1_D270 (known_extension)
# LIG_RPA_C_Vert_Mmin_DFL (known_extension)
# LIG_TRFH_1_M10_M451_D1_D370 (known_extension)
# LIG_TRFH_1_M10_M451_D1_D437 (known_extension)
# LIG_TRFH_1_M10_M451_Dmin (known_extension)
# LIG_TRFH_1_M228_M292_D1_D370 (known_extension)
# LIG_TRFH_1_M228_M292_D1_D437 (known_extension)
# LIG_TRFH_1_M228_M292_Dmin (known_extension)
# LIG_TRFH_1_M238_M282_D1_D370 (known_extension)
# LIG_TRFH_1_M238_M282_D1_D437 (known_extension)
# LIG_TRFH_1_M238_M282_Dmin (known_extension)
# LIG_TRFH_1_M248_M272_D1_D370 (known_extension)
# LIG_TRFH_1_M248_M272_D1_D437 (known_extension)
# LIG_TRFH_1_M248_M272_Dmin (known_extension)
# LIG_TRFH_1_M253_M267_D1_D370 (known_extension)
# LIG_TRFH_1_M253_M267_D1_D437 (known_extension)
# LIG_TRFH_1_M253_M267_Dmin (known_extension)
# LIG_TRFH_1_MFL_Dmin (known_extension)
# LIG_TRFH_1_Mmin_D1_D370 (known_extension)
# LIG_TRFH_1_Mmin_D1_D437 (known_extension)
# LIG_TRFH_1_Mmin_DFL (known_extension)
# LIG_ULM_U2AF65_1_M1_M140_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M140_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M140_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M1_M41_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M41_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M41_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M1_M59_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M59_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M59_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M1_M77_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M77_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M77_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M6_M32_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M6_M32_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M6_M32_Dmin (known_extension)
# LIG_ULM_U2AF65_1_MFL_Dmin (known_extension)
# LIG_ULM_U2AF65_1_Mmin_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_Mmin_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_Mmin_DFL (known_extension)
# LIG_Vh1_VBS_1_M196_M1983_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M196_M1983_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M196_M1983_Dmin (known_extension)
# LIG_Vh1_VBS_1_M494_M740_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M494_M740_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M494_M740_Dmin (known_extension)
# LIG_Vh1_VBS_1_M532_M702_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M532_M702_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M532_M702_Dmin (known_extension)
# LIG_Vh1_VBS_1_M570_M664_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M570_M664_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M570_M664_Dmin (known_extension)
# LIG_Vh1_VBS_1_M589_M645_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M589_M645_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M589_M645_Dmin (known_extension)
# LIG_Vh1_VBS_1_MFL_Dmin (known_extension)
# LIG_Vh1_VBS_1_Mmin_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_Mmin_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_Mmin_DFL (known_extension)
# LIG_WW_1_M597_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M597_M895_Dmin (known_extension)
# LIG_WW_1_M865_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M865_M895_Dmin (known_extension)
# LIG_WW_1_M873_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M873_M895_Dmin (known_extension)
# LIG_WW_1_M881_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M881_M895_Dmin (known_extension)
# LIG_WW_1_M885_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M885_M895_Dmin (known_extension)
# LIG_WW_1_MFL_Dmin (known_extension)
# LIG_WW_1_Mmin_D2925_D3362 (known_extension)
# TRG_AP2beta_CARGO_1_M190_M308_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M190_M308_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M190_M308_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M212_M308_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M212_M308_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M212_M308_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M234_M288_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M234_M288_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M234_M288_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M245_M277_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M245_M277_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M245_M277_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M38_M308_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M38_M308_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M38_M308_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_MFL_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_Mmin_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_Mmin_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_Mmin_DFL (known_extension)
#      model_preset    benchmark_set                    prediction_name  \
# 2710          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2711          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2712          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2713          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2714          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# ...           ...              ...                                ...
# 5525          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5526          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5527          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5528          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5529          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
#
#       model_id                                         model_path  \
# 2710  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2711  ranked_1  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2712  ranked_2  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2713  ranked_3  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2714  ranked_4  AlphaFold_benchmark_DMI/known_extension/nostal...
# ...        ...                                                ...
# 5525  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5526  ranked_1  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5527  ranked_2  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5528  ranked_3  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5529  ranked_4  AlphaFold_benchmark_DMI/known_extension/sponta...
#
#       ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 2710            1.0            NaN            NaN                  NaN
# 2711            0.9            NaN            NaN                  NaN
# 2712            0.8            NaN            NaN                  NaN
# 2713            0.7            NaN            NaN                  NaN
# 2714            0.6            NaN            NaN                  NaN
# ...             ...            ...            ...                  ...
# 5525            1.0            NaN            NaN                  NaN
# 5526            0.9            NaN            NaN                  NaN
# 5527            0.8            NaN            NaN                  NaN
# 5528            0.7            NaN            NaN                  NaN
# 5529            0.6            NaN            NaN                  NaN
#
#       has_clash  ...  ELM_instance_random_paired  DDI_pfam_id_random_paired  \
# 2710        NaN  ...                        None                       None
# 2711        NaN  ...                        None                       None
# 2712        NaN  ...                        None                       None
# 2713        NaN  ...                        None                       None
# 2714        NaN  ...                        None                       None
# ...         ...  ...                         ...                        ...
# 5525        NaN  ...                        None                       None
# 5526        NaN  ...                        None                       None
# 5527        NaN  ...                        None                       None
# 5528        NaN  ...                        None                       None
# 5529        NaN  ...                        None                       None
#
#       PDB_id  align_score_domain  num_align_atoms_domain  \
# 2710    4GGD              1681.0                    2414
# 2711    4GGD              1681.0                    2414
# 2712    4GGD              1681.0                    2414
# 2713    4GGD              1681.0                    2414
# 2714    4GGD              1681.0                    2414
# ...      ...                 ...                     ...
# 5525    2G30              1224.0                    1848
# 5526    2G30              1224.0                    1848
# 5527    2G30              1224.0                    1848
# 5528    2G30              1224.0                    1848
# 5529    2G30              1224.0                    1848
#
#       num_align_resi_domain  RMSD_all_atom  RMSD_domain  \
# 2710                    312       0.779362     0.779362
# 2711                    312       0.850033     0.850033
# 2712                    312       0.802006     0.802006
# 2713                    312       0.846242     0.846242
# 2714                    312       0.806754     0.806754
# ...                     ...            ...          ...
# 5525                    233       0.854878     0.818453
# 5526                    233       0.879837     0.854961
# 5527                    233       0.883954     0.857443
# 5528                    233       0.857197     0.815641
# 5529                    233       0.819131     0.793186
#
#       RMSD_backbone_peptide  RMSD_all_atom_peptide
# 2710              32.487099              33.511379
# 2711              32.519211              33.687027
# 2712               0.850706               1.085235
# 2713              33.459137              34.722588
# 2714              32.800415              34.047897
# ...                     ...                    ...
# 5525               0.820616                1.43463
# 5526               0.626592               1.300052
# 5527               0.783449               1.336963
# 5528               0.791843               1.497762
# 5529               0.540157               1.245331
#
# [2820 rows x 41 columns]

# %% [markdown]
# ### 4 DockQ
# Calculate DockQ metrics for the known_DMI and known_DDI set using the offical package. The following columns are added to the table:
# - **DockQ**: DockQ metric
# - **iRMSD**: RMSD of interfacial residues
# - **LRMSD**: Ligand RMSD. In case of DMI is this the motif, for DDI the smaller domain
# - **Fnonnat**: Fraction of predicted contacts that are not native (same as FPR)
#
# For more details read the details on the offical GitHub repo: [https://github.com/bjornwallner/DockQ](https://github.com/bjornwallner/DockQ)

# %%
from DockQ.DockQ import load_PDB, run_on_all_native_interfaces

dataAF["DockQ"] = np.nan
dataAF["iRMSD"] = np.nan
dataAF["LRMSD"] = np.nan
dataAF["Fnonnat"] = np.nan
for i, row in dataAF[dataAF["benchmark_set"].isin(["known_extension"])].iterrows():
    benchmark_set = str(row["benchmark_set"])
    _set = "DDI" if "DDI" in benchmark_set else "DMI"
    pdb_id = str(row["PDB_id"]) if row.notnull()["PDB_id"] else None
    pdb_id_2 =  None
    ddi_pfam_id =  None
    ddi_pfam_id_2 = None
    prediction_name = str(row["prediction_name"]) if row.notnull()["prediction_name"] else None
    model_id = str(row["model_id"]) if row.notnull()["model_id"] else None
    chainA_id = str(row["chainA_id"]) if row.notnull()["chainA_id"] else None
    chainB_id = str(row["chainB_id"]) if row.notnull()["chainB_id"] else None
    chainA_start = int(row["chainA_start"]) if row.notnull()["chainA_start"] else None
    chainB_start = int(row["chainB_start"]) if row.notnull()["chainB_start"] else None
    chainA_end = int(row["chainA_end"]) if row.notnull()["chainA_end"] else None
    chainB_end = int(row["chainB_end"]) if row.notnull()["chainB_end"] else None

    if model_id == "ranked_0":
        print(f"{bcolors.OKBLUE}{prediction_name} ({benchmark_set}){bcolors.ENDC}")

    structure_path = path_resources / "DMI" / benchmark_set / prediction_name / (model_id + ".pdb")
    if not structure_path.exists():
        print(f"\t{bcolors.FAIL}{prediction_name} ({benchmark_set}) does not exist.{bcolors.ENDC} Skip DockQ")
        continue

    template_row = dataSolved.loc[np.logical_and(dataSolved["set"] == _set, np.logical_and(dataSolved["PDB_id"] == pdb_id, np.logical_or(dataSolved["DDI_pfam_id"] == ddi_pfam_id, dataSolved["DDI_pfam_id"].isna())))]
    if len(template_row) == 0:
        print(f"\t{bcolors.FAIL}Can't find template structure for {prediction_name} ({benchmark_set}) and PDB ID {pdb_id}.{bcolors.ENDC} Skip")
        continue
    elif len(template_row) >= 2:
        print(f"\t{bcolors.FAIL}Multiple template structures found for {prediction_name} ({benchmark_set}) and PDB ID {pdb_id}.{bcolors.ENDC} Skip")
        continue
    template_path = path_solved / str(template_row["path"].item())
    dockq_structure_af = load_PDB(str(structure_path))
    dockq_structure_solved = load_PDB(str(template_path))

    chain_map = {chainA_id: "A", chainB_id:"B"}
    chain_key = chainA_id + chainB_id

    result = run_on_all_native_interfaces(dockq_structure_af, dockq_structure_solved, chain_map=chain_map)[0]
    dataAF.at[i, "DockQ"] = result[chain_key]["DockQ"]
    dataAF.at[i, "iRMSD"] = result[chain_key]["iRMSD"]
    dataAF.at[i, "LRMSD"] = result[chain_key]["LRMSD"]
    dataAF.at[i, "Fnonnat"] = np.float64(result[chain_key]["fnonnat"])

display(dataAF)
# Out:
# DEG_APCC_KENBOX_2_M15_M39_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M15_M39_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M1_M189_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M1_M189_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M1_M57_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M1_M57_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M20_M34_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M20_M34_Dmin (known_extension)
# DEG_APCC_KENBOX_2_M5_M49_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_M5_M49_Dmin (known_extension)
# DEG_APCC_KENBOX_2_MFL_Dmin (known_extension)
# DEG_APCC_KENBOX_2_Mmin_D1_D499 (known_extension)
# DEG_APCC_KENBOX_2_Mmin_DFL (known_extension)
# DEG_Kelch_Keap1_1_M1_M568_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M1_M568_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M1_M568_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M41_M118_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M41_M118_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M41_M118_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M53_M106_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M53_M106_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M53_M106_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M65_M94_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M65_M94_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M65_M94_Dmin (known_extension)
# DEG_Kelch_Keap1_1_M71_M88_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_M71_M88_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_M71_M88_Dmin (known_extension)
# DEG_Kelch_Keap1_1_MFL_Dmin (known_extension)
# DEG_Kelch_Keap1_1_Mmin_D175_D624 (known_extension)
# DEG_Kelch_Keap1_1_Mmin_D295_D624 (known_extension)
# DEG_Kelch_Keap1_1_Mmin_DFL (known_extension)
# DEG_MDM2_SWIB_1_M11_M34_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M11_M34_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M11_M34_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M1_M298_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M1_M298_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M1_M298_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M1_M58_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M1_M58_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M1_M58_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M1_M74_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M1_M74_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M1_M74_Dmin (known_extension)
# DEG_MDM2_SWIB_1_M3_M42_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_M3_M42_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_M3_M42_Dmin (known_extension)
# DEG_MDM2_SWIB_1_MFL_Dmin (known_extension)
# DEG_MDM2_SWIB_1_Mmin_D1_D290 (known_extension)
# DEG_MDM2_SWIB_1_Mmin_D1_D337 (known_extension)
# DEG_MDM2_SWIB_1_Mmin_DFL (known_extension)
# DEG_SIAH_1_M1_M166_D1_D282 (known_extension)
# DEG_SIAH_1_M1_M166_Dmin (known_extension)
# DEG_SIAH_1_M23_M103_D1_D282 (known_extension)
# DEG_SIAH_1_M23_M103_Dmin (known_extension)
# DEG_SIAH_1_M41_M85_D1_D282 (known_extension)
# DEG_SIAH_1_M41_M85_Dmin (known_extension)
# DEG_SIAH_1_M50_M76_D1_D282 (known_extension)
# DEG_SIAH_1_M50_M76_Dmin (known_extension)
# DEG_SIAH_1_M5_M121_D1_D282 (known_extension)
# DEG_SIAH_1_M5_M121_Dmin (known_extension)
# DEG_SIAH_1_MFL_Dmin (known_extension)
# DEG_SIAH_1_Mmin_D1_D282 (known_extension)
# DEG_SIAH_1_Mmin_DFL (known_extension)
# DOC_ANK_TNKS_1_M1_M322_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M1_M322_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M1_M322_Dmin (known_extension)
# DOC_ANK_TNKS_1_M29_M132_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M29_M132_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M29_M132_Dmin (known_extension)
# DOC_ANK_TNKS_1_M45_M116_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M45_M116_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M45_M116_Dmin (known_extension)
# DOC_ANK_TNKS_1_M61_M100_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M61_M100_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M61_M100_Dmin (known_extension)
# DOC_ANK_TNKS_1_M69_M92_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_M69_M92_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_M69_M92_Dmin (known_extension)
# DOC_ANK_TNKS_1_MFL_Dmin (known_extension)
# DOC_ANK_TNKS_1_Mmin_D391_D742 (known_extension)
# DOC_ANK_TNKS_1_Mmin_D471_D669 (known_extension)
# DOC_ANK_TNKS_1_Mmin_DFL (known_extension)
# DOC_MAPK_JIP1_4_M29_M455_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M29_M455_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M301_M391_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M301_M391_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M315_M377_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M315_M377_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M329_M363_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M329_M363_Dmin (known_extension)
# DOC_MAPK_JIP1_4_M336_M356_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_M336_M356_Dmin (known_extension)
# DOC_MAPK_JIP1_4_MFL_Dmin (known_extension)
# DOC_MAPK_JIP1_4_Mmin_D1_D464 (known_extension)
# DOC_MAPK_JIP1_4_Mmin_DFL (known_extension)
# DOC_SPAK_OSR1_1_M1006_M1030_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1006_M1030_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1006_M1030_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M1011_M1025_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1011_M1025_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M1011_M1025_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M443_M1243_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M443_M1243_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M443_M1243_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M986_M1050_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M986_M1050_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M986_M1050_Dmin (known_extension)
# DOC_SPAK_OSR1_1_M996_M1040_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_M996_M1040_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_M996_M1040_Dmin (known_extension)
# DOC_SPAK_OSR1_1_MFL_Dmin (known_extension)
# DOC_SPAK_OSR1_1_Mmin_D301_D527 (known_extension)
# DOC_SPAK_OSR1_1_Mmin_D7_D527 (known_extension)
# DOC_SPAK_OSR1_1_Mmin_DFL (known_extension)
# DOC_USP7_MATH_1_M290_M491_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M290_M491_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M290_M491_Dmin (known_extension)
# DOC_USP7_MATH_1_M367_M431_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M367_M431_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M367_M431_Dmin (known_extension)
# DOC_USP7_MATH_1_M377_M421_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M377_M421_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M377_M421_Dmin (known_extension)
# DOC_USP7_MATH_1_M387_M411_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M387_M411_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M387_M411_Dmin (known_extension)
# DOC_USP7_MATH_1_M392_M406_D1_D204 (known_extension)
# DOC_USP7_MATH_1_M392_M406_D1_D528 (known_extension)
# DOC_USP7_MATH_1_M392_M406_Dmin (known_extension)
# DOC_USP7_MATH_1_MFL_Dmin (known_extension)
# DOC_USP7_MATH_1_Mmin_D1_D204 (known_extension)
# DOC_USP7_MATH_1_Mmin_D1_D528 (known_extension)
# DOC_USP7_MATH_1_Mmin_DFL (known_extension)
# DOC_USP7_UBL2_3_M1099_M1135_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1135_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1135_Dmin (known_extension)
# DOC_USP7_UBL2_3_M1099_M1140_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1140_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1099_M1140_Dmin (known_extension)
# DOC_USP7_UBL2_3_M1101_M1125_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1101_M1125_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1101_M1125_Dmin (known_extension)
# DOC_USP7_UBL2_3_M1106_M1120_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M1106_M1120_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M1106_M1120_Dmin (known_extension)
# DOC_USP7_UBL2_3_M922_M1603_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_M922_M1603_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_M922_M1603_Dmin (known_extension)
# DOC_USP7_UBL2_3_MFL_Dmin (known_extension)
# DOC_USP7_UBL2_3_Mmin_D204_D1096 (known_extension)
# DOC_USP7_UBL2_3_Mmin_D528_D865 (known_extension)
# DOC_USP7_UBL2_3_Mmin_DFL (known_extension)
# LIG_BIR_III_2_M151_M416_D156_D497 (known_extension)
# LIG_BIR_III_2_M151_M416_D240_D437 (known_extension)
# LIG_BIR_III_2_M151_M416_Dmin (known_extension)
# LIG_BIR_III_2_M285_M349_D156_D497 (known_extension)
# LIG_BIR_III_2_M285_M349_D240_D437 (known_extension)
# LIG_BIR_III_2_M285_M349_Dmin (known_extension)
# LIG_BIR_III_2_M295_M339_D156_D497 (known_extension)
# LIG_BIR_III_2_M295_M339_D240_D437 (known_extension)
# LIG_BIR_III_2_M295_M339_Dmin (known_extension)
# LIG_BIR_III_2_M305_M329_D156_D497 (known_extension)
# LIG_BIR_III_2_M305_M329_D240_D437 (known_extension)
# LIG_BIR_III_2_M305_M329_Dmin (known_extension)
# LIG_BIR_III_2_M310_M324_D156_D497 (known_extension)
# LIG_BIR_III_2_M310_M324_D240_D437 (known_extension)
# LIG_BIR_III_2_M310_M324_Dmin (known_extension)
# LIG_BIR_III_2_MFL_Dmin (known_extension)
# LIG_BIR_III_2_Mmin_D156_D497 (known_extension)
# LIG_BIR_III_2_Mmin_D240_D437 (known_extension)
# LIG_BIR_III_2_Mmin_DFL (known_extension)
# LIG_CAP-Gly_1_M1406_M1438_D1_D517 (known_extension)
# LIG_CAP-Gly_1_M1406_M1438_D1_D815 (known_extension)
# LIG_CAP-Gly_1_M1406_M1438_Dmin (known_extension)
# LIG_CAP-Gly_1_M1432_M1438_D1_D517 (known_extension)
# LIG_CAP-Gly_1_M1432_M1438_D1_D815 (known_extension)
# LIG_CAP-Gly_1_M1432_M1438_Dmin (known_extension)
# LIG_CAP-Gly_1_MFL_Dmin (known_extension)
# LIG_CAP-Gly_1_Mmin_D1_D517 (known_extension)
# LIG_CAP-Gly_1_Mmin_D1_D815 (known_extension)
# LIG_CAP-Gly_1_Mmin_DFL (known_extension)
# LIG_CAP-Gly_2_M120_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M120_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M120_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M533_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M533_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M533_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M547_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M547_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M547_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M561_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M561_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M561_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_M568_M581_D1_D204 (known_extension)
# LIG_CAP-Gly_2_M568_M581_D1_D288 (known_extension)
# LIG_CAP-Gly_2_M568_M581_Dmin (known_extension)
# LIG_CAP-Gly_2_MFL_Dmin (known_extension)
# LIG_CAP-Gly_2_Mmin_D1_D204 (known_extension)
# LIG_CAP-Gly_2_Mmin_D1_D288 (known_extension)
# LIG_CAP-Gly_2_Mmin_DFL (known_extension)
# LIG_CNOT1_NIM_1_M1_M109_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M109_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M109_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M1_M276_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M276_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M276_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M1_M89_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M89_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M1_M89_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M20_M69_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M20_M69_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M20_M69_Dmin (known_extension)
# LIG_CNOT1_NIM_1_M30_M59_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M30_M59_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_M30_M59_Dmin (known_extension)
# LIG_CNOT1_NIM_1_MFL_Dmin (known_extension)
# LIG_CNOT1_NIM_1_Mmin_D1377_D2376 (known_extension)
# LIG_CNOT1_NIM_1_Mmin_D1544_D2376 (known_extension)
# LIG_CNOT1_NIM_1_Mmin_DFL (known_extension)
# LIG_EF_ALG2_ABM_1_M403_M868_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M403_M868_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M748_M864_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M748_M864_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M766_M846_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M766_M846_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M784_M828_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M784_M828_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_M793_M819_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_M793_M819_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_MFL_Dmin (known_extension)
# LIG_EF_ALG2_ABM_1_Mmin_D1_D191 (known_extension)
# LIG_EF_ALG2_ABM_1_Mmin_DFL (known_extension)
# LIG_GYF_M125_M351_D1_D341 (known_extension)
# LIG_GYF_M125_M351_Dmin (known_extension)
# LIG_GYF_M241_M351_D1_D341 (known_extension)
# LIG_GYF_M241_M351_Dmin (known_extension)
# LIG_GYF_M259_M339_D1_D341 (known_extension)
# LIG_GYF_M259_M339_Dmin (known_extension)
# LIG_GYF_M277_M321_D1_D341 (known_extension)
# LIG_GYF_M277_M321_Dmin (known_extension)
# LIG_GYF_M286_M312_D1_D341 (known_extension)
# LIG_GYF_M286_M312_Dmin (known_extension)
# LIG_GYF_MFL_Dmin (known_extension)
# LIG_GYF_Mmin_D1_D341 (known_extension)
# LIG_GYF_Mmin_DFL (known_extension)
# LIG_HOMEOBOX_M156_M207_D242_D430 (known_extension)
# LIG_HOMEOBOX_M156_M207_D30_D430 (known_extension)
# LIG_HOMEOBOX_M156_M207_Dmin (known_extension)
# LIG_HOMEOBOX_M164_M199_D242_D430 (known_extension)
# LIG_HOMEOBOX_M164_M199_D30_D430 (known_extension)
# LIG_HOMEOBOX_M164_M199_Dmin (known_extension)
# LIG_HOMEOBOX_M172_M191_D242_D430 (known_extension)
# LIG_HOMEOBOX_M172_M191_D30_D430 (known_extension)
# LIG_HOMEOBOX_M172_M191_Dmin (known_extension)
# LIG_HOMEOBOX_M176_M187_D242_D430 (known_extension)
# LIG_HOMEOBOX_M176_M187_D30_D430 (known_extension)
# LIG_HOMEOBOX_M176_M187_Dmin (known_extension)
# LIG_HOMEOBOX_M1_M270_D242_D430 (known_extension)
# LIG_HOMEOBOX_M1_M270_D30_D430 (known_extension)
# LIG_HOMEOBOX_M1_M270_Dmin (known_extension)
# LIG_HOMEOBOX_MFL_Dmin (known_extension)
# LIG_HOMEOBOX_Mmin_D242_D430 (known_extension)
# LIG_HOMEOBOX_Mmin_D30_D430 (known_extension)
# LIG_HOMEOBOX_Mmin_DFL (known_extension)
# LIG_LIR_Gen_1_M369_M966_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M369_M966_Dmin (known_extension)
# LIG_LIR_Gen_1_M664_M806_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M664_M806_Dmin (known_extension)
# LIG_LIR_Gen_1_M686_M784_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M686_M784_Dmin (known_extension)
# LIG_LIR_Gen_1_M708_M762_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M708_M762_Dmin (known_extension)
# LIG_LIR_Gen_1_M719_M751_D1_D117 (known_extension)
# LIG_LIR_Gen_1_M719_M751_Dmin (known_extension)
# LIG_LIR_Gen_1_MFL_Dmin (known_extension)
# LIG_LIR_Gen_1_Mmin_D1_D117 (known_extension)
# LIG_LIR_Gen_1_Mmin_DFL (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M149_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M149_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M149_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M85_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M85_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M1_M85_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M23_M57_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M23_M57_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M23_M57_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M30_M50_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M30_M50_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M30_M50_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_M9_M71_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_M9_M71_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_M9_M71_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_MFL_Dmin (known_extension)
# LIG_LRP6_Inhibitor_1_Mmin_D1_D362 (known_extension)
# LIG_LRP6_Inhibitor_1_Mmin_D1_D422 (known_extension)
# LIG_LRP6_Inhibitor_1_Mmin_DFL (known_extension)
# LIG_NBox_RRM_1_M1_M102_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M1_M102_Dmin (known_extension)
# LIG_NBox_RRM_1_M1_M175_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M1_M175_Dmin (known_extension)
# LIG_NBox_RRM_1_M1_M85_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M1_M85_Dmin (known_extension)
# LIG_NBox_RRM_1_M20_M52_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M20_M52_Dmin (known_extension)
# LIG_NBox_RRM_1_M9_M63_D1_D559 (known_extension)
# LIG_NBox_RRM_1_M9_M63_Dmin (known_extension)
# LIG_NBox_RRM_1_MFL_Dmin (known_extension)
# LIG_NBox_RRM_1_Mmin_D1_D559 (known_extension)
# LIG_NBox_RRM_1_Mmin_DFL (known_extension)
# LIG_NRBOX_M453_M826_D174_D595 (known_extension)
# LIG_NRBOX_M453_M826_D262_D542 (known_extension)
# LIG_NRBOX_M453_M826_Dmin (known_extension)
# LIG_NRBOX_M647_M737_D174_D595 (known_extension)
# LIG_NRBOX_M647_M737_D262_D542 (known_extension)
# LIG_NRBOX_M647_M737_Dmin (known_extension)
# LIG_NRBOX_M661_M723_D174_D595 (known_extension)
# LIG_NRBOX_M661_M723_D262_D542 (known_extension)
# LIG_NRBOX_M661_M723_Dmin (known_extension)
# LIG_NRBOX_M675_M709_D174_D595 (known_extension)
# LIG_NRBOX_M675_M709_D262_D542 (known_extension)
# LIG_NRBOX_M675_M709_Dmin (known_extension)
# LIG_NRBOX_M682_M702_D174_D595 (known_extension)
# LIG_NRBOX_M682_M702_D262_D542 (known_extension)
# LIG_NRBOX_M682_M702_Dmin (known_extension)
# LIG_NRBOX_MFL_Dmin (known_extension)
# LIG_NRBOX_Mmin_D174_D595 (known_extension)
# LIG_NRBOX_Mmin_D262_D542 (known_extension)
# LIG_NRBOX_Mmin_DFL (known_extension)
# LIG_OCRL_FandH_1_M12_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M12_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M12_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M145_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M145_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M145_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M171_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M171_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M171_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M197_M249_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M197_M249_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M197_M249_Dmin (known_extension)
# LIG_OCRL_FandH_1_M210_M248_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_M210_M248_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_M210_M248_Dmin (known_extension)
# LIG_OCRL_FandH_1_MFL_Dmin (known_extension)
# LIG_OCRL_FandH_1_Mmin_D235_D901 (known_extension)
# LIG_OCRL_FandH_1_Mmin_D534_D901 (known_extension)
# LIG_OCRL_FandH_1_Mmin_DFL (known_extension)
# LIG_PAM2_1_M1_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M1_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M1_M127_Dmin (known_extension)
# LIG_PAM2_1_M31_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M31_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M31_M127_Dmin (known_extension)
# LIG_PAM2_1_M57_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M57_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M57_M127_Dmin (known_extension)
# LIG_PAM2_1_M83_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M83_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M83_M127_Dmin (known_extension)
# LIG_PAM2_1_M96_M127_D286_D636 (known_extension)
# LIG_PAM2_1_M96_M127_D373_D636 (known_extension)
# LIG_PAM2_1_M96_M127_Dmin (known_extension)
# LIG_PAM2_1_MFL_Dmin (known_extension)
# LIG_PAM2_1_Mmin_D286_D636 (known_extension)
# LIG_PAM2_1_Mmin_D373_D636 (known_extension)
# LIG_PAM2_1_Mmin_DFL (known_extension)
# LIG_PAM2_2_M1248_M1522_D286_D636 (known_extension)
# LIG_PAM2_2_M1248_M1522_D373_D636 (known_extension)
# LIG_PAM2_2_M1248_M1522_Dmin (known_extension)
# LIG_PAM2_2_M1301_M1482_D286_D636 (known_extension)
# LIG_PAM2_2_M1301_M1482_D373_D636 (known_extension)
# LIG_PAM2_2_M1301_M1482_Dmin (known_extension)
# LIG_PAM2_2_M1329_M1454_D286_D636 (known_extension)
# LIG_PAM2_2_M1329_M1454_D373_D636 (known_extension)
# LIG_PAM2_2_M1329_M1454_Dmin (known_extension)
# LIG_PAM2_2_M1357_M1426_D286_D636 (known_extension)
# LIG_PAM2_2_M1357_M1426_D373_D636 (known_extension)
# LIG_PAM2_2_M1357_M1426_Dmin (known_extension)
# LIG_PAM2_2_M1371_M1412_D286_D636 (known_extension)
# LIG_PAM2_2_M1371_M1412_D373_D636 (known_extension)
# LIG_PAM2_2_M1371_M1412_Dmin (known_extension)
# LIG_PAM2_2_MFL_Dmin (known_extension)
# LIG_PAM2_2_Mmin_D286_D636 (known_extension)
# LIG_PAM2_2_Mmin_D373_D636 (known_extension)
# LIG_PAM2_2_Mmin_DFL (known_extension)
# LIG_PCNA_PIPBox_1_M104_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M104_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M11_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M11_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M124_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M124_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M134_M163_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M134_M163_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_M84_M164_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_M84_M164_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_MFL_Dmin (known_extension)
# LIG_PCNA_PIPBox_1_Mmin_D1_D261 (known_extension)
# LIG_PCNA_PIPBox_1_Mmin_DFL (known_extension)
# LIG_PCNA_TLS_4_M401_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M401_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M814_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M814_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M830_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M830_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M846_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M846_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_M854_M870_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_M854_M870_Dmin (known_extension)
# LIG_PCNA_TLS_4_MFL_Dmin (known_extension)
# LIG_PCNA_TLS_4_Mmin_D1_D261 (known_extension)
# LIG_PCNA_TLS_4_Mmin_DFL (known_extension)
# LIG_PDZ_Class_1_M1560_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1560_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1560_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M1572_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1572_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1572_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M1584_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1584_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1584_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M1590_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M1590_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M1590_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_M853_M1601_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_M853_M1601_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_M853_M1601_Dmin (known_extension)
# LIG_PDZ_Class_1_MFL_Dmin (known_extension)
# LIG_PDZ_Class_1_Mmin_D1084_D1593 (known_extension)
# LIG_PDZ_Class_1_Mmin_D1185_D1492 (known_extension)
# LIG_PDZ_Class_1_Mmin_DFL (known_extension)
# LIG_Pex14_3_M1_M412_D1_D377 (known_extension)
# LIG_Pex14_3_M1_M412_Dmin (known_extension)
# LIG_Pex14_3_M26_M103_D1_D377 (known_extension)
# LIG_Pex14_3_M26_M103_Dmin (known_extension)
# LIG_Pex14_3_M38_M91_D1_D377 (known_extension)
# LIG_Pex14_3_M38_M91_Dmin (known_extension)
# LIG_Pex14_3_M50_M79_D1_D377 (known_extension)
# LIG_Pex14_3_M50_M79_Dmin (known_extension)
# LIG_Pex14_3_M56_M73_D1_D377 (known_extension)
# LIG_Pex14_3_M56_M73_Dmin (known_extension)
# LIG_Pex14_3_MFL_Dmin (known_extension)
# LIG_Pex14_3_Mmin_D1_D377 (known_extension)
# LIG_Pex14_3_Mmin_DFL (known_extension)
# LIG_REV1ctd_RIR_1_M401_M870_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M401_M870_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M401_M870_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M526_M624_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M624_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M624_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M526_M648_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M648_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M526_M648_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M541_M600_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M541_M600_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M541_M600_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_M553_M588_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M553_M588_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_M553_M588_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_MFL_Dmin (known_extension)
# LIG_REV1ctd_RIR_1_Mmin_D1002_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_Mmin_D1052_D1251 (known_extension)
# LIG_REV1ctd_RIR_1_Mmin_DFL (known_extension)
# LIG_RPA_C_Vert_M1_M144_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M1_M144_Dmin (known_extension)
# LIG_RPA_C_Vert_M1_M309_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M1_M309_Dmin (known_extension)
# LIG_RPA_C_Vert_M41_M120_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M41_M120_Dmin (known_extension)
# LIG_RPA_C_Vert_M57_M104_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M57_M104_Dmin (known_extension)
# LIG_RPA_C_Vert_M9_M144_D1_D270 (known_extension)
# LIG_RPA_C_Vert_M9_M144_Dmin (known_extension)
# LIG_RPA_C_Vert_MFL_Dmin (known_extension)
# LIG_RPA_C_Vert_Mmin_D1_D270 (known_extension)
# LIG_RPA_C_Vert_Mmin_DFL (known_extension)
# LIG_TRFH_1_M10_M451_D1_D370 (known_extension)
# LIG_TRFH_1_M10_M451_D1_D437 (known_extension)
# LIG_TRFH_1_M10_M451_Dmin (known_extension)
# LIG_TRFH_1_M228_M292_D1_D370 (known_extension)
# LIG_TRFH_1_M228_M292_D1_D437 (known_extension)
# LIG_TRFH_1_M228_M292_Dmin (known_extension)
# LIG_TRFH_1_M238_M282_D1_D370 (known_extension)
# LIG_TRFH_1_M238_M282_D1_D437 (known_extension)
# LIG_TRFH_1_M238_M282_Dmin (known_extension)
# LIG_TRFH_1_M248_M272_D1_D370 (known_extension)
# LIG_TRFH_1_M248_M272_D1_D437 (known_extension)
# LIG_TRFH_1_M248_M272_Dmin (known_extension)
# LIG_TRFH_1_M253_M267_D1_D370 (known_extension)
# LIG_TRFH_1_M253_M267_D1_D437 (known_extension)
# LIG_TRFH_1_M253_M267_Dmin (known_extension)
# LIG_TRFH_1_MFL_Dmin (known_extension)
# LIG_TRFH_1_Mmin_D1_D370 (known_extension)
# LIG_TRFH_1_Mmin_D1_D437 (known_extension)
# LIG_TRFH_1_Mmin_DFL (known_extension)
# LIG_ULM_U2AF65_1_M1_M140_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M140_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M140_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M1_M41_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M41_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M41_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M1_M59_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M59_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M59_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M1_M77_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M77_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M1_M77_Dmin (known_extension)
# LIG_ULM_U2AF65_1_M6_M32_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_M6_M32_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_M6_M32_Dmin (known_extension)
# LIG_ULM_U2AF65_1_MFL_Dmin (known_extension)
# LIG_ULM_U2AF65_1_Mmin_D251_D475 (known_extension)
# LIG_ULM_U2AF65_1_Mmin_D340_D475 (known_extension)
# LIG_ULM_U2AF65_1_Mmin_DFL (known_extension)
# LIG_Vh1_VBS_1_M196_M1983_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M196_M1983_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M196_M1983_Dmin (known_extension)
# LIG_Vh1_VBS_1_M494_M740_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M494_M740_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M494_M740_Dmin (known_extension)
# LIG_Vh1_VBS_1_M532_M702_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M532_M702_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M532_M702_Dmin (known_extension)
# LIG_Vh1_VBS_1_M570_M664_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M570_M664_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M570_M664_Dmin (known_extension)
# LIG_Vh1_VBS_1_M589_M645_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_M589_M645_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_M589_M645_Dmin (known_extension)
# LIG_Vh1_VBS_1_MFL_Dmin (known_extension)
# LIG_Vh1_VBS_1_Mmin_D1_D471 (known_extension)
# LIG_Vh1_VBS_1_Mmin_D1_D925 (known_extension)
# LIG_Vh1_VBS_1_Mmin_DFL (known_extension)
# LIG_WW_1_M597_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M597_M895_Dmin (known_extension)
# LIG_WW_1_M865_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M865_M895_Dmin (known_extension)
# LIG_WW_1_M873_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M873_M895_Dmin (known_extension)
# LIG_WW_1_M881_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M881_M895_Dmin (known_extension)
# LIG_WW_1_M885_M895_D2925_D3362 (known_extension)
# LIG_WW_1_M885_M895_Dmin (known_extension)
# LIG_WW_1_MFL_Dmin (known_extension)
# LIG_WW_1_Mmin_D2925_D3362 (known_extension)
# TRG_AP2beta_CARGO_1_M190_M308_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M190_M308_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M190_M308_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M212_M308_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M212_M308_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M212_M308_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M234_M288_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M234_M288_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M234_M288_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M245_M277_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M245_M277_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M245_M277_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_M38_M308_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M38_M308_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_M38_M308_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_MFL_Dmin (known_extension)
# TRG_AP2beta_CARGO_1_Mmin_D4_D937 (known_extension)
# TRG_AP2beta_CARGO_1_Mmin_D542_D937 (known_extension)
# TRG_AP2beta_CARGO_1_Mmin_DFL (known_extension)
#      model_preset    benchmark_set                    prediction_name  \
# 2710          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2711          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2712          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2713          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2714          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# ...           ...              ...                                ...
# 5525          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5526          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5527          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5528          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5529          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
#
#       model_id                                         model_path  \
# 2710  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2711  ranked_1  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2712  ranked_2  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2713  ranked_3  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2714  ranked_4  AlphaFold_benchmark_DMI/known_extension/nostal...
# ...        ...                                                ...
# 5525  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5526  ranked_1  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5527  ranked_2  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5528  ranked_3  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5529  ranked_4  AlphaFold_benchmark_DMI/known_extension/sponta...
#
#       ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 2710            1.0            NaN            NaN                  NaN
# 2711            0.9            NaN            NaN                  NaN
# 2712            0.8            NaN            NaN                  NaN
# 2713            0.7            NaN            NaN                  NaN
# 2714            0.6            NaN            NaN                  NaN
# ...             ...            ...            ...                  ...
# 5525            1.0            NaN            NaN                  NaN
# 5526            0.9            NaN            NaN                  NaN
# 5527            0.8            NaN            NaN                  NaN
# 5528            0.7            NaN            NaN                  NaN
# 5529            0.6            NaN            NaN                  NaN
#
#       has_clash  ...  num_align_atoms_domain  num_align_resi_domain  \
# 2710        NaN  ...                    2414                    312
# 2711        NaN  ...                    2414                    312
# 2712        NaN  ...                    2414                    312
# 2713        NaN  ...                    2414                    312
# 2714        NaN  ...                    2414                    312
# ...         ...  ...                     ...                    ...
# 5525        NaN  ...                    1848                    233
# 5526        NaN  ...                    1848                    233
# 5527        NaN  ...                    1848                    233
# 5528        NaN  ...                    1848                    233
# 5529        NaN  ...                    1848                    233
#
#       RMSD_all_atom  RMSD_domain  RMSD_backbone_peptide  \
# 2710       0.779362     0.779362              32.487099
# 2711       0.850033     0.850033              32.519211
# 2712       0.802006     0.802006               0.850706
# 2713       0.846242     0.846242              33.459137
# 2714       0.806754     0.806754              32.800415
# ...             ...          ...                    ...
# 5525       0.854878     0.818453               0.820616
# 5526       0.879837     0.854961               0.626592
# 5527       0.883954     0.857443               0.783449
# 5528       0.857197     0.815641               0.791843
# 5529       0.819131     0.793186               0.540157
#
#       RMSD_all_atom_peptide     DockQ     iRMSD      LRMSD   Fnonnat
# 2710              33.511379  0.030091  9.154708  32.471571  1.000000
# 2711              33.687027  0.030029  9.165312  32.505639  1.000000
# 2712               1.085235  0.957491  0.311560   0.821135  0.000000
# 2713              34.722588  0.028471  9.429981  33.426638  1.000000
# 2714              34.047897  0.029560  9.242351  32.776340  1.000000
# ...                     ...       ...       ...        ...       ...
# 5525                1.43463  0.955996  0.370099   0.859152  0.093750
# 5526               1.300052  0.960844  0.333205   0.656404  0.093750
# 5527               1.336963  0.959846  0.331209   0.830493  0.093750
# 5528               1.497762  0.953670  0.396883   0.812161  0.121212
# 5529               1.245331  0.961073  0.336588   0.560241  0.064516
#
# [2820 rows x 45 columns]

# %% [markdown]
# ### 5 IPSAE metric
# Calculating the new ipSAE metric using the file from the repo ([https://github.com/DunbrackLab/IPSAE/blob/main/ipsae.py](https://github.com/DunbrackLab/IPSAE/blob/main/ipsae.py)). Currently, only AlphaFold 3 is possible as the files from John do not include the confidence.json files anymore. Adds the following column:
# - **ipSAE** (all structures): The ipSAE metric for the AlphaFold prediction

# %%
def calc_ipsae_metric(row: pd.Series):
    path_cif = path_AF_luck_drive / Path(row["model_path"])

    sample_dir = path_cif.parent
    design_name = sample_dir.parent.name
    sample_name = sample_dir.name
    base_filename = f"{design_name}_{sample_name}"
    path_confidences = sample_dir / f"{base_filename}_confidences.json"
    path_summary_confidences = sample_dir / f"{base_filename}_summary_confidences.json"


    with tempfile.TemporaryDirectory() as tmpdir:
        shutil.copy(path_cif, tmp_path_cif := (Path(tmpdir) / "model.cif"))
        shutil.copy(path_confidences, tmp_path_confidences := (Path(tmpdir) / "confidences.json"))
        shutil.copy(path_summary_confidences, tmp_path_summary_confidences := (Path(tmpdir) / "summary_confidences.json"))
        subprocess.run(["python", path_ipsae_script, tmp_path_confidences, tmp_path_cif, "10", "10"], env=os.environ.copy())

        path_output = Path(tmpdir) / "model_10_10.txt"

        df_ipsae = pd.read_csv(path_output, header=0, skiprows=[0], sep=" ", skipinitialspace=True)
    return df_ipsae

# For AF2 the json files do not exist anymore
if af_mode == "AF3":
    dataAF["ipSAE"] = np.nan
    for i, row in dataAF.iterrows():
        if row["model_id"] == "ranked_0":
            print(row["prediction_name"], f"({round(100*i/len(dataAF))} %)")
        df_ipsae = calc_ipsae_metric(row)
        dataAF.at[i, "ipSAE"] = np.float64(df_ipsae["ipSAE"][2])
display(dataAF["ipSAE"])
# Out:
# DEG_APCC_KENBOX_2_M15_M39_D1_D499 (96 %)
# DEG_APCC_KENBOX_2_M15_M39_Dmin (96 %)
# DEG_APCC_KENBOX_2_M1_M189_D1_D499 (96 %)
# DEG_APCC_KENBOX_2_M1_M189_Dmin (97 %)
# DEG_APCC_KENBOX_2_M1_M57_D1_D499 (97 %)
# DEG_APCC_KENBOX_2_M1_M57_Dmin (97 %)
# DEG_APCC_KENBOX_2_M20_M34_D1_D499 (97 %)
# DEG_APCC_KENBOX_2_M20_M34_Dmin (97 %)
# DEG_APCC_KENBOX_2_M5_M49_D1_D499 (98 %)
# DEG_APCC_KENBOX_2_M5_M49_Dmin (98 %)
# DEG_APCC_KENBOX_2_MFL_Dmin (98 %)
# DEG_APCC_KENBOX_2_Mmin_D1_D499 (98 %)
# DEG_APCC_KENBOX_2_Mmin_DFL (98 %)
# DEG_Kelch_Keap1_1_M1_M568_D175_D624 (98 %)
# DEG_Kelch_Keap1_1_M1_M568_D295_D624 (99 %)
# DEG_Kelch_Keap1_1_M1_M568_Dmin (99 %)
# DEG_Kelch_Keap1_1_M41_M118_D175_D624 (99 %)
# DEG_Kelch_Keap1_1_M41_M118_D295_D624 (99 %)
# DEG_Kelch_Keap1_1_M41_M118_Dmin (99 %)
# DEG_Kelch_Keap1_1_M53_M106_D175_D624 (99 %)
# DEG_Kelch_Keap1_1_M53_M106_D295_D624 (100 %)
# DEG_Kelch_Keap1_1_M53_M106_Dmin (100 %)
# DEG_Kelch_Keap1_1_M65_M94_D175_D624 (100 %)
# DEG_Kelch_Keap1_1_M65_M94_D295_D624 (100 %)
# DEG_Kelch_Keap1_1_M65_M94_Dmin (100 %)
# DEG_Kelch_Keap1_1_M71_M88_D175_D624 (101 %)
# DEG_Kelch_Keap1_1_M71_M88_D295_D624 (101 %)
# DEG_Kelch_Keap1_1_M71_M88_Dmin (101 %)
# DEG_Kelch_Keap1_1_MFL_Dmin (101 %)
# DEG_Kelch_Keap1_1_Mmin_D175_D624 (101 %)
# DEG_Kelch_Keap1_1_Mmin_D295_D624 (101 %)
# DEG_Kelch_Keap1_1_Mmin_DFL (102 %)
# DEG_MDM2_SWIB_1_M11_M34_D1_D290 (102 %)
# DEG_MDM2_SWIB_1_M11_M34_D1_D337 (102 %)
# DEG_MDM2_SWIB_1_M11_M34_Dmin (102 %)
# DEG_MDM2_SWIB_1_M1_M298_D1_D290 (102 %)
# DEG_MDM2_SWIB_1_M1_M298_D1_D337 (102 %)
# DEG_MDM2_SWIB_1_M1_M298_Dmin (103 %)
# DEG_MDM2_SWIB_1_M1_M58_D1_D290 (103 %)
# DEG_MDM2_SWIB_1_M1_M58_D1_D337 (103 %)
# DEG_MDM2_SWIB_1_M1_M58_Dmin (103 %)
# DEG_MDM2_SWIB_1_M1_M74_D1_D290 (103 %)
# DEG_MDM2_SWIB_1_M1_M74_D1_D337 (104 %)
# DEG_MDM2_SWIB_1_M1_M74_Dmin (104 %)
# DEG_MDM2_SWIB_1_M3_M42_D1_D290 (104 %)
# DEG_MDM2_SWIB_1_M3_M42_D1_D337 (104 %)
# DEG_MDM2_SWIB_1_M3_M42_Dmin (104 %)
# DEG_MDM2_SWIB_1_MFL_Dmin (104 %)
# DEG_MDM2_SWIB_1_Mmin_D1_D290 (105 %)
# DEG_MDM2_SWIB_1_Mmin_D1_D337 (105 %)
# DEG_MDM2_SWIB_1_Mmin_DFL (105 %)
# DEG_SIAH_1_M1_M166_D1_D282 (105 %)
# DEG_SIAH_1_M1_M166_Dmin (105 %)
# DEG_SIAH_1_M23_M103_D1_D282 (105 %)
# DEG_SIAH_1_M23_M103_Dmin (106 %)
# DEG_SIAH_1_M41_M85_D1_D282 (106 %)
# DEG_SIAH_1_M41_M85_Dmin (106 %)
# DEG_SIAH_1_M50_M76_D1_D282 (106 %)
# DEG_SIAH_1_M50_M76_Dmin (106 %)
# DEG_SIAH_1_M5_M121_D1_D282 (107 %)
# DEG_SIAH_1_M5_M121_Dmin (107 %)
# DEG_SIAH_1_MFL_Dmin (107 %)
# DEG_SIAH_1_Mmin_D1_D282 (107 %)
# DEG_SIAH_1_Mmin_DFL (107 %)
# DOC_ANK_TNKS_1_M1_M322_D391_D742 (107 %)
# DOC_ANK_TNKS_1_M1_M322_D471_D669 (108 %)
# DOC_ANK_TNKS_1_M1_M322_Dmin (108 %)
# DOC_ANK_TNKS_1_M29_M132_D391_D742 (108 %)
# DOC_ANK_TNKS_1_M29_M132_D471_D669 (108 %)
# DOC_ANK_TNKS_1_M29_M132_Dmin (108 %)
# DOC_ANK_TNKS_1_M45_M116_D391_D742 (109 %)
# DOC_ANK_TNKS_1_M45_M116_D471_D669 (109 %)
# DOC_ANK_TNKS_1_M45_M116_Dmin (109 %)
# DOC_ANK_TNKS_1_M61_M100_D391_D742 (109 %)
# DOC_ANK_TNKS_1_M61_M100_D471_D669 (109 %)
# DOC_ANK_TNKS_1_M61_M100_Dmin (109 %)
# DOC_ANK_TNKS_1_M69_M92_D391_D742 (110 %)
# DOC_ANK_TNKS_1_M69_M92_D471_D669 (110 %)
# DOC_ANK_TNKS_1_M69_M92_Dmin (110 %)
# DOC_ANK_TNKS_1_MFL_Dmin (110 %)
# DOC_ANK_TNKS_1_Mmin_D391_D742 (110 %)
# DOC_ANK_TNKS_1_Mmin_D471_D669 (110 %)
# DOC_ANK_TNKS_1_Mmin_DFL (111 %)
# DOC_MAPK_JIP1_4_M29_M455_D1_D464 (111 %)
# DOC_MAPK_JIP1_4_M29_M455_Dmin (111 %)
# DOC_MAPK_JIP1_4_M301_M391_D1_D464 (111 %)
# DOC_MAPK_JIP1_4_M301_M391_Dmin (111 %)
# DOC_MAPK_JIP1_4_M315_M377_D1_D464 (112 %)
# DOC_MAPK_JIP1_4_M315_M377_Dmin (112 %)
# DOC_MAPK_JIP1_4_M329_M363_D1_D464 (112 %)
# DOC_MAPK_JIP1_4_M329_M363_Dmin (112 %)
# DOC_MAPK_JIP1_4_M336_M356_D1_D464 (112 %)
# DOC_MAPK_JIP1_4_M336_M356_Dmin (112 %)
# DOC_MAPK_JIP1_4_MFL_Dmin (113 %)
# DOC_MAPK_JIP1_4_Mmin_D1_D464 (113 %)
# DOC_MAPK_JIP1_4_Mmin_DFL (113 %)
# DOC_SPAK_OSR1_1_M1006_M1030_D301_D527 (113 %)
# DOC_SPAK_OSR1_1_M1006_M1030_D7_D527 (113 %)
# DOC_SPAK_OSR1_1_M1006_M1030_Dmin (113 %)
# DOC_SPAK_OSR1_1_M1011_M1025_D301_D527 (114 %)
# DOC_SPAK_OSR1_1_M1011_M1025_D7_D527 (114 %)
# DOC_SPAK_OSR1_1_M1011_M1025_Dmin (114 %)
# DOC_SPAK_OSR1_1_M443_M1243_D301_D527 (114 %)
# DOC_SPAK_OSR1_1_M443_M1243_D7_D527 (114 %)
# DOC_SPAK_OSR1_1_M443_M1243_Dmin (115 %)
# DOC_SPAK_OSR1_1_M986_M1050_D301_D527 (115 %)
# DOC_SPAK_OSR1_1_M986_M1050_D7_D527 (115 %)
# DOC_SPAK_OSR1_1_M986_M1050_Dmin (115 %)
# DOC_SPAK_OSR1_1_M996_M1040_D301_D527 (115 %)
# DOC_SPAK_OSR1_1_M996_M1040_D7_D527 (115 %)
# DOC_SPAK_OSR1_1_M996_M1040_Dmin (116 %)
# DOC_SPAK_OSR1_1_MFL_Dmin (116 %)
# DOC_SPAK_OSR1_1_Mmin_D301_D527 (116 %)
# DOC_SPAK_OSR1_1_Mmin_D7_D527 (116 %)
# DOC_SPAK_OSR1_1_Mmin_DFL (116 %)
# DOC_USP7_MATH_1_M290_M491_D1_D204 (116 %)
# DOC_USP7_MATH_1_M290_M491_D1_D528 (117 %)
# DOC_USP7_MATH_1_M290_M491_Dmin (117 %)
# DOC_USP7_MATH_1_M367_M431_D1_D204 (117 %)
# DOC_USP7_MATH_1_M367_M431_D1_D528 (117 %)
# DOC_USP7_MATH_1_M367_M431_Dmin (117 %)
# DOC_USP7_MATH_1_M377_M421_D1_D204 (118 %)
# DOC_USP7_MATH_1_M377_M421_D1_D528 (118 %)
# DOC_USP7_MATH_1_M377_M421_Dmin (118 %)
# DOC_USP7_MATH_1_M387_M411_D1_D204 (118 %)
# DOC_USP7_MATH_1_M387_M411_D1_D528 (118 %)
# DOC_USP7_MATH_1_M387_M411_Dmin (118 %)
# DOC_USP7_MATH_1_M392_M406_D1_D204 (119 %)
# DOC_USP7_MATH_1_M392_M406_D1_D528 (119 %)
# DOC_USP7_MATH_1_M392_M406_Dmin (119 %)
# DOC_USP7_MATH_1_MFL_Dmin (119 %)
# DOC_USP7_MATH_1_Mmin_D1_D204 (119 %)
# DOC_USP7_MATH_1_Mmin_D1_D528 (120 %)
# DOC_USP7_MATH_1_Mmin_DFL (120 %)
# DOC_USP7_UBL2_3_M1099_M1135_D204_D1096 (120 %)
# DOC_USP7_UBL2_3_M1099_M1135_D528_D865 (120 %)
# DOC_USP7_UBL2_3_M1099_M1135_Dmin (120 %)
# DOC_USP7_UBL2_3_M1099_M1140_D204_D1096 (120 %)
# DOC_USP7_UBL2_3_M1099_M1140_D528_D865 (121 %)
# DOC_USP7_UBL2_3_M1099_M1140_Dmin (121 %)
# DOC_USP7_UBL2_3_M1101_M1125_D204_D1096 (121 %)
# DOC_USP7_UBL2_3_M1101_M1125_D528_D865 (121 %)
# DOC_USP7_UBL2_3_M1101_M1125_Dmin (121 %)
# DOC_USP7_UBL2_3_M1106_M1120_D204_D1096 (121 %)
# DOC_USP7_UBL2_3_M1106_M1120_D528_D865 (122 %)
# DOC_USP7_UBL2_3_M1106_M1120_Dmin (122 %)
# DOC_USP7_UBL2_3_M922_M1603_D204_D1096 (122 %)
# DOC_USP7_UBL2_3_M922_M1603_D528_D865 (122 %)
# DOC_USP7_UBL2_3_M922_M1603_Dmin (122 %)
# DOC_USP7_UBL2_3_MFL_Dmin (123 %)
# DOC_USP7_UBL2_3_Mmin_D204_D1096 (123 %)
# DOC_USP7_UBL2_3_Mmin_D528_D865 (123 %)
# DOC_USP7_UBL2_3_Mmin_DFL (123 %)
# LIG_BIR_III_2_M151_M416_D156_D497 (123 %)
# LIG_BIR_III_2_M151_M416_D240_D437 (123 %)
# LIG_BIR_III_2_M151_M416_Dmin (124 %)
# LIG_BIR_III_2_M285_M349_D156_D497 (124 %)
# LIG_BIR_III_2_M285_M349_D240_D437 (124 %)
# LIG_BIR_III_2_M285_M349_Dmin (124 %)
# LIG_BIR_III_2_M295_M339_D156_D497 (124 %)
# LIG_BIR_III_2_M295_M339_D240_D437 (124 %)
# LIG_BIR_III_2_M295_M339_Dmin (125 %)
# LIG_BIR_III_2_M305_M329_D156_D497 (125 %)
# LIG_BIR_III_2_M305_M329_D240_D437 (125 %)
# LIG_BIR_III_2_M305_M329_Dmin (125 %)
# LIG_BIR_III_2_M310_M324_D156_D497 (125 %)
# LIG_BIR_III_2_M310_M324_D240_D437 (126 %)
# LIG_BIR_III_2_M310_M324_Dmin (126 %)
# LIG_BIR_III_2_MFL_Dmin (126 %)
# LIG_BIR_III_2_Mmin_D156_D497 (126 %)
# LIG_BIR_III_2_Mmin_D240_D437 (126 %)
# LIG_BIR_III_2_Mmin_DFL (126 %)
# LIG_CAP-Gly_1_M1406_M1438_D1_D517 (127 %)
# LIG_CAP-Gly_1_M1406_M1438_D1_D815 (127 %)
# LIG_CAP-Gly_1_M1406_M1438_Dmin (127 %)
# LIG_CAP-Gly_1_M1432_M1438_D1_D517 (127 %)
# LIG_CAP-Gly_1_M1432_M1438_D1_D815 (127 %)
# LIG_CAP-Gly_1_M1432_M1438_Dmin (127 %)
# LIG_CAP-Gly_1_MFL_Dmin (128 %)
# LIG_CAP-Gly_1_Mmin_D1_D517 (128 %)
# LIG_CAP-Gly_1_Mmin_D1_D815 (128 %)
# LIG_CAP-Gly_1_Mmin_DFL (128 %)
# LIG_CAP-Gly_2_M120_M581_D1_D204 (128 %)
# LIG_CAP-Gly_2_M120_M581_D1_D288 (129 %)
# LIG_CAP-Gly_2_M120_M581_Dmin (129 %)
# LIG_CAP-Gly_2_M533_M581_D1_D204 (129 %)
# LIG_CAP-Gly_2_M533_M581_D1_D288 (129 %)
# LIG_CAP-Gly_2_M533_M581_Dmin (129 %)
# LIG_CAP-Gly_2_M547_M581_D1_D204 (129 %)
# LIG_CAP-Gly_2_M547_M581_D1_D288 (130 %)
# LIG_CAP-Gly_2_M547_M581_Dmin (130 %)
# LIG_CAP-Gly_2_M561_M581_D1_D204 (130 %)
# LIG_CAP-Gly_2_M561_M581_D1_D288 (130 %)
# LIG_CAP-Gly_2_M561_M581_Dmin (130 %)
# LIG_CAP-Gly_2_M568_M581_D1_D204 (130 %)
# LIG_CAP-Gly_2_M568_M581_D1_D288 (131 %)
# LIG_CAP-Gly_2_M568_M581_Dmin (131 %)
# LIG_CAP-Gly_2_MFL_Dmin (131 %)
# LIG_CAP-Gly_2_Mmin_D1_D204 (131 %)
# LIG_CAP-Gly_2_Mmin_D1_D288 (131 %)
# LIG_CAP-Gly_2_Mmin_DFL (132 %)
# LIG_CNOT1_NIM_1_M1_M109_D1377_D2376 (132 %)
# LIG_CNOT1_NIM_1_M1_M109_D1544_D2376 (132 %)
# LIG_CNOT1_NIM_1_M1_M109_Dmin (132 %)
# LIG_CNOT1_NIM_1_M1_M276_D1377_D2376 (132 %)
# LIG_CNOT1_NIM_1_M1_M276_D1544_D2376 (132 %)
# LIG_CNOT1_NIM_1_M1_M276_Dmin (133 %)
# LIG_CNOT1_NIM_1_M1_M89_D1377_D2376 (133 %)
# LIG_CNOT1_NIM_1_M1_M89_D1544_D2376 (133 %)
# LIG_CNOT1_NIM_1_M1_M89_Dmin (133 %)
# LIG_CNOT1_NIM_1_M20_M69_D1377_D2376 (133 %)
# LIG_CNOT1_NIM_1_M20_M69_D1544_D2376 (134 %)
# LIG_CNOT1_NIM_1_M20_M69_Dmin (134 %)
# LIG_CNOT1_NIM_1_M30_M59_D1377_D2376 (134 %)
# LIG_CNOT1_NIM_1_M30_M59_D1544_D2376 (134 %)
# LIG_CNOT1_NIM_1_M30_M59_Dmin (134 %)
# LIG_CNOT1_NIM_1_MFL_Dmin (134 %)
# LIG_CNOT1_NIM_1_Mmin_D1377_D2376 (135 %)
# LIG_CNOT1_NIM_1_Mmin_D1544_D2376 (135 %)
# LIG_CNOT1_NIM_1_Mmin_DFL (135 %)
# Traceback (most recent call last):
#   File "/Users/imb/Desktop/ipsae.py", line 416, in <module>
#     data = json.load(file)
#   File "/opt/miniconda3/envs/pymol_env/lib/python3.10/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/opt/miniconda3/envs/pymol_env/lib/python3.10/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd0 in position 25165832: invalid continuation byte
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[49], line 29
#      27         if row["model_id"] == "ranked_0":
#      28             print(row["prediction_name"], f"({round(100*i/len(dataAF))} %)")
# ---> 29         df_ipsae = calc_ipsae_metric(row)
#      30         dataAF.at[i, "ipSAE"] = np.float64(df_ipsae["ipSAE"][2])
#      31 display(dataAF["ipSAE"])
#
# Cell In[49], line 20, in calc_ipsae_metric(row)
#      16     subprocess.run(["python", path_ipsae_script, tmp_path_confidences, tmp_path_cif, "10", "10"], env=os.environ.copy())
#      18     path_output = Path(tmpdir) / "model_10_10.txt"
# ---> 20     df_ipsae = pd.read_csv(path_output, header=0, skiprows=[0], sep=" ", skipinitialspace=True)
#      21 return df_ipsae
#
# File /opt/miniconda3/envs/pymol_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/pymol_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/miniconda3/envs/pymol_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/pymol_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File /opt/miniconda3/envs/pymol_env/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
print(tempfile.TemporaryDirectory())
# Out:
# <TemporaryDirectory '/var/folders/y7/rw09j59914xbqkvqvgq68_1c0000gn/T/tmpwe2zj6hd'>

# %% [markdown]
# ### 6 Interaction metrics
# Calculate the interaction interface metrics with the newly developed library. Adds the following columns to all structures with an experimentally solved counterpart (None if not):
# - **min_distance** [Å]: Distance of the C_alpha atoms (in Angstroms) in the interface if at least one atom pair between the residues is closer than 15 Angstrom.
# - **buried_area** [Å²]: Buried surface area of the interface (in Angstrom squared)
# - **disulfide_bonds** [count]: Number of disulfide bonds in the interface
# - **salt_bridges** [count]: Number of salt bridges in the interface
# - **hbonds** [count]: Number of hydrogen bonds in the interface
# - **hydrophobic_interactions** [count]: Number of hydrophobic interactions in the interface
#
# For a detailed explanation see either the library file (measure_PPI.py) or the bachelor thesis (can be found in the group drive)

# %%
libpath = Path("../Interface Metrics").resolve()
print(libpath)
sys.path.insert(0, str(libpath))
import measure_PPI
# Out:
# /Users/imb/Interface Metrics
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 4
#       2 print(libpath)
#       3 sys.path.insert(0, str(libpath))
# ----> 4 import measure_PPI
#
# ModuleNotFoundError: No module named 'measure_PPI'

# %%
pathObj = []
for i, row in dataAF.iterrows():
    benchmark_set = str(row["benchmark_set"])
    _set = "DDI" if "DDI" in benchmark_set else "DMI"
    prediction_name = str(row["prediction_name"]) if row.notnull()["prediction_name"] else None
    model_id = str(row["model_id"]) if row.notnull()["model_id"] else None

    structure_path = path_AF / _set / benchmark_set / prediction_name / (model_id + ".pdb")
    if not structure_path.exists():
        if row["model_id"] == "ranked_0":
            print(f"\t{bcolors.FAIL}{prediction_name} ({benchmark_set}) does not exist.{bcolors.ENDC} Skip interface metrics")
        continue

    pathObj.append((structure_path.resolve(), prediction_name))
df_intf_metrics = measure_PPI.Run(pathObj=pathObj, num_threads=12)
# Out:
# 	PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_resi172 (known_DDI) does not exist. Skip interface metrics
# 	PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57_resi127 (known_DDI) does not exist. Skip interface metrics
# [2025-05-15 19:06:35,957 | measure_PPI | INFO] Started Taskpool of 12 processes for 3170 files
# [2025-05-15 19:06:41,001 | measure_PPI | INFO] 2% - ETA 0:03:43 | current speed 14.077 s⁻¹ | average speed 13.878 s⁻¹
# [2025-05-15 19:06:46,038 | measure_PPI | INFO] 5% - ETA 0:02:40 | current speed 23.227 s⁻¹ | average speed 18.55 s⁻¹
# [2025-05-15 19:06:51,048 | measure_PPI | INFO] 11% - ETA 0:01:53 | current speed 36.922 s⁻¹ | average speed 24.649 s⁻¹
# [2025-05-15 19:06:56,112 | measure_PPI | INFO] 17% - ETA 0:01:37 | current speed 34.174 s⁻¹ | average speed 27.042 s⁻¹
# [2025-05-15 19:07:01,129 | measure_PPI | INFO] 22% - ETA 0:01:27 | current speed 33.074 s⁻¹ | average speed 28.245 s⁻¹
# [2025-05-15 19:07:06,139 | measure_PPI | INFO] 27% - ETA 0:01:20 | current speed 31.148 s⁻¹ | average speed 28.726 s⁻¹
# [2025-05-15 19:07:11,223 | measure_PPI | INFO] 32% - ETA 0:01:13 | current speed 30.878 s⁻¹ | average speed 29.037 s⁻¹
# [2025-05-15 19:07:16,317 | measure_PPI | INFO] 37% - ETA 0:01:08 | current speed 29.641 s⁻¹ | average speed 29.113 s⁻¹
# [2025-05-15 19:07:21,322 | measure_PPI | INFO] 42% - ETA 0:01:02 | current speed 32.368 s⁻¹ | average speed 29.472 s⁻¹
# [2025-05-15 19:07:26,335 | measure_PPI | INFO] 45% - ETA 0:01:00 | current speed 21.548 s⁻¹ | average speed 28.684 s⁻¹
# [2025-05-15 19:07:31,464 | measure_PPI | INFO] 49% - ETA 0:00:57 | current speed 22.223 s⁻¹ | average speed 28.087 s⁻¹
# [2025-05-15 19:07:36,543 | measure_PPI | INFO] 53% - ETA 0:00:52 | current speed 27.565 s⁻¹ | average speed 28.043 s⁻¹
# [2025-05-15 19:07:41,554 | measure_PPI | INFO] 58% - ETA 0:00:46 | current speed 32.128 s⁻¹ | average speed 28.355 s⁻¹
# [2025-05-15 19:07:46,595 | measure_PPI | INFO] 64% - ETA 0:00:39 | current speed 35.903 s⁻¹ | average speed 28.894 s⁻¹
# [2025-05-15 19:07:51,758 | measure_PPI | INFO] 68% - ETA 0:00:34 | current speed 26.733 s⁻¹ | average speed 28.747 s⁻¹
# [2025-05-15 19:07:56,759 | measure_PPI | INFO] 75% - ETA 0:00:26 | current speed 42.589 s⁻¹ | average speed 29.603 s⁻¹
# [2025-05-15 19:08:01,772 | measure_PPI | INFO] 81% - ETA 0:00:19 | current speed 37.301 s⁻¹ | average speed 30.053 s⁻¹
# [2025-05-15 19:08:06,932 | measure_PPI | INFO] 85% - ETA 0:00:15 | current speed 23.452 s⁻¹ | average speed 29.679 s⁻¹
# [2025-05-15 19:08:12,118 | measure_PPI | INFO] 86% - ETA 0:00:14 | current speed 8.674 s⁻¹ | average speed 28.546 s⁻¹
# [2025-05-15 19:08:17,186 | measure_PPI | INFO] 87% - ETA 0:00:14 | current speed 5.132 s⁻¹ | average speed 27.374 s⁻¹
# [2025-05-15 19:08:22,334 | measure_PPI | INFO] 88% - ETA 0:00:13 | current speed 9.713 s⁻¹ | average speed 26.519 s⁻¹
# [2025-05-15 19:08:27,450 | measure_PPI | INFO] 90% - ETA 0:00:11 | current speed 12.119 s⁻¹ | average speed 25.858 s⁻¹
# [2025-05-15 19:08:32,618 | measure_PPI | INFO] 92% - ETA 0:00:09 | current speed 11.03 s⁻¹ | average speed 25.201 s⁻¹
# [2025-05-15 19:08:37,727 | measure_PPI | INFO] 94% - ETA 0:00:07 | current speed 7.828 s⁻¹ | average speed 24.472 s⁻¹
# [2025-05-15 19:08:42,806 | measure_PPI | INFO] 94% - ETA 0:00:06 | current speed 5.908 s⁻¹ | average speed 23.729 s⁻¹
# [2025-05-15 19:08:47,929 | measure_PPI | INFO] 96% - ETA 0:00:05 | current speed 8.589 s⁻¹ | average speed 23.141 s⁻¹
# [2025-05-15 19:08:53,028 | measure_PPI | INFO] 97% - ETA 0:00:03 | current speed 8.628 s⁻¹ | average speed 22.601 s⁻¹
# [2025-05-15 19:08:58,070 | measure_PPI | INFO] 99% - ETA 0:00:00 | current speed 12.098 s⁻¹ | average speed 22.229 s⁻¹
# [2025-05-15 19:08:58,852 | measure_PPI | INFO] Finished processing 3170 objects in 0:02:22 | average speed 22.184 s⁻¹

# %%
display(df_intf_metrics)
# Out:
#                                      structure_name          file  hbonds  \
# 2924  D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34  ranked_0.pdb       1
# 2925  D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34  ranked_1.pdb       3
# 2933  D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34  ranked_2.pdb       1
# 2932  D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34  ranked_3.pdb       5
# 2934  D1PF00009_PF01873_2D74.D2PF00026_PF06394_1F34  ranked_4.pdb      15
# ...                                             ...           ...     ...
# 2695                        TRG_PTS1_2C0L_NAKL.NAKD  ranked_0.pdb      10
# 2698                        TRG_PTS1_2C0L_NAKL.NAKD  ranked_1.pdb       8
# 2696                        TRG_PTS1_2C0L_NAKL.NAKD  ranked_2.pdb      12
# 2699                        TRG_PTS1_2C0L_NAKL.NAKD  ranked_3.pdb      11
# 2697                        TRG_PTS1_2C0L_NAKL.NAKD  ranked_4.pdb      10
#
#       salt_bridges  buried_area  min_distance  hydrophobic_interactions  \
# 2924             0     1692.652         4.191                        86
# 2925             0     1708.317         3.670                        96
# 2933             1     1907.898         4.643                        79
# 2932             0     1577.972         3.718                       107
# 2934             1     2139.539         3.955                       101
# ...            ...          ...           ...                       ...
# 2695             3      839.162         4.782                        11
# 2698             3      862.629         4.900                        10
# 2696             2      861.115         4.704                         9
# 2699             2      854.038         4.943                         9
# 2697             3      851.724         5.097                         8
#
#       disulfide_bonds
# 2924                0
# 2925                0
# 2933                0
# 2932                0
# 2934                0
# ...               ...
# 2695                0
# 2698                0
# 2696                0
# 2699                0
# 2697                0
#
# [3170 rows x 8 columns]

# %%
dataAF["min_distance"] = None
dataAF["buried_area"] = None
dataAF["disulfide_bonds"] = None
dataAF["salt_bridges"] = None
dataAF["hbonds"] = None
dataAF["hydrophobic_interactions"] = None

for i, row in dataAF.iterrows():
    row_intf = df_intf_metrics[(df_intf_metrics["structure_name"] == row["prediction_name"]) & (df_intf_metrics["file"] == row["model_id"] + ".pdb")]
    if len(row_intf) != 1:
        print(f"\t{bcolors.FAIL}Failed to locate {row["prediction_name"]} {row["model_id"]}{bcolors.ENDC}")
        continue

    dataAF.at[i, "buried_area"] = row_intf["buried_area"].item()
    dataAF.at[i, "min_distance"] = row_intf["min_distance"].item()
    dataAF.at[i, "salt_bridges"] = row_intf["salt_bridges"].item()
    dataAF.at[i, "hbonds"] = row_intf["hbonds"].item()
    dataAF.at[i, "hydrophobic_interactions"] = row_intf["hydrophobic_interactions"].item()
    dataAF.at[i, "disulfide_bonds"] = row_intf["disulfide_bonds"].item()
display(dataAF)
# Out:
# 	Failed to locate PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_resi172 ranked_0
# 	Failed to locate PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_resi172 ranked_1
# 	Failed to locate PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_resi172 ranked_2
# 	Failed to locate PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_resi172 ranked_3
# 	Failed to locate PF07724_PF00227_1OFH_C_resi39_resi340.H_resi1_resi172 ranked_4
# 	Failed to locate PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57_resi127 ranked_0
# 	Failed to locate PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57_resi127 ranked_1
# 	Failed to locate PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57_resi127 ranked_2
# 	Failed to locate PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57_resi127 ranked_3
# 	Failed to locate PF14978_PF00327_3J7Y_o_resi13_resi101.Z_resi57_resi127 ranked_4
#                  project_name run_id benchmark_set  \
# 0         AlphaFold_benchmark  run37     known_DMI
# 1         AlphaFold_benchmark  run37     known_DMI
# 2         AlphaFold_benchmark  run37     known_DMI
# 3         AlphaFold_benchmark  run37     known_DMI
# 4         AlphaFold_benchmark  run37     known_DMI
# ...                       ...    ...           ...
# 3175  AlphaFold_benchmark_DDI   run6    random_DDI
# 3176  AlphaFold_benchmark_DDI   run6    random_DDI
# 3177  AlphaFold_benchmark_DDI   run6    random_DDI
# 3178  AlphaFold_benchmark_DDI   run6    random_DDI
# 3179  AlphaFold_benchmark_DDI   run6    random_DDI
#
#                                     prediction_name  model_id  chainA_length  \
# 0                            DEG_APCC_KENBOX_2_4GGD  ranked_0            312
# 1                            DEG_APCC_KENBOX_2_4GGD  ranked_1            312
# 2                            DEG_APCC_KENBOX_2_4GGD  ranked_2            312
# 3                            DEG_APCC_KENBOX_2_4GGD  ranked_3            312
# 4                            DEG_APCC_KENBOX_2_4GGD  ranked_4            312
# ...                                             ...       ...            ...
# 3175  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_0             60
# 3176  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_1             60
# 3177  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_2             60
# 3178  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_3             60
# 3179  D1PF18773_PF00071_2X19.D2PF00009_PF01873_2D74  ranked_4             60
#
#       chainB_length chainA_id chainB_id  chainA_start  ...     DockQ  \
# 0                 5         A         B           165  ...  0.878344
# 1                 5         A         B           165  ...  0.880716
# 2                 5         A         B           165  ...  0.883186
# 3                 5         A         B           165  ...  0.475511
# 4                 5         A         B           165  ...  0.223400
# ...             ...       ...       ...           ...  ...       ...
# 3175            113         B         B           392  ...       NaN
# 3176            113         B         B           392  ...       NaN
# 3177            113         B         B           392  ...       NaN
# 3178            113         B         B           392  ...       NaN
# 3179            113         B         B           392  ...       NaN
#
#          iRMSD     LRMSD   Fnonnat buried_area min_distance disulfide_bonds  \
# 0     0.603831  1.575394  0.086957     613.651        6.063               0
# 1     0.418230  1.100588  0.050000      580.31        6.083               0
# 2     0.641834  1.776257  0.185185     662.104        6.072               0
# 3     1.686332  5.358800  0.363636     398.498        5.417               0
# 4     2.928606  9.908745  0.888889     323.304        5.092               0
# ...        ...       ...       ...         ...          ...             ...
# 3175       NaN       NaN       NaN    1617.382        5.591               0
# 3176       NaN       NaN       NaN     791.256        6.373               0
# 3177       NaN       NaN       NaN     882.547        7.906               0
# 3178       NaN       NaN       NaN    1020.896        4.628               0
# 3179       NaN       NaN       NaN     882.571        5.461               0
#
#      salt_bridges hbonds hydrophobic_interactions
# 0               0      9                        0
# 1               0      9                        0
# 2               0     10                        3
# 3               0      2                        0
# 4               0      2                        9
# ...           ...    ...                      ...
# 3175            3      7                       56
# 3176            0      3                        7
# 3177            1      2                       11
# 3178            3      7                       44
# 3179            3     10                       14
#
# [3180 rows x 49 columns]

# %% [markdown]
# ### Export table

# %%
# Inspect
enhance_dataframe()
dataAF
# Out:
# Column num_mutations not (yet) in data frame
# Column hbonds not (yet) in data frame
# Column salt_bridges not (yet) in data frame
# Column hydrophobic_interactions not (yet) in data frame
# Column disulfide_bonds not (yet) in data frame
# Column sequence_initial not (yet) in data frame
# Column sequence_mutated not (yet) in data frame
# Column num_mutations not (yet) in data frame
# Column buried_area not (yet) in data frame
# Column min_distance not (yet) in data frame
# Column disulfide_bonds not (yet) in data frame
# Column salt_bridges not (yet) in data frame
# Column hbonds not (yet) in data frame
# Column hydrophobic_interactions not (yet) in data frame
#      model_preset    benchmark_set                    prediction_name  \
# 2710          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2711          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2712          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2713          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# 2714          NaN  known_extension  DEG_APCC_KENBOX_2_M15_M39_D1_D499
# ...           ...              ...                                ...
# 5525          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5526          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5527          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5528          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
# 5529          NaN  known_extension       TRG_AP2beta_CARGO_1_Mmin_DFL
#
#       model_id                                         model_path  \
# 2710  ranked_0  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2711  ranked_1  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2712  ranked_2  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2713  ranked_3  AlphaFold_benchmark_DMI/known_extension/nostal...
# 2714  ranked_4  AlphaFold_benchmark_DMI/known_extension/nostal...
# ...        ...                                                ...
# 5525  ranked_0  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5526  ranked_1  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5527  ranked_2  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5528  ranked_3  AlphaFold_benchmark_DMI/known_extension/sponta...
# 5529  ranked_4  AlphaFold_benchmark_DMI/known_extension/sponta...
#
#       ranking_score  chainA_length  chainB_length chainA_id chainB_id  ...  \
# 2710            1.0            NaN            NaN         A         B  ...
# 2711            0.9            NaN            NaN         A         B  ...
# 2712            0.8            NaN            NaN         A         B  ...
# 2713            0.7            NaN            NaN         A         B  ...
# 2714            0.6            NaN            NaN         A         B  ...
# ...             ...            ...            ...       ...       ...  ...
# 5525            1.0            NaN            NaN         A         B  ...
# 5526            0.9            NaN            NaN         A         B  ...
# 5527            0.8            NaN            NaN         A         B  ...
# 5528            0.7            NaN            NaN         A         B  ...
# 5529            0.6            NaN            NaN         A         B  ...
#
#       RMSD_all_atom_peptide  RMSD_all_atom  iPAE  pDockQ chains_flipped  \
# 2710              33.511379       0.779362   NaN     NaN          False
# 2711              33.687027       0.850033   NaN     NaN          False
# 2712               1.085235       0.802006   NaN     NaN          False
# 2713              34.722588       0.846242   NaN     NaN          False
# 2714              34.047897       0.806754   NaN     NaN          False
# ...                     ...            ...   ...     ...            ...
# 5525                1.43463       0.854878   NaN     NaN          False
# 5526               1.300052       0.879837   NaN     NaN          False
# 5527               1.336963       0.883954   NaN     NaN          False
# 5528               1.497762       0.857197   NaN     NaN          False
# 5529               1.245331       0.819131   NaN     NaN          False
#
#          DockQ     iRMSD      LRMSD   Fnonnat     ipSAE
# 2710  0.030091  9.154708  32.471571  1.000000  0.680212
# 2711  0.030029  9.165312  32.505639  1.000000  0.573150
# 2712  0.957491  0.311560   0.821135  0.000000  0.794550
# 2713  0.028471  9.429981  33.426638  1.000000  0.638900
# 2714  0.029560  9.242351  32.776340  1.000000  0.656448
# ...        ...       ...        ...       ...       ...
# 5525  0.955996  0.370099   0.859152  0.093750       NaN
# 5526  0.960844  0.333205   0.656404  0.093750       NaN
# 5527  0.959846  0.331209   0.830493  0.093750       NaN
# 5528  0.953670  0.396883   0.812161  0.121212       NaN
# 5529  0.961073  0.336588   0.560241  0.064516       NaN
#
# [2820 rows x 46 columns]

# %%
# Save
enhance_dataframe()
dataAF.to_csv(path_AF / (path_AF.name + "_metrics.tsv"), sep="\t", index=None)
dataAF.to_excel(path_AF/ (path_AF.name + "_metrics.xlsx"), sheet_name=f"{af_mode} metrics", index=None)
# Out:
# Column num_mutations not (yet) in data frame
# Column hbonds not (yet) in data frame
# Column salt_bridges not (yet) in data frame
# Column hydrophobic_interactions not (yet) in data frame
# Column disulfide_bonds not (yet) in data frame
# Column sequence_initial not (yet) in data frame
# Column sequence_mutated not (yet) in data frame
# Column num_mutations not (yet) in data frame
# Column buried_area not (yet) in data frame
# Column min_distance not (yet) in data frame
# Column disulfide_bonds not (yet) in data frame
# Column salt_bridges not (yet) in data frame
# Column hbonds not (yet) in data frame
# Column hydrophobic_interactions not (yet) in data frame
