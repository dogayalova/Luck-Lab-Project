# %% [markdown]
# # Parsing output of AF3 from the cluster
# created by Andreas 2025-02-04
#
# Script to parse output from AF3 running on the IMB server cluster. Also detects errors on the runs using the reports created by Nextflow
#
# This notebook supports to be run cell by cell from top to bottom. Runtime was around 35 minutes, but most (I estimate 90%) is comming from accessing the files on a network drive

# %% [markdown]
# ### 0 Settings + Imports
#
# Run the following lines and edited in the second cell the necessary paths / settings
#
# Note: In this run the known_extensions have been excluded. To include them, change the code in the _# Loading the output folders_ cell in this section and the first cell of section 3

# %%
# Imports
from pathlib import Path
import pandas as pd
import numpy as np
import re
import json

import pymol
from Bio.PDB import PDBParser
from Bio.PDB.Structure import Structure as BioPy_PDBStructure
from Bio.PDB.Model import Model as BioPy_PDBModel
from Bio.PDB.PDBExceptions import PDBConstructionException
parser = PDBParser(QUIET=True)

ressources_path = Path("../ressources").resolve()

# %%
# Settings

# The base folder of the AF output. The AF3 files are searched inside /Alpha
luck_drive_folder = Path("/Volumes/imb-luckgr/imb-luckgr2/projects/AlphaFold") 

# The folder to export the output
export_destination = Path("/Users/imb/Desktop")

# Set this option to skip existing structures
export_skip_existing_structures = False

# %%
# Loading the output folders
# Note: The known_extension structures should not be considered, so exclude them explicitly
af3_runs_folder = luck_drive_folder / "AlphaFold3"
DMI_folders = [af3_runs_folder / "AlphaFold_benchmark_DMI"/"random_minimal"]
#DDI_folders = [p for p in (af3_runs_folder / "AlphaFold_benchmark_DDI").iterdir() if p.is_dir()]
benchmark_folders = DMI_folders #+ DDI_folders

# Load also the AF2 folder to get the original input files without switched chains to undo the chain switching
af2_folders = { #"known_minimal": luck_drive_folder / "AlphaFold_benchmark_DMI" / "run37", # DMI known minimals
                "random_minimal": luck_drive_folder / "AlphaFold_benchmark_DMI" / "run38", # DMI random minimals
                #"known_extension": luck_drive_folder / "AlphaFold_benchmark_DMI" / "run60", # DMI known extensions
                #"mutations": luck_drive_folder / "AlphaFold_benchmark_DMI" / "run43", # DMI mutations
                #"known_ddi": luck_drive_folder / "AlphaFold_benchmark_DDI" / "run5", # DDI known DDI
                #"random_ddi": luck_drive_folder / "AlphaFold_benchmark_DDI" / "run6", # DDI random DDI
}

print("Folders with AF3 output:")
for p in benchmark_folders:
    if not p.exists():
        print(f"{p} does not exist")
    else:
        print(p)
        
print("Folders with AF2 output")
for p in af2_folders.values():
    if not p.exists():
        print(f"{p} does not exist")
    else:
        print(p)
# Out:
# Folders with AF3 output:
# /Volumes/imb-luckgr/imb-luckgr2/projects/AlphaFold/AlphaFold3/AlphaFold_benchmark_DMI/random_minimal
# Folders with AF2 output
# /Volumes/imb-luckgr/imb-luckgr2/projects/AlphaFold/AlphaFold_benchmark_DMI/run38

# %% [markdown]
# ### 1 Scanning input .json files and report.html files
# Scans for all input .json files and corresponding report_%time%.html files to find failed runs
#
# * **benchmark_set** refers to the pairing method (mutated, randomized, ...) and is equal to the folder name (example: known_minimal)
# * **prediction_name** is extracted from a) the json file or b) the report_%time%.html file. If the value can't be extracted from report_%time%.html, it is set to None
# * **report_file** refers to the name of the report_%time%.html file and is None if the json input file could not been matched with a report file (--> input json has not been run on the cluster \[yet\])
# * **run_ok** refers to if there had been an error running the input file on the server. Set to None if the input file has not been run on the cluster.
# * **input_json** is set to the filename of the input json or to None if the report_%time%.html could not be matched with a input json file.
#
# Use <i>report_file == None</i> or <i>run_ok == None</i> to identify scheduled but not yet run structures.<br>Use <i>input_json == None</i> to find runs without a input file

# %%
# Scanning input and report files
report_df = pd.DataFrame(columns=["benchmark_set", "prediction_name", "report_file", "run_ok", "input_json"])


for folder in benchmark_folders:
    benchmark_set = folder.name
    print(benchmark_set)
    # Ignore the f.is_file() check in the following lines as it will decrease performance massively on a network drive (example runtime: 0.9s --> 1m 25.6 s (!))
    nextflow_inputs = [f for f in folder.iterdir() if f.suffix.lower() == ".json"]
    for nextflow_input in nextflow_inputs:
        prediction_name = nextflow_input.stem
        report_df.loc[len(report_df)] = {"benchmark_set": benchmark_set, "prediction_name": prediction_name, "report_file": None, "run_ok": None, "input_json": nextflow_input.name}
    
    for p in [f for f in folder.iterdir() if  "report_" in f.stem and f.suffix.lower() == ".html"]:
        print("\t", p.name, end=" ")
        with open(p) as f:
            content = f.read()
        
        # Extract all prediction names from the HTML
        prediction_names = []
        finished = bool("Workflow execution completed successfully!" in content)
        
        # Pattern 1: [id:[LIST_OF_NAMES]] - extract all names from the list
        list_matches = re.findall(r"\[id:\[([^\]]+)\]\]", content)
        for match in list_matches:
            # Split by comma and clean up each name
            names = [name.strip() for name in match.split(',')]
            prediction_names.extend(names)
        
        # Pattern 2: [id:single_name, model:something] - extract single names
        single_matches = re.findall(r"\[id:([^,\]]+)(?:,|\])", content)
        prediction_names.extend(single_matches)
        
        # Clean up prediction names: remove leading brackets, strip whitespace, normalize case
        cleaned_names = []
        for name in prediction_names:
            # Remove leading bracket if present
            cleaned_name = name.lstrip('[').strip()
            if cleaned_name:  # Only add non-empty names
                cleaned_names.append(cleaned_name)
        
        # Remove duplicates by converting to lowercase, then keep original case for first occurrence
        seen_lower = set()
        unique_names = []
        for name in cleaned_names:
            name_lower = name.lower()
            if name_lower not in seen_lower:
                seen_lower.add(name_lower)
                unique_names.append(name)
        
        prediction_names = unique_names
        
        if prediction_names:
            print(f"-> Found {len(prediction_names)} predictions: {prediction_names[:3]}{'...' if len(prediction_names) > 3 else ''}")
            
            # Track how many predictions we successfully matched
            matched_predictions = 0
            
            # Update all matching rows for each prediction found in this report
            for prediction_name in prediction_names:
                # Case-insensitive matching: compare lowercase versions
                matching_mask = np.logical_and(
                    report_df["benchmark_set"] == benchmark_set, 
                    report_df["prediction_name"].str.lower() == prediction_name.lower()
                )
                num_matches = len(report_df.loc[matching_mask])
                
                if num_matches > 0:
                    matched_predictions += 1
                    print(f"\t\tUpdating {num_matches} rows for prediction: {prediction_name}")
                    report_df.loc[matching_mask, "run_ok"] = finished
                    report_df.loc[matching_mask, "report_file"] = p.name
                # Note: We don't create new rows for unmatched predictions to avoid duplicates
            
            # If no predictions matched any JSON files, create a single row with None
            if matched_predictions == 0:
                print("\t\tNo JSON files found for any predictions in this report")
                report_df.loc[len(report_df)] = {"benchmark_set": benchmark_set, "report_file": p.name, "prediction_name": None, "run_ok": finished, "input_json": None}
                
        else:
            print("-> No predictions found")
            # Create entry with None prediction_name (same as original behavior)
            report_df.loc[len(report_df)] = {"benchmark_set": benchmark_set, "report_file": p.name, "prediction_name": None, "run_ok": finished, "input_json": None}
        finished = bool("Workflow execution completed successfully!" in content)
        
        # Extract all prediction names from the HTML
# Out:
# random_minimal
# 	 report_2025-02-12_23-07.html -> Found 1 predictions: ['MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7']
# 		Updating 1 rows for prediction: MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7
# 	 report_2025-02-12_23-26.html -> Found 1 predictions: ['MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY']
# 		Updating 1 rows for prediction: MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY
# 	 report_2025-02-12_23-44.html -> Found 1 predictions: ['MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P']
# 		Updating 1 rows for prediction: MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P
# 	 report_2025-02-13_00-02.html -> Found 1 predictions: ['MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV']
# 		Updating 1 rows for prediction: MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV
# 	 report_2025-02-13_00-18.html -> Found 1 predictions: ['MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9']
# 		Updating 1 rows for prediction: MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9
# 	 report_2025-02-13_00-35.html -> Found 1 predictions: ['MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU']
# 		Updating 1 rows for prediction: MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU
# 	 report_2025-02-13_00-56.html -> Found 1 predictions: ['MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO']
# 		Updating 1 rows for prediction: MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO
# 	 report_2025-02-13_01-12.html -> Found 1 predictions: ['MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G']
# 		Updating 1 rows for prediction: MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G
# 	 report_2025-02-13_01-32.html -> Found 1 predictions: ['MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25']
# 		Updating 1 rows for prediction: MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25
# 	 report_2025-02-13_01-50.html -> Found 1 predictions: ['MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ']
# 		Updating 1 rows for prediction: MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ
# 	 report_2025-02-13_02-11.html -> Found 1 predictions: ['MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ']
# 		Updating 1 rows for prediction: MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ
# 	 report_2025-02-13_02-28.html -> Found 1 predictions: ['MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6']
# 		Updating 1 rows for prediction: MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6
# 	 report_2025-02-13_02-45.html -> Found 1 predictions: ['MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52']
# 		Updating 1 rows for prediction: MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52
# 	 report_2025-02-13_03-07.html -> Found 1 predictions: ['MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q']
# 		Updating 1 rows for prediction: MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q
# 	 report_2025-02-13_04-10.html -> Found 1 predictions: ['MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH']
# 		Updating 1 rows for prediction: MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH
# 	 report_2025-02-13_05-08.html -> Found 1 predictions: ['MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I']
# 		Updating 1 rows for prediction: MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I
# 	 report_2025-02-13_05-29.html -> Found 1 predictions: ['MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48']
# 		Updating 1 rows for prediction: MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48
# 	 report_2025-02-13_05-57.html -> Found 1 predictions: ['MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B']
# 		Updating 1 rows for prediction: MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B
# 	 report_2025-02-13_06-45.html -> Found 1 predictions: ['MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM']
# 		Updating 1 rows for prediction: MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM
# 	 report_2025-02-13_07-08.html -> Found 1 predictions: ['MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM']
# 		Updating 1 rows for prediction: MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM
# 	 report_2025-02-13_07-31.html -> Found 1 predictions: ['MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J']
# 		Updating 1 rows for prediction: MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J
# 	 report_2025-02-13_08-22.html -> Found 1 predictions: ['MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH']
# 		Updating 1 rows for prediction: MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH
# 	 report_2025-02-13_09-21.html -> Found 1 predictions: ['MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH']
# 		Updating 1 rows for prediction: MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH
# 	 report_2025-02-13_11-10.html -> Found 1 predictions: ['MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6']
# 		Updating 1 rows for prediction: MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6
# 	 report_2025-02-13_11-40.html -> Found 1 predictions: ['MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S']
# 		Updating 1 rows for prediction: MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S
# 	 report_2025-02-13_11-56.html -> Found 1 predictions: ['MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8']
# 		Updating 1 rows for prediction: MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8
# 	 report_2025-02-13_12-13.html -> Found 1 predictions: ['MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO']
# 		Updating 1 rows for prediction: MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO
# 	 report_2025-02-13_12-29.html -> Found 1 predictions: ['MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3']
# 		Updating 1 rows for prediction: MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3
# 	 report_2025-02-13_12-45.html -> Found 1 predictions: ['MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC']
# 		Updating 1 rows for prediction: MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC
# 	 report_2025-02-13_13-04.html -> Found 1 predictions: ['MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW']
# 		Updating 1 rows for prediction: MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW
# 	 report_2025-02-13_13-21.html -> Found 1 predictions: ['MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8']
# 		Updating 1 rows for prediction: MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8
# 	 report_2025-02-13_13-37.html -> Found 1 predictions: ['MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY']
# 		Updating 1 rows for prediction: MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY
# 	 report_2025-02-13_13-53.html -> Found 1 predictions: ['MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG']
# 		Updating 1 rows for prediction: MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG
# 	 report_2025-02-13_14-11.html -> Found 1 predictions: ['MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5']
# 		Updating 1 rows for prediction: MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5
# 	 report_2025-02-13_14-27.html -> Found 1 predictions: ['MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH']
# 		Updating 1 rows for prediction: MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH
# 	 report_2025-02-13_14-46.html -> Found 1 predictions: ['MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH']
# 		Updating 1 rows for prediction: MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH
# 	 report_2025-02-13_15-59.html -> Found 1 predictions: ['MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3']
# 		Updating 1 rows for prediction: MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3
# 	 report_2025-02-13_16-16.html -> Found 1 predictions: ['MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW']
# 		Updating 1 rows for prediction: MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW
# 	 report_2025-02-13_16-33.html -> Found 1 predictions: ['MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2']
# 		Updating 1 rows for prediction: MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2
# 	 report_2025-02-13_16-53.html -> Found 1 predictions: ['MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42']
# 		Updating 1 rows for prediction: MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42
# 	 report_2025-02-13_17-09.html -> Found 1 predictions: ['MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN']
# 		Updating 1 rows for prediction: MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN
# 	 report_2025-02-13_17-25.html -> Found 1 predictions: ['MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY']
# 		Updating 1 rows for prediction: MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY
# 	 report_2025-02-13_17-41.html -> Found 1 predictions: ['MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY']
# 		Updating 1 rows for prediction: MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY
# 	 report_2025-02-13_17-57.html -> Found 1 predictions: ['MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1']
# 		Updating 1 rows for prediction: MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1
# 	 report_2025-02-13_19-16.html -> Found 1 predictions: ['MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD']
# 		Updating 1 rows for prediction: MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD
# 	 report_2025-02-13_19-32.html -> Found 1 predictions: ['MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ']
# 		Updating 1 rows for prediction: MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ
# 	 report_2025-02-13_19-51.html -> Found 1 predictions: ['MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH']
# 		Updating 1 rows for prediction: MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH
# 	 report_2025-02-13_20-07.html -> Found 1 predictions: ['MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U']
# 		Updating 1 rows for prediction: MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U
# 	 report_2025-02-13_20-43.html -> Found 1 predictions: ['MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7']
# 		Updating 1 rows for prediction: MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7
# 	 report_2025-02-13_21-00.html -> Found 1 predictions: ['MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70']
# 		Updating 1 rows for prediction: MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70
# 	 report_2025-02-13_21-21.html -> Found 1 predictions: ['MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9']
# 		Updating 1 rows for prediction: MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9
# 	 report_2025-02-13_21-37.html -> Found 1 predictions: ['MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P']
# 		Updating 1 rows for prediction: MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P
# 	 report_2025-02-13_21-54.html -> Found 1 predictions: ['MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8']
# 		Updating 1 rows for prediction: MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8
# 	 report_2025-02-13_22-11.html -> Found 1 predictions: ['MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE']
# 		Updating 1 rows for prediction: MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE
# 	 report_2025-02-13_22-29.html -> Found 1 predictions: ['MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P']
# 		Updating 1 rows for prediction: MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P
# 	 report_2025-02-11_14-07.html -> Found 1 predictions: ['MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9']
# 		Updating 1 rows for prediction: MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9
# 	 report_2025-02-11_15-06.html -> Found 1 predictions: ['MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM']
# 		Updating 1 rows for prediction: MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM
# 	 report_2025-02-11_15-23.html -> Found 1 predictions: ['MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG']
# 		Updating 1 rows for prediction: MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG
# 	 report_2025-02-11_15-47.html -> Found 1 predictions: ['MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW']
# 		Updating 1 rows for prediction: MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW
# 	 report_2025-02-11_16-05.html -> Found 1 predictions: ['MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ']
# 		Updating 1 rows for prediction: MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ
# 	 report_2025-02-11_16-26.html -> Found 1 predictions: ['MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN']
# 		Updating 1 rows for prediction: MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN
# 	 report_2025-02-11_16-43.html -> Found 1 predictions: ['MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q']
# 		Updating 1 rows for prediction: MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q
# 	 report_2025-02-11_16-59.html -> Found 1 predictions: ['MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE']
# 		Updating 1 rows for prediction: MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE
# 	 report_2025-02-11_17-18.html -> Found 1 predictions: ['MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72']
# 		Updating 1 rows for prediction: MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72
# 	 report_2025-02-11_17-37.html -> Found 1 predictions: ['MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q']
# 		Updating 1 rows for prediction: MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q
# 	 report_2025-02-11_17-53.html -> Found 1 predictions: ['MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74']
# 		Updating 1 rows for prediction: MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74
# 	 report_2025-02-11_18-12.html -> Found 1 predictions: ['MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4']
# 		Updating 1 rows for prediction: MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4
# 	 report_2025-02-11_18-32.html -> Found 1 predictions: ['MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU']
# 		Updating 1 rows for prediction: MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU
# 	 report_2025-02-11_18-53.html -> Found 1 predictions: ['MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY']
# 		Updating 1 rows for prediction: MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY
# 	 report_2025-02-11_19-10.html -> Found 1 predictions: ['MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5']
# 		Updating 1 rows for prediction: MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5
# 	 report_2025-02-11_19-26.html -> Found 1 predictions: ['MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG']
# 		Updating 1 rows for prediction: MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG
# 	 report_2025-02-11_19-42.html -> Found 1 predictions: ['MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9']
# 		Updating 1 rows for prediction: MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9
# 	 report_2025-02-11_20-29.html -> Found 1 predictions: ['MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0']
# 		Updating 1 rows for prediction: MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0
# 	 report_2025-02-11_20-47.html -> Found 1 predictions: ['MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG']
# 		Updating 1 rows for prediction: MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG
# 	 report_2025-02-11_21-04.html -> Found 1 predictions: ['MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3']
# 		Updating 1 rows for prediction: MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3
# 	 report_2025-02-11_21-40.html -> Found 1 predictions: ['MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM']
# 		Updating 1 rows for prediction: MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM
# 	 report_2025-02-11_22-03.html -> Found 1 predictions: ['MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B']
# 		Updating 1 rows for prediction: MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B
# 	 report_2025-02-11_22-52.html -> Found 1 predictions: ['MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7']
# 		Updating 1 rows for prediction: MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7
# 	 report_2025-02-11_23-13.html -> Found 1 predictions: ['MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1']
# 		Updating 1 rows for prediction: MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1
# 	 report_2025-02-11_23-43.html -> Found 1 predictions: ['MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD']
# 		Updating 1 rows for prediction: MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD
# 	 report_2025-02-12_00-05.html -> Found 1 predictions: ['MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K']
# 		Updating 1 rows for prediction: MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K
# 	 report_2025-02-12_00-27.html -> Found 1 predictions: ['MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD']
# 		Updating 1 rows for prediction: MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD
# 	 report_2025-02-12_00-47.html -> Found 1 predictions: ['MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA']
# 		Updating 1 rows for prediction: MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA
# 	 report_2025-02-12_02-26.html -> Found 1 predictions: ['MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41']
# 		Updating 1 rows for prediction: MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41
# 	 report_2025-02-12_02-48.html -> Found 1 predictions: ['MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48']
# 		Updating 1 rows for prediction: MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48
# 	 report_2025-02-12_03-18.html -> Found 1 predictions: ['MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S']
# 		Updating 1 rows for prediction: MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S
# 	 report_2025-02-12_03-40.html -> Found 1 predictions: ['MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA']
# 		Updating 1 rows for prediction: MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA
# 	 report_2025-02-12_05-20.html -> Found 1 predictions: ['MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP']
# 		Updating 1 rows for prediction: MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP
# 	 report_2025-02-12_06-00.html -> Found 1 predictions: ['MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7']
# 		Updating 1 rows for prediction: MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7
# 	 report_2025-02-12_06-21.html -> Found 1 predictions: ['MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C']
# 		Updating 1 rows for prediction: MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C
# 	 report_2025-02-12_06-38.html -> Found 1 predictions: ['MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z']
# 		Updating 1 rows for prediction: MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z
# 	 report_2025-02-12_06-57.html -> Found 1 predictions: ['MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH']
# 		Updating 1 rows for prediction: MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH
# 	 report_2025-02-12_07-14.html -> Found 1 predictions: ['MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2']
# 		Updating 1 rows for prediction: MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2
# 	 report_2025-02-12_07-32.html -> Found 1 predictions: ['MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH']
# 		Updating 1 rows for prediction: MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH
# 	 report_2025-02-12_07-51.html -> Found 1 predictions: ['MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI']
# 		Updating 1 rows for prediction: MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI
# 	 report_2025-02-12_09-30.html -> Found 1 predictions: ['MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK']
# 		Updating 1 rows for prediction: MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK
# 	 report_2025-02-12_10-06.html -> Found 1 predictions: ['MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70']
# 		Updating 1 rows for prediction: MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70
# 	 report_2025-02-12_10-26.html -> Found 1 predictions: ['MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70']
# 		Updating 1 rows for prediction: MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70
# 	 report_2025-02-12_10-46.html -> Found 1 predictions: ['MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3']
# 		Updating 1 rows for prediction: MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3
# 	 report_2025-02-12_11-21.html -> Found 1 predictions: ['MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT']
# 		Updating 1 rows for prediction: MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT
# 	 report_2025-02-12_11-41.html -> Found 1 predictions: ['MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN']
# 		Updating 1 rows for prediction: MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN
# 	 report_2025-02-12_11-59.html -> Found 1 predictions: ['MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5']
# 		Updating 1 rows for prediction: MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5
# 	 report_2025-02-12_12-19.html -> Found 1 predictions: ['MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1']
# 		Updating 1 rows for prediction: MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1
# 	 report_2025-02-12_12-38.html -> Found 1 predictions: ['MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6']
# 		Updating 1 rows for prediction: MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6
# 	 report_2025-02-12_13-05.html -> Found 1 predictions: ['MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR']
# 		Updating 1 rows for prediction: MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR
# 	 report_2025-02-12_13-22.html -> Found 1 predictions: ['MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU']
# 		Updating 1 rows for prediction: MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU
# 	 report_2025-02-12_13-48.html -> Found 1 predictions: ['MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5']
# 		Updating 1 rows for prediction: MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5
# 	 report_2025-02-12_14-05.html -> Found 1 predictions: ['MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK']
# 		Updating 1 rows for prediction: MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK
# 	 report_2025-02-12_14-40.html -> Found 1 predictions: ['MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH']
# 		Updating 1 rows for prediction: MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH
# 	 report_2025-02-12_14-56.html -> Found 1 predictions: ['MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ']
# 		Updating 1 rows for prediction: MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ
# 	 report_2025-02-12_15-18.html -> Found 1 predictions: ['MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS']
# 		Updating 1 rows for prediction: MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS
# 	 report_2025-02-12_15-35.html -> Found 1 predictions: ['MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN']
# 		Updating 1 rows for prediction: MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN
# 	 report_2025-02-12_15-52.html -> Found 1 predictions: ['MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU']
# 		Updating 1 rows for prediction: MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU
# 	 report_2025-02-12_16-10.html -> Found 1 predictions: ['MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ']
# 		Updating 1 rows for prediction: MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ
# 	 report_2025-02-12_16-33.html -> Found 1 predictions: ['MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM']
# 		Updating 1 rows for prediction: MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM
# 	 report_2025-02-12_16-53.html -> Found 1 predictions: ['MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV']
# 		Updating 1 rows for prediction: MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV
# 	 report_2025-02-12_17-09.html -> Found 1 predictions: ['MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU']
# 		Updating 1 rows for prediction: MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU
# 	 report_2025-02-12_17-33.html -> Found 1 predictions: ['MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ']
# 		Updating 1 rows for prediction: MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ
# 	 report_2025-02-12_17-50.html -> Found 1 predictions: ['MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN']
# 		Updating 1 rows for prediction: MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN
# 	 report_2025-02-12_18-07.html -> Found 1 predictions: ['MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6']
# 		Updating 1 rows for prediction: MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6
# 	 report_2025-02-12_18-33.html -> Found 1 predictions: ['MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD']
# 		Updating 1 rows for prediction: MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD
# 	 report_2025-02-12_18-48.html -> Found 1 predictions: ['MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02']
# 		Updating 1 rows for prediction: MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02
# 	 report_2025-02-12_19-09.html -> Found 1 predictions: ['MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM']
# 		Updating 1 rows for prediction: MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM
# 	 report_2025-02-12_19-26.html -> Found 1 predictions: ['MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q']
# 		Updating 1 rows for prediction: MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q
# 	 report_2025-02-12_19-42.html -> Found 1 predictions: ['MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV']
# 		Updating 1 rows for prediction: MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV
# 	 report_2025-02-12_19-58.html -> Found 1 predictions: ['MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J']
# 		Updating 1 rows for prediction: MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J
# 	 report_2025-02-12_20-14.html -> Found 1 predictions: ['MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74']
# 		Updating 1 rows for prediction: MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74
# 	 report_2025-02-12_20-32.html -> Found 1 predictions: ['MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB']
# 		Updating 1 rows for prediction: MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB
# 	 report_2025-02-12_20-48.html -> Found 1 predictions: ['MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3']
# 		Updating 1 rows for prediction: MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3
# 	 report_2025-02-12_21-05.html -> Found 1 predictions: ['MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS']
# 		Updating 1 rows for prediction: MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS
# 	 report_2025-02-12_21-20.html -> Found 1 predictions: ['MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G']
# 		Updating 1 rows for prediction: MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G
# 	 report_2025-02-12_21-37.html -> Found 1 predictions: ['MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30']
# 		Updating 1 rows for prediction: MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30
# 	 report_2025-02-12_21-56.html -> Found 1 predictions: ['MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS']
# 		Updating 1 rows for prediction: MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS
# 	 report_2025-02-12_22-13.html -> Found 1 predictions: ['MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0']
# 		Updating 1 rows for prediction: MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0
# 	 report_2025-02-12_22-32.html -> Found 1 predictions: ['MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6']
# 		Updating 1 rows for prediction: MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6
# 	 report_2025-02-12_22-48.html -> Found 1 predictions: ['MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW']
# 		Updating 1 rows for prediction: MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW

# %%
# Displaying output
num_input = len(report_df[~report_df['input_json'].isna()])
num_output_with_input = len(report_df[np.logical_and(~report_df["input_json"].isna(), ~report_df["report_file"].isna())])
num_output_total = len(report_df[~report_df['report_file'].isna()])
num_ok_with_input = len(report_df[np.logical_and(~report_df["input_json"].isna(), report_df["run_ok"] == True)])
num_fail_with_input = len(report_df[np.logical_and(~report_df["input_json"].isna(), report_df["run_ok"] == False)])
num_ok = len(report_df[report_df["run_ok"] == True])
num_fail = len(report_df[report_df["run_ok"] == False])

print(f"{num_output_with_input}/{num_input} of the scheduled structures have finished. {num_ok_with_input} were successful and {num_fail_with_input} failed")
if num_output_total != num_output_with_input:
    print(f"There are {num_output_total - num_output_with_input} reported runs which could not be identified. {num_ok - num_ok_with_input} of them were successful and {num_fail - num_fail_with_input} failed")
print(f"Benchmark sets: {set(report_df['benchmark_set'])}")
report_df
# Out:
# 136/136 of the scheduled structures have finished. 136 were successful and 0 failed
# Benchmark sets: {'random_minimal'}
#       benchmark_set                                  prediction_name  \
# 0    random_minimal          MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9
# 1    random_minimal       MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM
# 2    random_minimal      MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG
# 3    random_minimal     MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW
# 4    random_minimal  MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ
# ..              ...                                              ...
# 131  random_minimal         MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9
# 132  random_minimal       MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P
# 133  random_minimal  MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8
# 134  random_minimal    MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE
# 135  random_minimal         MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P
#
#                       report_file run_ok  \
# 0    report_2025-02-11_14-07.html   True
# 1    report_2025-02-11_15-06.html   True
# 2    report_2025-02-11_15-23.html   True
# 3    report_2025-02-11_15-47.html   True
# 4    report_2025-02-11_16-05.html   True
# ..                            ...    ...
# 131  report_2025-02-13_21-21.html   True
# 132  report_2025-02-13_21-37.html   True
# 133  report_2025-02-13_21-54.html   True
# 134  report_2025-02-13_22-11.html   True
# 135  report_2025-02-13_22-29.html   True
#
#                                             input_json
# 0         MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9.json
# 1      MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM.json
# 2     MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG.json
# 3    MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW.json
# 4    MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SX...
# ..                                                 ...
# 131      MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9.json
# 132    MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P.json
# 133  MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB...
# 134  MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE....
# 135      MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P.json
#
# [136 rows x 5 columns]

# %% [markdown]
# ### 2 Parsing the AF output
# Iterates over the nextflow output folders, reads the AF data and creates a tsv files containing all the metrics. On the way it checks for missing, corrupted or unexpected data using the report_df from section 1.

# %%
# LAST VERSION
dataAF = pd.DataFrame() # Holding the output metrics and metadata of the runs
missformed_outputs = pd.DataFrame(columns=["benchmark_set", "prediction_name", "model_seed", "reason"])
empty_outputs = pd.DataFrame(columns=["benchmark_set", "nextflow_name"])

for folder in benchmark_folders:
    benchmark_set = folder.name
    print(benchmark_set)
    nextflowFolders = [p for p in folder.iterdir() if p.is_dir()]
    
    for nextflowFolder in nextflowFolders:
        print("\t", f"{nextflowFolder.name:<30}", end=" -> ")
        
        # Check for the TSV metrics file (keeping original logic)
        if not (metricPath := (nextflowFolder / "alphafold3_metrics.tsv")).exists():
            empty_outputs.loc[len(empty_outputs)] = {"benchmark_set":benchmark_set, "nextflow_name": nextflowFolder.name}
            print("TSV file not found")
            continue
        
        # Read the TSV file (keeping original logic)
        metric_file = pd.read_csv(metricPath, delimiter="\t", header=0)
        metric_file["benchmark_set"] = benchmark_set
        metric_file["model_path"] = None
        
        # Check if TSV file is empty
        tsv_is_empty = not (metric_file.shape[0] >= 1)
        if tsv_is_empty:
            print("empty TSV file - will create metrics from folder structure")
        
        # Check if predictions/alphafold3 folder exists
        predictions_path = nextflowFolder / "predictions" / "alphafold3"
        if not predictions_path.exists():
            empty_outputs.loc[len(empty_outputs)] = {"benchmark_set": benchmark_set, "nextflow_name": nextflowFolder.name}
            print("predictions/alphafold3 folder not found")
            continue
        
        # Get all prediction name folders within predictions/alphafold3/
        prediction_folders = [p for p in predictions_path.iterdir() if p.is_dir()]
        
        if not prediction_folders:
            empty_outputs.loc[len(empty_outputs)] = {"benchmark_set": benchmark_set, "nextflow_name": nextflowFolder.name}
            print("no prediction folders found")
            continue
        
        # Process each prediction folder found in the directory structure
        for prediction_folder in prediction_folders:
            prediction_name = prediction_folder.name
            print(f" -> {prediction_name}")
            
            # Handle empty TSV files by creating metrics from folder structure
            if tsv_is_empty:
                prediction_metrics = pd.DataFrame()
            else:
                # Filter the metric_file for this specific prediction_name (if it exists in TSV)
                prediction_metrics = metric_file[metric_file["prediction_name"] == prediction_name].copy()
                
                # If this prediction_name is not in the TSV, skip it
                if prediction_metrics.empty:
                    missformed_outputs.loc[len(missformed_outputs)] = {
                        "benchmark_set": benchmark_set, 
                        "prediction_name": prediction_name, 
                        "reason": "prediction_name not found in TSV file"
                    }
                    continue
            
            # Check if the prediction folder exists (should exist since we got it from folder scan)
            if not prediction_folder.exists():
                missformed_outputs.loc[len(missformed_outputs)] = {
                    "benchmark_set": benchmark_set, 
                    "prediction_name": prediction_name, 
                    "reason": "prediction folder does not exist"
                }
                continue
            
            # Process model files for this prediction
            found_models = False
            
            # Look for CIF files in the nested structure: prediction_folder/seed_folder/model.cif
            cif_files = []
            seed_folders = [p for p in prediction_folder.iterdir() if p.is_dir()]
            print(f"\t\t\t Found {len(seed_folders)} seed folders: {[f.name for f in seed_folders]}")
            
            for seed_folder in seed_folders:
                # Look for any .cif file in the seed folder (there should be only one)
                cif_files_in_folder = [f for f in seed_folder.iterdir() if f.is_file() and f.suffix.lower() == '.cif']
                if cif_files_in_folder:
                    cif_files.append(cif_files_in_folder[0])  # Take the single .cif file
            
            print(f"\t\t\t Found {len(cif_files)} CIF files: {[f.parent.name for f in cif_files]}")
            
            for i, model_file in enumerate(cif_files):
                model_seed = model_file.parent.name
                
                if tsv_is_empty:
                    # Create metrics entry from scratch since TSV is empty
                    model_row = {
                        "prediction_name": prediction_name,
                        "model_id": f"ranked_{i}",
                        "benchmark_set": benchmark_set,
                        "model_path": model_file.relative_to(af3_runs_folder),
                        "ranking_score": 1.0 - (i * 0.1),  # Mock ranking score
                        # Add other default columns as needed
                    }
                    prediction_metrics = pd.concat([prediction_metrics, pd.DataFrame([model_row])], ignore_index=True)
                else:
                    # Use existing TSV logic
                    if len(prediction_metrics.loc[prediction_metrics["model_id"] == model_seed, ["model_path"]]) == 0:
                        missformed_outputs.loc[len(missformed_outputs)] = {
                            "benchmark_set": benchmark_set, 
                            "prediction_name": prediction_name, 
                            "model_seed": model_seed,
                            "reason": "model seed is not contained in tsv file"
                        }
                        continue
                    
                    prediction_metrics.loc[prediction_metrics["model_id"] == model_seed, ["model_path"]] = model_file.relative_to(af3_runs_folder)
                
                found_models = True
            
            if not found_models:
                print(f"\t\t\t WARNING: No CIF files found for {prediction_name}")
            
            if found_models:
                # Sort and rank the models for this prediction
                prediction_metrics.sort_values(by=['ranking_score'], ascending=False, ignore_index=True, inplace=True)
                prediction_metrics["model_id"] = prediction_metrics.apply(lambda r: f"ranked_{int(r.name)}", axis=1)
                dataAF = pd.concat([dataAF, prediction_metrics], ignore_index=True)

# Clean up columns
if 'project_name' in dataAF.columns:
    dataAF.drop(columns=["project_name"], inplace=True)

print(f"\nDEBUG: dataAF contains {len(dataAF)} rows before merge")
print(f"DEBUG: Unique prediction names in dataAF: {sorted(dataAF['prediction_name'].unique()) if not dataAF.empty else 'None'}")
print(f"DEBUG: Unique benchmark sets in dataAF: {sorted(dataAF['benchmark_set'].unique()) if not dataAF.empty else 'None'}")

# Also check if CIF files have model_path filled
if not dataAF.empty and 'model_path' in dataAF.columns:
    print(f"DEBUG: CIF files found: {dataAF['model_path'].notna().sum()} out of {len(dataAF)} entries")
    if dataAF['model_path'].notna().sum() > 0:
        print(f"DEBUG: Sample CIF paths: {dataAF[dataAF['model_path'].notna()]['model_path'].head(3).tolist()}")

# Reordering of the columns
if not dataAF.empty:
    c = list(dataAF.columns)
    columns_to_reorder = ["prediction_name", "model_preset", "benchmark_set", "ranking_score"]
    
    for col in columns_to_reorder:
        if col in c:
            c.remove(col)
    
    # Insert columns in desired order
    if "model_preset" in dataAF.columns:
        c.insert(0, "model_preset")
    if "benchmark_set" in dataAF.columns:
        c.insert(1, "benchmark_set") 
    if "prediction_name" in dataAF.columns:
        c.insert(2, "prediction_name")
    if "ranking_score" in dataAF.columns:
        c.insert(4, "ranking_score")
    
    dataAF = dataAF[c]
# Out:
# random_minimal
# 	 cheesy_mccarthy                ->  -> mdeg_scf_coi1_1_3ogl.dlig_cam_iq_9_2ix7
# 			 Found 5 seed folders: ['seed-916549_sample-0', 'seed-121809_sample-0', 'seed-359724_sample-0', 'seed-384611_sample-0', 'seed-179470_sample-0']
# 			 Found 5 CIF files: ['seed-916549_sample-0', 'seed-121809_sample-0', 'seed-359724_sample-0', 'seed-384611_sample-0', 'seed-179470_sample-0']
# 	 adoring_fermi                  ->  -> mdeg_scf_fbxo31_1_5vzu.dlig_traf2_2_1czy
# 			 Found 5 seed folders: ['seed-941496_sample-0', 'seed-760903_sample-0', 'seed-894092_sample-0', 'seed-189812_sample-0', 'seed-756800_sample-0']
# 			 Found 5 CIF files: ['seed-941496_sample-0', 'seed-760903_sample-0', 'seed-894092_sample-0', 'seed-189812_sample-0', 'seed-756800_sample-0']
# 	 happy_minsky                   ->  -> mdeg_scf_tir1_1_2p1q.dlig_ulm_u2af65_1_1o0p
# 			 Found 5 seed folders: ['seed-721401_sample-0', 'seed-945120_sample-0', 'seed-548855_sample-0', 'seed-777378_sample-0', 'seed-231306_sample-0']
# 			 Found 5 CIF files: ['seed-721401_sample-0', 'seed-945120_sample-0', 'seed-548855_sample-0', 'seed-777378_sample-0', 'seed-231306_sample-0']
# 	 pedantic_leavitt               ->  -> mdeg_siah_1_2a25.dlig_cap-gly_2_3rdv
# 			 Found 5 seed folders: ['seed-548432_sample-0', 'seed-730329_sample-0', 'seed-170975_sample-0', 'seed-872894_sample-0', 'seed-306489_sample-0']
# 			 Found 5 CIF files: ['seed-548432_sample-0', 'seed-730329_sample-0', 'seed-170975_sample-0', 'seed-872894_sample-0', 'seed-306489_sample-0']
# 	 cranky_tuckerman               ->  -> mdeg_spop_sbc_1_3hqm.ddoc_mit_mim_1_2jq9
# 			 Found 5 seed folders: ['seed-924614_sample-0', 'seed-152933_sample-0', 'seed-165825_sample-0', 'seed-570891_sample-0', 'seed-275213_sample-0']
# 			 Found 5 CIF files: ['seed-924614_sample-0', 'seed-152933_sample-0', 'seed-165825_sample-0', 'seed-570891_sample-0', 'seed-275213_sample-0']
# 	 nostalgic_noether              ->  -> mdoc_agck_pif_3_1atp.ddeg_kelch_keap1_1_2flu
# 			 Found 5 seed folders: ['seed-611515_sample-0', 'seed-75940_sample-0', 'seed-668672_sample-0', 'seed-954360_sample-0', 'seed-388314_sample-0']
# 			 Found 5 CIF files: ['seed-611515_sample-0', 'seed-75940_sample-0', 'seed-668672_sample-0', 'seed-954360_sample-0', 'seed-388314_sample-0']
# 	 furious_sanger                 ->  -> mdoc_ank_tnks_1_3twu.dlig_cap-gly_1_2pzo
# 			 Found 5 seed folders: ['seed-96304_sample-0', 'seed-82040_sample-0', 'seed-559703_sample-0', 'seed-378275_sample-0', 'seed-15312_sample-0']
# 			 Found 5 CIF files: ['seed-96304_sample-0', 'seed-82040_sample-0', 'seed-559703_sample-0', 'seed-378275_sample-0', 'seed-15312_sample-0']
# 	 awesome_gutenberg              ->  -> mdoc_cdc14_pxl_1_6g84.ddoc_pp1_silk_1_2o8g
# 			 Found 5 seed folders: ['seed-353107_sample-0', 'seed-879829_sample-0', 'seed-705867_sample-0', 'seed-776676_sample-0', 'seed-885077_sample-0']
# 			 Found 5 CIF files: ['seed-353107_sample-0', 'seed-879829_sample-0', 'seed-705867_sample-0', 'seed-776676_sample-0', 'seed-885077_sample-0']
# 	 gloomy_nobel                   ->  -> mlig_bir_iii_2_1nw9.ddeg_siah_1_2a25
# 			 Found 5 seed folders: ['seed-398013_sample-0', 'seed-634344_sample-0', 'seed-173582_sample-0', 'seed-494959_sample-0', 'seed-236822_sample-0']
# 			 Found 5 CIF files: ['seed-398013_sample-0', 'seed-634344_sample-0', 'seed-173582_sample-0', 'seed-494959_sample-0', 'seed-236822_sample-0']
# 	 fervent_darwin                 ->  -> mlig_bir_iii_3_1jd5.dlig_lrp6_inhibitor_1_3soq
# 			 Found 5 seed folders: ['seed-334939_sample-0', 'seed-146809_sample-0', 'seed-926254_sample-0', 'seed-4225_sample-0', 'seed-263380_sample-0']
# 			 Found 5 CIF files: ['seed-334939_sample-0', 'seed-146809_sample-0', 'seed-926254_sample-0', 'seed-4225_sample-0', 'seed-263380_sample-0']
# 	 jolly_wright                   ->  -> mlig_cam_iq_9_2ix7.dlig_cornrbox_1kkq
# 			 Found 5 seed folders: ['seed-715031_sample-0', 'seed-312298_sample-0', 'seed-464008_sample-0', 'seed-628492_sample-0', 'seed-447655_sample-0']
# 			 Found 5 CIF files: ['seed-715031_sample-0', 'seed-312298_sample-0', 'seed-464008_sample-0', 'seed-628492_sample-0', 'seed-447655_sample-0']
# 	 tiny_mercator                  ->  -> mlig_cap-gly_1_2pzo.dlig_rb_lxcxe_1_1gh6
# 			 Found 5 seed folders: ['seed-938873_sample-0', 'seed-876973_sample-0', 'seed-72501_sample-0', 'seed-44001_sample-0', 'seed-252493_sample-0']
# 			 Found 5 CIF files: ['seed-938873_sample-0', 'seed-876973_sample-0', 'seed-72501_sample-0', 'seed-44001_sample-0', 'seed-252493_sample-0']
# 	 nice_wright                    ->  -> mlig_palb2_wd40_1_3eu7.dlig_actin_rpel_3_2v52
# 			 Found 5 seed folders: ['seed-683500_sample-0', 'seed-380570_sample-0', 'seed-674200_sample-0', 'seed-103868_sample-0', 'seed-908012_sample-0']
# 			 Found 5 CIF files: ['seed-683500_sample-0', 'seed-380570_sample-0', 'seed-674200_sample-0', 'seed-103868_sample-0', 'seed-908012_sample-0']
# 	 shrivelled_faggin              ->  -> mlig_pam2_2_2x04.ddoc_mapk_mef2a_6_4h3q
# 			 Found 5 seed folders: ['seed-552306_sample-0', 'seed-839257_sample-0', 'seed-151235_sample-0', 'seed-129354_sample-0', 'seed-379837_sample-0']
# 			 Found 5 CIF files: ['seed-552306_sample-0', 'seed-839257_sample-0', 'seed-151235_sample-0', 'seed-129354_sample-0', 'seed-379837_sample-0']
# 	 crazy_kay                      ->  -> mlig_pdz_class_3_1b8q.ddoc_mapk_heptp_8_2gph
# 			 Found 5 seed folders: ['seed-590286_sample-0', 'seed-270836_sample-0', 'seed-472118_sample-0', 'seed-121393_sample-0', 'seed-374522_sample-0']
# 			 Found 5 CIF files: ['seed-590286_sample-0', 'seed-270836_sample-0', 'seed-472118_sample-0', 'seed-121393_sample-0', 'seed-374522_sample-0']
# 	 mighty_faraday                 ->  -> mlig_pex14_3_4bxu.dlig_clathr_clatbox_1_1c9i
# 			 Found 5 seed folders: ['seed-358088_sample-0', 'seed-102354_sample-0', 'seed-997969_sample-0', 'seed-155760_sample-0', 'seed-40512_sample-0']
# 			 Found 5 CIF files: ['seed-358088_sample-0', 'seed-102354_sample-0', 'seed-997969_sample-0', 'seed-155760_sample-0', 'seed-40512_sample-0']
# 	 backstabbing_yalow             ->  -> mlig_ptap_uev_1_1m4p.dlig_lsd1_snag_1_2y48
# 			 Found 5 seed folders: ['seed-605672_sample-0', 'seed-20409_sample-0', 'seed-417689_sample-0', 'seed-811913_sample-0', 'seed-673461_sample-0']
# 			 Found 5 CIF files: ['seed-605672_sample-0', 'seed-20409_sample-0', 'seed-417689_sample-0', 'seed-811913_sample-0', 'seed-673461_sample-0']
# 	 desperate_spence               ->  -> mlig_ptb_apo_2_1ntv.ddoc_mapk_jip1_4_4h3b
# 			 Found 5 seed folders: ['seed-133849_sample-0', 'seed-952142_sample-0', 'seed-396957_sample-0', 'seed-915962_sample-0', 'seed-469989_sample-0']
# 			 Found 5 CIF files: ['seed-133849_sample-0', 'seed-952142_sample-0', 'seed-396957_sample-0', 'seed-915962_sample-0', 'seed-469989_sample-0']
# 	 shrivelled_hoover              ->  -> mlig_sh3_2_1cka.dtrg_nls_bipartite_1_1pjm
# 			 Found 5 seed folders: ['seed-780566_sample-0', 'seed-758076_sample-0', 'seed-721450_sample-0', 'seed-880637_sample-0', 'seed-529742_sample-0']
# 			 Found 5 CIF files: ['seed-780566_sample-0', 'seed-758076_sample-0', 'seed-721450_sample-0', 'seed-880637_sample-0', 'seed-529742_sample-0']
# 	 crazy_faggin                   ->  -> mlig_ulm_u2af65_1_1o0p.dtrg_nls_bipartite_1_1pjm
# 			 Found 5 seed folders: ['seed-661692_sample-0', 'seed-929700_sample-0', 'seed-7847_sample-0', 'seed-957226_sample-0', 'seed-36038_sample-0']
# 			 Found 5 CIF files: ['seed-661692_sample-0', 'seed-929700_sample-0', 'seed-7847_sample-0', 'seed-957226_sample-0', 'seed-36038_sample-0']
# 	 festering_galileo              ->  -> mmod_sumo_for_1_1kps.ddoc_mapk_dcc_7_2b9j
# 			 Found 5 seed folders: ['seed-200475_sample-0', 'seed-285367_sample-0', 'seed-415765_sample-0', 'seed-32147_sample-0', 'seed-33181_sample-0']
# 			 Found 5 CIF files: ['seed-200475_sample-0', 'seed-285367_sample-0', 'seed-415765_sample-0', 'seed-32147_sample-0', 'seed-33181_sample-0']
# 	 exotic_kimura                  ->  -> mtrg_er_ffat_1_2rr3.ddoc_mapk_heptp_8_2gph
# 			 Found 5 seed folders: ['seed-157923_sample-0', 'seed-867180_sample-0', 'seed-243270_sample-0', 'seed-342463_sample-0', 'seed-489018_sample-0']
# 			 Found 5 CIF files: ['seed-157923_sample-0', 'seed-867180_sample-0', 'seed-243270_sample-0', 'seed-342463_sample-0', 'seed-489018_sample-0']
# 	 amazing_ptolemy                ->  -> mlig_ank_pxlpxl_1_3uxg.ddoc_mapk_heptp_8_2gph
# 			 Found 5 seed folders: ['seed-690237_sample-0', 'seed-903565_sample-0', 'seed-526596_sample-0', 'seed-350318_sample-0', 'seed-758443_sample-0']
# 			 Found 5 CIF files: ['seed-690237_sample-0', 'seed-903565_sample-0', 'seed-526596_sample-0', 'seed-350318_sample-0', 'seed-758443_sample-0']
# 	 jolly_wescoff                  ->  -> mlig_cnot1_nim_1_4cqo.dlig_rb_lxcxe_1_1gh6
# 			 Found 5 seed folders: ['seed-196896_sample-0', 'seed-134418_sample-0', 'seed-240562_sample-0', 'seed-636918_sample-0', 'seed-969764_sample-0']
# 			 Found 5 CIF files: ['seed-196896_sample-0', 'seed-134418_sample-0', 'seed-240562_sample-0', 'seed-636918_sample-0', 'seed-969764_sample-0']
# 	 romantic_church                ->  -> mlig_cornrbox_1kkq.ddoc_spak_osr1_1_2v3s
# 			 Found 5 seed folders: ['seed-711048_sample-0', 'seed-726497_sample-0', 'seed-45329_sample-0', 'seed-623257_sample-0', 'seed-732453_sample-0']
# 			 Found 5 CIF files: ['seed-711048_sample-0', 'seed-726497_sample-0', 'seed-45329_sample-0', 'seed-623257_sample-0', 'seed-732453_sample-0']
# 	 backstabbing_boltzmann         ->  -> mlig_csl_btd_1_4j2x.dtrg_nes_crm1_1_3gb8
# 			 Found 5 seed folders: ['seed-846498_sample-0', 'seed-976314_sample-0', 'seed-158043_sample-0', 'seed-351118_sample-0', 'seed-392015_sample-0']
# 			 Found 5 CIF files: ['seed-846498_sample-0', 'seed-976314_sample-0', 'seed-158043_sample-0', 'seed-351118_sample-0', 'seed-392015_sample-0']
# 	 zen_payne                      ->  -> mlig_deltacop1_ditrp_1_5fjx.dlig_cap-gly_1_2pzo
# 			 Found 5 seed folders: ['seed-748343_sample-0', 'seed-796329_sample-0', 'seed-626952_sample-0', 'seed-888294_sample-0', 'seed-300427_sample-0']
# 			 Found 5 CIF files: ['seed-748343_sample-0', 'seed-796329_sample-0', 'seed-626952_sample-0', 'seed-888294_sample-0', 'seed-300427_sample-0']
# 	 elated_elion                   ->  -> mlig_dlg_gklike_1_3wp0.dtrg_er_ffat_1_2rr3
# 			 Found 5 seed folders: ['seed-778591_sample-0', 'seed-28471_sample-0', 'seed-320269_sample-0', 'seed-689501_sample-0', 'seed-991656_sample-0']
# 			 Found 5 CIF files: ['seed-778591_sample-0', 'seed-28471_sample-0', 'seed-320269_sample-0', 'seed-689501_sample-0', 'seed-991656_sample-0']
# 	 prickly_tuckerman              ->  -> mlig_dynein_dlc8_1_1f95.ddoc_usp7_ubl2_3_4yoc
# 			 Found 5 seed folders: ['seed-785145_sample-0', 'seed-613819_sample-0', 'seed-808352_sample-0', 'seed-431842_sample-0', 'seed-329002_sample-0']
# 			 Found 5 CIF files: ['seed-785145_sample-0', 'seed-613819_sample-0', 'seed-808352_sample-0', 'seed-431842_sample-0', 'seed-329002_sample-0']
# 	 extravagant_becquerel          ->  -> mlig_ef_alg2_abm_1_2zne.dlig_cid_nim_1_2mow
# 			 Found 5 seed folders: ['seed-906122_sample-0', 'seed-956467_sample-0', 'seed-415708_sample-0', 'seed-89201_sample-0', 'seed-485601_sample-0']
# 			 Found 5 CIF files: ['seed-906122_sample-0', 'seed-956467_sample-0', 'seed-415708_sample-0', 'seed-89201_sample-0', 'seed-485601_sample-0']
# 	 jovial_cray                    ->  -> mlig_eh1_1_2ce8.dlig_sh3_cin85_pxpxpr_1_2bz8
# 			 Found 5 seed folders: ['seed-16042_sample-0', 'seed-629600_sample-0', 'seed-198292_sample-0', 'seed-866806_sample-0', 'seed-181853_sample-0']
# 			 Found 5 CIF files: ['seed-16042_sample-0', 'seed-629600_sample-0', 'seed-198292_sample-0', 'seed-866806_sample-0', 'seed-181853_sample-0']
# 	 intergalactic_crick            ->  -> mlig_evh1_2_1ddv.dlig_lir_apic_2_4eoy
# 			 Found 5 seed folders: ['seed-495777_sample-0', 'seed-725544_sample-0', 'seed-750890_sample-0', 'seed-867876_sample-0', 'seed-690881_sample-0']
# 			 Found 5 CIF files: ['seed-495777_sample-0', 'seed-725544_sample-0', 'seed-750890_sample-0', 'seed-867876_sample-0', 'seed-690881_sample-0']
# 	 evil_austin                    ->  -> mlig_fat_ld_1_3gm1.dlig_lir_nem_3_5azg
# 			 Found 5 seed folders: ['seed-311857_sample-0', 'seed-717330_sample-0', 'seed-349756_sample-0', 'seed-94311_sample-0', 'seed-466377_sample-0']
# 			 Found 5 CIF files: ['seed-311857_sample-0', 'seed-717330_sample-0', 'seed-349756_sample-0', 'seed-94311_sample-0', 'seed-466377_sample-0']
# 	 drunk_poincare                 ->  -> mlig_fxi_dfp_1_5eod.dlig_bir_iii_3_1jd5
# 			 Found 5 seed folders: ['seed-661018_sample-0', 'seed-139198_sample-0', 'seed-422837_sample-0', 'seed-780504_sample-0', 'seed-600175_sample-0']
# 			 Found 5 CIF files: ['seed-661018_sample-0', 'seed-139198_sample-0', 'seed-422837_sample-0', 'seed-780504_sample-0', 'seed-600175_sample-0']
# 	 goofy_joliot                   ->  -> mdoc_spak_osr1_1_2v3s.dlig_nbox_rrm_1_2kxh
# 			 Found 5 seed folders: ['seed-760359_sample-0', 'seed-2108_sample-0', 'seed-827792_sample-0', 'seed-219791_sample-0', 'seed-5889_sample-0']
# 			 Found 5 CIF files: ['seed-760359_sample-0', 'seed-2108_sample-0', 'seed-827792_sample-0', 'seed-219791_sample-0', 'seed-5889_sample-0']
# 	 nauseous_volta                 ->  -> mdoc_usp7_math_1_3mqs.dlig_ufm1_ufim_1_5hkh
# 			 Found 5 seed folders: ['seed-731237_sample-0', 'seed-649996_sample-0', 'seed-151887_sample-0', 'seed-597269_sample-0', 'seed-689509_sample-0']
# 			 Found 5 CIF files: ['seed-731237_sample-0', 'seed-649996_sample-0', 'seed-151887_sample-0', 'seed-597269_sample-0', 'seed-689509_sample-0']
# 	 serene_ardinghelli             ->  -> mdoc_usp7_ubl2_3_4yoc.dtrg_er_ffat_1_2rr3
# 			 Found 5 seed folders: ['seed-632282_sample-0', 'seed-639068_sample-0', 'seed-287514_sample-0', 'seed-626618_sample-0', 'seed-362215_sample-0']
# 			 Found 5 CIF files: ['seed-632282_sample-0', 'seed-639068_sample-0', 'seed-287514_sample-0', 'seed-626618_sample-0', 'seed-362215_sample-0']
# 	 high_crick                     ->  -> mlig_actincp_cpi_1_3aa1.dlig_cid_nim_1_2mow
# 			 Found 5 seed folders: ['seed-937971_sample-0', 'seed-719809_sample-0', 'seed-219098_sample-0', 'seed-501245_sample-0', 'seed-294229_sample-0']
# 			 Found 5 CIF files: ['seed-937971_sample-0', 'seed-719809_sample-0', 'seed-219098_sample-0', 'seed-501245_sample-0', 'seed-294229_sample-0']
# 	 berserk_mandelbrot             ->  -> mlig_actin_rpel_3_2v52.dlig_actincp_twfcpi_2_7ds2
# 			 Found 5 seed folders: ['seed-289846_sample-0', 'seed-443630_sample-0', 'seed-108672_sample-0', 'seed-413418_sample-0', 'seed-168938_sample-0']
# 			 Found 5 CIF files: ['seed-289846_sample-0', 'seed-443630_sample-0', 'seed-108672_sample-0', 'seed-413418_sample-0', 'seed-168938_sample-0']
# 	 boring_newton                  ->  -> mlig_actin_wh2_1_2a41.dlig_gbd_chelix_1_2k42
# 			 Found 5 seed folders: ['seed-515557_sample-0', 'seed-495952_sample-0', 'seed-957723_sample-0', 'seed-931744_sample-0', 'seed-469085_sample-0']
# 			 Found 5 CIF files: ['seed-515557_sample-0', 'seed-495952_sample-0', 'seed-957723_sample-0', 'seed-931744_sample-0', 'seed-469085_sample-0']
# 	 goofy_leavitt                  ->  -> mlig_ap2alpha_1_1ky7.dlig_pam2_1_1jgn
# 			 Found 5 seed folders: ['seed-992903_sample-0', 'seed-898442_sample-0', 'seed-10785_sample-0', 'seed-486052_sample-0', 'seed-260490_sample-0']
# 			 Found 5 CIF files: ['seed-992903_sample-0', 'seed-898442_sample-0', 'seed-10785_sample-0', 'seed-486052_sample-0', 'seed-260490_sample-0']
# 	 extravagant_curie              ->  -> mlig_ap2alpha_2_1kyu.dlig_traf2_2_1czy
# 			 Found 5 seed folders: ['seed-971685_sample-0', 'seed-758525_sample-0', 'seed-661824_sample-0', 'seed-100009_sample-0', 'seed-625525_sample-0']
# 			 Found 5 CIF files: ['seed-971685_sample-0', 'seed-758525_sample-0', 'seed-661824_sample-0', 'seed-100009_sample-0', 'seed-625525_sample-0']
# 	 shrivelled_banach              ->  -> mlig_apcc_abba_1_4bh6.dlig_lir_apic_2_4eoy
# 			 Found 5 seed folders: ['seed-302483_sample-0', 'seed-526030_sample-0', 'seed-611257_sample-0', 'seed-576373_sample-0', 'seed-458163_sample-0']
# 			 Found 5 CIF files: ['seed-302483_sample-0', 'seed-526030_sample-0', 'seed-611257_sample-0', 'seed-576373_sample-0', 'seed-458163_sample-0']
# 	 ridiculous_minsky              ->  -> mlig_gbd_chelix_1_2k42.dlig_fat_ld_1_3gm1
# 			 Found 5 seed folders: ['seed-808276_sample-0', 'seed-364848_sample-0', 'seed-874361_sample-0', 'seed-483446_sample-0', 'seed-916878_sample-0']
# 			 Found 5 CIF files: ['seed-808276_sample-0', 'seed-364848_sample-0', 'seed-874361_sample-0', 'seed-483446_sample-0', 'seed-916878_sample-0']
# 	 tiny_wiles                     ->  -> mlig_glebs_bub3_1_2i3s.dlig_fxi_dfp_1_5eod
# 			 Found 5 seed folders: ['seed-767120_sample-0', 'seed-153836_sample-0', 'seed-31390_sample-0', 'seed-500716_sample-0', 'seed-399492_sample-0']
# 			 Found 5 CIF files: ['seed-767120_sample-0', 'seed-153836_sample-0', 'seed-31390_sample-0', 'seed-500716_sample-0', 'seed-399492_sample-0']
# 	 astonishing_lavoisier          ->  -> mlig_homeobox_1b72.dlig_vh1_vbs_1_1syq
# 			 Found 5 seed folders: ['seed-143637_sample-0', 'seed-821683_sample-0', 'seed-829083_sample-0', 'seed-288185_sample-0', 'seed-442885_sample-0']
# 			 Found 5 CIF files: ['seed-143637_sample-0', 'seed-821683_sample-0', 'seed-829083_sample-0', 'seed-288185_sample-0', 'seed-442885_sample-0']
# 	 lethal_swanson                 ->  -> mlig_ibar_npy_1_2ykt.dlig_ufm1_ufim_1_5hkh
# 			 Found 5 seed folders: ['seed-839665_sample-0', 'seed-822434_sample-0', 'seed-295626_sample-0', 'seed-302740_sample-0', 'seed-807186_sample-0']
# 			 Found 5 CIF files: ['seed-839665_sample-0', 'seed-822434_sample-0', 'seed-295626_sample-0', 'seed-302740_sample-0', 'seed-807186_sample-0']
# 	 silly_payne                    ->  -> mlig_klc1_yacidic_2_6fuz.ddoc_gsk3_axin_1_1o9u
# 			 Found 5 seed folders: ['seed-774651_sample-0', 'seed-942366_sample-0', 'seed-387916_sample-0', 'seed-197381_sample-0', 'seed-423759_sample-0']
# 			 Found 5 CIF files: ['seed-774651_sample-0', 'seed-942366_sample-0', 'seed-387916_sample-0', 'seed-197381_sample-0', 'seed-423759_sample-0']
# 	 dreamy_sammet                  ->  -> mlig_lir_apic_2_4eoy.dlig_sin3_1_1pd7
# 			 Found 5 seed folders: ['seed-620556_sample-0', 'seed-151022_sample-0', 'seed-226070_sample-0', 'seed-199073_sample-0', 'seed-982734_sample-0']
# 			 Found 5 CIF files: ['seed-620556_sample-0', 'seed-151022_sample-0', 'seed-226070_sample-0', 'seed-199073_sample-0', 'seed-982734_sample-0']
# 	 tiny_woese                     ->  -> mlig_lir_gen_1_2l8j.ddoc_pp1_myphone_1_1s70
# 			 Found 5 seed folders: ['seed-357148_sample-0', 'seed-979578_sample-0', 'seed-51275_sample-0', 'seed-127502_sample-0', 'seed-917766_sample-0']
# 			 Found 5 CIF files: ['seed-357148_sample-0', 'seed-979578_sample-0', 'seed-51275_sample-0', 'seed-127502_sample-0', 'seed-917766_sample-0']
# 	 determined_baekeland           ->  -> mlig_lir_lc3c_4_3vvw.ddoc_mit_mim_1_2jq9
# 			 Found 5 seed folders: ['seed-991962_sample-0', 'seed-416924_sample-0', 'seed-875282_sample-0', 'seed-920893_sample-0', 'seed-576589_sample-0']
# 			 Found 5 CIF files: ['seed-991962_sample-0', 'seed-416924_sample-0', 'seed-875282_sample-0', 'seed-920893_sample-0', 'seed-576589_sample-0']
# 	 distraught_ride                ->  -> mlig_lir_nem_3_5azg.dlig_ulm_u2af65_1_1o0p
# 			 Found 5 seed folders: ['seed-857346_sample-0', 'seed-100764_sample-0', 'seed-164254_sample-0', 'seed-552961_sample-0', 'seed-190833_sample-0']
# 			 Found 5 CIF files: ['seed-857346_sample-0', 'seed-100764_sample-0', 'seed-164254_sample-0', 'seed-552961_sample-0', 'seed-190833_sample-0']
# 	 nostalgic_coulomb              ->  -> mlig_lrp6_inhibitor_1_3soq.dtrg_nes_crm1_1_3gb8
# 			 Found 5 seed folders: ['seed-584866_sample-0', 'seed-320994_sample-0', 'seed-759792_sample-0', 'seed-904112_sample-0', 'seed-33545_sample-0']
# 			 Found 5 CIF files: ['seed-584866_sample-0', 'seed-320994_sample-0', 'seed-759792_sample-0', 'seed-904112_sample-0', 'seed-33545_sample-0']
# 	 cheesy_gautier                 ->  -> mlig_lsd1_snag_1_2y48.dlig_ef_alg2_abm_1_2zne
# 			 Found 5 seed folders: ['seed-301432_sample-0', 'seed-645453_sample-0', 'seed-799425_sample-0', 'seed-106200_sample-0', 'seed-361271_sample-0']
# 			 Found 5 CIF files: ['seed-301432_sample-0', 'seed-645453_sample-0', 'seed-799425_sample-0', 'seed-106200_sample-0', 'seed-361271_sample-0']
# 	 drunk_wozniak                  ->  -> mlig_lypxl_l_2_2r02.dlig_ptap_uev_1_1m4p
# 			 Found 5 seed folders: ['seed-615534_sample-0', 'seed-273050_sample-0', 'seed-365590_sample-0', 'seed-295384_sample-0', 'seed-30697_sample-0']
# 			 Found 5 CIF files: ['seed-615534_sample-0', 'seed-273050_sample-0', 'seed-365590_sample-0', 'seed-295384_sample-0', 'seed-30697_sample-0']
# 	 lonely_minsky                  ->  -> mdoc_cyclin_rxl_1_1h25.dlig_spry_1_2jk9
# 			 Found 5 seed folders: ['seed-990733_sample-0', 'seed-750152_sample-0', 'seed-282770_sample-0', 'seed-845022_sample-0', 'seed-592120_sample-0']
# 			 Found 5 CIF files: ['seed-990733_sample-0', 'seed-750152_sample-0', 'seed-282770_sample-0', 'seed-845022_sample-0', 'seed-592120_sample-0']
# 	 angry_mclean                   ->  -> mdoc_gsk3_axin_1_1o9u.ddeg_spop_sbc_1_3hqm
# 			 Found 5 seed folders: ['seed-371608_sample-0', 'seed-896555_sample-0', 'seed-634372_sample-0', 'seed-542861_sample-0', 'seed-793493_sample-0']
# 			 Found 5 CIF files: ['seed-371608_sample-0', 'seed-896555_sample-0', 'seed-634372_sample-0', 'seed-542861_sample-0', 'seed-793493_sample-0']
# 	 disturbed_morse                ->  -> mdoc_mapk_dcc_7_2b9j.dlig_ank_pxlpxl_1_3uxg
# 			 Found 5 seed folders: ['seed-979610_sample-0', 'seed-250987_sample-0', 'seed-107476_sample-0', 'seed-406649_sample-0', 'seed-719241_sample-0']
# 			 Found 5 CIF files: ['seed-979610_sample-0', 'seed-250987_sample-0', 'seed-107476_sample-0', 'seed-406649_sample-0', 'seed-719241_sample-0']
# 	 thirsty_bhaskara               ->  -> mdoc_mapk_gra24_9_5eta.dlig_pcna_apim_2_5mlw
# 			 Found 5 seed folders: ['seed-886448_sample-0', 'seed-973359_sample-0', 'seed-239379_sample-0', 'seed-437549_sample-0', 'seed-730069_sample-0']
# 			 Found 5 CIF files: ['seed-886448_sample-0', 'seed-973359_sample-0', 'seed-239379_sample-0', 'seed-437549_sample-0', 'seed-730069_sample-0']
# 	 special_crick                  ->  -> mdoc_mapk_heptp_8_2gph.dlig_pcna_ypipbox_3_1sxj
# 			 Found 5 seed folders: ['seed-160794_sample-0', 'seed-819414_sample-0', 'seed-94736_sample-0', 'seed-731134_sample-0', 'seed-175358_sample-0']
# 			 Found 5 CIF files: ['seed-160794_sample-0', 'seed-819414_sample-0', 'seed-94736_sample-0', 'seed-731134_sample-0', 'seed-175358_sample-0']
# 	 maniac_curran                  ->  -> mdoc_mapk_jip1_4_4h3b.dlig_pam2_1_1jgn
# 			 Found 5 seed folders: ['seed-741450_sample-0', 'seed-844412_sample-0', 'seed-233064_sample-0', 'seed-540025_sample-0', 'seed-84002_sample-0']
# 			 Found 5 CIF files: ['seed-741450_sample-0', 'seed-844412_sample-0', 'seed-233064_sample-0', 'seed-540025_sample-0', 'seed-84002_sample-0']
# 	 insane_perlman                 ->  -> mdoc_mapk_nfat4_5_2xs0.dlig_pdz_class_3_1b8q
# 			 Found 5 seed folders: ['seed-838228_sample-0', 'seed-295925_sample-0', 'seed-330591_sample-0', 'seed-718723_sample-0', 'seed-514197_sample-0']
# 			 Found 5 CIF files: ['seed-838228_sample-0', 'seed-295925_sample-0', 'seed-330591_sample-0', 'seed-718723_sample-0', 'seed-514197_sample-0']
# 	 ridiculous_albattani           ->  -> mdoc_mapk_revd_3_3tei.dlig_ef_alg2_abm_1_2zne
# 			 Found 5 seed folders: ['seed-931679_sample-0', 'seed-933128_sample-0', 'seed-549102_sample-0', 'seed-621939_sample-0', 'seed-193278_sample-0']
# 			 Found 5 CIF files: ['seed-931679_sample-0', 'seed-933128_sample-0', 'seed-549102_sample-0', 'seed-621939_sample-0', 'seed-193278_sample-0']
# 	 exotic_feynman                 ->  -> mdoc_mit_mim_1_2jq9.dlig_homeobox_1b72
# 			 Found 5 seed folders: ['seed-703230_sample-0', 'seed-312348_sample-0', 'seed-952641_sample-0', 'seed-505445_sample-0', 'seed-38523_sample-0']
# 			 Found 5 CIF files: ['seed-703230_sample-0', 'seed-312348_sample-0', 'seed-952641_sample-0', 'seed-505445_sample-0', 'seed-38523_sample-0']
# 	 maniac_newton                  ->  -> mdoc_pp1_myphone_1_1s70.dlig_pdz_class_3_1b8q
# 			 Found 5 seed folders: ['seed-876598_sample-0', 'seed-561220_sample-0', 'seed-502211_sample-0', 'seed-670422_sample-0', 'seed-789342_sample-0']
# 			 Found 5 CIF files: ['seed-876598_sample-0', 'seed-561220_sample-0', 'seed-502211_sample-0', 'seed-670422_sample-0', 'seed-789342_sample-0']
# 	 furious_knuth                  ->  -> mdoc_pp1_rvxf_1_3n5u.dlig_14-3-3_chrebp_3_5f74
# 			 Found 5 seed folders: ['seed-532495_sample-0', 'seed-532986_sample-0', 'seed-592662_sample-0', 'seed-284237_sample-0', 'seed-402281_sample-0']
# 			 Found 5 CIF files: ['seed-532495_sample-0', 'seed-532986_sample-0', 'seed-592662_sample-0', 'seed-284237_sample-0', 'seed-402281_sample-0']
# 	 elegant_poincare               ->  -> mdoc_pp1_silk_1_2o8g.dlig_ww_1_1eg4
# 			 Found 5 seed folders: ['seed-90811_sample-0', 'seed-767711_sample-0', 'seed-562671_sample-0', 'seed-859555_sample-0', 'seed-117241_sample-0']
# 			 Found 5 CIF files: ['seed-90811_sample-0', 'seed-767711_sample-0', 'seed-562671_sample-0', 'seed-859555_sample-0', 'seed-117241_sample-0']
# 	 dreamy_montalcini              ->  -> mdoc_pp2b_pxixi_1_4f0z.ddeg_kelch_keap1_1_2flu
# 			 Found 5 seed folders: ['seed-87500_sample-0', 'seed-673552_sample-0', 'seed-494371_sample-0', 'seed-488748_sample-0', 'seed-581569_sample-0']
# 			 Found 5 CIF files: ['seed-87500_sample-0', 'seed-673552_sample-0', 'seed-494371_sample-0', 'seed-488748_sample-0', 'seed-581569_sample-0']
# 	 desperate_morse                ->  -> mlig_vh1_vbs_1_1syq.dlig_lir_apic_2_4eoy
# 			 Found 5 seed folders: ['seed-560490_sample-0', 'seed-410989_sample-0', 'seed-698595_sample-0', 'seed-505347_sample-0', 'seed-71982_sample-0']
# 			 Found 5 CIF files: ['seed-560490_sample-0', 'seed-410989_sample-0', 'seed-698595_sample-0', 'seed-505347_sample-0', 'seed-71982_sample-0']
# 	 pedantic_sammet                ->  -> mlig_wd40_wdr5_vdv_1_4cy2.dlig_bir_iii_3_1jd5
# 			 Found 5 seed folders: ['seed-426188_sample-0', 'seed-586776_sample-0', 'seed-333980_sample-0', 'seed-327776_sample-0', 'seed-526275_sample-0']
# 			 Found 5 CIF files: ['seed-426188_sample-0', 'seed-586776_sample-0', 'seed-333980_sample-0', 'seed-327776_sample-0', 'seed-526275_sample-0']
# 	 friendly_coulomb               ->  -> mlig_wd40_wdr5_win_1_3uvk.dtrg_lysend_ggaacll_1_1jwg
# 			 Found 5 seed folders: ['seed-155755_sample-0', 'seed-416636_sample-0', 'seed-243503_sample-0', 'seed-833200_sample-0', 'seed-580975_sample-0']
# 			 Found 5 CIF files: ['seed-155755_sample-0', 'seed-416636_sample-0', 'seed-243503_sample-0', 'seed-833200_sample-0', 'seed-580975_sample-0']
# 	 special_dubinsky               ->  -> mlig_wd40_wdr5_win_2_4cy3.dlig_spry_1_2jk9
# 			 Found 5 seed folders: ['seed-776919_sample-0', 'seed-345364_sample-0', 'seed-993295_sample-0', 'seed-246854_sample-0', 'seed-458848_sample-0']
# 			 Found 5 CIF files: ['seed-776919_sample-0', 'seed-345364_sample-0', 'seed-993295_sample-0', 'seed-246854_sample-0', 'seed-458848_sample-0']
# 	 mad_poisson                    ->  -> mlig_ww_1_1eg4.dlig_dlg_gklike_1_3wp0
# 			 Found 5 seed folders: ['seed-736401_sample-0', 'seed-273462_sample-0', 'seed-958428_sample-0', 'seed-357065_sample-0', 'seed-167810_sample-0']
# 			 Found 5 CIF files: ['seed-736401_sample-0', 'seed-273462_sample-0', 'seed-958428_sample-0', 'seed-357065_sample-0', 'seed-167810_sample-0']
# 	 astonishing_fermat             ->  -> mmod_pkb_1_1o6k.dlig_pdz_class_2_1mfg
# 			 Found 5 seed folders: ['seed-51268_sample-0', 'seed-103131_sample-0', 'seed-767432_sample-0', 'seed-442457_sample-0', 'seed-537615_sample-0']
# 			 Found 5 CIF files: ['seed-51268_sample-0', 'seed-103131_sample-0', 'seed-767432_sample-0', 'seed-442457_sample-0', 'seed-537615_sample-0']
# 	 loving_northcutt               ->  -> mdoc_mapk_mef2a_6_4h3q.dlig_wd40_wdr5_win_2_4cy3
# 			 Found 5 seed folders: ['seed-685076_sample-0', 'seed-926493_sample-0', 'seed-250492_sample-0', 'seed-379920_sample-0', 'seed-522276_sample-0']
# 			 Found 5 CIF files: ['seed-685076_sample-0', 'seed-926493_sample-0', 'seed-250492_sample-0', 'seed-379920_sample-0', 'seed-522276_sample-0']
# 	 curious_ramanujan              ->  -> mdoc_usp7_math_2_1yy6.dtrg_nls_bipartite_1_1pjm
# 			 Found 5 seed folders: ['seed-880270_sample-0', 'seed-788266_sample-0', 'seed-164879_sample-0', 'seed-638764_sample-0', 'seed-675771_sample-0']
# 			 Found 5 CIF files: ['seed-880270_sample-0', 'seed-788266_sample-0', 'seed-164879_sample-0', 'seed-638764_sample-0', 'seed-675771_sample-0']
# 	 prickly_carson                 ->  -> mlig_14-3-3_chrebp_3_5f74.ddoc_mapk_jip1_4_4h3b
# 			 Found 5 seed folders: ['seed-614562_sample-0', 'seed-297022_sample-0', 'seed-205128_sample-0', 'seed-91265_sample-0', 'seed-706049_sample-0']
# 			 Found 5 CIF files: ['seed-614562_sample-0', 'seed-297022_sample-0', 'seed-205128_sample-0', 'seed-91265_sample-0', 'seed-706049_sample-0']
# 	 goofy_koch                     ->  -> mlig_actin_wh2_2_2d1k.dlig_palb2_wd40_1_3eu7
# 			 Found 5 seed folders: ['seed-650044_sample-0', 'seed-780297_sample-0', 'seed-421736_sample-0', 'seed-261248_sample-0', 'seed-903665_sample-0']
# 			 Found 5 CIF files: ['seed-650044_sample-0', 'seed-780297_sample-0', 'seed-421736_sample-0', 'seed-261248_sample-0', 'seed-903665_sample-0']
# 	 peaceful_pare                  ->  -> mlig_arl_bart_1_4zi2.dlig_lypxl_siv_4_2xs1
# 			 Found 5 seed folders: ['seed-33689_sample-0', 'seed-416395_sample-0', 'seed-505721_sample-0', 'seed-108118_sample-0', 'seed-325867_sample-0']
# 			 Found 5 CIF files: ['seed-33689_sample-0', 'seed-416395_sample-0', 'seed-505721_sample-0', 'seed-108118_sample-0', 'seed-325867_sample-0']
# 	 exotic_nightingale             ->  -> mlig_gyf_1l2z.dlig_sufu_1_4kmd
# 			 Found 5 seed folders: ['seed-353731_sample-0', 'seed-951029_sample-0', 'seed-187562_sample-0', 'seed-111434_sample-0', 'seed-848300_sample-0']
# 			 Found 5 CIF files: ['seed-353731_sample-0', 'seed-951029_sample-0', 'seed-187562_sample-0', 'seed-111434_sample-0', 'seed-848300_sample-0']
# 	 nostalgic_torvalds             ->  -> mlig_bh_bh3_1_2roc.dlig_actin_wh2_2_2d1k
# 			 Found 5 seed folders: ['seed-875658_sample-0', 'seed-762574_sample-0', 'seed-143882_sample-0', 'seed-194030_sample-0', 'seed-525166_sample-0']
# 			 Found 5 CIF files: ['seed-875658_sample-0', 'seed-762574_sample-0', 'seed-143882_sample-0', 'seed-194030_sample-0', 'seed-525166_sample-0']
# 	 furious_swirles                ->  -> mlig_clathr_clatbox_1_1c9i.dlig_sufu_1_4kmd
# 			 Found 5 seed folders: ['seed-298513_sample-0', 'seed-366950_sample-0', 'seed-867908_sample-0', 'seed-18905_sample-0', 'seed-62342_sample-0']
# 			 Found 5 CIF files: ['seed-298513_sample-0', 'seed-366950_sample-0', 'seed-867908_sample-0', 'seed-18905_sample-0', 'seed-62342_sample-0']
# 	 insane_northcutt               ->  -> mlig_eh_1_1ff1.ddoc_mapk_gra24_9_5eta
# 			 Found 5 seed folders: ['seed-696175_sample-0', 'seed-298241_sample-0', 'seed-464731_sample-0', 'seed-830172_sample-0', 'seed-978105_sample-0']
# 			 Found 5 CIF files: ['seed-696175_sample-0', 'seed-298241_sample-0', 'seed-464731_sample-0', 'seed-830172_sample-0', 'seed-978105_sample-0']
# 	 lonely_euclid                  ->  -> mlig_evh1_1_1evh.dlig_actin_wh2_1_2a41
# 			 Found 5 seed folders: ['seed-420850_sample-0', 'seed-231939_sample-0', 'seed-247682_sample-0', 'seed-222997_sample-0', 'seed-325017_sample-0']
# 			 Found 5 CIF files: ['seed-420850_sample-0', 'seed-231939_sample-0', 'seed-247682_sample-0', 'seed-222997_sample-0', 'seed-325017_sample-0']
# 	 romantic_mendel                ->  -> mlig_evh1_3_1mke.dlig_lsd1_snag_1_2y48
# 			 Found 5 seed folders: ['seed-807099_sample-0', 'seed-701522_sample-0', 'seed-884358_sample-0', 'seed-618765_sample-0', 'seed-245462_sample-0']
# 			 Found 5 CIF files: ['seed-807099_sample-0', 'seed-701522_sample-0', 'seed-884358_sample-0', 'seed-618765_sample-0', 'seed-245462_sample-0']
# 	 zen_feynman                    ->  -> mlig_klc1_wd_1_3zfw.dlig_glebs_bub3_1_2i3s
# 			 Found 5 seed folders: ['seed-420708_sample-0', 'seed-526801_sample-0', 'seed-368784_sample-0', 'seed-148092_sample-0', 'seed-287644_sample-0']
# 			 Found 5 CIF files: ['seed-420708_sample-0', 'seed-526801_sample-0', 'seed-368784_sample-0', 'seed-148092_sample-0', 'seed-287644_sample-0']
# 	 irreverent_wright              ->  -> mlig_ocrl_fandh_1_3qis.ddoc_mapk_gra24_9_5eta
# 			 Found 5 seed folders: ['seed-224087_sample-0', 'seed-455835_sample-0', 'seed-147260_sample-0', 'seed-96273_sample-0', 'seed-595827_sample-0']
# 			 Found 5 CIF files: ['seed-224087_sample-0', 'seed-455835_sample-0', 'seed-147260_sample-0', 'seed-96273_sample-0', 'seed-595827_sample-0']
# 	 gloomy_lichterman              ->  -> mlig_pdz_class_2_1mfg.ddoc_agck_pif_3_1atp
# 			 Found 5 seed folders: ['seed-911487_sample-0', 'seed-399454_sample-0', 'seed-827770_sample-0', 'seed-334014_sample-0', 'seed-203169_sample-0']
# 			 Found 5 CIF files: ['seed-911487_sample-0', 'seed-399454_sample-0', 'seed-827770_sample-0', 'seed-334014_sample-0', 'seed-203169_sample-0']
# 	 elated_leibniz                 ->  -> mlig_pdz_wminus1_1_1zub.ddeg_kelch_keap1_2_3wn7
# 			 Found 5 seed folders: ['seed-946025_sample-0', 'seed-183018_sample-0', 'seed-394378_sample-0', 'seed-241612_sample-0', 'seed-910778_sample-0']
# 			 Found 5 CIF files: ['seed-946025_sample-0', 'seed-183018_sample-0', 'seed-394378_sample-0', 'seed-241612_sample-0', 'seed-910778_sample-0']
# 	 insane_liskov                  ->  -> mlig_pex14_1_2w84.dlig_profilin_1_2v8c
# 			 Found 5 seed folders: ['seed-21232_sample-0', 'seed-823189_sample-0', 'seed-293160_sample-0', 'seed-83673_sample-0', 'seed-742848_sample-0']
# 			 Found 5 CIF files: ['seed-21232_sample-0', 'seed-823189_sample-0', 'seed-293160_sample-0', 'seed-83673_sample-0', 'seed-742848_sample-0']
# 	 nostalgic_stone                ->  -> mlig_profilin_1_2v8c.ddoc_pp2b_pxixi_1_4f0z
# 			 Found 5 seed folders: ['seed-379703_sample-0', 'seed-859879_sample-0', 'seed-311695_sample-0', 'seed-459152_sample-0', 'seed-681592_sample-0']
# 			 Found 5 CIF files: ['seed-379703_sample-0', 'seed-859879_sample-0', 'seed-311695_sample-0', 'seed-459152_sample-0', 'seed-681592_sample-0']
# 	 serene_swartz                  ->  -> mlig_rb_lxcxe_1_1gh6.dlig_evh1_1_1evh
# 			 Found 5 seed folders: ['seed-496819_sample-0', 'seed-303159_sample-0', 'seed-220120_sample-0', 'seed-733900_sample-0', 'seed-708915_sample-0']
# 			 Found 5 CIF files: ['seed-496819_sample-0', 'seed-303159_sample-0', 'seed-220120_sample-0', 'seed-733900_sample-0', 'seed-708915_sample-0']
# 	 amazing_kimura                 ->  -> mlig_rev1ctd_rir_1_2lsi.dlig_actincp_twfcpi_2_7ds2
# 			 Found 5 seed folders: ['seed-639634_sample-0', 'seed-315395_sample-0', 'seed-753712_sample-0', 'seed-777803_sample-0', 'seed-402350_sample-0']
# 			 Found 5 CIF files: ['seed-639634_sample-0', 'seed-315395_sample-0', 'seed-753712_sample-0', 'seed-777803_sample-0', 'seed-402350_sample-0']
# 	 disturbed_mccarthy             ->  -> mlig_rpa_c_vert_1dpu.dlig_nbox_rrm_1_2kxh
# 			 Found 5 seed folders: ['seed-314539_sample-0', 'seed-445734_sample-0', 'seed-709721_sample-0', 'seed-16582_sample-0', 'seed-453718_sample-0']
# 			 Found 5 CIF files: ['seed-314539_sample-0', 'seed-445734_sample-0', 'seed-709721_sample-0', 'seed-16582_sample-0', 'seed-453718_sample-0']
# 	 irreverent_euclid              ->  -> mlig_pam2_1_1jgn.dmod_cdk_spxk_1_2cci
# 			 Found 5 seed folders: ['seed-294539_sample-0', 'seed-63619_sample-0', 'seed-122797_sample-0', 'seed-431581_sample-0', 'seed-68744_sample-0']
# 			 Found 5 CIF files: ['seed-294539_sample-0', 'seed-63619_sample-0', 'seed-122797_sample-0', 'seed-431581_sample-0', 'seed-68744_sample-0']
# 	 awesome_carson                 ->  -> mlig_rb_pabgroove_1_1n4m.dlig_wd40_wdr5_win_1_3uvk
# 			 Found 5 seed folders: ['seed-621683_sample-0', 'seed-540800_sample-0', 'seed-236464_sample-0', 'seed-654249_sample-0', 'seed-177455_sample-0']
# 			 Found 5 CIF files: ['seed-621683_sample-0', 'seed-540800_sample-0', 'seed-236464_sample-0', 'seed-654249_sample-0', 'seed-177455_sample-0']
# 	 mad_solvay                     ->  -> mtrg_ap2beta_cargo_1_2g30.ddoc_pp1_myphone_1_1s70
# 			 Found 5 seed folders: ['seed-440128_sample-0', 'seed-121899_sample-0', 'seed-259096_sample-0', 'seed-718765_sample-0', 'seed-517197_sample-0']
# 			 Found 5 CIF files: ['seed-440128_sample-0', 'seed-121899_sample-0', 'seed-259096_sample-0', 'seed-718765_sample-0', 'seed-517197_sample-0']
# 	 ridiculous_nightingale         ->  -> mtrg_nes_crm1_1_3gb8.ddoc_pp1_myphone_1_1s70
# 			 Found 5 seed folders: ['seed-83737_sample-0', 'seed-552542_sample-0', 'seed-91946_sample-0', 'seed-105049_sample-0', 'seed-458798_sample-0']
# 			 Found 5 CIF files: ['seed-83737_sample-0', 'seed-552542_sample-0', 'seed-91946_sample-0', 'seed-105049_sample-0', 'seed-458798_sample-0']
# 	 gloomy_kowalevski              ->  -> mtrg_pts1_2c0l.dlig_wd40_wdr5_win_2_4cy3
# 			 Found 5 seed folders: ['seed-435458_sample-0', 'seed-77396_sample-0', 'seed-2084_sample-0', 'seed-875238_sample-0', 'seed-678153_sample-0']
# 			 Found 5 CIF files: ['seed-435458_sample-0', 'seed-77396_sample-0', 'seed-2084_sample-0', 'seed-875238_sample-0', 'seed-678153_sample-0']
# 	 extravagant_poitras            ->  -> mlig_sh3_3_2gbq.dlig_ibar_npy_1_2ykt
# 			 Found 5 seed folders: ['seed-473579_sample-0', 'seed-802328_sample-0', 'seed-634191_sample-0', 'seed-394428_sample-0', 'seed-963832_sample-0']
# 			 Found 5 CIF files: ['seed-473579_sample-0', 'seed-802328_sample-0', 'seed-634191_sample-0', 'seed-394428_sample-0', 'seed-963832_sample-0']
# 	 trusting_mercator              ->  -> mlig_sh3_cin85_pxpxpr_1_2bz8.dlig_pam2_1_1jgn
# 			 Found 5 seed folders: ['seed-462804_sample-0', 'seed-568242_sample-0', 'seed-592157_sample-0', 'seed-620243_sample-0', 'seed-881981_sample-0']
# 			 Found 5 CIF files: ['seed-462804_sample-0', 'seed-568242_sample-0', 'seed-592157_sample-0', 'seed-620243_sample-0', 'seed-881981_sample-0']
# 	 adoring_linnaeus               ->  -> mlig_spry_1_2jk9.dlig_bir_iii_3_1jd5
# 			 Found 5 seed folders: ['seed-846761_sample-0', 'seed-335727_sample-0', 'seed-622005_sample-0', 'seed-535882_sample-0', 'seed-260898_sample-0']
# 			 Found 5 CIF files: ['seed-846761_sample-0', 'seed-335727_sample-0', 'seed-622005_sample-0', 'seed-535882_sample-0', 'seed-260898_sample-0']
# 	 stupefied_banach               ->  -> mlig_sufu_1_4kmd.dlig_actincp_cpi_1_3aa1
# 			 Found 5 seed folders: ['seed-959563_sample-0', 'seed-464302_sample-0', 'seed-296167_sample-0', 'seed-898334_sample-0', 'seed-50250_sample-0']
# 			 Found 5 CIF files: ['seed-959563_sample-0', 'seed-464302_sample-0', 'seed-296167_sample-0', 'seed-898334_sample-0', 'seed-50250_sample-0']
# 	 cranky_avogadro                ->  -> mlig_sumo_sim_anti_2_2kqs.dlig_apcc_abba_1_4bh6
# 			 Found 5 seed folders: ['seed-333473_sample-0', 'seed-298194_sample-0', 'seed-378816_sample-0', 'seed-874979_sample-0', 'seed-245232_sample-0']
# 			 Found 5 CIF files: ['seed-333473_sample-0', 'seed-298194_sample-0', 'seed-378816_sample-0', 'seed-874979_sample-0', 'seed-245232_sample-0']
# 	 extravagant_kilby              ->  -> mlig_sumo_sim_par_1_2asq.dtrg_dileu_balyen_6_2jkr
# 			 Found 5 seed folders: ['seed-901008_sample-0', 'seed-304250_sample-0', 'seed-499524_sample-0', 'seed-432454_sample-0', 'seed-118378_sample-0']
# 			 Found 5 CIF files: ['seed-901008_sample-0', 'seed-304250_sample-0', 'seed-499524_sample-0', 'seed-432454_sample-0', 'seed-118378_sample-0']
# 	 nostalgic_lorenz               ->  -> mlig_tpr_1elr.ddoc_ank_tnks_1_3twu
# 			 Found 5 seed folders: ['seed-178895_sample-0', 'seed-458689_sample-0', 'seed-46736_sample-0', 'seed-698353_sample-0', 'seed-426387_sample-0']
# 			 Found 5 CIF files: ['seed-178895_sample-0', 'seed-458689_sample-0', 'seed-46736_sample-0', 'seed-698353_sample-0', 'seed-426387_sample-0']
# 	 evil_mayer                     ->  -> mlig_traf2_1_1ca9.dlig_bir_iii_3_1jd5
# 			 Found 5 seed folders: ['seed-456866_sample-0', 'seed-741929_sample-0', 'seed-622652_sample-0', 'seed-297675_sample-0', 'seed-734411_sample-0']
# 			 Found 5 CIF files: ['seed-456866_sample-0', 'seed-741929_sample-0', 'seed-622652_sample-0', 'seed-297675_sample-0', 'seed-734411_sample-0']
# 	 sharp_baekeland                ->  -> mlig_traf2_2_1czy.dlig_wd40_wdr5_win_1_3uvk
# 			 Found 5 seed folders: ['seed-493446_sample-0', 'seed-267369_sample-0', 'seed-184349_sample-0', 'seed-813990_sample-0', 'seed-20272_sample-0']
# 			 Found 5 CIF files: ['seed-493446_sample-0', 'seed-267369_sample-0', 'seed-184349_sample-0', 'seed-813990_sample-0', 'seed-20272_sample-0']
# 	 pensive_lamport                ->  -> mlig_trfh_1_3bqo.dlig_ufm1_ufim_1_5hkh
# 			 Found 5 seed folders: ['seed-56214_sample-0', 'seed-401516_sample-0', 'seed-484930_sample-0', 'seed-788133_sample-0', 'seed-544708_sample-0']
# 			 Found 5 CIF files: ['seed-56214_sample-0', 'seed-401516_sample-0', 'seed-484930_sample-0', 'seed-788133_sample-0', 'seed-544708_sample-0']
# 	 spontaneous_boltzmann          ->  -> mlig_ufm1_ufim_1_5hkh.dlig_klc1_yacidic_2_6fuz
# 			 Found 5 seed folders: ['seed-134144_sample-0', 'seed-849286_sample-0', 'seed-614516_sample-0', 'seed-898332_sample-0', 'seed-65282_sample-0']
# 			 Found 5 CIF files: ['seed-134144_sample-0', 'seed-849286_sample-0', 'seed-614516_sample-0', 'seed-898332_sample-0', 'seed-65282_sample-0']
# 	 gigantic_keller                ->  -> mlig_mynd_2_2odd.dmod_sumo_for_1_1kps
# 			 Found 5 seed folders: ['seed-386624_sample-0', 'seed-72053_sample-0', 'seed-60737_sample-0', 'seed-180158_sample-0', 'seed-384211_sample-0']
# 			 Found 5 CIF files: ['seed-386624_sample-0', 'seed-72053_sample-0', 'seed-60737_sample-0', 'seed-180158_sample-0', 'seed-384211_sample-0']
# 	 suspicious_mcclintock          ->  -> mlig_nbox_rrm_1_2kxh.dlig_pam2_1_1jgn
# 			 Found 5 seed folders: ['seed-263648_sample-0', 'seed-789487_sample-0', 'seed-669560_sample-0', 'seed-670267_sample-0', 'seed-205069_sample-0']
# 			 Found 5 CIF files: ['seed-263648_sample-0', 'seed-789487_sample-0', 'seed-669560_sample-0', 'seed-670267_sample-0', 'seed-205069_sample-0']
# 	 nauseous_khorana               ->  -> mlig_nrbox_1gwq.dlig_ap2alpha_2_1kyu
# 			 Found 5 seed folders: ['seed-544818_sample-0', 'seed-339632_sample-0', 'seed-457591_sample-0', 'seed-24277_sample-0', 'seed-90431_sample-0']
# 			 Found 5 CIF files: ['seed-544818_sample-0', 'seed-339632_sample-0', 'seed-457591_sample-0', 'seed-24277_sample-0', 'seed-90431_sample-0']
# 	 drunk_payne                    ->  -> mlig_nrp_cendr_1_2orz.dlig_klc1_yacidic_2_6fuz
# 			 Found 5 seed folders: ['seed-234963_sample-0', 'seed-280661_sample-0', 'seed-74611_sample-0', 'seed-753076_sample-0', 'seed-606317_sample-0']
# 			 Found 5 CIF files: ['seed-234963_sample-0', 'seed-280661_sample-0', 'seed-74611_sample-0', 'seed-753076_sample-0', 'seed-606317_sample-0']
# 	 happy_lumiere                  ->  -> mlig_pcna_apim_2_5mlw.ddeg_spop_sbc_1_3hqm
# 			 Found 5 seed folders: ['seed-872740_sample-0', 'seed-343658_sample-0', 'seed-505956_sample-0', 'seed-618999_sample-0', 'seed-247047_sample-0']
# 			 Found 5 CIF files: ['seed-872740_sample-0', 'seed-343658_sample-0', 'seed-505956_sample-0', 'seed-618999_sample-0', 'seed-247047_sample-0']
# 	 furious_aryabhata              ->  -> mlig_pcna_pipbox_1_1axc.dlig_ptb_apo_2_1ntv
# 			 Found 5 seed folders: ['seed-147958_sample-0', 'seed-159927_sample-0', 'seed-87128_sample-0', 'seed-749656_sample-0', 'seed-541849_sample-0']
# 			 Found 5 CIF files: ['seed-147958_sample-0', 'seed-159927_sample-0', 'seed-87128_sample-0', 'seed-749656_sample-0', 'seed-541849_sample-0']
# 	 dreamy_heyrovsky               ->  -> mlig_pcna_tls_4_2zvl.ddoc_ank_tnks_1_3twu
# 			 Found 5 seed folders: ['seed-635901_sample-0', 'seed-262928_sample-0', 'seed-279533_sample-0', 'seed-660760_sample-0', 'seed-941770_sample-0']
# 			 Found 5 CIF files: ['seed-635901_sample-0', 'seed-262928_sample-0', 'seed-279533_sample-0', 'seed-660760_sample-0', 'seed-941770_sample-0']
# 	 chaotic_cajal                  ->  -> mlig_pcna_ypipbox_3_1sxj.dlig_cornrbox_1kkq
# 			 Found 5 seed folders: ['seed-519662_sample-0', 'seed-624027_sample-0', 'seed-974388_sample-0', 'seed-127274_sample-0', 'seed-359962_sample-0']
# 			 Found 5 CIF files: ['seed-519662_sample-0', 'seed-624027_sample-0', 'seed-974388_sample-0', 'seed-127274_sample-0', 'seed-359962_sample-0']
# 	 sleepy_waddington              ->  -> mlig_pdz_class_1_1d5g.dlig_pam2_1_1jgn
# 			 Found 5 seed folders: ['seed-999575_sample-0', 'seed-29488_sample-0', 'seed-553568_sample-0', 'seed-935601_sample-0', 'seed-799722_sample-0']
# 			 Found 5 CIF files: ['seed-999575_sample-0', 'seed-29488_sample-0', 'seed-553568_sample-0', 'seed-935601_sample-0', 'seed-799722_sample-0']
# 	 stupefied_hypatia              ->  -> mlig_lypxl_siv_4_2xs1.dlig_apcc_abba_1_4bh6
# 			 Found 5 seed folders: ['seed-890182_sample-0', 'seed-289038_sample-0', 'seed-826932_sample-0', 'seed-568003_sample-0', 'seed-660270_sample-0']
# 			 Found 5 CIF files: ['seed-890182_sample-0', 'seed-289038_sample-0', 'seed-826932_sample-0', 'seed-568003_sample-0', 'seed-660270_sample-0']
# 	 stupefied_hugle                ->  -> mlig_lypxl_s_1_2r03.dlig_fxi_dfp_1_5eod
# 			 Found 5 seed folders: ['seed-227702_sample-0', 'seed-294372_sample-0', 'seed-967418_sample-0', 'seed-932615_sample-0', 'seed-406880_sample-0']
# 			 Found 5 CIF files: ['seed-227702_sample-0', 'seed-294372_sample-0', 'seed-967418_sample-0', 'seed-932615_sample-0', 'seed-406880_sample-0']
# 	 happy_bhabha                   ->  -> mlig_mad2_1go4.dlig_lypxl_l_2_2r02
# 			 Found 5 seed folders: ['seed-705172_sample-0', 'seed-886273_sample-0', 'seed-242631_sample-0', 'seed-674527_sample-0', 'seed-185259_sample-0']
# 			 Found 5 CIF files: ['seed-705172_sample-0', 'seed-886273_sample-0', 'seed-242631_sample-0', 'seed-674527_sample-0', 'seed-185259_sample-0']
# 	 irreverent_perlman             ->  -> mlig_mlh1_mipbox_1_4fmo.ddeg_spop_sbc_1_3hqm
# 			 Found 5 seed folders: ['seed-790828_sample-0', 'seed-338323_sample-0', 'seed-454605_sample-0', 'seed-834980_sample-0', 'seed-819833_sample-0']
# 			 Found 5 CIF files: ['seed-790828_sample-0', 'seed-338323_sample-0', 'seed-454605_sample-0', 'seed-834980_sample-0', 'seed-819833_sample-0']
# 	 insane_brattain                ->  -> mlig_cap-gly_2_3rdv.dlig_pdz_class_3_1b8q
# 			 Found 5 seed folders: ['seed-194652_sample-0', 'seed-969485_sample-0', 'seed-363220_sample-0', 'seed-123668_sample-0', 'seed-209472_sample-0']
# 			 Found 5 CIF files: ['seed-194652_sample-0', 'seed-969485_sample-0', 'seed-363220_sample-0', 'seed-123668_sample-0', 'seed-209472_sample-0']
# 	 jovial_waddington              ->  -> mlig_cid_nim_1_2mow.dlig_evh1_2_1ddv
# 			 Found 5 seed folders: ['seed-196902_sample-0', 'seed-769149_sample-0', 'seed-197153_sample-0', 'seed-765597_sample-0', 'seed-104176_sample-0']
# 			 Found 5 CIF files: ['seed-196902_sample-0', 'seed-769149_sample-0', 'seed-197153_sample-0', 'seed-765597_sample-0', 'seed-104176_sample-0']
# 	 drunk_gates                    ->  -> mlig_clathr_clatbox_2_1utc.dlig_lir_gen_1_2l8j
# 			 Found 5 seed folders: ['seed-362134_sample-0', 'seed-553990_sample-0', 'seed-345236_sample-0', 'seed-823778_sample-0', 'seed-312756_sample-0']
# 			 Found 5 CIF files: ['seed-362134_sample-0', 'seed-553990_sample-0', 'seed-345236_sample-0', 'seed-823778_sample-0', 'seed-312756_sample-0']
# 	 distracted_brenner             ->  -> mtrg_dileu_baen_1_4nee.dlig_14-3-3_chrebp_3_5f74
# 			 Found 5 seed folders: ['seed-549562_sample-0', 'seed-875738_sample-0', 'seed-713947_sample-0', 'seed-423825_sample-0', 'seed-348677_sample-0']
# 			 Found 5 CIF files: ['seed-549562_sample-0', 'seed-875738_sample-0', 'seed-713947_sample-0', 'seed-423825_sample-0', 'seed-348677_sample-0']
# 	 fabulous_ampere                ->  -> mtrg_dileu_balyen_6_2jkr.dlig_pdz_wminus1_1_1zub
# 			 Found 5 seed folders: ['seed-62954_sample-0', 'seed-12512_sample-0', 'seed-263436_sample-0', 'seed-465350_sample-0', 'seed-978416_sample-0']
# 			 Found 5 CIF files: ['seed-62954_sample-0', 'seed-12512_sample-0', 'seed-263436_sample-0', 'seed-465350_sample-0', 'seed-978416_sample-0']
# 	 romantic_archimedes            ->  -> mtrg_endocytic_2_1bxx.dtrg_er_ffat_1_2rr3
# 			 Found 5 seed folders: ['seed-904997_sample-0', 'seed-451529_sample-0', 'seed-960608_sample-0', 'seed-255679_sample-0', 'seed-145197_sample-0']
# 			 Found 5 CIF files: ['seed-904997_sample-0', 'seed-451529_sample-0', 'seed-960608_sample-0', 'seed-255679_sample-0', 'seed-145197_sample-0']
# 	 lonely_torricelli              ->  -> mtrg_lysend_ggaacll_1_1jwg.dlig_sumo_sim_anti_2_2kqs
# 			 Found 5 seed folders: ['seed-272974_sample-0', 'seed-149722_sample-0', 'seed-267013_sample-0', 'seed-484371_sample-0', 'seed-405732_sample-0']
# 			 Found 5 CIF files: ['seed-272974_sample-0', 'seed-149722_sample-0', 'seed-267013_sample-0', 'seed-484371_sample-0', 'seed-405732_sample-0']
# 	 sad_poisson                    ->  -> mtrg_nls_bipartite_1_1pjm.dlig_pdz_class_1_1d5g
# 			 Found 5 seed folders: ['seed-235626_sample-0', 'seed-763204_sample-0', 'seed-36838_sample-0', 'seed-377304_sample-0', 'seed-661100_sample-0']
# 			 Found 5 CIF files: ['seed-235626_sample-0', 'seed-763204_sample-0', 'seed-36838_sample-0', 'seed-377304_sample-0', 'seed-661100_sample-0']
# 	 distracted_kimura              ->  -> mdeg_apcc_kenbox_2_4ggd.dtrg_ap2beta_cargo_1_2g30
# 			 Found 5 seed folders: ['seed-412972_sample-0', 'seed-953583_sample-0', 'seed-891120_sample-0', 'seed-498599_sample-0', 'seed-796882_sample-0']
# 			 Found 5 CIF files: ['seed-412972_sample-0', 'seed-953583_sample-0', 'seed-891120_sample-0', 'seed-498599_sample-0', 'seed-796882_sample-0']
# 	 reverent_hopper                ->  -> mdeg_cop1_1_5igo.ddoc_usp7_math_1_3mqs
# 			 Found 5 seed folders: ['seed-503777_sample-0', 'seed-226736_sample-0', 'seed-2102_sample-0', 'seed-433647_sample-0', 'seed-517130_sample-0']
# 			 Found 5 CIF files: ['seed-503777_sample-0', 'seed-226736_sample-0', 'seed-2102_sample-0', 'seed-433647_sample-0', 'seed-517130_sample-0']
# 	 elegant_mirzakhani             ->  -> mdeg_kelch_keap1_1_2flu.dlig_dlg_gklike_1_3wp0
# 			 Found 5 seed folders: ['seed-13897_sample-0', 'seed-656510_sample-0', 'seed-579553_sample-0', 'seed-698196_sample-0', 'seed-155428_sample-0']
# 			 Found 5 CIF files: ['seed-13897_sample-0', 'seed-656510_sample-0', 'seed-579553_sample-0', 'seed-698196_sample-0', 'seed-155428_sample-0']
# 	 boring_colden                  ->  -> mdeg_kelch_keap1_2_3wn7.ddoc_usp7_math_2_1yy6
# 			 Found 5 seed folders: ['seed-187002_sample-0', 'seed-522890_sample-0', 'seed-842405_sample-0', 'seed-755578_sample-0', 'seed-306308_sample-0']
# 			 Found 5 CIF files: ['seed-187002_sample-0', 'seed-522890_sample-0', 'seed-842405_sample-0', 'seed-755578_sample-0', 'seed-306308_sample-0']
# 	 tender_monod                   ->  -> mdeg_mdm2_swib_1_1ycr.dlig_pcna_apim_2_5mlw
# 			 Found 5 seed folders: ['seed-92574_sample-0', 'seed-501210_sample-0', 'seed-495470_sample-0', 'seed-987543_sample-0', 'seed-143258_sample-0']
# 			 Found 5 CIF files: ['seed-92574_sample-0', 'seed-501210_sample-0', 'seed-495470_sample-0', 'seed-987543_sample-0', 'seed-143258_sample-0']
#
# DEBUG: dataAF contains 680 rows before merge
# DEBUG: Unique prediction names in dataAF: ['mdeg_apcc_kenbox_2_4ggd.dtrg_ap2beta_cargo_1_2g30', 'mdeg_cop1_1_5igo.ddoc_usp7_math_1_3mqs', 'mdeg_kelch_keap1_1_2flu.dlig_dlg_gklike_1_3wp0', 'mdeg_kelch_keap1_2_3wn7.ddoc_usp7_math_2_1yy6', 'mdeg_mdm2_swib_1_1ycr.dlig_pcna_apim_2_5mlw', 'mdeg_scf_coi1_1_3ogl.dlig_cam_iq_9_2ix7', 'mdeg_scf_fbxo31_1_5vzu.dlig_traf2_2_1czy', 'mdeg_scf_tir1_1_2p1q.dlig_ulm_u2af65_1_1o0p', 'mdeg_siah_1_2a25.dlig_cap-gly_2_3rdv', 'mdeg_spop_sbc_1_3hqm.ddoc_mit_mim_1_2jq9', 'mdoc_agck_pif_3_1atp.ddeg_kelch_keap1_1_2flu', 'mdoc_ank_tnks_1_3twu.dlig_cap-gly_1_2pzo', 'mdoc_cdc14_pxl_1_6g84.ddoc_pp1_silk_1_2o8g', 'mdoc_cyclin_rxl_1_1h25.dlig_spry_1_2jk9', 'mdoc_gsk3_axin_1_1o9u.ddeg_spop_sbc_1_3hqm', 'mdoc_mapk_dcc_7_2b9j.dlig_ank_pxlpxl_1_3uxg', 'mdoc_mapk_gra24_9_5eta.dlig_pcna_apim_2_5mlw', 'mdoc_mapk_heptp_8_2gph.dlig_pcna_ypipbox_3_1sxj', 'mdoc_mapk_jip1_4_4h3b.dlig_pam2_1_1jgn', 'mdoc_mapk_mef2a_6_4h3q.dlig_wd40_wdr5_win_2_4cy3', 'mdoc_mapk_nfat4_5_2xs0.dlig_pdz_class_3_1b8q', 'mdoc_mapk_revd_3_3tei.dlig_ef_alg2_abm_1_2zne', 'mdoc_mit_mim_1_2jq9.dlig_homeobox_1b72', 'mdoc_pp1_myphone_1_1s70.dlig_pdz_class_3_1b8q', 'mdoc_pp1_rvxf_1_3n5u.dlig_14-3-3_chrebp_3_5f74', 'mdoc_pp1_silk_1_2o8g.dlig_ww_1_1eg4', 'mdoc_pp2b_pxixi_1_4f0z.ddeg_kelch_keap1_1_2flu', 'mdoc_spak_osr1_1_2v3s.dlig_nbox_rrm_1_2kxh', 'mdoc_usp7_math_1_3mqs.dlig_ufm1_ufim_1_5hkh', 'mdoc_usp7_math_2_1yy6.dtrg_nls_bipartite_1_1pjm', 'mdoc_usp7_ubl2_3_4yoc.dtrg_er_ffat_1_2rr3', 'mlig_14-3-3_chrebp_3_5f74.ddoc_mapk_jip1_4_4h3b', 'mlig_actin_rpel_3_2v52.dlig_actincp_twfcpi_2_7ds2', 'mlig_actin_wh2_1_2a41.dlig_gbd_chelix_1_2k42', 'mlig_actin_wh2_2_2d1k.dlig_palb2_wd40_1_3eu7', 'mlig_actincp_cpi_1_3aa1.dlig_cid_nim_1_2mow', 'mlig_ank_pxlpxl_1_3uxg.ddoc_mapk_heptp_8_2gph', 'mlig_ap2alpha_1_1ky7.dlig_pam2_1_1jgn', 'mlig_ap2alpha_2_1kyu.dlig_traf2_2_1czy', 'mlig_apcc_abba_1_4bh6.dlig_lir_apic_2_4eoy', 'mlig_arl_bart_1_4zi2.dlig_lypxl_siv_4_2xs1', 'mlig_bh_bh3_1_2roc.dlig_actin_wh2_2_2d1k', 'mlig_bir_iii_2_1nw9.ddeg_siah_1_2a25', 'mlig_bir_iii_3_1jd5.dlig_lrp6_inhibitor_1_3soq', 'mlig_cam_iq_9_2ix7.dlig_cornrbox_1kkq', 'mlig_cap-gly_1_2pzo.dlig_rb_lxcxe_1_1gh6', 'mlig_cap-gly_2_3rdv.dlig_pdz_class_3_1b8q', 'mlig_cid_nim_1_2mow.dlig_evh1_2_1ddv', 'mlig_clathr_clatbox_1_1c9i.dlig_sufu_1_4kmd', 'mlig_clathr_clatbox_2_1utc.dlig_lir_gen_1_2l8j', 'mlig_cnot1_nim_1_4cqo.dlig_rb_lxcxe_1_1gh6', 'mlig_cornrbox_1kkq.ddoc_spak_osr1_1_2v3s', 'mlig_csl_btd_1_4j2x.dtrg_nes_crm1_1_3gb8', 'mlig_deltacop1_ditrp_1_5fjx.dlig_cap-gly_1_2pzo', 'mlig_dlg_gklike_1_3wp0.dtrg_er_ffat_1_2rr3', 'mlig_dynein_dlc8_1_1f95.ddoc_usp7_ubl2_3_4yoc', 'mlig_ef_alg2_abm_1_2zne.dlig_cid_nim_1_2mow', 'mlig_eh1_1_2ce8.dlig_sh3_cin85_pxpxpr_1_2bz8', 'mlig_eh_1_1ff1.ddoc_mapk_gra24_9_5eta', 'mlig_evh1_1_1evh.dlig_actin_wh2_1_2a41', 'mlig_evh1_2_1ddv.dlig_lir_apic_2_4eoy', 'mlig_evh1_3_1mke.dlig_lsd1_snag_1_2y48', 'mlig_fat_ld_1_3gm1.dlig_lir_nem_3_5azg', 'mlig_fxi_dfp_1_5eod.dlig_bir_iii_3_1jd5', 'mlig_gbd_chelix_1_2k42.dlig_fat_ld_1_3gm1', 'mlig_glebs_bub3_1_2i3s.dlig_fxi_dfp_1_5eod', 'mlig_gyf_1l2z.dlig_sufu_1_4kmd', 'mlig_homeobox_1b72.dlig_vh1_vbs_1_1syq', 'mlig_ibar_npy_1_2ykt.dlig_ufm1_ufim_1_5hkh', 'mlig_klc1_wd_1_3zfw.dlig_glebs_bub3_1_2i3s', 'mlig_klc1_yacidic_2_6fuz.ddoc_gsk3_axin_1_1o9u', 'mlig_lir_apic_2_4eoy.dlig_sin3_1_1pd7', 'mlig_lir_gen_1_2l8j.ddoc_pp1_myphone_1_1s70', 'mlig_lir_lc3c_4_3vvw.ddoc_mit_mim_1_2jq9', 'mlig_lir_nem_3_5azg.dlig_ulm_u2af65_1_1o0p', 'mlig_lrp6_inhibitor_1_3soq.dtrg_nes_crm1_1_3gb8', 'mlig_lsd1_snag_1_2y48.dlig_ef_alg2_abm_1_2zne', 'mlig_lypxl_l_2_2r02.dlig_ptap_uev_1_1m4p', 'mlig_lypxl_s_1_2r03.dlig_fxi_dfp_1_5eod', 'mlig_lypxl_siv_4_2xs1.dlig_apcc_abba_1_4bh6', 'mlig_mad2_1go4.dlig_lypxl_l_2_2r02', 'mlig_mlh1_mipbox_1_4fmo.ddeg_spop_sbc_1_3hqm', 'mlig_mynd_2_2odd.dmod_sumo_for_1_1kps', 'mlig_nbox_rrm_1_2kxh.dlig_pam2_1_1jgn', 'mlig_nrbox_1gwq.dlig_ap2alpha_2_1kyu', 'mlig_nrp_cendr_1_2orz.dlig_klc1_yacidic_2_6fuz', 'mlig_ocrl_fandh_1_3qis.ddoc_mapk_gra2 ...
# DEBUG: Unique benchmark sets in dataAF: ['random_minimal']
# DEBUG: CIF files found: 680 out of 680 entries
# DEBUG: Sample CIF paths: [PosixPath('AlphaFold_benchmark_DMI/random_minimal/cheesy_mccarthy/predictions/alphafold3/mdeg_scf_coi1_1_3ogl.dlig_cam_iq_9_2ix7/seed-359724_sample-0/model.cif'), PosixPath('AlphaFold_benchmark_DMI/random_minimal/cheesy_mccarthy/predictions/alphafold3/mdeg_scf_coi1_1_3ogl.dlig_cam_iq_9_2ix7/seed-916549_sample-0/model.cif'), PosixPath('AlphaFold_benchmark_DMI/random_minimal/cheesy_mccarthy/predictions/alphafold3/mdeg_scf_coi1_1_3ogl.dlig_cam_iq_9_2ix7/seed-121809_sample-0/model.cif')]

# %%
# Find missing structures and correct lower case names

report_df_ = report_df[~report_df["prediction_name"].isna()].copy() # Create copy to allow merging by lowercase prediction_name
report_df_["prediction_name_lower"] = report_df["prediction_name"].str.lower()

# Correcting lower case names
dataAF = pd.merge(
    left = dataAF,
    right = report_df_,
    how="outer", # Using outer to check for missing runs using report_df and filter in a later step
    left_on = ["benchmark_set", "prediction_name"],
    right_on = ["benchmark_set", "prediction_name_lower"],
    suffixes = ["", "_input"]
)

# Detecting missing outputs (= structures with input json but without a output nextflow folder)
missing_outputs = dataAF[np.logical_and(~dataAF["input_json"].isna(), dataAF["prediction_name"].isna())]
missing_outputs = missing_outputs[["benchmark_set", "prediction_name_input", "report_file", "run_ok", "input_json"]]
# Detect unidentified outputs (= output folders, which do not have a input.json)
unidentified_outputs = dataAF[dataAF["prediction_name_input"].isna()]
unidentified_outputs = dataAF[["benchmark_set", "prediction_name", "model_id"]]

# Filter to only include AF outputs and not input files
dataAF = dataAF[~dataAF["prediction_name"].isna()]
# Replacing AF prediction_name with the proper upper case variant
dataAF["prediction_name"] = dataAF["prediction_name_input"] 
# Drop the unnecessary columns added
dataAF.drop(columns=["prediction_name_input", "prediction_name_lower", "report_file", "run_ok", "input_json"], inplace=True) 
dataAF = dataAF.copy()

# %%
# Display the dataAF output and informations about potential errors
print(f"Currently {len(set(dataAF['prediction_name']))} valid AF output folders have been generated")
display(dataAF)
print("Processed files with errors or missing output")
display(missing_outputs)
print("Missformed outputs")
display(missformed_outputs)
print("Empty output folders")
display(empty_outputs)
# Out:
# Currently 136 valid AF output folders have been generated
#     model_preset   benchmark_set  \
# 0     alphafold3  random_minimal
# 1     alphafold3  random_minimal
# 2     alphafold3  random_minimal
# 3     alphafold3  random_minimal
# 4     alphafold3  random_minimal
# ..           ...             ...
# 675   alphafold3  random_minimal
# 676   alphafold3  random_minimal
# 677   alphafold3  random_minimal
# 678   alphafold3  random_minimal
# 679   alphafold3  random_minimal
#
#                                        prediction_name  model_id  \
# 0    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_0
# 1    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_1
# 2    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_2
# 3    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_3
# 4    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_4
# ..                                                 ...       ...
# 675           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_0
# 676           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_1
# 677           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_2
# 678           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_3
# 679           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_4
#
#      ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 0             0.65              5            237                 0.02
# 1             0.65              5            237                 0.02
# 2             0.65              5            237                 0.02
# 3             0.64              5            237                 0.02
# 4             0.62              5            237                 0.02
# ..             ...            ...            ...                  ...
# 675           0.93              4            312                 0.02
# 676           0.92              4            312                 0.01
# 677           0.92              4            312                 0.02
# 678           0.91              4            312                 0.01
# 679           0.84              4            312                 0.01
#
#      has_clash  iptm  ...  chainA_intf_avg_plddt  chainB_intf_avg_plddt  \
# 0          0.0  0.57  ...                  49.49                  83.95
# 1          0.0  0.56  ...                  48.41                  84.70
# 2          0.0  0.56  ...                  49.80                  85.32
# 3          0.0  0.56  ...                  50.50                  84.09
# 4          0.0  0.53  ...                  48.32                  83.69
# ..         ...   ...  ...                    ...                    ...
# 675        0.0  0.91  ...                  84.04                  96.90
# 676        0.0  0.90  ...                  83.70                  97.70
# 677        0.0  0.90  ...                  83.24                  96.88
# 678        0.0  0.90  ...                  83.07                  97.64
# 679        0.0  0.81  ...                  73.17                  96.18
#
#      intf_avg_plddt  num_chainA_intf_res  num_chainB_intf_res  \
# 0             74.38                    5                   13
# 1             74.62                    5                   13
# 2             75.97                    5                   14
# 3             75.69                    5                   15
# 4             73.87                    5                   13
# ..              ...                  ...                  ...
# 675           94.45                    4                   17
# 676           95.04                    4                   17
# 677           94.40                    4                   18
# 678           94.86                    4                   17
# 679           92.18                    4                   19
#
#      num_res_res_contact  num_atom_atom_contact   iPAE  pDockQ  \
# 0                     20                    178  10.60    0.07
# 1                     21                    224  11.00    0.09
# 2                     21                    196  10.80    0.08
# 3                     22                    199  11.80    0.08
# 4                     21                    206  11.90    0.08
# ..                   ...                    ...    ...     ...
# 675                   26                    239   3.50    0.31
# 676                   26                    233   3.60    0.31
# 677                   28                    246   3.65    0.30
# 678                   26                    232   3.60    0.30
# 679                   26                    204   4.90    0.17
#
#                                             model_path
# 0    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 1    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 2    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 3    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 4    AlphaFold_benchmark_DMI/random_minimal/distrac...
# ..                                                 ...
# 675  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 676  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 677  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 678  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 679  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
#
# [680 rows x 21 columns]
# Processed files with errors or missing output
# Empty DataFrame
# Columns: [benchmark_set, prediction_name_input, report_file, run_ok, input_json]
# Index: []
# Missformed outputs
# Empty DataFrame
# Columns: [benchmark_set, prediction_name, model_seed, reason]
# Index: []
# Empty output folders
# Empty DataFrame
# Columns: [benchmark_set, nextflow_name]
# Index: []

# %% [markdown]
# ### 3 Output adjustments
# The following sections corrent some errors and problems with the data

# %% [markdown]
# ### 3a Undo chain naming by length
# For the AF3 run, the chains have been given an ID by their length (chain A is shortest, chain B is longest). This is fine for DMI, but fails for DDI. Proper chain ID as in the solved structures is important for template depended metrics. The following cells reads the fasta files of the AF2 runs to switch chain A and chain B if necessary.

# %%
# Undos chain moving if necessary
# This function is based on a function of Joelle Strom in make_json_files.py (Last updated: 24.01.2025) to detect runs where the chain IDs have been switched
from pathlib import Path

def have_chains_been_switched(prediction_name: str, benchmark_set: str):
    """
        Modified function from make_json_files.py to detect switched chains

    """
    path_af2 = af2_folders[benchmark_set] / (af2_folders[benchmark_set].name + "_" + prediction_name + ".fasta")
    #path_af3 = af3_runs_folder/ benchmark_set / (prediction_name.upper() + ".json")


        # Automatically find the correct subdirectory under af3_runs_folder
    for subdir in af3_runs_folder.iterdir():
        candidate = subdir / benchmark_set / (prediction_name.upper() + ".json")
        if candidate.exists():
            path_af3 = candidate
            break
    else:
        raise FileNotFoundError(f"No JSON found for {prediction_name.upper()} in any subdir of {af3_runs_folder}")


    with open(path_af3, "r") as f:
        af3_input = json.load(f)
        af3_input_len1 = len(af3_input["sequences"][0]["protein"]["sequence"])
        af3_input_len2 = len(af3_input["sequences"][1]["protein"]["sequence"])
    if not path_af2.exists():
        print(f"Can't find {path_af2.name} in {path_af2.parent.parent.name}/{path_af2.parent.name}", end="")
        return None
    chains = {}
    with open(path_af2, "r") as f:
        fasta_contents = f.readlines()
    i = 0
    for line in fasta_contents:
        if re.search(">",line):
            new_chain = True
            i+=1
        else:
            new_chain = False
        if new_chain:
            id = str(i)
            sequence = []
        else:
            sequence.append(line.strip("\n"))
            sequence_str = "".join(sequence)
            chains[i] = sequence_str
    if not len(chains) == 2:
        print(f"{prediction_name} has an invalid chain length of {len(chains)}", end="")
        return None
    if (l1 := len(list(chains.values())[0])) == af3_input_len1:
        return False
    elif (l2 := len(list(chains.values())[1])) == af3_input_len2:
        return False
    elif l1 == l2:
        print("(same length) ", end="")
    else:
        return True

# Generate column in data frame if chains have been switched
dataAF["chains_flipped"] = None
for i, row in dataAF.iterrows():
    prediction_name, benchmark_set = row["prediction_name"], row["benchmark_set"]
    print(f"{f'{prediction_name} ({benchmark_set}) -> ':<80}", end="")
    chains_switched = have_chains_been_switched(prediction_name, benchmark_set)
    dataAF.at[i, "chains_flipped"] = chains_switched
    print(chains_switched)
# Out:
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30 (random_minimal) ->           True
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30 (random_minimal) ->           True
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30 (random_minimal) ->           True
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30 (random_minimal) ->           True
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30 (random_minimal) ->           True
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS (random_minimal) ->                      True
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS (random_minimal) ->                      True
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS (random_minimal) ->                      True
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS (random_minimal) ->                      True
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS (random_minimal) ->                      True
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->              True
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->              True
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->              True
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->              True
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->              True
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6 (random_minimal) ->               True
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6 (random_minimal) ->               True
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6 (random_minimal) ->               True
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6 (random_minimal) ->               True
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6 (random_minimal) ->               True
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                 True
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                 True
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                 True
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                 True
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                 True
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7 (random_minimal) ->                     True
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7 (random_minimal) ->                     True
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7 (random_minimal) ->                     True
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7 (random_minimal) ->                     True
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7 (random_minimal) ->                     True
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY (random_minimal) ->                    True
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY (random_minimal) ->                    True
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY (random_minimal) ->                    True
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY (random_minimal) ->                    True
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY (random_minimal) ->                    True
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                 True
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                 True
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                 True
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                 True
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                 True
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV (random_minimal) ->                        True
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV (random_minimal) ->                        True
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV (random_minimal) ->                        True
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV (random_minimal) ->                        True
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV (random_minimal) ->                        True
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->                True
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->                True
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->                True
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->                True
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->                True
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO (random_minimal) ->                    True
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO (random_minimal) ->                    True
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO (random_minimal) ->                    True
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO (random_minimal) ->                    True
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO (random_minimal) ->                    True
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G (random_minimal) ->                  True
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G (random_minimal) ->                  True
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G (random_minimal) ->                  True
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G (random_minimal) ->                  True
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G (random_minimal) ->                  True
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9 (random_minimal) ->                     True
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9 (random_minimal) ->                     True
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9 (random_minimal) ->                     True
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9 (random_minimal) ->                     True
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9 (random_minimal) ->                     True
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG (random_minimal) ->                 True
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG (random_minimal) ->                 True
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG (random_minimal) ->                 True
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG (random_minimal) ->                 True
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG (random_minimal) ->                 True
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                True
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                True
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                True
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                True
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW (random_minimal) ->                True
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ (random_minimal) ->             True
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ (random_minimal) ->             True
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ (random_minimal) ->             True
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ (random_minimal) ->             True
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ (random_minimal) ->             True
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->            True
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->            True
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->            True
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->            True
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->            True
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                True
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                True
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                True
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                True
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                True
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72 (random_minimal) ->                      True
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72 (random_minimal) ->                      True
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72 (random_minimal) ->                      True
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72 (random_minimal) ->                      True
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72 (random_minimal) ->                      True
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->               True
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->               True
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->               True
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->               True
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->               True
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->              True
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->              True
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->              True
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->              True
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->              True
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4 (random_minimal) ->                         True
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4 (random_minimal) ->                         True
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4 (random_minimal) ->                         True
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4 (random_minimal) ->                         True
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4 (random_minimal) ->                         True
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->              True
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->              True
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->              True
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->              True
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU (random_minimal) ->              True
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                  True
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                  True
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                  True
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                  True
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                  True
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                 True
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                 True
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                 True
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                 True
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                 True
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->             True
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->             True
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->             True
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->             True
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->             True
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->             True
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->             True
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->             True
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->             True
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->             True
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->           True
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->           True
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->           True
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->           True
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->           True
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42 (random_minimal) ->                True
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42 (random_minimal) ->                True
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42 (random_minimal) ->                True
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42 (random_minimal) ->                True
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42 (random_minimal) ->                True
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7 (random_minimal) ->                True
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7 (random_minimal) ->                True
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7 (random_minimal) ->                True
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7 (random_minimal) ->                True
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7 (random_minimal) ->                True
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->               True
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->               True
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->               True
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->               True
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->               True
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY (random_minimal) ->                      True
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY (random_minimal) ->                      True
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY (random_minimal) ->                      True
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY (random_minimal) ->                      True
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY (random_minimal) ->                      True
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                  True
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                  True
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                  True
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                  True
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                  True
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1 (random_minimal) ->                  True
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1 (random_minimal) ->                  True
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1 (random_minimal) ->                  True
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1 (random_minimal) ->                  True
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1 (random_minimal) ->                  True
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K (random_minimal) ->                    True
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K (random_minimal) ->                    True
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K (random_minimal) ->                    True
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K (random_minimal) ->                    True
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K (random_minimal) ->                    True
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25 (random_minimal) ->                        True
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25 (random_minimal) ->                        True
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25 (random_minimal) ->                        True
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25 (random_minimal) ->                        True
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25 (random_minimal) ->                        True
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ (random_minimal) ->              True
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ (random_minimal) ->              True
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ (random_minimal) ->              True
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ (random_minimal) ->              True
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ (random_minimal) ->              True
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ (random_minimal) ->                       True
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ (random_minimal) ->                       True
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ (random_minimal) ->                       True
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ (random_minimal) ->                       True
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ (random_minimal) ->                       True
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                    True
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                    True
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                    True
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                    True
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                    True
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                   True
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                   True
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                   True
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                   True
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q (random_minimal) ->                   True
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV (random_minimal) ->                        True
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV (random_minimal) ->                        True
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV (random_minimal) ->                        True
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV (random_minimal) ->                        True
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV (random_minimal) ->                        True
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD (random_minimal) ->                 True
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD (random_minimal) ->                 True
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD (random_minimal) ->                 True
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD (random_minimal) ->                 True
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD (random_minimal) ->                 True
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J (random_minimal) ->              True
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J (random_minimal) ->              True
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J (random_minimal) ->              True
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J (random_minimal) ->              True
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J (random_minimal) ->              True
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                  True
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                  True
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                  True
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                  True
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6 (random_minimal) ->                  True
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S (random_minimal) ->                    True
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S (random_minimal) ->                    True
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S (random_minimal) ->                    True
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S (random_minimal) ->                    True
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S (random_minimal) ->                    True
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->                    True
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->                    True
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->                    True
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->                    True
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->                    True
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO (random_minimal) ->             True
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO (random_minimal) ->             True
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO (random_minimal) ->             True
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO (random_minimal) ->             True
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO (random_minimal) ->             True
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                  True
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                  True
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                  True
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                  True
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                  True
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC (random_minimal) ->               True
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC (random_minimal) ->               True
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC (random_minimal) ->               True
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC (random_minimal) ->               True
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC (random_minimal) ->               True
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW (random_minimal) ->                 True
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8 (random_minimal) ->                True
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8 (random_minimal) ->                True
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8 (random_minimal) ->                True
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8 (random_minimal) ->                True
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8 (random_minimal) ->                True
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->                       True
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->                       True
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->                       True
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->                       True
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->                       True
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41 (random_minimal) ->                      True
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41 (random_minimal) ->                      True
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41 (random_minimal) ->                      True
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41 (random_minimal) ->                      True
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41 (random_minimal) ->                      True
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                       True
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                       True
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                       True
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                       True
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                       True
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                      True
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                      True
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                      True
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                      True
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                      True
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG (random_minimal) ->                      True
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG (random_minimal) ->                      True
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG (random_minimal) ->                      True
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG (random_minimal) ->                      True
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG (random_minimal) ->                      True
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5 (random_minimal) ->                     True
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5 (random_minimal) ->                     True
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5 (random_minimal) ->                     True
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5 (random_minimal) ->                     True
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5 (random_minimal) ->                     True
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1 (random_minimal) ->                   True
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1 (random_minimal) ->                   True
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1 (random_minimal) ->                   True
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1 (random_minimal) ->                   True
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1 (random_minimal) ->                   True
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                  True
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                  True
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                  True
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                  True
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                  True
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD (random_minimal) ->                              True
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD (random_minimal) ->                              True
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD (random_minimal) ->                              True
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD (random_minimal) ->                              True
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD (random_minimal) ->                              True
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ (random_minimal) ->                      True
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ (random_minimal) ->                      True
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ (random_minimal) ->                      True
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ (random_minimal) ->                      True
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ (random_minimal) ->                      True
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                  True
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                  True
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                  True
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                  True
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                  True
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S (random_minimal) ->                  True
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S (random_minimal) ->                  True
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S (random_minimal) ->                  True
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S (random_minimal) ->                  True
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S (random_minimal) ->                  True
# MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U (random_minimal) ->              True
# MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U (random_minimal) ->              True
# MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U (random_minimal) ->              True
# MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U (random_minimal) ->              True
# MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U (random_minimal) ->              True
# MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7 (random_minimal) ->                       True
# MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7 (random_minimal) ->                       True
# MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7 (random_minimal) ->                       True
# MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7 (random_minimal) ->                       True
# MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7 (random_minimal) ->                       True
# MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                 True
# MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                 True
# MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                 True
# MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                 True
# MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                 True
# MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9 (random_minimal) ->                    True
# MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                  True
# MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                  True
# MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                  True
# MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                  True
# MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P (random_minimal) ->                  True
# MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->             True
# MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->             True
# MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->             True
# MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->             True
# MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8 (random_minimal) ->             True
# MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE (random_minimal) ->               True
# MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P (random_minimal) ->                    True
# MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P (random_minimal) ->                    True
# MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P (random_minimal) ->                    True
# MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P (random_minimal) ->                    True
# MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P (random_minimal) ->                    True
# MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                     True
# MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                     True
# MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                     True
# MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                     True
# MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD (random_minimal) ->                     True
# MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->                 True
# MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->                 True
# MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->                 True
# MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->                 True
# MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->                 True
# MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02 (random_minimal) ->                          True
# MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02 (random_minimal) ->                          True
# MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02 (random_minimal) ->                          True
# MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02 (random_minimal) ->                          True
# MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02 (random_minimal) ->                          True
# MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                True
# MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                True
# MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                True
# MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                True
# MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                True
# MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS (random_minimal) ->                       True
# MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS (random_minimal) ->                       True
# MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS (random_minimal) ->                       True
# MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS (random_minimal) ->                       True
# MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS (random_minimal) ->                       True
# MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN (random_minimal) ->                       True
# MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU (random_minimal) ->                        True
# MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU (random_minimal) ->                        True
# MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU (random_minimal) ->                        True
# MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU (random_minimal) ->                        True
# MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU (random_minimal) ->                        True
# MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->               True
# MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->               True
# MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->               True
# MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->               True
# MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA (random_minimal) ->               True
# MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52 (random_minimal) ->               True
# MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52 (random_minimal) ->               True
# MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52 (random_minimal) ->               True
# MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52 (random_minimal) ->               True
# MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52 (random_minimal) ->               True
# MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI (random_minimal) ->                       True
# MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI (random_minimal) ->                       True
# MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI (random_minimal) ->                       True
# MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI (random_minimal) ->                       True
# MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI (random_minimal) ->                       True
# MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q (random_minimal) ->                     True
# MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q (random_minimal) ->                     True
# MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q (random_minimal) ->                     True
# MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q (random_minimal) ->                     True
# MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q (random_minimal) ->                     True
# MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM (random_minimal) ->                  True
# MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV (random_minimal) ->                 True
# MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV (random_minimal) ->                 True
# MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV (random_minimal) ->                 True
# MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV (random_minimal) ->                 True
# MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV (random_minimal) ->                 True
# MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                   True
# MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                   True
# MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                   True
# MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                   True
# MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                   True
# MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ (random_minimal) ->                 True
# MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ (random_minimal) ->                 True
# MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ (random_minimal) ->                 True
# MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ (random_minimal) ->                 True
# MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ (random_minimal) ->                 True
# MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN (random_minimal) ->                      True
# MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP (random_minimal) ->                  True
# MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP (random_minimal) ->                  True
# MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP (random_minimal) ->                  True
# MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP (random_minimal) ->                  True
# MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP (random_minimal) ->                  True
# MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                True
# MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                True
# MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                True
# MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                True
# MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                True
# MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7 (random_minimal) ->             True
# MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7 (random_minimal) ->             True
# MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7 (random_minimal) ->             True
# MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7 (random_minimal) ->             True
# MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7 (random_minimal) ->             True
# MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C (random_minimal) ->                      True
# MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C (random_minimal) ->                      True
# MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C (random_minimal) ->                      True
# MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C (random_minimal) ->                      True
# MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C (random_minimal) ->                      True
# MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I (random_minimal) ->                True
# MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I (random_minimal) ->                True
# MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I (random_minimal) ->                True
# MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I (random_minimal) ->                True
# MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I (random_minimal) ->                True
# MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z (random_minimal) ->                 True
# MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z (random_minimal) ->                 True
# MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z (random_minimal) ->                 True
# MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z (random_minimal) ->                 True
# MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z (random_minimal) ->                 True
# MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                  True
# MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                  True
# MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                  True
# MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                  True
# MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48 (random_minimal) ->                  True
# MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->                   True
# MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->                   True
# MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->                   True
# MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->                   True
# MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B (random_minimal) ->                   True
# MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH (random_minimal) ->                       True
# MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH (random_minimal) ->                       True
# MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH (random_minimal) ->                       True
# MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH (random_minimal) ->                       True
# MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH (random_minimal) ->                       True
# MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->          True
# MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->          True
# MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->          True
# MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->          True
# MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->          True
# MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->          True
# MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->          True
# MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->          True
# MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->          True
# MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2 (random_minimal) ->          True
# MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                   True
# MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                   True
# MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                   True
# MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                   True
# MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH (random_minimal) ->                   True
# MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->                   True
# MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->                   True
# MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->                   True
# MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->                   True
# MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->                   True
# MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT (random_minimal) ->                        True
# MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT (random_minimal) ->                        True
# MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT (random_minimal) ->                        True
# MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT (random_minimal) ->                        True
# MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT (random_minimal) ->                        True
# MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN (random_minimal) ->               True
# MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN (random_minimal) ->               True
# MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN (random_minimal) ->               True
# MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN (random_minimal) ->               True
# MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN (random_minimal) ->               True
# MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                        True
# MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                        True
# MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                        True
# MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                        True
# MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                        True
# MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1 (random_minimal) ->                    True
# MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1 (random_minimal) ->                    True
# MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1 (random_minimal) ->                    True
# MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1 (random_minimal) ->                    True
# MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1 (random_minimal) ->                    True
# MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->             True
# MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->             True
# MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->             True
# MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->             True
# MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6 (random_minimal) ->             True
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR (random_minimal) ->           True
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR (random_minimal) ->           True
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR (random_minimal) ->           True
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR (random_minimal) ->           True
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR (random_minimal) ->           True
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                          True
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                          True
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                          True
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                          True
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU (random_minimal) ->                          True
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                       True
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                       True
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                       True
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                       True
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5 (random_minimal) ->                       True
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->                 True
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->                 True
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->                 True
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->                 True
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK (random_minimal) ->                 True
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                      True
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                      True
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                      True
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                      True
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH (random_minimal) ->                      True
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ (random_minimal) ->              True
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->            True
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->            True
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->            True
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->            True
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM (random_minimal) ->            True
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                    True
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                    True
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                    True
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                    True
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY (random_minimal) ->                    True
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5 (random_minimal) ->               True
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5 (random_minimal) ->               True
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5 (random_minimal) ->               True
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5 (random_minimal) ->               True
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5 (random_minimal) ->               True
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG (random_minimal) ->        True
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG (random_minimal) ->        True
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG (random_minimal) ->        True
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG (random_minimal) ->        True
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG (random_minimal) ->        True
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9 (random_minimal) ->                  True
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9 (random_minimal) ->                  True
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9 (random_minimal) ->                  True
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9 (random_minimal) ->                  True
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9 (random_minimal) ->                  True
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->                       True
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->                       True
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->                       True
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->                       True
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0 (random_minimal) ->                       True
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG (random_minimal) ->                       True
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG (random_minimal) ->                       True
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG (random_minimal) ->                       True
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG (random_minimal) ->                       True
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG (random_minimal) ->                       True
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J (random_minimal) ->                   True
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J (random_minimal) ->                   True
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J (random_minimal) ->                   True
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J (random_minimal) ->                   True
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J (random_minimal) ->                   True
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->           True
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->           True
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->           True
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->           True
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->           True
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->            True
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->            True
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->            True
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->            True
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74 (random_minimal) ->            True
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB (random_minimal) ->            True
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB (random_minimal) ->            True
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB (random_minimal) ->            True
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB (random_minimal) ->            True
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB (random_minimal) ->            True
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3 (random_minimal) ->                   True
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                  True
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                  True
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                  True
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                  True
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH (random_minimal) ->                  True
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS (random_minimal) ->        True
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS (random_minimal) ->        True
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS (random_minimal) ->        True
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS (random_minimal) ->        True
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS (random_minimal) ->        True
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                True
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                True
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                True
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                True
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70 (random_minimal) ->                True
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G (random_minimal) ->             True
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G (random_minimal) ->             True
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G (random_minimal) ->             True
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G (random_minimal) ->             True
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G (random_minimal) ->             True
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->                    True
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->                    True
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->                    True
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->                    True
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3 (random_minimal) ->                    True

# %%
# Flip the metrics if necessary
for i, row in dataAF.iterrows():
    if not row["chains_flipped"]:
        continue
    dataAF.at[i, "chainA_length"], dataAF.at[i, "chainB_length"] = row["chainB_length"], row["chainA_length"]
    dataAF.at[i, "chainA_intf_avg_plddt"], dataAF.at[i, "chainB_intf_avg_plddt"] = row["chainB_intf_avg_plddt"], row["chainA_intf_avg_plddt"]
    dataAF.at[i, "num_chainA_intf_res"], dataAF.at[i, "num_chainB_intf_res"] = row["num_chainB_intf_res"], row["num_chainA_intf_res"]
    if row["model_id"] == "ranked_0":
        print(f"Modified {row['prediction_name']}")
# Out:
# Modified MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30
# Modified MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS
# Modified MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0
# Modified MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6
# Modified MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW
# Modified MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7
# Modified MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY
# Modified MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P
# Modified MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV
# Modified MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9
# Modified MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU
# Modified MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO
# Modified MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G
# Modified MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9
# Modified MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM
# Modified MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG
# Modified MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW
# Modified MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ
# Modified MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN
# Modified MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3
# Modified MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q
# Modified MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE
# Modified MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72
# Modified MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q
# Modified MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74
# Modified MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4
# Modified MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU
# Modified MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH
# Modified MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH
# Modified MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM
# Modified MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3
# Modified MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B
# Modified MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2
# Modified MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42
# Modified MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7
# Modified MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW
# Modified MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH
# Modified MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN
# Modified MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY
# Modified MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY
# Modified MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1
# Modified MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K
# Modified MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25
# Modified MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ
# Modified MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ
# Modified MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6
# Modified MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q
# Modified MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV
# Modified MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD
# Modified MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J
# Modified MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6
# Modified MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S
# Modified MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8
# Modified MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO
# Modified MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3
# Modified MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC
# Modified MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW
# Modified MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8
# Modified MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA
# Modified MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41
# Modified MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY
# Modified MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48
# Modified MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG
# Modified MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5
# Modified MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1
# Modified MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD
# Modified MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD
# Modified MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ
# Modified MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH
# Modified MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S
# Modified MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U
# Modified MLIG_LIR_Apic_2_4EOY.DLIG_Sin3_1_1PD7
# Modified MLIG_LIR_Gen_1_2L8J.DDOC_PP1_MyPhoNE_1_1S70
# Modified MLIG_LIR_LC3C_4_3VVW.DDOC_MIT_MIM_1_2JQ9
# Modified MLIG_LIR_Nem_3_5AZG.DLIG_ULM_U2AF65_1_1O0P
# Modified MLIG_LRP6_Inhibitor_1_3SOQ.DTRG_NES_CRM1_1_3GB8
# Modified MLIG_LSD1_SNAG_1_2Y48.DLIG_EF_ALG2_ABM_1_2ZNE
# Modified MLIG_LYPXL_L_2_2R02.DLIG_PTAP_UEV_1_1M4P
# Modified MLIG_LYPXL_S_1_2R03.DLIG_FXI_DFP_1_5EOD
# Modified MLIG_LYPXL_SIV_4_2XS1.DLIG_APCC_ABBA_1_4BH6
# Modified MLIG_MAD2_1GO4.DLIG_LYPXL_L_2_2R02
# Modified MLIG_MLH1_MIPbox_1_4FMO.DDEG_SPOP_SBC_1_3HQM
# Modified MLIG_MYND_2_2ODD.DMOD_SUMO_for_1_1KPS
# Modified MLIG_NBox_RRM_1_2KXH.DLIG_PAM2_1_1JGN
# Modified MLIG_NRBOX_1GWQ.DLIG_AP2alpha_2_1KYU
# Modified MLIG_NRP_CendR_1_2ORZ.DLIG_KLC1_Yacidic_2_6FUZ
# Modified MLIG_OCRL_FandH_1_3QIS.DDOC_MAPK_GRA24_9_5ETA
# Modified MLIG_PALB2_WD40_1_3EU7.DLIG_Actin_RPEL_3_2V52
# Modified MLIG_PAM2_1_1JGN.DMOD_CDK_SPxK_1_2CCI
# Modified MLIG_PAM2_2_2X04.DDOC_MAPK_MEF2A_6_4H3Q
# Modified MLIG_PCNA_APIM_2_5MLW.DDEG_SPOP_SBC_1_3HQM
# Modified MLIG_PCNA_PIPBox_1_1AXC.DLIG_PTB_Apo_2_1NTV
# Modified MLIG_PCNA_TLS_4_2ZVL.DDOC_ANK_TNKS_1_3TWU
# Modified MLIG_PCNA_yPIPBox_3_1SXJ.DLIG_CORNRBOX_1KKQ
# Modified MLIG_PDZ_Class_1_1D5G.DLIG_PAM2_1_1JGN
# Modified MLIG_PDZ_Class_2_1MFG.DDOC_AGCK_PIF_3_1ATP
# Modified MLIG_PDZ_Class_3_1B8Q.DDOC_MAPK_HePTP_8_2GPH
# Modified MLIG_PDZ_Wminus1_1_1ZUB.DDEG_Kelch_Keap1_2_3WN7
# Modified MLIG_Pex14_1_2W84.DLIG_PROFILIN_1_2V8C
# Modified MLIG_Pex14_3_4BXU.DLIG_Clathr_ClatBox_1_1C9I
# Modified MLIG_PROFILIN_1_2V8C.DDOC_PP2B_PxIxI_1_4F0Z
# Modified MLIG_PTAP_UEV_1_1M4P.DLIG_LSD1_SNAG_1_2Y48
# Modified MLIG_PTB_Apo_2_1NTV.DDOC_MAPK_JIP1_4_4H3B
# Modified MLIG_Rb_LxCxE_1_1GH6.DLIG_EVH1_1_1EVH
# Modified MLIG_Rb_pABgroove_1_1N4M.DLIG_WD40_WDR5_WIN_1_3UVK
# Modified MLIG_REV1ctd_RIR_1_2LSI.DLIG_ActinCP_TwfCPI_2_7DS2
# Modified MLIG_RPA_C_Vert_1DPU.DLIG_NBox_RRM_1_2KXH
# Modified MLIG_SH3_2_1CKA.DTRG_NLS_Bipartite_1_1PJM
# Modified MLIG_SH3_3_2GBQ.DLIG_IBAR_NPY_1_2YKT
# Modified MLIG_SH3_CIN85_PxpxPR_1_2BZ8.DLIG_PAM2_1_1JGN
# Modified MLIG_SPRY_1_2JK9.DLIG_BIR_III_3_1JD5
# Modified MLIG_SUFU_1_4KMD.DLIG_ActinCP_CPI_1_3AA1
# Modified MLIG_SUMO_SIM_anti_2_2KQS.DLIG_APCC_ABBA_1_4BH6
# Modified MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR
# Modified MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU
# Modified MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5
# Modified MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK
# Modified MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH
# Modified MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ
# Modified MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM
# Modified MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY
# Modified MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5
# Modified MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG
# Modified MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9
# Modified MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0
# Modified MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG
# Modified MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J
# Modified MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70
# Modified MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74
# Modified MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB
# Modified MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3
# Modified MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH
# Modified MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS
# Modified MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70
# Modified MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G
# Modified MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3

# %% [markdown]
# ### 4 Converting AF3 structure files (.cif) to pdb files
# The following section loads the model.cif files in the dataAF table and exports them to the destination path. Already existing structures are skipped depending on the setting _export_skip_existing_structures_. The chains are flipped as described in the sections above

# %%
# Converting .cif to .pdb files 
try:
    dataAF
except NameError:
    raise Exception("Please first run the cells to get the dataAF frame")

# If this property is not set, pymol will ignore the alter commands on the ID when exporting
pymol.cmd.set("pdb_retain_ids", False)
# No interest to mess up with segments instead of chain IDs
pymol.cmd.set("ignore_pdb_segi", True)

if not export_destination.exists() or not export_destination.is_dir():
    raise Exception("Your destination path does not exist")

for index, row in dataAF.iterrows():
    prediction_file = af3_runs_folder / Path(row["model_path"])
    chains_flipped = row["chains_flipped"]
    if not prediction_file.exists():
        print(f"For {row['prediction_name']} does not exist at expected location ({prediction_file.resolve()})")
        continue

    structure_folder_dest: Path = (export_destination / ("DDI" if "ddi" in str(row['benchmark_set']).lower() else "DMI") / row["benchmark_set"] / row["prediction_name"])
    structure_folder_dest.mkdir(parents=True, exist_ok=True)

    if (structure_file_dest := structure_folder_dest / (str(row["model_id"]) + ".pdb")).exists() and export_skip_existing_structures:
        print(f"{row['prediction_name']}/{structure_file_dest.name} already processed. Skip")
        continue
    else:
        print(f"{row['prediction_name']}/{structure_file_dest.name} ->", "Flipping chains" if chains_flipped else "")

    pymol.cmd.load(prediction_file, prediction_file.stem)

    if chains_flipped: # Reorder chains
        pymol.cmd.alter(selection="chain A", expression="chain = 'C'")
        pymol.cmd.alter(selection="chain B", expression="chain = 'A'")
        pymol.cmd.alter(selection="chain C", expression="chain = 'B'")
        pymol.cmd.alter(selection="segi A", expression="segi = 'C'")
        pymol.cmd.alter(selection="segi B", expression="segi = 'A'")
        pymol.cmd.alter(selection="segi C", expression="segi = 'B'")
        pymol.cmd.sort()
        pymol.cmd.alter(selection="chain A", expression=f"ID = (int(ID) - {pymol.cmd.count_atoms('chain B')})")
        pymol.cmd.alter(selection="chain B", expression=f"ID = (int(ID) + {pymol.cmd.count_atoms('chain A')})")
        pymol.cmd.sort()

    pymol.cmd.save(structure_file_dest)
    for o in pymol.cmd.get_object_list():
        pymol.cmd.delete(o)
# Out:
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_COP1_1_5IGO.DDOC_USP7_MATH_1_3MQS/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_1_2FLU.DLIG_DLG_GKlike_1_3WP0/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_Kelch_Keap1_2_3WN7.DDOC_USP7_MATH_2_1YY6/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_MDM2_SWIB_1_1YCR.DLIG_PCNA_APIM_2_5MLW/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_COI1_1_3OGL.DLIG_CaM_IQ_9_2IX7/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_FBXO31_1_5VZU.DLIG_TRAF2_2_1CZY/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SCF_TIR1_1_2P1Q.DLIG_ULM_U2AF65_1_1O0P/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SIAH_1_2A25.DLIG_CAP-Gly_2_3RDV/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDEG_SPOP_SBC_1_3HQM.DDOC_MIT_MIM_1_2JQ9/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_AGCK_PIF_3_1ATP.DDEG_Kelch_Keap1_1_2FLU/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_ANK_TNKS_1_3TWU.DLIG_CAP-Gly_1_2PZO/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CDC14_PxL_1_6G84.DDOC_PP1_SILK_1_2O8G/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_CYCLIN_RxL_1_1H25.DLIG_SPRY_1_2JK9/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_GSK3_Axin_1_1O9U.DDEG_SPOP_SBC_1_3HQM/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_DCC_7_2B9J.DLIG_ANK_PxLPxL_1_3UXG/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_GRA24_9_5ETA.DLIG_PCNA_APIM_2_5MLW/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_HePTP_8_2GPH.DLIG_PCNA_yPIPBox_3_1SXJ/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_JIP1_4_4H3B.DLIG_PAM2_1_1JGN/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_MEF2A_6_4H3Q.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_NFAT4_5_2XS0.DLIG_PDZ_Class_3_1B8Q/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MAPK_RevD_3_3TEI.DLIG_EF_ALG2_ABM_1_2ZNE/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_MIT_MIM_1_2JQ9.DLIG_HOMEOBOX_1B72/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_MyPhoNE_1_1S70.DLIG_PDZ_Class_3_1B8Q/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_RVXF_1_3N5U.DLIG_14-3-3_ChREBP_3_5F74/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP1_SILK_1_2O8G.DLIG_WW_1_1EG4/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_PP2B_PxIxI_1_4F0Z.DDEG_Kelch_Keap1_1_2FLU/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_SPAK_OSR1_1_2V3S.DLIG_NBox_RRM_1_2KXH/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_1_3MQS.DLIG_UFM1_UFIM_1_5HKH/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_MATH_2_1YY6.DTRG_NLS_Bipartite_1_1PJM/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MDOC_USP7_UBL2_3_4YOC.DTRG_ER_FFAT_1_2RR3/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_14-3-3_ChREBP_3_5F74.DDOC_MAPK_JIP1_4_4H3B/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_RPEL_3_2V52.DLIG_ActinCP_TwfCPI_2_7DS2/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_1_2A41.DLIG_GBD_Chelix_1_2K42/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Actin_WH2_2_2D1K.DLIG_PALB2_WD40_1_3EU7/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ActinCP_CPI_1_3AA1.DLIG_CID_NIM_1_2MOW/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ANK_PxLPxL_1_3UXG.DDOC_MAPK_HePTP_8_2GPH/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_1_1KY7.DLIG_PAM2_1_1JGN/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_AP2alpha_2_1KYU.DLIG_TRAF2_2_1CZY/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_APCC_ABBA_1_4BH6.DLIG_LIR_Apic_2_4EOY/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ARL_BART_1_4ZI2.DLIG_LYPXL_SIV_4_2XS1/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BH_BH3_1_2ROC.DLIG_Actin_WH2_2_2D1K/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_2_1NW9.DDEG_SIAH_1_2A25/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_BIR_III_3_1JD5.DLIG_LRP6_Inhibitor_1_3SOQ/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CaM_IQ_9_2IX7.DLIG_CORNRBOX_1KKQ/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_1_2PZO.DLIG_Rb_LxCxE_1_1GH6/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CAP-Gly_2_3RDV.DLIG_PDZ_Class_3_1B8Q/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CID_NIM_1_2MOW.DLIG_EVH1_2_1DDV/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_1_1C9I.DLIG_SUFU_1_4KMD/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Clathr_ClatBox_2_1UTC.DLIG_LIR_Gen_1_2L8J/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CNOT1_NIM_1_4CQO.DLIG_Rb_LxCxE_1_1GH6/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CORNRBOX_1KKQ.DDOC_SPAK_OSR1_1_2V3S/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_CSL_BTD_1_4J2X.DTRG_NES_CRM1_1_3GB8/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_deltaCOP1_diTrp_1_5FJX.DLIG_CAP-Gly_1_2PZO/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_DLG_GKlike_1_3WP0.DTRG_ER_FFAT_1_2RR3/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Dynein_DLC8_1_1F95.DDOC_USP7_UBL2_3_4YOC/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EF_ALG2_ABM_1_2ZNE.DLIG_CID_NIM_1_2MOW/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH1_1_2CE8.DLIG_SH3_CIN85_PxpxPR_1_2BZ8/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EH_1_1FF1.DDOC_MAPK_GRA24_9_5ETA/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_1_1EVH.DLIG_Actin_WH2_1_2A41/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_2_1DDV.DLIG_LIR_Apic_2_4EOY/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_EVH1_3_1MKE.DLIG_LSD1_SNAG_1_2Y48/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FAT_LD_1_3GM1.DLIG_LIR_Nem_3_5AZG/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_FXI_DFP_1_5EOD.DLIG_BIR_III_3_1JD5/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GBD_Chelix_1_2K42.DLIG_FAT_LD_1_3GM1/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GLEBS_BUB3_1_2I3S.DLIG_FXI_DFP_1_5EOD/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_GYF_1L2Z.DLIG_SUFU_1_4KMD/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_HOMEOBOX_1B72.DLIG_Vh1_VBS_1_1SYQ/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_IBAR_NPY_1_2YKT.DLIG_UFM1_UFIM_1_5HKH/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_KLC1_WD_1_3ZFW.DLIG_GLEBS_BUB3_1_2I3S/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_KLC1_Yacidic_2_6FUZ.DDOC_GSK3_Axin_1_1O9U/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# ...
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_SUMO_SIM_par_1_2ASQ.DTRG_DiLeu_BaLyEn_6_2JKR/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TPR_1ELR.DDOC_ANK_TNKS_1_3TWU/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_1_1CA9.DLIG_BIR_III_3_1JD5/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRAF2_2_1CZY.DLIG_WD40_WDR5_WIN_1_3UVK/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_TRFH_1_3BQO.DLIG_UFM1_UFIM_1_5HKH/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_UFM1_UFIM_1_5HKH.DLIG_KLC1_Yacidic_2_6FUZ/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_ULM_U2AF65_1_1O0P.DTRG_NLS_Bipartite_1_1PJM/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_Vh1_VBS_1_1SYQ.DLIG_LIR_Apic_2_4EOY/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_VDV_1_4CY2.DLIG_BIR_III_3_1JD5/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_1_3UVK.DTRG_LysEnd_GGAAcLL_1_1JWG/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WD40_WDR5_WIN_2_4CY3.DLIG_SPRY_1_2JK9/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MLIG_WW_1_1EG4.DLIG_DLG_GKlike_1_3WP0/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_PKB_1_1O6K.DLIG_PDZ_Class_2_1MFG/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MMOD_SUMO_for_1_1KPS.DDOC_MAPK_DCC_7_2B9J/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_AP2beta_CARGO_1_2G30.DDOC_PP1_MyPhoNE_1_1S70/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaEn_1_4NEE.DLIG_14-3-3_ChREBP_3_5F74/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_DiLeu_BaLyEn_6_2JKR.DLIG_PDZ_Wminus1_1_1ZUB/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ENDOCYTIC_2_1BXX.DTRG_ER_FFAT_1_2RR3/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_ER_FFAT_1_2RR3.DDOC_MAPK_HePTP_8_2GPH/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_LysEnd_GGAAcLL_1_1JWG.DLIG_SUMO_SIM_anti_2_2KQS/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NES_CRM1_1_3GB8.DDOC_PP1_MyPhoNE_1_1S70/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_NLS_Bipartite_1_1PJM.DLIG_PDZ_Class_1_1D5G/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_0.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_1.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_2.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_3.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore
# MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3/ranked_4.pdb -> Flipping chains
#  Warning: 'model' is a reserved keyword, appending underscore

# %%
# Helper cell: If pymol crashes, use this cell to reset pymol
for o in pymol.cmd.get_object_list():
        pymol.cmd.delete(o)

# %% [markdown]
# ### 5 Reorder of columns

# %%
dataAF.columns
# Out:
# Index(['model_preset', 'benchmark_set', 'prediction_name', 'model_id',
#        'ranking_score', 'chainA_length', 'chainB_length',
#        'fraction_disordered', 'has_clash', 'iptm', 'ptm',
#        'chainA_intf_avg_plddt', 'chainB_intf_avg_plddt', 'intf_avg_plddt',
#        'num_chainA_intf_res', 'num_chainB_intf_res', 'num_res_res_contact',
#        'num_atom_atom_contact', 'iPAE', 'pDockQ', 'model_path',
#        'chains_flipped'],
#       dtype='object')

# %%
c = list(dataAF.columns)
c.remove("model_path")
c.remove("chains_flipped")
c.append("chains_flipped")
c.append("model_path")

if "num_mutations" in c:
    c.remove("num_mutations")
    c.insert(4,"num_mutations")

dataAF = dataAF[c].copy()
dataAF
# Out:
#     model_preset   benchmark_set  \
# 0     alphafold3  random_minimal
# 1     alphafold3  random_minimal
# 2     alphafold3  random_minimal
# 3     alphafold3  random_minimal
# 4     alphafold3  random_minimal
# ..           ...             ...
# 675   alphafold3  random_minimal
# 676   alphafold3  random_minimal
# 677   alphafold3  random_minimal
# 678   alphafold3  random_minimal
# 679   alphafold3  random_minimal
#
#                                        prediction_name  model_id  \
# 0    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_0
# 1    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_1
# 2    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_2
# 3    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_3
# 4    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_4
# ..                                                 ...       ...
# 675           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_0
# 676           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_1
# 677           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_2
# 678           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_3
# 679           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_4
#
#      ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 0             0.65            237              5                 0.02
# 1             0.65            237              5                 0.02
# 2             0.65            237              5                 0.02
# 3             0.64            237              5                 0.02
# 4             0.62            237              5                 0.02
# ..             ...            ...            ...                  ...
# 675           0.93            312              4                 0.02
# 676           0.92            312              4                 0.01
# 677           0.92            312              4                 0.02
# 678           0.91            312              4                 0.01
# 679           0.84            312              4                 0.01
#
#      has_clash  iptm  ...  chainB_intf_avg_plddt  intf_avg_plddt  \
# 0          0.0  0.57  ...                  49.49           74.38
# 1          0.0  0.56  ...                  48.41           74.62
# 2          0.0  0.56  ...                  49.80           75.97
# 3          0.0  0.56  ...                  50.50           75.69
# 4          0.0  0.53  ...                  48.32           73.87
# ..         ...   ...  ...                    ...             ...
# 675        0.0  0.91  ...                  84.04           94.45
# 676        0.0  0.90  ...                  83.70           95.04
# 677        0.0  0.90  ...                  83.24           94.40
# 678        0.0  0.90  ...                  83.07           94.86
# 679        0.0  0.81  ...                  73.17           92.18
#
#      num_chainA_intf_res  num_chainB_intf_res  num_res_res_contact  \
# 0                     13                    5                   20
# 1                     13                    5                   21
# 2                     14                    5                   21
# 3                     15                    5                   22
# 4                     13                    5                   21
# ..                   ...                  ...                  ...
# 675                   17                    4                   26
# 676                   17                    4                   26
# 677                   18                    4                   28
# 678                   17                    4                   26
# 679                   19                    4                   26
#
#      num_atom_atom_contact   iPAE  pDockQ  chains_flipped  \
# 0                      178  10.60    0.07            True
# 1                      224  11.00    0.09            True
# 2                      196  10.80    0.08            True
# 3                      199  11.80    0.08            True
# 4                      206  11.90    0.08            True
# ..                     ...    ...     ...             ...
# 675                    239   3.50    0.31            True
# 676                    233   3.60    0.31            True
# 677                    246   3.65    0.30            True
# 678                    232   3.60    0.30            True
# 679                    204   4.90    0.17            True
#
#                                             model_path
# 0    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 1    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 2    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 3    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 4    AlphaFold_benchmark_DMI/random_minimal/distrac...
# ..                                                 ...
# 675  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 676  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 677  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 678  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 679  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
#
# [680 rows x 22 columns]

# %% [markdown]
# ### 6 Save metric file

# %%
# Sorting the file
dataAF["_benchmark_id"] = dataAF["benchmark_set"].replace({"known_minimal": "1", "random_minimal": "2", "mutations": "3","known_extension": "4", "known_ddi": "5", "random_ddi": "6"}).astype(int)
dataAF.sort_values(["_benchmark_id", "prediction_name", "model_id"], inplace=True)
dataAF.drop(columns=["_benchmark_id"], inplace=True)
dataAF.reset_index(drop=True, inplace=True)

dataAF
# Out:
#     model_preset   benchmark_set  \
# 0     alphafold3  random_minimal
# 1     alphafold3  random_minimal
# 2     alphafold3  random_minimal
# 3     alphafold3  random_minimal
# 4     alphafold3  random_minimal
# ..           ...             ...
# 675   alphafold3  random_minimal
# 676   alphafold3  random_minimal
# 677   alphafold3  random_minimal
# 678   alphafold3  random_minimal
# 679   alphafold3  random_minimal
#
#                                        prediction_name  model_id  \
# 0    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_0
# 1    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_1
# 2    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_2
# 3    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_3
# 4    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_4
# ..                                                 ...       ...
# 675           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_0
# 676           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_1
# 677           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_2
# 678           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_3
# 679           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_4
#
#      ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 0             0.65            237              5                 0.02
# 1             0.65            237              5                 0.02
# 2             0.65            237              5                 0.02
# 3             0.64            237              5                 0.02
# 4             0.62            237              5                 0.02
# ..             ...            ...            ...                  ...
# 675           0.93            312              4                 0.02
# 676           0.92            312              4                 0.01
# 677           0.92            312              4                 0.02
# 678           0.91            312              4                 0.01
# 679           0.84            312              4                 0.01
#
#      has_clash  iptm  ...  chainB_intf_avg_plddt  intf_avg_plddt  \
# 0          0.0  0.57  ...                  49.49           74.38
# 1          0.0  0.56  ...                  48.41           74.62
# 2          0.0  0.56  ...                  49.80           75.97
# 3          0.0  0.56  ...                  50.50           75.69
# 4          0.0  0.53  ...                  48.32           73.87
# ..         ...   ...  ...                    ...             ...
# 675        0.0  0.91  ...                  84.04           94.45
# 676        0.0  0.90  ...                  83.70           95.04
# 677        0.0  0.90  ...                  83.24           94.40
# 678        0.0  0.90  ...                  83.07           94.86
# 679        0.0  0.81  ...                  73.17           92.18
#
#      num_chainA_intf_res  num_chainB_intf_res  num_res_res_contact  \
# 0                     13                    5                   20
# 1                     13                    5                   21
# 2                     14                    5                   21
# 3                     15                    5                   22
# 4                     13                    5                   21
# ..                   ...                  ...                  ...
# 675                   17                    4                   26
# 676                   17                    4                   26
# 677                   18                    4                   28
# 678                   17                    4                   26
# 679                   19                    4                   26
#
#      num_atom_atom_contact   iPAE  pDockQ  chains_flipped  \
# 0                      178  10.60    0.07            True
# 1                      224  11.00    0.09            True
# 2                      196  10.80    0.08            True
# 3                      199  11.80    0.08            True
# 4                      206  11.90    0.08            True
# ..                     ...    ...     ...             ...
# 675                    239   3.50    0.31            True
# 676                    233   3.60    0.31            True
# 677                    246   3.65    0.30            True
# 678                    232   3.60    0.30            True
# 679                    204   4.90    0.17            True
#
#                                             model_path
# 0    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 1    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 2    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 3    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 4    AlphaFold_benchmark_DMI/random_minimal/distrac...
# ..                                                 ...
# 675  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 676  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 677  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 678  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 679  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
#
# [680 rows x 22 columns]

# %%
# Export metrics files
if not export_destination.exists() or not export_destination.is_dir():
    raise Exception("Your destination path is not valid")

dataAF.to_csv(export_destination / "AF3_output_only_known_minimal.tsv", sep="\t", index=False)
dataAF.to_excel(export_destination / "AF3_output_only_known_minimal.xlsx", sheet_name="AF3", index=False)

# %% [markdown]
# Need to load the metric file to recalculate some columns? Remove the comments on the following cell

# %%
# Load metrics file
dataAF = pd.read_csv(export_destination / "AF3_output_only_known_minimal.tsv", sep="\t")
dataAF
# Out:
#     model_preset   benchmark_set  \
# 0     alphafold3  random_minimal
# 1     alphafold3  random_minimal
# 2     alphafold3  random_minimal
# 3     alphafold3  random_minimal
# 4     alphafold3  random_minimal
# ..           ...             ...
# 675   alphafold3  random_minimal
# 676   alphafold3  random_minimal
# 677   alphafold3  random_minimal
# 678   alphafold3  random_minimal
# 679   alphafold3  random_minimal
#
#                                        prediction_name  model_id  \
# 0    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_0
# 1    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_1
# 2    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_2
# 3    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_3
# 4    MDEG_APCC_KENBOX_2_4GGD.DTRG_AP2beta_CARGO_1_2G30  ranked_4
# ..                                                 ...       ...
# 675           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_0
# 676           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_1
# 677           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_2
# 678           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_3
# 679           MTRG_PTS1_2C0L.DLIG_WD40_WDR5_WIN_2_4CY3  ranked_4
#
#      ranking_score  chainA_length  chainB_length  fraction_disordered  \
# 0             0.65            237              5                 0.02
# 1             0.65            237              5                 0.02
# 2             0.65            237              5                 0.02
# 3             0.64            237              5                 0.02
# 4             0.62            237              5                 0.02
# ..             ...            ...            ...                  ...
# 675           0.93            312              4                 0.02
# 676           0.92            312              4                 0.01
# 677           0.92            312              4                 0.02
# 678           0.91            312              4                 0.01
# 679           0.84            312              4                 0.01
#
#      has_clash  iptm  ...  chainB_intf_avg_plddt  intf_avg_plddt  \
# 0          0.0  0.57  ...                  49.49           74.38
# 1          0.0  0.56  ...                  48.41           74.62
# 2          0.0  0.56  ...                  49.80           75.97
# 3          0.0  0.56  ...                  50.50           75.69
# 4          0.0  0.53  ...                  48.32           73.87
# ..         ...   ...  ...                    ...             ...
# 675        0.0  0.91  ...                  84.04           94.45
# 676        0.0  0.90  ...                  83.70           95.04
# 677        0.0  0.90  ...                  83.24           94.40
# 678        0.0  0.90  ...                  83.07           94.86
# 679        0.0  0.81  ...                  73.17           92.18
#
#      num_chainA_intf_res  num_chainB_intf_res  num_res_res_contact  \
# 0                     13                    5                   20
# 1                     13                    5                   21
# 2                     14                    5                   21
# 3                     15                    5                   22
# 4                     13                    5                   21
# ..                   ...                  ...                  ...
# 675                   17                    4                   26
# 676                   17                    4                   26
# 677                   18                    4                   28
# 678                   17                    4                   26
# 679                   19                    4                   26
#
#      num_atom_atom_contact   iPAE  pDockQ  chains_flipped  \
# 0                      178  10.60    0.07            True
# 1                      224  11.00    0.09            True
# 2                      196  10.80    0.08            True
# 3                      199  11.80    0.08            True
# 4                      206  11.90    0.08            True
# ..                     ...    ...     ...             ...
# 675                    239   3.50    0.31            True
# 676                    233   3.60    0.31            True
# 677                    246   3.65    0.30            True
# 678                    232   3.60    0.30            True
# 679                    204   4.90    0.17            True
#
#                                             model_path
# 0    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 1    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 2    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 3    AlphaFold_benchmark_DMI/random_minimal/distrac...
# 4    AlphaFold_benchmark_DMI/random_minimal/distrac...
# ..                                                 ...
# 675  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 676  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 677  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 678  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
# 679  AlphaFold_benchmark_DMI/random_minimal/gloomy_...
#
# [680 rows x 22 columns]
